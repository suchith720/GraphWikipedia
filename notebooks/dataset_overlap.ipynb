# %%
import os
import json

# %%
project = 'enwiki'
dump_date = "20220420"
dataset_home = '/home/scai/phd/aiz218323/scratch/XML/wikipedia-data-science/'

data_dir = f"{dataset_home}/data"
partition_dir = f"{dataset_home}/partition"

# %% [markdown]
# ## helper_code

# %%
def read_data(filename):
    with open(filename, 'r') as fin:
        data = json.loads(fin.read())
    return data

# %%
def is_node(title):
    return title in title_to_id

def is_redirect(title):
    return title in redirects

# %%
def separate_titles(same_titles, diff_titles, path):
    with open(path, encoding='latin-1') as fin:
        for line in fin.readlines():
            page = json.loads(line)
            title = page['title'].replace('_', ' ')
            title = title[0].lower() + title[1:]
            if title:
                if title in title_to_id:
                    same_titles.append(title)
                else:
                    diff_titles.append(title)

# %% [markdown]
# ## id-to-title

# %%
id_title_file = f'{partition_dir}/enwiki-20220420_id-to-title.ndjson'

id_to_title = read_data(id_title_file)

# %%
for i, (page_id, title) in enumerate(id_to_title.items()):
    print(f'{i+1}: {page_id} {title}')
    if i > 4:
        break
# Out:
# 1: 12 anarchism
# 2: 25 autism
# 3: 39 albedo
# 4: 290 a
# 5: 303 alabama
# 6: 305 achilles

# %%
title_to_id = {title:page_id for page_id, title in id_to_title.items()}

# %%
for i, (title, page_id) in enumerate(title_to_id.items()):
    print(f'{i+1}: {title} {page_id}')
    if i > 4:
        break
# Out:
# 1: anarchism 12
# 2: autism 25
# 3: albedo 39
# 4: a 290
# 5: alabama 303
# 6: achilles 305

# %%
len(id_to_title)
# Out:
# 6472830

# %% [markdown]
# ## Redirect page

# %%
redirects_file = f'{partition_dir}/enwiki-20220420_redirects.ndjson'
redirects = read_data(redirects_file)

# %%
for i, (title1, title2) in enumerate(redirects.items()):
    print(f'{i+1}: {title1} - {title2}')
    if i > 4:
        break
# Out:
# 1: accessibleComputing - computer accessibility
# 2: afghanistanHistory - history of Afghanistan
# 3: afghanistanGeography - geography of Afghanistan
# 4: afghanistanPeople - demographics of Afghanistan
# 5: afghanistanCommunications - communications in Afghanistan
# 6: afghanistanTransportations - transport in Afghanistan

# %% [markdown]
# ## WikiSeeAlsoTitles-350K

# %%
data_path = f"{data_dir}/WikiSeeAlsoTItles-350K/"

train_path = f"{data_path}/trn.json"
test_path = f"{data_path}/tst.json"

# %%
same_titles, diff_titles = [], []

separate_titles(same_titles, diff_titles, train_path)
separate_titles(same_titles, diff_titles, test_path)

# %%
len(same_titles), len(diff_titles), len(same_titles)+len(diff_titles)
# Out:
# (692785, 99124, 791909)

# %%
total_pages = len(same_titles)+len(diff_titles)
print(f"Number of similar pages : {len(same_titles)} ({100.*len(same_titles)/total_pages:.4f}%)")
print(f"Number of different pages : {len(diff_titles)} ({100.*len(diff_titles)/total_pages:.4f}%)")
# Out:
# Number of similar pages : 692785 (87.4829%)
# Number of different pages : 99124 (12.5171%)

# %%
diff_titles
# Out:
# ['asociaciÃ³n Alumni',
#  'andrÃ© Gide',
#  'royal Antigua and Barbuda Defence Force',
#  'list of Governors of Alabama',
#  'casa BatllÃ³',
#  'park GÃ¼ell',
#  'casa MilÃ',
#  'atanasoffâ\x80\x93Berry computer',
#  'anadyr River',
#  'abbotsford House',
#  'approximant consonant',
#  'ã\x86lle of Sussex',
#  'aramaic language',
#  'albrecht DÃ¼rer',
#  'conservation and restoration of cultural heritage',
#  'andrÃ© the Giant',
#  'ã\x81ed mac CinÃ¡eda',
#  'aberration of light',
#  'alcobaÃ§a, Portugal',
#  'amiga 500 Plus',
#  'blindness in literature',
#  'books of the Bible',
#  'british and Irish Lions',
#  'borsukâ\x80\x93Ulam theorem',
#  'beerâ\x80\x93Lambert law',
#  'braâ\x80\x93ket notation',
#  'batman & Robin (film)',
#  'brasÃ\xadlia',
#  'murmured voice',
#  'boer',
#  'bathyscaphe Trieste',
#  'bjÃ¸rn Lomborg',
#  'canadaâ\x80\x93United States relations',
#  'republic of Croatia Armed Forces',
#  'wu Xing',
#  'czesÅ\x82aw MiÅ\x82osz',
#  'cleveland Indians',
#  'rod (optics)',
#  'customer-relationship management',
#  'comet Haleâ\x80\x93Bopp',
#  'cuitlÃ¡huac',
#  'cuauhtÃ©moc',
#  'cauchyâ\x80\x93Riemann equations',
#  'coptic Orthodox Church of Alexandria',
#  'deutsches Institut fÃ¼r Normung',
#  'list of decades',
#  'diogo CÃ£o',
#  'examples of differential equations',
#  'ducati Motor Holding S.p.A.',
#  'debian GNU/Hurd',
#  'domnall mac AilpÃ\xadn',
#  'dÃ©jÃ\xa0 vu',
#  'helsingÃ¸r',
#  'encyclopÃ¦dia Britannica',
#  'ã\x89douard Manet',
#  'list of recently extinct bird species',
#  'ã\x89variste Galois',
#  'elblÄ\x85g',
#  "european People's Party group",
#  'ã\x86thelberht of Kent',
#  'ã\x89lisabeth VigÃ©e Le Brun',
#  'ã\x86thelred the Unready',
#  'emperor ShÅ\x8dmu',
#  'ã\x89mile Baudot',
#  'enhanced Data Rates for GSM Evolution',
#  'edward VI of England',
#  'eastern Orthodox Church organization',
#  'evliya Ã\x87elebi',
#  'emperor YÅ\x8dmei',
#  'empress KÅ\x8dgyoku',
#  'emperor KÅ\x8dtoku',
#  'emperor KÅ\x8dbun',
#  'empress JitÅ\x8d',
#  'emperor SukÅ\x8d',
#  "emperor Go-En'yÅ«",
#  'emperor KÅ\x8dshÅ\x8d',
#  'emperor KÅ\x8dan',
#  'emperor KÅ\x8drei',
#  'emperor KÅ\x8dgen',
#  'emperor KeikÅ\x8d',
#  'emperor ChÅ«ai',
#  'emperor Å\x8cjin',
#  'emperor RichÅ«',
#  'emperor IngyÅ\x8d',
#  'emperor AnkÅ\x8d',
#  'emperor KenzÅ\x8d',
#  'emperor NinmyÅ\x8d',
#  'emperor KÅ\x8dkÅ\x8d',
#  'friedrich WÃ¶hler',
#  'melbourne Grand Prix Circuit',
#  "franÃ§ois d'Aguilon",
#  'fÃ©lix Guattari',
#  'falstaff',
#  'fatherland',
#  'frÃ©dÃ©ric Bazille',
#  'fianna FÃ¡il',
#  'functional theories of grammar',
#  'fricative consonant',
#  'foixâ\x80\x93Alajouanine syndrome',
#  'gÃ¶ta Canal',
#  'gil Ã\x81lvarez Carrillo de Albornoz',
#  'gallâ\x80\x93Peters projection',
#  'military of Hong Kong',
#  'hermann GÃ¶ring',
#  'hydrostatic shock (firearms)',
#  'henry VIII of England',
#  'heckler & Koch MP5',
#  'huygensâ\x80\x93Fresnel principle',
#  'harold Eugene Edgerton',
#  'list of Indian massacres',
#  'indian Institute of Technology Kanpur',
#  'interwiki links',
#  'intel 80386',
#  'interpreted language',
#  'intel 80486',
#  'irish wolfhound',
#  'ä°skender kebap',
#  'indian numerals',
#  'list of airports',
#  'jean-FranÃ§ois Millet',
#  'james Tiptree Jr. Award',
#  'jan DÅ\x82ugosz',
#  'takamine JÅ\x8dkichi',
#  'karl DÃ¶nitz',
#  'krakÃ³w',
#  'kitÃ¡b-i-Aqdas',
#  'koÅ\x82obrzeg',
#  'lÃ¼beck',
#  'communications in Libya',
#  'long shot',
#  'lagÃ¢ri Hasan Ã\x87elebi',
#  'edward Plunkett, 18th Baron of Dunsany',
#  'loa',
#  'relative direction',
#  'libro de los juegos',
#  'lyon & Healy',
#  'louis XIV of France',
#  'lincos (artificial language)',
#  'loya jirga',
#  'malmÃ¶',
#  'mÃ¤laren',
#  'army of the Republic of North Macedonia',
#  'telecommunications in Mexico',
#  'monkey Island (series)',
#  'maciej PÅ\x82aÅ¼yÅ\x84ski',
#  'mOO (programming language)',
#  'the MorrÃ\xadgan',
#  "man'yÅ\x8dshÅ«",
#  'moonie (nickname)',
#  'multiple document interface',
#  'malthusian catastrophe',
#  'province of Massa and Carrara',
#  'transport in New Caledonia',
#  'niccolÃ² Machiavelli',
#  'wiccan views on LGBT people',
#  'papal diplomacy',
#  'non-fiction',
#  'nSAP address',
#  'n ray',
#  'nikolay Kuznetsov (officer)',
#  'nÃ¼rburgring',
#  'open content',
#  'owain GlyndÅµr',
#  'old Fashioned',
#  'pocketbike racing',
#  'phoenix (TV series)',
#  'paul CÃ©zanne',
#  'pedro MartÃ\xadnez',
#  'p5 (microarchitecture)',
#  'permianâ\x80\x93Triassic extinction event',
#  'philips CD-i',
#  'pelÃ©',
#  'protonâ\x80\x93proton chain reaction',
#  'puget Sound Naval Shipyard and Intermediate Maintenance Facility',
#  'peenemÃ¼nde Army Research Center',
#  'renÃ© Descartes',
#  'riddarfjÃ¤rden',
#  'economy of RÃ©union',
#  'reykjavÃ\xadk',
#  'raÃ«lism',
#  'renÃ© Magritte',
#  'reforms of AmÄ\x81nullÄ\x81h KhÄ\x81n and civil war',
#  'î\x9c-recursive function',
#  'marine archeology in the Gulf of Khambhat',
#  'list of members of the United States Senate',
#  'sabine River (Texasâ\x80\x93Louisiana)',
#  'saint Lawrence Seaway',
#  'å\xa0koda Auto',
#  'cLIÃ\x89',
#  'logudorese dialect',
#  'sÃ¸ren Kierkegaard',
#  'history of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'skÃ\xadÃ°blaÃ°nir',
#  'standard Alphabet by Lepsius',
#  'sinn FÃ©in',
#  'nicolas LÃ©onard Sadi Carnot',
#  'square (company)',
#  'sigismund BÃ¡thory',
#  'suprÃªme sauce',
#  "soup all'Imperatrice",
#  'shÅ\x8dgun',
#  'list of Seleucid rulers',
#  'spawn (comics)',
#  'stop consonant',
#  'science & Environmental Policy Project',
#  'sigma-algebra',
#  'sierpinski carpet',
#  'sierpinski triangle',
#  'telefÃ³nica',
#  'tacitus on Christ',
#  'tlÄ\x81loc',
#  'titiusâ\x80\x93Bode law',
#  'thÃ\xadch Nháº¥t Háº¡nh',
#  'throughput',
#  'time transfer',
#  'toruÅ\x84',
#  'taliban treatment of women',
#  'tongue-twister',
#  'the Weakest Link (UK game show)',
#  'threads',
#  'umeÃ¥ University',
#  'uSS Greeneville (SSN-772)',
#  'urzÄ\x85d Ochrony PaÅ\x84stwa',
#  'batavia (ship)',
#  'visegrÃ¡d Group',
#  'whitehorse, Yukon',
#  'juan Pujol GarcÃ\xada',
#  'wÅ\x82adysÅ\x82aw Reymont',
#  'wisÅ\x82awa Szymborska',
#  'wacÅ\x82aw SierpiÅ\x84ski',
#  'yottabyte',
#  'election threshold',
#  '22nd century',
#  'george Marshall',
#  'emperor Go-IchijÅ\x8d',
#  'animated cartoon',
#  'paweÅ\x82 Jasienica',
#  'jÃ¸rn Utzon',
#  'brutus the Younger',
#  "d'Urville Island (New Zealand)",
#  'media of Venezuela',
#  'ante-Nicene Fathers',
#  'august Ferdinand MÃ¶bius',
#  'united States National Guard',
#  'cosÃ¬ fan tutte',
#  'jacques VergÃ¨s',
#  'poznaÅ\x84 University of Technology',
#  'list of violent incidents in the Israeliâ\x80\x93Palestinian conflict, 2002',
#  'imperial, royal and noble styles',
#  'charles XIV John of Sweden',
#  'wikipedia:Article titles',
#  'rupert, King of Germany',
#  'juan GarcÃ\xada Esquivel',
#  'battle of MohÃ¡cs',
#  'physical law',
#  'alburyâ\x80\x93Wodonga',
#  'jefferies tube',
#  'possessive and possessed cases',
#  'ã\x89lie Ducommun',
#  'wikipedia:Etiquette',
#  'net profit',
#  'cathedral of Saint John the Divine',
#  'salvador DalÃ\xad',
#  'outline of space technology',
#  'ole Einar BjÃ¸rndalen',
#  'cnut the Great',
#  'sviatoslav I of Kiev',
#  'knife-edge effect',
#  'spragueâ\x80\x93Grundy theorem',
#  'round-trip delay time',
#  'george III of the United Kingdom',
#  'data transmission',
#  'ã\x89amon de Valera',
#  'sÅ\x82uÅ¼ba BezpieczeÅ\x84stwa',
#  'second Great Awakening',
#  'teresa of Ã\x81vila',
#  'tÃ³rshavn',
#  'franÃ§ois Villon',
#  'north Ossetiaâ\x80\x93Alania',
#  'amÃ©lie',
#  'independent Media Center',
#  'allegro (software)',
#  'mahikeng',
#  'franÃ§ois Boucher',
#  'list of National Parks of Canada',
#  'mÃ©tis in Canada',
#  'franÃ§ois Arago',
#  'protected areas of South Africa',
#  'limit superior and limit inferior',
#  'speech organ',
#  'gÃ©rard Depardieu',
#  'sartÃ¨ne',
#  'dNA vaccination',
#  'chinese democracy movement',
#  'pre-emptive nuclear strike',
#  'grandfather paradox',
#  'sulfur mustard',
#  '35 mm film',
#  'assassins',
#  'mise-en-scÃ¨ne',
#  'entropy encoding',
#  'franÃ§ois Quesnay',
#  'navy List',
#  'sÃ¡ndor Ferenczi',
#  'ã\x86thelred I, King of Wessex',
#  'transistorâ\x80\x93transistor logic',
#  'le PÃ©tomane',
#  'josÃ© Saramago',
#  'charles Maurice de Talleyrand-PÃ©rigord',
#  'hugo ChÃ¡vez',
#  'tÃºpac Katari Guerrilla Army',
#  'age of the Earth',
#  'marÃ\xada FÃ©lix',
#  'antenna gain',
#  'canton of Basel-Landschaft',
#  'wikipedia:Offensive material',
#  'list of important operas',
#  'national Association for Research & Therapy of Homosexuality',
#  'sierra Nevada (U.S.)',
#  'daishÅ\x8d',
#  'paris MÃ©tro',
#  'star Wars: Episode I â\x80\x93 The Phantom Menace',
#  'miklÃ³s Horthy',
#  'citroÃ«n',
#  'miloÅ¡ Forman',
#  'buckingham Ï\x80 theorem',
#  'pratt & Whitney',
#  'biblical Elam',
#  'cisco Systems',
#  'list of people on postage stamps',
#  'julius PlÃ¼cker',
#  'sourceForge Enterprise Edition',
#  'dwarf (mythology)',
#  'bar and Bat Mitzvah',
#  'cÃ¡diz',
#  'î\x92-lactam antibiotic',
#  'georges-EugÃ¨ne Haussmann',
#  'sautÃ©ing',
#  'chandra Levy',
#  '2030',
#  'jean EugÃ¨ne Robert-Houdin',
#  'stanisÅ\x82aw Wojciechowski',
#  'champagne (wine region)',
#  'fordâ\x80\x93Fulkerson algorithm',
#  'centre Georges Pompidou',
#  'ryÅ\x8dji Noyori',
#  'kÃ¼ltepe',
#  'de Broglieâ\x80\x93Bohm theory',
#  'nat Turner',
#  'praderâ\x80\x93Willi syndrome',
#  'treaty of NiÅ¡ (1739)',
#  'andrÃ© Breton',
#  'passes of the Silvretta and RÃ¤tikon Ranges',
#  'rock Ridge',
#  'star Wars: Episode III â\x80\x93 Revenge of the Sith',
#  'humphreyâ\x80\x93Hawkins Full Employment Act',
#  'mannâ\x80\x93Elkins Act',
#  'norrisâ\x80\x93La Guardia Act of 1932',
#  'gramm-Latta Budget',
#  'cyclops',
#  'japanese school uniform',
#  'pelizaeusâ\x80\x93Merzbacher disease',
#  'riding (country subdivision)',
#  'ã\x8ele de RÃ©',
#  'ob River',
#  'pÃ©clet number',
#  "algerian People's National Armed Forces",
#  'battle of Cape St Vincent (1797)',
#  'jean-FranÃ§ois de Galaup, comte de LapÃ©rouse',
#  'franÃ§ois-NoÃ«l Babeuf',
#  'ã\x89cole Polytechnique massacre',
#  'timeline of time measurement technology',
#  'john Bacon (sculptor)',
#  'battle of CrÃ©cy',
#  'dagger (typography)',
#  'sagrada FamÃ\xadlia',
#  'palau GÃ¼ell',
#  'vladimÃ\xadr MeÄ\x8diar',
#  'secretary of State for Foreign and Commonwealth Affairs',
#  'front de libÃ©ration du QuÃ©bec',
#  'magic 8-Ball',
#  'huáº¿',
#  'schrÃ¶dinger equation',
#  'triton II',
#  'bloc QuÃ©bÃ©cois',
#  'iBM Notes',
#  'archie search engine',
#  'list of Intel microprocessors',
#  'chancellor of Germany (1949â\x80\x93present)',
#  'excavation (archaeology)',
#  'boxâ\x80\x93Muller transform',
#  'timiÈ\x99oara',
#  'bible story',
#  'uSS Akron (ZRS-4)',
#  'northstar (Marvel Comics)',
#  'siege of OrlÃ©ans',
#  'bartolomeu de GusmÃ£o',
#  'finistÃ¨re',
#  'robert Watson (scientist)',
#  'rose-Hulman Institute of Technology',
#  'wilhelm RÃ¶ntgen',
#  'les MisÃ©rables (1935 film)',
#  'chÃ¢teau',
#  'lozÃ¨re',
#  'irÃ¨ne Joliot-Curie',
#  'louis XVIII of France',
#  'organisation armÃ©e secrÃ¨te',
#  'jÃ©rÃ´me Bonaparte',
#  'end instrument',
#  'eager evaluation',
#  'draughts',
#  'irtysh River',
#  'napolÃ©on, Prince Imperial',
#  'eugÃ©nie de Montijo',
#  'eosinophiliaâ\x80\x93myalgia syndrome',
#  'mount Eccles National Park',
#  'symbol (chemistry)',
#  'roberto DurÃ¡n',
#  'jacques-BÃ©nigne Bossuet',
#  'volga River',
#  'akallabÃªth',
#  'of the Rings of Power and the Third Age',
#  'wikipedia:About',
#  'four past Midnight',
#  'lothlÃ³rien',
#  'moirÃ© pattern',
#  'military of Iceland',
#  'mercÃ¨ Rodoreda',
#  'ã\x89dith Piaf',
#  'curaÃ§ao',
#  'nandor (Middle-earth)',
#  'island Caribs',
#  'leo I the Thracian',
#  'democratic Party â\x80\x93 demokraci.pl',
#  'japanese aircraft carrier ShÅ\x8dkaku',
#  'soÄ\x8da Reggae Riversplash',
#  'comic science fiction',
#  'affricate consonant',
#  'waterloo & City line',
#  'philip JosÃ© Farmer',
#  'one-China policy',
#  'mikimoto KÅ\x8dkichi',
#  'peÃ±Ã³n de VÃ©lez de la Gomera',
#  'warner Music Australasia',
#  'fourth Age',
#  'tÃºpac Amaru',
#  'full metal jacket bullet',
#  'busy Beaver game',
#  'viá»\x87t Minh',
#  'ã\x81lava',
#  'my Lai Massacre',
#  'lluÃ\xads Companys',
#  'eDE (desktop environment)',
#  'mcCabe & Mrs. Miller',
#  'ã\x86non',
#  'kaldorâ\x80\x93Hicks efficiency',
#  'object-relational database',
#  'list of Australian Capital Territory protected areas',
#  'individual Savings Account',
#  'resurrection of the dead',
#  'brighton & Hove Albion F.C.',
#  'geÊ½ez',
#  'vigenÃ¨re cipher',
#  'potiphar and his wife',
#  'netpbm format',
#  'eastern League (baseball)',
#  'southern League (baseball)',
#  'electronic Entertainment Expo',
#  'castile and LeÃ³n',
#  'list of Governors of New York',
#  "linus's Law",
#  'stanisÅ\x82awa Walasiewicz',
#  'gulf of Saint Lawrence',
#  'tÃ¶di',
#  'non-linear editing system',
#  'arizona League',
#  'sÃ©curitÃ©',
#  'ausiÃ\xa0s March',
#  'pa amb tomÃ\xa0quet',
#  'extended Backusâ\x80\x93Naur form',
#  'wikipedia:What is an article?',
#  'infant mortality',
#  'andrÃ©s Segovia',
#  'ã\x89cole Polytechnique FÃ©dÃ©rale de Lausanne',
#  'signs (film)',
#  'phineas Quimby',
#  'double Indemnity (film)',
#  'tâ\x80\x93V distinction',
#  'pietÃ\xa0 (Michelangelo)',
#  'high Frequency Active Auroral Research Program',
#  'osnabrÃ¼ck',
#  'vÄ\x9bra Ä\x8cÃ¡slavskÃ¡',
#  'greed (film)',
#  'theodora Porphyrogenita (11th century)',
#  'nadia ComÄ\x83neci',
#  'bielsko-BiaÅ\x82a',
#  'waÅ\x82brzych',
#  'pÅ\x82ock',
#  'castellÃ³n de la Plana',
#  'little Miss Marker',
#  'jeanne SauvÃ©',
#  'flat racing',
#  'biotâ\x80\x93Savart law',
#  'whose Line Is It Anyway? (UK TV series)',
#  'nothing But a Man',
#  'dÅ\x8dgen',
#  'minnesota Democraticâ\x80\x93Farmerâ\x80\x93Labor Party',
#  'jean ChrÃ©tien',
#  'concepciÃ³n, Chile',
#  'juan Carlos I of Spain',
#  'orlÃ©ans',
#  'dEFLATE',
#  'simona AmÃ¢nar',
#  'choi Hong Hi',
#  'chindÅ\x8dgu',
#  'list of Governors of Florida',
#  'salomÃ© (1923 film)',
#  'wikipedia:Most wanted stubs',
#  'josÃ© Carioca',
#  'underground mining (hard rock)',
#  'la DÃ©fense',
#  'service dog',
#  'luÃ\xads de CamÃµes',
#  'sky (company)',
#  'muhammad ibn Zakariya al-Razi',
#  'seven Against Thebes',
#  'armor-piercing shell',
#  "valÃ©ry Giscard d'Estaing",
#  'bouches-du-RhÃ´ne',
#  'rafael Moreno Aranzadi',
#  'crime of apartheid',
#  'tables (board game)',
#  'bilderberg Meeting',
#  'alexis ArgÃ¼ello',
#  'list of rock music performers',
#  'list of Latin names of rivers',
#  'wikipedia:WikiProject French departments',
#  'matÃ³',
#  'rhÃ´ne (department)',
#  'interstate 238',
#  'orbital (The Culture)',
#  'list of Presidents of Brazil',
#  'political compass',
#  'helenus',
#  'wilfredo GÃ³mez',
#  'the Raven: Anarchist Quarterly',
#  "chÃ¢teau d'Amboise",
#  'wilfred BenÃ\xadtez',
#  'suprÃªme NTM',
#  'chÃ¢teau de Chenonceau',
#  'chÃ¢teau de Blois',
#  "chÃ¢teau d'Angers",
#  'heinrich BÃ¶ll',
#  'julio CÃ©sar ChÃ¡vez',
#  'list of television stations in the United Kingdom',
#  'list of United States terrestrial television networks',
#  'teatro ColÃ³n',
#  'rape, Abuse & Incest National Network',
#  'luis MuÃ±oz MarÃ\xadn International Airport',
#  'ialysos (mythology)',
#  'danaÃ«',
#  'ã\x89cole centrale de Nantes',
#  'ã\x89cole Centrale Paris',
#  'ernst RÃ¶hm',
#  'chÃ¢teau de Saumur',
#  'copÃ¡n',
#  'beyoncÃ©',
#  'fÃ©lix Trinidad',
#  'wikipedia:Size comparisons',
#  'ã\x86thelbald of Mercia',
#  'salvador SÃ¡nchez',
#  'drÃ´me',
#  'angoulÃªme',
#  'hÃ©rault',
#  'louis-Ferdinand CÃ©line',
#  'aeromÃ©xico',
#  'meiji period',
#  'matarÃ³',
#  'dÄ«s Pater',
#  'timeline of computing 1950â\x80\x931979',
#  'mohammed Omar',
#  'clÃ\xadodhna',
#  'tommy Burns (boxer)',
#  'international Association of Athletics Federations',
#  'scÃ¡thach',
#  'fergus mac RÃ³ich',
#  'hÃ©ctor Camacho',
#  'pike (programming language)',
#  'coxâ\x80\x93Forbes theory',
#  'besanÃ§on',
#  'adÃ©lie penguin',
#  'list of association football clubs',
#  'carlos MonzÃ³n',
#  'gunnar HÃ¡mundarson',
#  'rocket launch',
#  'sÃ¦hrÃ\xadmnir',
#  'heiÃ°rÃºn',
#  'prince of Walesâ\x80\x93Hyder Census Area, Alaska',
#  'list of states and territories of the United States by population',
#  'auÃ°umbla',
#  'le BÃ©bÃªte Show',
#  'adamari LÃ³pez',
#  'ada VÃ©lez',
#  'popular Front for the Liberation of Palestine â\x80\x93 General Command',
#  'list of national parks of Brazil',
#  'hautes-PyrÃ©nÃ©es',
#  'pressed flower craft',
#  'chÃ¢teau de Chaumont',
#  'chÃ¢teau de Montsoreau',
#  'vÃ\xadctor Jara',
#  'vendÃ©e',
#  "chÃ¢teau d'UssÃ©",
#  'dievturÄ«ba',
#  'kakapo',
#  'chÃ¢teau de Brissac',
#  'chÃ¢teau de Montreuil-Bellay',
#  "chÃ¢teau d'Oiron",
#  'courts of the United Kingdom',
#  'appliquÃ©',
#  'castlemaine XXXX',
#  'cÅ\x8dÄ\x81tlÄ«cue',
#  'mictlÄ\x81ntÄ\x93cutli',
#  'mictÄ\x93cacihuÄ\x81tl',
#  'tlazÅ\x8dlteÅ\x8dtl',
#  'chicomecÅ\x8dÄ\x81tl',
#  'cihuacÅ\x8dÄ\x81tl',
#  'popocatÃ©petl',
#  'software engineer',
#  'puy-de-DÃ´me',
#  'ardÃ¨che',
#  "cÃ´te-d'Or",
#  'niÃ¨vre',
#  'haute-SaÃ´ne',
#  'saÃ´ne-et-Loire',
#  'deux-SÃ¨vres',
#  "cÃ´tes-d'Armor",
#  'herrenhausen',
#  'list of French islands in the Indian and Pacific oceans',
#  'saint-RÃ©my-de-Provence',
#  'port Laoise',
#  'daitÅ\x8d-ryÅ« Aiki-jÅ«jutsu',
#  'user space',
#  'artaxerxes II of Persia',
#  'milk River (Albertaâ\x80\x93Montana)',
#  'montana State Universityâ\x80\x93Northern',
#  'arvo PÃ¤rt',
#  'cÃ©sar Vallejo',
#  'samuel Pierpont Langley',
#  'mosinâ\x80\x93Nagant',
#  'solfÃ¨ge',
#  'auahitÅ«roa',
#  'hine-nui-te-pÅ\x8d',
#  'wÄ\x81kea',
#  'jesÃºs GonzÃ¡lez (boxer)',
#  'realencyclopÃ¤die der classischen Altertumswissenschaft',
#  'dauphinÃ©',
#  'coenzyme Q â\x80\x93 cytochrome c reductase',
#  'chÃ¢teau-Thierry',
#  'ironâ\x80\x93sulfur cluster',
#  "gabrielle d'EstrÃ©es",
#  'livia (gens)',
#  'nautilus (Verne)',
#  'max OphÃ¼ls',
#  'the Swan (film)',
#  'treaty of LunÃ©ville',
#  'basset (card game)',
#  'dacian Fortresses of the OrÄ\x83È\x99tie Mountains',
#  'sighiÈ\x99oara',
#  'relational database management system',
#  'renÃ© Farrait',
#  'felipe VI of Spain',
#  'chÃ¢lons-en-Champagne',
#  'gascon language',
#  'ricky MelÃ©ndez',
#  'bertrand DelanoÃ«',
#  'federico GarcÃ\xada Lorca',
#  'skinny Call Control Protocol',
#  'conservation (ethic)',
#  'sri',
#  'á¹\x9ata',
#  'vÃ\xadctor RaÃºl Haya de la Torre',
#  'annapurna Massif',
#  'ä\x80tman (Hinduism)',
#  'brahmani',
#  'plonk (Usenet)',
#  'list of Governors of Maryland',
#  'eulerâ\x80\x93Jacobi pseudoprime',
#  'uluá¹\x9fu-Kata Tjuá¹¯a National Park',
#  'west MacDonnell National Park',
#  'double-entry bookkeeping system',
#  'innes National Park',
#  'rich GarcÃ©s',
#  'ant Broads & Marshes National Nature Reserve',
#  'jacques PrÃ©vert',
#  'hojÅ\x8djutsu',
#  'annika SÃ¶renstam',
#  'hidden Valley National Park',
#  'xavier SerbiÃ¡',
#  'josÃ© MartÃ\xad International Airport',
#  'university of TromsÃ¸',
#  'mormon Tabernacle Choir',
#  'nÃ®mes',
#  'modern flat Earth societies',
#  'royal Space Force: The Wings of HonnÃªamise',
#  'benito JuÃ¡rez',
#  'moreton Island National Park',
#  'mount Jim Crow National Park',
#  'maâ\x80\x99alpiku Island National Park',
#  'denise QuiÃ±ones',
#  'wildfowl & Wetlands Trust',
#  'general American',
#  'gustav IV Adolf of Sweden',
#  'salon des RefusÃ©s',
#  'imre KertÃ©sz',
#  'pallars SobirÃ',
#  'pallars JussÃ',
#  'p-Funk',
#  'list of Canadian provinces and territories by population',
#  'rovira i Virgili University',
#  'poblet Monastery',
#  'palau de la MÃºsica Catalana',
#  'pedro MontaÃ±ez',
#  'parti QuÃ©bÃ©cois',
#  'bertsch-Oceanview, California',
#  'vandenberg Air Force Base',
#  'coal Creek, Boulder County, Colorado',
#  'roy RossellÃ³',
#  'josÃ© Ferrer',
#  'risk-free interest rate',
#  'vox (musical equipment)',
#  'list of metropolitan areas by population',
#  'gÃ¼iro',
#  'empÃºries',
#  'malung-SÃ¤len Municipality',
#  'ekerÃ¶ Municipality',
#  'lidingÃ¶ Municipality',
#  'norrtÃ¤lje Municipality',
#  'campion Hall',
#  'vÃ¤rmdÃ¶ Municipality',
#  'lidkÃ¶ping Municipality',
#  'skÃ¶vde',
#  'tjÃ¶rn Municipality',
#  'antoni KÄ\x99piÅ\x84ski',
#  'josÃ© Luis RodrÃ\xadguez (singer)',
#  'gÃ¤vle Municipality',
#  'jÃ¤mtland County',
#  'ã\x96stersund Municipality',
#  'jÃ¶nkÃ¶ping Municipality',
#  'luleÃ¥ Municipality',
#  'norrkÃ¶ping Municipality',
#  'sÃ¶derkÃ¶ping Municipality',
#  'vÃ¤rmland County',
#  'ã\x85rjÃ¤ng Municipality',
#  'vÃ¤sterbotten County',
#  'umeÃ¥ Municipality',
#  'vÃ¤nnÃ¤s Municipality',
#  'valencian',
#  'lake Taupo',
#  'spanish conquest of YucatÃ¡n',
#  'poltergeist (film series)',
#  'fairview, Bergen County, New Jersey',
#  'bÃ¡thory family',
#  'hachette Filipacchi MÃ©dias',
#  'enciclopedia Libre Universal en EspaÃ±ol',
#  'beÅ\x82Å¼ec extermination camp',
#  'history of Baden-WÃ¼rttemberg',
#  'denormal number',
#  'henryk GÃ³recki',
#  'marÃ\xada Celeste ArrarÃ¡s',
#  'madonna (entertainer)',
#  'josÃ© Ortiz (basketball)',
#  'amberley Museum & Heritage Centre',
#  'jean-FranÃ§ois Oeben',
#  'pedro RossellÃ³',
#  'list of Indigenous Australian group names',
#  'namu MyÅ\x8dhÅ\x8d Renge KyÅ\x8d',
#  'iBM Db2 Family',
#  'nicÃ©phore NiÃ©pce',
#  'vatnajÃ¶kull',
#  'langjÃ¶kull',
#  'douÃ©-la-Fontaine',
#  'province of CÃ¡diz',
#  'microsoft Notepad',
#  'province of LeÃ³n',
#  'doppelgÃ¤nger',
#  'samsÃ¸',
#  'grÃ¦sted-Gilleleje',
#  'leeâ\x80\x93Enfield',
#  'josÃ© Torres',
#  'north Walsham & Dilham Canal',
#  'wikipedia:Browser notes',
#  'ã\x86thelred of Mercia',
#  'hÃ¸je-Taastrup Municipality',
#  'evolution (software)',
#  'ray and Maria Stata Center',
#  'hjÃ¸rring Municipality',
#  'southwold lighthouse',
#  'lightvessels in the United Kingdom',
#  'ã\x86thelweard (historian)',
#  'list of heads of missions of the United Kingdom',
#  'bill & Melinda Gates Foundation',
#  'uK firefighter dispute 2002â\x80\x9303',
#  'kÅ\x8dtoku ShÅ«sui',
#  'icelandic krÃ³na',
#  'five-year plans for the national economy of the Soviet Union',
#  'ramsÃ¸',
#  'cearbhall Ã\x93 DÃ¡laigh',
#  'william McDougall (politician)',
#  'eurocopter HH-65 Dolphin',
#  'seÃ¡n Lemass',
#  'manu GinÃ³bili',
#  'hofsjÃ¶kull',
#  'cleveland, England',
#  'hIV vaccine',
#  'tithe barn',
#  'ernst ZÃ¼ndel',
#  'dothan (ancient city)',
#  'goiÃ¡s',
#  'brief reactive psychosis',
#  'ã\x89tienne FranÃ§ois, duc de Choiseul',
#  'constantine III (Western Roman Emperor)',
#  'president of the Irish Republic',
#  'shin-Yokohama RÄ\x81men Museum',
#  'uirÅ\x8d',
#  'johan Paulik',
#  'nonconformist',
#  'mayagÃ¼ez, Puerto Rico',
#  'lÃ¼neburg',
#  'jean-AndrÃ© Deluc',
#  'abelardo DÃ\xadaz Alfaro',
#  'vitrolles, Bouches-du-RhÃ´ne',
#  'ã\x89douard Lucas',
#  'aleksander KwaÅ\x9bniewski',
#  'adolf of Germany',
#  'littleport, Cambridgeshire',
#  'agustÃ\xadn de Iturbide',
#  'wilts & Berks Canal',
#  'one instruction set computer',
#  'carlos de LeÃ³n',
#  'josÃ© Celso Barbosa',
#  'air Raid Precautions in the United Kingdom',
#  'sarriÃ\xa0-Sant Gervasi',
#  'babylonian numerals',
#  'list of Prime Ministers of Italy',
#  'ribagorÃ§a',
#  'bertrand BarÃ¨re',
#  'organ (anatomy)',
#  'the Night of the Meek',
#  'luis MuÃ±oz MarÃ\xadn',
#  'rÆ¡ MÄ\x83m people',
#  'lÄ\x99bork',
#  'valence (city)',
#  'southern Ireland (1921â\x80\x9322)',
#  'zamoÅ\x9bÄ\x87',
#  "kÅ\x91nig's lemma",
#  'the Great Game',
#  'g.I. Generation',
#  'bÃ©thune',
#  'helgÃ¶',
#  'wolfenbÃ¼ttel',
#  'sacatepÃ©quez Department',
#  'allied Military phonetic spelling alphabets',
#  'mÃ¼nster',
#  'krzysztof KieÅ\x9blowski',
#  'second DÃ¡il',
#  'prokop DiviÅ¡',
#  'vÃ¤stergÃ¶tland',
#  'wikipedia:Geographic references',
#  'antigonish County, Nova Scotia',
#  'yarmouth County, Nova Scotia',
#  'basilios Bessarion',
#  'gÃ¶ttingen (district)',
#  'teachta DÃ¡la',
#  'mieczysÅ\x82aw KarÅ\x82owicz',
#  'irene SÃ¡ez',
#  'battle of HÃ¶chstÃ¤dt (1800)',
#  'esteban de JesÃºs',
#  'association des Bibliophiles Universels',
#  'first DÃ¡il',
#  'lutheran Churchâ\x80\x93Missouri Synod',
#  'media of the United States',
#  'king of the Romanians',
#  'list of Presidents of Turkey',
#  'frankfurtâ\x80\x93Hahn Airport',
#  'biljana PlavÅ¡iÄ\x87',
#  'wikipedia:Chemical infobox',
#  'universitÃ© du QuÃ©bec Ã\xa0 MontrÃ©al',
#  'universitÃ© du QuÃ©bec',
#  'council on Americanâ\x80\x93Islamic Relations',
#  'the Proms',
#  'ä\x80yah',
#  'klaipÄ\x97da',
#  'miloÅ¡ ObiliÄ\x87',
#  'media player (software)',
#  'miguel LÃ³pez de Legazpi',
#  'beren',
#  'dagor Bragollach',
#  'siege of Angband',
#  'dagor-nuin-Giliath',
#  "seÃ¡n T. O'Kelly",
#  'lÃ¡szlÃ³ Papp',
#  'gregorio LuperÃ³n International Airport',
#  'moria (video game)',
#  'proletÃ¤ren',
#  'ostroÅ\x82Ä\x99ka',
#  'vigdÃ\xads FinnbogadÃ³ttir',
#  'list of Presidents of Colombia',
#  'las PiÃ±as',
#  '26th Cavalry Regiment',
#  'list of Presidents of Italy',
#  'louis BlÃ©riot',
#  'herfindahl index',
#  'eastern District (Hong Kong)',
#  'priceâ\x80\x93earnings ratio',
#  'semaphore telegraph',
#  'passion of Saint Perpetua, Saint Felicitas, and their Companions',
#  'juan de OÃ±ate',
#  'list of Bailiffs of Guernsey',
#  'guillaume BudÃ©',
#  'family Computer Disk System',
#  'romani genocide',
#  'saint-RÃ©my-Blanzy',
#  'rangefinder',
#  "standard & Poor's",
#  'cause cÃ©lÃ¨bre',
#  'atmospheric sciences',
#  'lilo & Stitch',
#  'list of dams and reservoirs in United States',
#  'william Gilbert (astronomer)',
#  'uruk-hai',
#  'schÃ¶nbrunn Palace',
#  'list of U.S. National Forests',
#  'linkÃ¶ping University',
#  'list of violent incidents in the Israeliâ\x80\x93Palestinian conflict, 2003',
#  'franÃ§ois-RenÃ© de Chateaubriand',
#  'in & Out (film)',
#  'louise LabÃ©',
#  'ulster Scots dialects',
#  'national Gardens Scheme',
#  'sticks McGhee',
#  'agedashi dÅ\x8dfu',
#  'queensway Tunnel',
#  'childhood',
#  'indian Institute of Technology Bombay',
#  'fantÃ´mas',
#  'irish Famine (1740â\x80\x9341)',
#  'josÃ© Roman (boxer)',
#  'south Poleâ\x80\x93Aitken basin',
#  'jorge PÃ¡ez',
#  'vÃ©hicule Automatique LÃ©ger',
#  'naÃ¯ve physics',
#  'death of JonBenÃ©t Ramsey',
#  'liepÄ\x81ja',
#  'hÃ¥kan Lans',
#  'hans Adolf Krebs',
#  'luis BuÃ±uel',
#  'adversarial process',
#  'fucking, Austria',
#  'regents of the Univ. of Cal. v. Bakke',
#  'san Theodoros',
#  'mÄ\x81ori language revival',
#  'eugÃ¨ne Delacroix',
#  'canton of Grisons',
#  'murat & Jose',
#  'acadÃ©mie Julian',
#  'pomeranian (dog)',
#  'lance Cottrell',
#  'supergiant star',
#  'raÃ¯',
#  'galÃ¡pagos Islands',
#  'planck mass',
#  'tÄ«tokowaru',
#  'lÃ©opold SÃ©dar Senghor',
#  'subdivisions of Russia',
#  'centaur (minor planet)',
#  'foreign relations of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'new York blues',
#  'd. Napier & Son',
#  'nuremberg Rally',
#  'lamanite',
#  'zoltÃ¡n KodÃ¡ly',
#  'cayleyâ\x80\x93Hamilton theorem',
#  'law & Order',
#  'enoch (ancestor of Noah)',
#  'thorneâ\x80\x93Å»ytkow object',
#  'katÅ\x8d Takaaki',
#  'wakatsuki ReijirÅ\x8d',
#  'eisaku SatÅ\x8d',
#  'kid GavilÃ¡n',
#  'planck time',
#  'clintonâ\x80\x93Lewinsky scandal',
#  'raÄ\x8dak massacre',
#  'willy Wonka & the Chocolate Factory',
#  'atomic units',
#  'guillaume Thomas FranÃ§ois Raynal',
#  'mindâ\x80\x93body dualism',
#  'anhÃ©e',
#  'hastiÃ¨re',
#  'the Telegraph (Nashua)',
#  'jules GrÃ©vy',
#  ...]

# %%
redirects_titles = []
not_redirect_titles = []

for title in diff_titles: 
    if is_redirect(title):
        redirects_titles.append(title)
    else:
        not_redirect_titles.append(title)

# %%
print(f"Number of redirect pages : {len(redirects_titles)} ({100.*len(redirects_titles)/len(diff_titles):.4f}%)")
print(f"Number of not redirect pages : {len(not_redirect_titles)} ({100.*len(not_redirect_titles)/len(diff_titles):.4f}%)")
# Out:
# Number of redirect pages : 36069 (36.3878%)
# Number of not redirect pages : 63055 (63.6122%)

# %%
not_redirect_titles
# Out:
# ['asociaciÃ³n Alumni',
#  'andrÃ© Gide',
#  'casa BatllÃ³',
#  'park GÃ¼ell',
#  'casa MilÃ',
#  'atanasoffâ\x80\x93Berry computer',
#  'ã\x86lle of Sussex',
#  'albrecht DÃ¼rer',
#  'andrÃ© the Giant',
#  'ã\x81ed mac CinÃ¡eda',
#  'alcobaÃ§a, Portugal',
#  'borsukâ\x80\x93Ulam theorem',
#  'beerâ\x80\x93Lambert law',
#  'braâ\x80\x93ket notation',
#  'batman & Robin (film)',
#  'brasÃ\xadlia',
#  'bjÃ¸rn Lomborg',
#  'canadaâ\x80\x93United States relations',
#  'czesÅ\x82aw MiÅ\x82osz',
#  'comet Haleâ\x80\x93Bopp',
#  'cuitlÃ¡huac',
#  'cuauhtÃ©moc',
#  'cauchyâ\x80\x93Riemann equations',
#  'deutsches Institut fÃ¼r Normung',
#  'diogo CÃ£o',
#  'domnall mac AilpÃ\xadn',
#  'dÃ©jÃ\xa0 vu',
#  'helsingÃ¸r',
#  'encyclopÃ¦dia Britannica',
#  'ã\x89douard Manet',
#  'ã\x89variste Galois',
#  'elblÄ\x85g',
#  'ã\x86thelberht of Kent',
#  'ã\x89lisabeth VigÃ©e Le Brun',
#  'ã\x86thelred the Unready',
#  'emperor ShÅ\x8dmu',
#  'ã\x89mile Baudot',
#  'evliya Ã\x87elebi',
#  'emperor YÅ\x8dmei',
#  'empress KÅ\x8dgyoku',
#  'emperor KÅ\x8dtoku',
#  'emperor KÅ\x8dbun',
#  'empress JitÅ\x8d',
#  'emperor SukÅ\x8d',
#  "emperor Go-En'yÅ«",
#  'emperor KÅ\x8dshÅ\x8d',
#  'emperor KÅ\x8dan',
#  'emperor KÅ\x8drei',
#  'emperor KÅ\x8dgen',
#  'emperor KeikÅ\x8d',
#  'emperor ChÅ«ai',
#  'emperor Å\x8cjin',
#  'emperor RichÅ«',
#  'emperor IngyÅ\x8d',
#  'emperor AnkÅ\x8d',
#  'emperor KenzÅ\x8d',
#  'emperor NinmyÅ\x8d',
#  'emperor KÅ\x8dkÅ\x8d',
#  'friedrich WÃ¶hler',
#  "franÃ§ois d'Aguilon",
#  'fÃ©lix Guattari',
#  'frÃ©dÃ©ric Bazille',
#  'fianna FÃ¡il',
#  'foixâ\x80\x93Alajouanine syndrome',
#  'gÃ¶ta Canal',
#  'gil Ã\x81lvarez Carrillo de Albornoz',
#  'gallâ\x80\x93Peters projection',
#  'hermann GÃ¶ring',
#  'heckler & Koch MP5',
#  'huygensâ\x80\x93Fresnel principle',
#  'interwiki links',
#  'ä°skender kebap',
#  'jean-FranÃ§ois Millet',
#  'jan DÅ\x82ugosz',
#  'takamine JÅ\x8dkichi',
#  'karl DÃ¶nitz',
#  'krakÃ³w',
#  'kitÃ¡b-i-Aqdas',
#  'koÅ\x82obrzeg',
#  'lÃ¼beck',
#  'lagÃ¢ri Hasan Ã\x87elebi',
#  'lyon & Healy',
#  'malmÃ¶',
#  'mÃ¤laren',
#  'maciej PÅ\x82aÅ¼yÅ\x84ski',
#  'the MorrÃ\xadgan',
#  "man'yÅ\x8dshÅ«",
#  'transport in New Caledonia',
#  'niccolÃ² Machiavelli',
#  'nÃ¼rburgring',
#  'owain GlyndÅµr',
#  'paul CÃ©zanne',
#  'pedro MartÃ\xadnez',
#  'permianâ\x80\x93Triassic extinction event',
#  'pelÃ©',
#  'protonâ\x80\x93proton chain reaction',
#  'peenemÃ¼nde Army Research Center',
#  'renÃ© Descartes',
#  'riddarfjÃ¤rden',
#  'economy of RÃ©union',
#  'reykjavÃ\xadk',
#  'raÃ«lism',
#  'renÃ© Magritte',
#  'reforms of AmÄ\x81nullÄ\x81h KhÄ\x81n and civil war',
#  'î\x9c-recursive function',
#  'sabine River (Texasâ\x80\x93Louisiana)',
#  'å\xa0koda Auto',
#  'cLIÃ\x89',
#  'sÃ¸ren Kierkegaard',
#  'history of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'skÃ\xadÃ°blaÃ°nir',
#  'sinn FÃ©in',
#  'nicolas LÃ©onard Sadi Carnot',
#  'sigismund BÃ¡thory',
#  'suprÃªme sauce',
#  "soup all'Imperatrice",
#  'shÅ\x8dgun',
#  'science & Environmental Policy Project',
#  'telefÃ³nica',
#  'tlÄ\x81loc',
#  'titiusâ\x80\x93Bode law',
#  'thÃ\xadch Nháº¥t Háº¡nh',
#  'toruÅ\x84',
#  'umeÃ¥ University',
#  'urzÄ\x85d Ochrony PaÅ\x84stwa',
#  'visegrÃ¡d Group',
#  'juan Pujol GarcÃ\xada',
#  'wÅ\x82adysÅ\x82aw Reymont',
#  'wisÅ\x82awa Szymborska',
#  'wacÅ\x82aw SierpiÅ\x84ski',
#  'emperor Go-IchijÅ\x8d',
#  'paweÅ\x82 Jasienica',
#  'jÃ¸rn Utzon',
#  'august Ferdinand MÃ¶bius',
#  'cosÃ¬ fan tutte',
#  'jacques VergÃ¨s',
#  'poznaÅ\x84 University of Technology',
#  'list of violent incidents in the Israeliâ\x80\x93Palestinian conflict, 2002',
#  'wikipedia:Article titles',
#  'juan GarcÃ\xada Esquivel',
#  'battle of MohÃ¡cs',
#  'alburyâ\x80\x93Wodonga',
#  'ã\x89lie Ducommun',
#  'wikipedia:Etiquette',
#  'salvador DalÃ\xad',
#  'ole Einar BjÃ¸rndalen',
#  'spragueâ\x80\x93Grundy theorem',
#  'ã\x89amon de Valera',
#  'sÅ\x82uÅ¼ba BezpieczeÅ\x84stwa',
#  'teresa of Ã\x81vila',
#  'tÃ³rshavn',
#  'franÃ§ois Villon',
#  'north Ossetiaâ\x80\x93Alania',
#  'amÃ©lie',
#  'franÃ§ois Boucher',
#  'mÃ©tis in Canada',
#  'franÃ§ois Arago',
#  'gÃ©rard Depardieu',
#  'sartÃ¨ne',
#  'mise-en-scÃ¨ne',
#  'franÃ§ois Quesnay',
#  'sÃ¡ndor Ferenczi',
#  'ã\x86thelred I, King of Wessex',
#  'transistorâ\x80\x93transistor logic',
#  'le PÃ©tomane',
#  'josÃ© Saramago',
#  'charles Maurice de Talleyrand-PÃ©rigord',
#  'hugo ChÃ¡vez',
#  'tÃºpac Katari Guerrilla Army',
#  'marÃ\xada FÃ©lix',
#  'wikipedia:Offensive material',
#  'national Association for Research & Therapy of Homosexuality',
#  'daishÅ\x8d',
#  'paris MÃ©tro',
#  'star Wars: Episode I â\x80\x93 The Phantom Menace',
#  'miklÃ³s Horthy',
#  'citroÃ«n',
#  'miloÅ¡ Forman',
#  'buckingham Ï\x80 theorem',
#  'pratt & Whitney',
#  'julius PlÃ¼cker',
#  'cÃ¡diz',
#  'î\x92-lactam antibiotic',
#  'georges-EugÃ¨ne Haussmann',
#  'sautÃ©ing',
#  'jean EugÃ¨ne Robert-Houdin',
#  'stanisÅ\x82aw Wojciechowski',
#  'fordâ\x80\x93Fulkerson algorithm',
#  'ryÅ\x8dji Noyori',
#  'kÃ¼ltepe',
#  'de Broglieâ\x80\x93Bohm theory',
#  'praderâ\x80\x93Willi syndrome',
#  'treaty of NiÅ¡ (1739)',
#  'andrÃ© Breton',
#  'passes of the Silvretta and RÃ¤tikon Ranges',
#  'star Wars: Episode III â\x80\x93 Revenge of the Sith',
#  'humphreyâ\x80\x93Hawkins Full Employment Act',
#  'mannâ\x80\x93Elkins Act',
#  'norrisâ\x80\x93La Guardia Act of 1932',
#  'pelizaeusâ\x80\x93Merzbacher disease',
#  'ã\x8ele de RÃ©',
#  'pÃ©clet number',
#  'jean-FranÃ§ois de Galaup, comte de LapÃ©rouse',
#  'franÃ§ois-NoÃ«l Babeuf',
#  'ã\x89cole Polytechnique massacre',
#  'battle of CrÃ©cy',
#  'sagrada FamÃ\xadlia',
#  'palau GÃ¼ell',
#  'vladimÃ\xadr MeÄ\x8diar',
#  'front de libÃ©ration du QuÃ©bec',
#  'huáº¿',
#  'schrÃ¶dinger equation',
#  'bloc QuÃ©bÃ©cois',
#  'chancellor of Germany (1949â\x80\x93present)',
#  'boxâ\x80\x93Muller transform',
#  'timiÈ\x99oara',
#  'siege of OrlÃ©ans',
#  'bartolomeu de GusmÃ£o',
#  'finistÃ¨re',
#  'wilhelm RÃ¶ntgen',
#  'les MisÃ©rables (1935 film)',
#  'chÃ¢teau',
#  'lozÃ¨re',
#  'irÃ¨ne Joliot-Curie',
#  'organisation armÃ©e secrÃ¨te',
#  'jÃ©rÃ´me Bonaparte',
#  'napolÃ©on, Prince Imperial',
#  'eugÃ©nie de Montijo',
#  'eosinophiliaâ\x80\x93myalgia syndrome',
#  'roberto DurÃ¡n',
#  'jacques-BÃ©nigne Bossuet',
#  'akallabÃªth',
#  'wikipedia:About',
#  'lothlÃ³rien',
#  'moirÃ© pattern',
#  'mercÃ¨ Rodoreda',
#  'ã\x89dith Piaf',
#  'curaÃ§ao',
#  'democratic Party â\x80\x93 demokraci.pl',
#  'japanese aircraft carrier ShÅ\x8dkaku',
#  'soÄ\x8da Reggae Riversplash',
#  'waterloo & City line',
#  'philip JosÃ© Farmer',
#  'mikimoto KÅ\x8dkichi',
#  'peÃ±Ã³n de VÃ©lez de la Gomera',
#  'tÃºpac Amaru',
#  'viá»\x87t Minh',
#  'ã\x81lava',
#  'lluÃ\xads Companys',
#  'eDE (desktop environment)',
#  'mcCabe & Mrs. Miller',
#  'ã\x86non',
#  'kaldorâ\x80\x93Hicks efficiency',
#  'brighton & Hove Albion F.C.',
#  'geÊ½ez',
#  'vigenÃ¨re cipher',
#  'castile and LeÃ³n',
#  'stanisÅ\x82awa Walasiewicz',
#  'tÃ¶di',
#  'sÃ©curitÃ©',
#  'ausiÃ\xa0s March',
#  'pa amb tomÃ\xa0quet',
#  'extended Backusâ\x80\x93Naur form',
#  'wikipedia:What is an article?',
#  'andrÃ©s Segovia',
#  'ã\x89cole Polytechnique FÃ©dÃ©rale de Lausanne',
#  'tâ\x80\x93V distinction',
#  'pietÃ\xa0 (Michelangelo)',
#  'osnabrÃ¼ck',
#  'vÄ\x9bra Ä\x8cÃ¡slavskÃ¡',
#  'nadia ComÄ\x83neci',
#  'bielsko-BiaÅ\x82a',
#  'waÅ\x82brzych',
#  'pÅ\x82ock',
#  'castellÃ³n de la Plana',
#  'jeanne SauvÃ©',
#  'biotâ\x80\x93Savart law',
#  'dÅ\x8dgen',
#  'minnesota Democraticâ\x80\x93Farmerâ\x80\x93Labor Party',
#  'jean ChrÃ©tien',
#  'concepciÃ³n, Chile',
#  'orlÃ©ans',
#  'simona AmÃ¢nar',
#  'chindÅ\x8dgu',
#  'salomÃ© (1923 film)',
#  'wikipedia:Most wanted stubs',
#  'josÃ© Carioca',
#  'la DÃ©fense',
#  'luÃ\xads de CamÃµes',
#  "valÃ©ry Giscard d'Estaing",
#  'bouches-du-RhÃ´ne',
#  'alexis ArgÃ¼ello',
#  'list of rock music performers',
#  'matÃ³',
#  'rhÃ´ne (department)',
#  'wilfredo GÃ³mez',
#  "chÃ¢teau d'Amboise",
#  'wilfred BenÃ\xadtez',
#  'suprÃªme NTM',
#  'chÃ¢teau de Chenonceau',
#  'chÃ¢teau de Blois',
#  "chÃ¢teau d'Angers",
#  'heinrich BÃ¶ll',
#  'julio CÃ©sar ChÃ¡vez',
#  'teatro ColÃ³n',
#  'rape, Abuse & Incest National Network',
#  'luis MuÃ±oz MarÃ\xadn International Airport',
#  'danaÃ«',
#  'ã\x89cole centrale de Nantes',
#  'ã\x89cole Centrale Paris',
#  'ernst RÃ¶hm',
#  'chÃ¢teau de Saumur',
#  'copÃ¡n',
#  'beyoncÃ©',
#  'fÃ©lix Trinidad',
#  'wikipedia:Size comparisons',
#  'ã\x86thelbald of Mercia',
#  'salvador SÃ¡nchez',
#  'drÃ´me',
#  'angoulÃªme',
#  'hÃ©rault',
#  'louis-Ferdinand CÃ©line',
#  'aeromÃ©xico',
#  'matarÃ³',
#  'dÄ«s Pater',
#  'timeline of computing 1950â\x80\x931979',
#  'clÃ\xadodhna',
#  'scÃ¡thach',
#  'fergus mac RÃ³ich',
#  'hÃ©ctor Camacho',
#  'coxâ\x80\x93Forbes theory',
#  'besanÃ§on',
#  'adÃ©lie penguin',
#  'carlos MonzÃ³n',
#  'gunnar HÃ¡mundarson',
#  'sÃ¦hrÃ\xadmnir',
#  'heiÃ°rÃºn',
#  'prince of Walesâ\x80\x93Hyder Census Area, Alaska',
#  'auÃ°umbla',
#  'le BÃ©bÃªte Show',
#  'adamari LÃ³pez',
#  'ada VÃ©lez',
#  'popular Front for the Liberation of Palestine â\x80\x93 General Command',
#  'hautes-PyrÃ©nÃ©es',
#  'chÃ¢teau de Chaumont',
#  'chÃ¢teau de Montsoreau',
#  'vÃ\xadctor Jara',
#  'vendÃ©e',
#  "chÃ¢teau d'UssÃ©",
#  'dievturÄ«ba',
#  'chÃ¢teau de Brissac',
#  'chÃ¢teau de Montreuil-Bellay',
#  "chÃ¢teau d'Oiron",
#  'appliquÃ©',
#  'cÅ\x8dÄ\x81tlÄ«cue',
#  'mictlÄ\x81ntÄ\x93cutli',
#  'mictÄ\x93cacihuÄ\x81tl',
#  'tlazÅ\x8dlteÅ\x8dtl',
#  'chicomecÅ\x8dÄ\x81tl',
#  'cihuacÅ\x8dÄ\x81tl',
#  'popocatÃ©petl',
#  'puy-de-DÃ´me',
#  'ardÃ¨che',
#  "cÃ´te-d'Or",
#  'niÃ¨vre',
#  'haute-SaÃ´ne',
#  'saÃ´ne-et-Loire',
#  'deux-SÃ¨vres',
#  "cÃ´tes-d'Armor",
#  'saint-RÃ©my-de-Provence',
#  'daitÅ\x8d-ryÅ« Aiki-jÅ«jutsu',
#  'milk River (Albertaâ\x80\x93Montana)',
#  'montana State Universityâ\x80\x93Northern',
#  'arvo PÃ¤rt',
#  'cÃ©sar Vallejo',
#  'mosinâ\x80\x93Nagant',
#  'solfÃ¨ge',
#  'auahitÅ«roa',
#  'hine-nui-te-pÅ\x8d',
#  'wÄ\x81kea',
#  'jesÃºs GonzÃ¡lez (boxer)',
#  'realencyclopÃ¤die der classischen Altertumswissenschaft',
#  'dauphinÃ©',
#  'coenzyme Q â\x80\x93 cytochrome c reductase',
#  'chÃ¢teau-Thierry',
#  'ironâ\x80\x93sulfur cluster',
#  "gabrielle d'EstrÃ©es",
#  'max OphÃ¼ls',
#  'treaty of LunÃ©ville',
#  'dacian Fortresses of the OrÄ\x83È\x99tie Mountains',
#  'sighiÈ\x99oara',
#  'renÃ© Farrait',
#  'chÃ¢lons-en-Champagne',
#  'ricky MelÃ©ndez',
#  'bertrand DelanoÃ«',
#  'federico GarcÃ\xada Lorca',
#  'á¹\x9ata',
#  'vÃ\xadctor RaÃºl Haya de la Torre',
#  'ä\x80tman (Hinduism)',
#  'plonk (Usenet)',
#  'eulerâ\x80\x93Jacobi pseudoprime',
#  'uluá¹\x9fu-Kata Tjuá¹¯a National Park',
#  'rich GarcÃ©s',
#  'ant Broads & Marshes National Nature Reserve',
#  'jacques PrÃ©vert',
#  'hojÅ\x8djutsu',
#  'annika SÃ¶renstam',
#  'xavier SerbiÃ¡',
#  'josÃ© MartÃ\xad International Airport',
#  'university of TromsÃ¸',
#  'nÃ®mes',
#  'royal Space Force: The Wings of HonnÃªamise',
#  'benito JuÃ¡rez',
#  'maâ\x80\x99alpiku Island National Park',
#  'denise QuiÃ±ones',
#  'wildfowl & Wetlands Trust',
#  'salon des RefusÃ©s',
#  'imre KertÃ©sz',
#  'pallars SobirÃ',
#  'pallars JussÃ',
#  'palau de la MÃºsica Catalana',
#  'pedro MontaÃ±ez',
#  'parti QuÃ©bÃ©cois',
#  'roy RossellÃ³',
#  'josÃ© Ferrer',
#  'gÃ¼iro',
#  'empÃºries',
#  'malung-SÃ¤len Municipality',
#  'ekerÃ¶ Municipality',
#  'lidingÃ¶ Municipality',
#  'norrtÃ¤lje Municipality',
#  'vÃ¤rmdÃ¶ Municipality',
#  'lidkÃ¶ping Municipality',
#  'skÃ¶vde',
#  'tjÃ¶rn Municipality',
#  'antoni KÄ\x99piÅ\x84ski',
#  'josÃ© Luis RodrÃ\xadguez (singer)',
#  'gÃ¤vle Municipality',
#  'jÃ¤mtland County',
#  'ã\x96stersund Municipality',
#  'jÃ¶nkÃ¶ping Municipality',
#  'luleÃ¥ Municipality',
#  'norrkÃ¶ping Municipality',
#  'sÃ¶derkÃ¶ping Municipality',
#  'vÃ¤rmland County',
#  'ã\x85rjÃ¤ng Municipality',
#  'vÃ¤sterbotten County',
#  'umeÃ¥ Municipality',
#  'vÃ¤nnÃ¤s Municipality',
#  'spanish conquest of YucatÃ¡n',
#  'bÃ¡thory family',
#  'hachette Filipacchi MÃ©dias',
#  'enciclopedia Libre Universal en EspaÃ±ol',
#  'beÅ\x82Å¼ec extermination camp',
#  'history of Baden-WÃ¼rttemberg',
#  'henryk GÃ³recki',
#  'marÃ\xada Celeste ArrarÃ¡s',
#  'josÃ© Ortiz (basketball)',
#  'amberley Museum & Heritage Centre',
#  'jean-FranÃ§ois Oeben',
#  'pedro RossellÃ³',
#  'namu MyÅ\x8dhÅ\x8d Renge KyÅ\x8d',
#  'nicÃ©phore NiÃ©pce',
#  'vatnajÃ¶kull',
#  'langjÃ¶kull',
#  'douÃ©-la-Fontaine',
#  'province of CÃ¡diz',
#  'province of LeÃ³n',
#  'doppelgÃ¤nger',
#  'samsÃ¸',
#  'grÃ¦sted-Gilleleje',
#  'leeâ\x80\x93Enfield',
#  'josÃ© Torres',
#  'north Walsham & Dilham Canal',
#  'wikipedia:Browser notes',
#  'ã\x86thelred of Mercia',
#  'hÃ¸je-Taastrup Municipality',
#  'hjÃ¸rring Municipality',
#  'ã\x86thelweard (historian)',
#  'bill & Melinda Gates Foundation',
#  'uK firefighter dispute 2002â\x80\x9303',
#  'kÅ\x8dtoku ShÅ«sui',
#  'icelandic krÃ³na',
#  'ramsÃ¸',
#  'cearbhall Ã\x93 DÃ¡laigh',
#  'seÃ¡n Lemass',
#  'manu GinÃ³bili',
#  'hofsjÃ¶kull',
#  'ernst ZÃ¼ndel',
#  'goiÃ¡s',
#  'ã\x89tienne FranÃ§ois, duc de Choiseul',
#  'shin-Yokohama RÄ\x81men Museum',
#  'uirÅ\x8d',
#  'johan Paulik',
#  'mayagÃ¼ez, Puerto Rico',
#  'lÃ¼neburg',
#  'jean-AndrÃ© Deluc',
#  'abelardo DÃ\xadaz Alfaro',
#  'vitrolles, Bouches-du-RhÃ´ne',
#  'ã\x89douard Lucas',
#  'aleksander KwaÅ\x9bniewski',
#  'agustÃ\xadn de Iturbide',
#  'wilts & Berks Canal',
#  'carlos de LeÃ³n',
#  'josÃ© Celso Barbosa',
#  'sarriÃ\xa0-Sant Gervasi',
#  'ribagorÃ§a',
#  'bertrand BarÃ¨re',
#  'luis MuÃ±oz MarÃ\xadn',
#  'rÆ¡ MÄ\x83m people',
#  'lÄ\x99bork',
#  'southern Ireland (1921â\x80\x9322)',
#  'zamoÅ\x9bÄ\x87',
#  "kÅ\x91nig's lemma",
#  'bÃ©thune',
#  'helgÃ¶',
#  'wolfenbÃ¼ttel',
#  'sacatepÃ©quez Department',
#  'mÃ¼nster',
#  'krzysztof KieÅ\x9blowski',
#  'second DÃ¡il',
#  'prokop DiviÅ¡',
#  'vÃ¤stergÃ¶tland',
#  'wikipedia:Geographic references',
#  'gÃ¶ttingen (district)',
#  'teachta DÃ¡la',
#  'mieczysÅ\x82aw KarÅ\x82owicz',
#  'irene SÃ¡ez',
#  'battle of HÃ¶chstÃ¤dt (1800)',
#  'esteban de JesÃºs',
#  'association des Bibliophiles Universels',
#  'first DÃ¡il',
#  'lutheran Churchâ\x80\x93Missouri Synod',
#  'frankfurtâ\x80\x93Hahn Airport',
#  'biljana PlavÅ¡iÄ\x87',
#  'wikipedia:Chemical infobox',
#  'universitÃ© du QuÃ©bec Ã\xa0 MontrÃ©al',
#  'universitÃ© du QuÃ©bec',
#  'council on Americanâ\x80\x93Islamic Relations',
#  'ä\x80yah',
#  'klaipÄ\x97da',
#  'miloÅ¡ ObiliÄ\x87',
#  'miguel LÃ³pez de Legazpi',
#  "seÃ¡n T. O'Kelly",
#  'lÃ¡szlÃ³ Papp',
#  'gregorio LuperÃ³n International Airport',
#  'proletÃ¤ren',
#  'ostroÅ\x82Ä\x99ka',
#  'vigdÃ\xads FinnbogadÃ³ttir',
#  'las PiÃ±as',
#  'louis BlÃ©riot',
#  'priceâ\x80\x93earnings ratio',
#  'juan de OÃ±ate',
#  'guillaume BudÃ©',
#  'saint-RÃ©my-Blanzy',
#  "standard & Poor's",
#  'cause cÃ©lÃ¨bre',
#  'lilo & Stitch',
#  'schÃ¶nbrunn Palace',
#  'linkÃ¶ping University',
#  'list of violent incidents in the Israeliâ\x80\x93Palestinian conflict, 2003',
#  'franÃ§ois-RenÃ© de Chateaubriand',
#  'in & Out (film)',
#  'louise LabÃ©',
#  'agedashi dÅ\x8dfu',
#  'fantÃ´mas',
#  'irish Famine (1740â\x80\x9341)',
#  'josÃ© Roman (boxer)',
#  'south Poleâ\x80\x93Aitken basin',
#  'jorge PÃ¡ez',
#  'vÃ©hicule Automatique LÃ©ger',
#  'naÃ¯ve physics',
#  'death of JonBenÃ©t Ramsey',
#  'liepÄ\x81ja',
#  'hÃ¥kan Lans',
#  'luis BuÃ±uel',
#  'mÄ\x81ori language revival',
#  'eugÃ¨ne Delacroix',
#  'murat & Jose',
#  'acadÃ©mie Julian',
#  'lance Cottrell',
#  'raÃ¯',
#  'galÃ¡pagos Islands',
#  'tÄ«tokowaru',
#  'lÃ©opold SÃ©dar Senghor',
#  'foreign relations of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'd. Napier & Son',
#  'zoltÃ¡n KodÃ¡ly',
#  'cayleyâ\x80\x93Hamilton theorem',
#  'law & Order',
#  'thorneâ\x80\x93Å»ytkow object',
#  'katÅ\x8d Takaaki',
#  'wakatsuki ReijirÅ\x8d',
#  'eisaku SatÅ\x8d',
#  'kid GavilÃ¡n',
#  'clintonâ\x80\x93Lewinsky scandal',
#  'raÄ\x8dak massacre',
#  'willy Wonka & the Chocolate Factory',
#  'guillaume Thomas FranÃ§ois Raynal',
#  'mindâ\x80\x93body dualism',
#  'anhÃ©e',
#  'hastiÃ¨re',
#  'jules GrÃ©vy',
#  'luis Ã\x81ngel Firpo',
#  'parkerâ\x80\x93Hulme murder case',
#  'greater Moncton RomÃ©o LeBlanc International Airport',
#  'tommy MuÃ±iz',
#  'fernÃ£o Pires de Andrade',
#  'adamâ\x80\x93God doctrine',
#  'wikipedia:Libel',
#  'special Circumstances',
#  'askÃ¸y',
#  'osterÃ¸y',
#  'gebhard Leberecht von BlÃ¼cher',
#  'vÃ¥gsÃ¸y',
#  'aFLâ\x80\x93CIO',
#  'sandnessjÃ¸en',
#  'franÃ§ois FÃ©nelon',
#  'renÃ©e Vivien',
#  'josÃ© Miguel Agrelot',
#  'tony PÃ©rez',
#  'greisenâ\x80\x93Zatsepinâ\x80\x93Kuzmin limit',
#  'adalberto RodrÃ\xadguez',
#  'gaÃ«tan Dugas',
#  'university of GÃ¶ttingen',
#  'blohm & Voss BV 155',
#  'knasterâ\x80\x93Tarski theorem',
#  'chÃ¢lus',
#  'aimable PÃ©lissier',
#  'bishÅ\x8dnen',
#  'wikipedia:OpenFacts',
#  'tÅ\x8dkai region',
#  'bjÃ¸rnstjerne BjÃ¸rnson',
#  'johnsonâ\x80\x93Nyquist noise',
#  'franÃ§ois Guizot',
#  'wikipedia:Manual of Style/Dates and numbers',
#  'alexandra David-NÃ©el',
#  'c. F. Martin & Company',
#  'list of Canadians of Asian ancestry',
#  'rafael LimÃ³n',
#  'rafael HernÃ¡ndez Airport',
#  'svatba v korÃ¡lovÃ©m moÅ\x99i',
#  'jÅ«kichi Yagi',
#  'shÅ«sei Tokuda',
#  'chÅ«ya Nakahara',
#  'hiraide ShÅ«',
#  'ozaki KÅ\x8dyÅ\x8d',
#  'nickelâ\x80\x93cadmium battery',
#  'vendÃ´me',
#  'alfrÃ©d HajÃ³s',
#  'clube AtlÃ©tico Mineiro',
#  'konjaku MonogatarishÅ«',
#  'ramÃ³n Arellano FÃ©lix',
#  'juan SebastiÃ¡n Elcano',
#  'emperor NinkÅ\x8d',
#  'emperor KÅ\x8dkaku',
#  "l'Ã\x8ele-Dorval",
#  'george-Ã\x89tienne Cartier',
#  'henri CoandÄ\x83',
#  'ã\x93engus II',
#  'causantÃ\xadn mac Fergusa',
#  'coandÄ\x83 effect',
#  'erich von DÃ¤niken',
#  'otto HÃ¶lder',
#  'memÃ\xadn PinguÃ\xadn',
#  'martin NiemÃ¶ller',
#  'wikipedia:Article size',
#  'domangart RÃ©ti',
#  'fergus MÃ³r',
#  'å\x9awinoujÅ\x9bcie',
#  'jayâ\x80\x93Gardoqui Treaty',
#  'de LÃ´me Letter',
#  'clÃ©ment Ader',
#  'robert Livingston (1708â\x80\x931790)',
#  'drÃ¸bak',
#  'goran IvaniÅ¡eviÄ\x87',
#  'marcos PÃ©rez JimÃ©nez',
#  'shunryÅ« Suzuki',
#  'emperor Go-YÅ\x8dzei',
#  'emperor ShijÅ\x8d',
#  'emperor ChÅ«kyÅ\x8d',
#  'emperor RokujÅ\x8d',
#  'wikipedia:List of bibliographies',
#  'adolfo PÃ©rez Esquivel',
#  'la GÃ¼era',
#  'acadÃ©mie royale de peinture et de sculpture',
#  'purÃ©pecha',
#  'michoacÃ¡n',
#  'josÃ© Clemente Orozco',
#  'jÃ©rÃ´me Lalande',
#  'jean-Marie Roland de la PlatiÃ¨re',
#  'constantin FranÃ§ois de ChassebÅ\x93uf, comte de Volney',
#  'yusuf AkÃ§ura',
#  'alfons KarpiÅ\x84ski',
#  'jerzy RÃ³Å¼ycki',
#  'chÅ«goku region',
#  "ngÅ©gÄ© wa Thiong'o",
#  'aosdÃ¡na',
#  'rhÃ´ne-Alpes',
#  'spanish aircraft carrier PrÃ\xadncipe de Asturias',
#  'viesÄ«te',
#  'bibliothÃ¨que nationale de France',
#  'pia KjÃ¦rsgaard',
#  'louis Christophe FranÃ§ois Hachette',
#  'joseph de VillÃ¨le',
#  'emmanuel Joseph SieyÃ¨s',
#  'bÃ©zier triangle',
#  'franÃ§ois Tombalbaye',
#  'marie-Joseph AngÃ©lique',
#  'ã\x89liphas LÃ©vi',
#  "chÃ¢teau d'If",
#  'kantÅ\x8d region',
#  'josÃ© de Acosta',
#  'kumÄ\x81rajÄ«va',
#  'alejandro GonzÃ¡lez MalavÃ©',
#  'kanÅ\x8d Eitoku',
#  'hDMS SÃ¦len (S323)',
#  'chÃ¢teau de Coucy',
#  'composite BÃ©zier curve',
#  'limba noastrÄ\x83',
#  'orlÃ©anist',
#  'tÅ\x8dhoku region',
#  'lÃ©on Gambetta',
#  'coupÃ©',
#  'ferenc PuskÃ¡s',
#  'austral LÃ\xadneas AÃ©reas',
#  'sibleyâ\x80\x93Ahlquist taxonomy of birds',
#  "bahÃ¡'Ã\xad calendar",
#  'gÃ¶teborgs-Posten',
#  'cangaÃ§o',
#  'luÃ\xads Carlos Prestes',
#  'saguenayâ\x80\x93St. Lawrence Marine Park',
#  'josÃ© Feliciano',
#  'isabel MartÃ\xadnez de PerÃ³n',
#  'tigrisâ\x80\x93Euphrates river system',
#  'jacques Marie EugÃ¨ne Godefroy Cavaignac',
#  'ã\x86lfweard of Wessex',
#  'sanzÅ\x8d Nosaka',
#  'germaine de StaÃ«l',
#  "canon d'Infanterie de 37 modÃ¨le 1916 TRP",
#  'sDPâ\x80\x93Liberal Alliance',
#  'lÃ¡zaro CÃ¡rdenas',
#  'pÃ©cs',
#  '7.5 cm leichtes InfanteriegeschÃ¼tz 18',
#  'pierre Claude FranÃ§ois Daunou',
#  'barthÃ©lemy Prosper Enfantin',
#  'eugÃ¨ne Burnouf',
#  '7.5 cm InfanteriegeschÃ¼tz 37',
#  'pedro de ArbuÃ©s',
#  'montbÃ©liard',
#  'nord-du-QuÃ©bec',
#  'wikipedia:Orphan',
#  'list of people known as "the Great"',
#  'cataÃ±o, Puerto Rico',
#  'lucecita BenÃ\xadtez',
#  'ertuÄ\x9frul',
#  'zoÃ« Porphyrogenita',
#  'luleÃ¥ University of Technology',
#  'the Institute of Technology at LinkÃ¶ping University',
#  'mÃ¤lardalen University College',
#  'sÃ¶dertÃ¶rn University',
#  'history of Sweden (800â\x80\x931521)',
#  'history of Sweden (1611â\x80\x9348)',
#  'ngÃ´ Ä\x90Ã¬nh Thá»¥c',
#  'battle of KÃ¶niggrÃ¤tz',
#  'eugen BÃ¶hm von Bawerk',
#  'antonio Rivera RodrÃ\xadguez Airport',
#  'lÃ¼ Dongbin',
#  'ivÃ¡n CalderÃ³n (boxer)',
#  'niccolÃ² Piccinni',
#  'pierre-Louis GinguenÃ©',
#  'mjÃ¶lnir',
#  'josÃ© Cecilio del Valle',
#  'calixa LavallÃ©e',
#  'nuevo LeÃ³n',
#  'ramÃ³n Luis Rivera',
#  'nicolÃ¡s GuillÃ©n',
#  'christiane NÃ¼sslein-Volhard',
#  'josÃ© Luis RamÃ\xadrez',
#  'bernâ\x80\x93LÃ¶tschbergâ\x80\x93Simplon railway',
#  'wikipedia:WikiLove',
#  'san FermÃ\xadn',
#  'ferrocarril de SÃ³ller',
#  'timeline of preâ\x80\x93United States history',
#  'bronisÅ\x82aw Malinowski',
#  'romÃ©o LeBlanc',
#  'the HaÃ§ienda',
#  'rTÃ\x892',
#  'sÃ¼dliche WeinstraÃ\x9fe',
#  'gabriel Dumont (MÃ©tis leader)',
#  'ã\x89tude',
#  'vipÄ\x81ka',
#  'coat of arms of Ã\x96land',
#  'emperor Å\x8cgimachi',
#  'paranÃ¡ (state)',
#  'sÃ£o Paulo (state)',
#  'amapÃ¡',
#  'cearÃ¡',
#  'parÃ¡',
#  'paraÃ\xadba',
#  'mouvement RÃ©formateur',
#  'cinÃ©ma vÃ©ritÃ©',
#  'akraâ\x80\x93Bazzi method',
#  'josÃ© NÃ¡poles',
#  'dom PÃ©rignon (monk)',
#  'pÅ\x99emysl the Ploughman',
#  'index of Korea-related articles',
#  'george of PodÄ\x9bbrady',
#  'kermit CintrÃ³n',
#  'kÅ\x8dbe Station',
#  'neuilly-la-ForÃªt',
#  'history of the Ã\x85land Islands',
#  'polytechnique MontrÃ©al',
#  'norteÃ±os',
#  'ã\x89leuthÃ¨re IrÃ©nÃ©e du Pont',
#  'schrÃ¤ge Musik',
#  'calciumâ\x80\x93aluminium-rich inclusion',
#  'newtonâ\x80\x93Cotes formulas',
#  'museo Nacional Centro de Arte Reina SofÃ\xada',
#  'tol EressÃ«a',
#  'acilia (gens)',
#  'les MisÃ©rables (musical)',
#  "duÅ¡an's Code",
#  'domrÃ©my-la-Pucelle',
#  'amÃ©lie Mauresmo',
#  'stanfordâ\x80\x93Binet Intelligence Scales',
#  'viÄ¼Ä\x81ni',
#  'rÃ³bert BÃ¡rÃ¡ny',
#  'dNAâ\x80\x93DNA hybridization',
#  'cÃ³rdoba, Argentina',
#  'avalokiteÅ\x9bvara',
#  'dievs, svÄ\x93tÄ« Latviju!',
#  'jean-FranÃ§ois Lyotard',
#  'å\x81omÅ¼a',
#  'hana MandlÃ\xadkovÃ¡',
#  'beinecke Rare Book & Manuscript Library',
#  'physical information',
#  'ã\x81lvaro Uribe',
#  'gÃ¼nter Blobel',
#  "wikipedia:Modelling Wikipedia's growth",
#  'tullia (gens)',
#  'hradec KrÃ¡lovÃ©',
#  'gavia (gens)',
#  'philadelphia Wings (1987â\x80\x932014)',
#  'josÃ© Cuevas (boxer)',
#  'pedro Ã\x81lvares Cabral',
#  'romÃ¡n Baldorioty de Castro',
#  'glasses fetishism',
#  'duchy of Brunswick-LÃ¼neburg',
#  'christian BÃ¶k',
#  'copa AmÃ©rica',
#  'odalys GarcÃ\xada',
#  'peÃ±uelas, Puerto Rico',
#  'stefan UroÅ¡ V',
#  'toÃ±o Bicicleta',
#  'marc-Vivien FoÃ©',
#  'jÃ¤ger Movement',
#  'mount PelÃ©e',
#  'tropicÃ¡lia',
#  'ramÃ³n Ramos',
#  'santiago RamÃ³n y Cajal',
#  'ilha de ItamaracÃ¡',
#  'wikipedia:Manual of Style/Images',
#  'jyvÃ¤skylÃ¤',
#  'university of JyvÃ¤skylÃ¤',
#  'rÃ©jean Ducharme',
#  'st. Marys River (Michiganâ\x80\x93Ontario)',
#  "hon'inbÅ\x8d",
#  'la FertÃ©-Alais',
#  'treaty of BrÃ©tigny',
#  'shÅ\x8dwa period',
#  'joaquÃ\xadn Crespo',
#  'juan Vicente GÃ³mez',
#  'sunshine LogroÃ±o',
#  'ä°skenderun',
#  'octave CrÃ©mazie',
#  'university of TÃ¼bingen',
#  'riviÃ¨re des Mille Ã\x8eles',
#  'troutonâ\x80\x93Noble experiment',
#  'rarÃ¡muri',
#  'rebellions of 1837â\x80\x931838',
#  'nÃ¡jera',
#  'rÃ\xado Muni',
#  'josef Ä\x8capek',
#  'lÃ©ognan',
#  'list of villages depopulated during the Arabâ\x80\x93Israeli conflict',
#  "pÃ¨re David's deer",
#  'lÃ¼ Meng',
#  'y-Î\x94 transform',
#  'botoÈ\x99ani County',
#  'galaÈ\x9bi County',
#  'timiÈ\x99 County',
#  'st. Peteâ\x80\x93Clearwater International Airport',
#  'reninâ\x80\x93angiotensin system',
#  'chaordic organization',
#  'roberto CofresÃ\xad',
#  'josÃ© Padilla (prisoner)',
#  'efraÃ\xadn RÃ\xados Montt',
#  'flores, El PetÃ©n',
#  'leÃ³n, Nicaragua',
#  'citroÃ«n Berlingo',
#  'felipe GonzÃ¡lez',
#  'manuel AzaÃ±a',
#  'dolores IbÃ¡rruri',
#  'weberâ\x80\x93Fechner law',
#  'carlos Morocho HernÃ¡ndez',
#  'antÃ´nio Rodrigo Nogueira',
#  'davÃ\xadÃ° Oddsson',
#  'schÃ¶n scandal',
#  'dendermondeâ\x80\x93Puurs Steam Railway',
#  'humberto GonzÃ¡lez',
#  'french frigate MÃ©duse (1810)',
#  'etiÃ¤inen',
#  'mcCuneâ\x80\x93Reischauer',
#  'provenÃ§al dialect',
#  'baÄ\x8dka Palanka',
#  'beÄ\x8dej',
#  'ä\x8caÄ\x8dak',
#  'ä\x86uprija',
#  'inÄ\x91ija',
#  'kruÅ¡evac',
#  'peÄ\x87',
#  'poÅ¾arevac',
#  'zajeÄ\x8dar',
#  'ã\x96land',
#  'bÃ©zier surface',
#  'hÃ©lÃ¨ne Dutrieu',
#  'spokeâ\x80\x93hub distribution paradigm',
#  'zbigniew RybczyÅ\x84ski',
#  'josÃ© Fernando de Abascal y Sousa',
#  'black & White Records',
#  'radio y TelevisiÃ³n MartÃ\xad',
#  'henri CoandÄ\x83 International Airport',
#  'gaston, Duke of OrlÃ©ans',
#  'georges de ScudÃ©ry',
#  "shin'ichirÅ\x8d Tomonaga",
#  'tonlÃ© Sap',
#  'cancÃºn',
#  'wikipedia:Criticisms',
#  'cÃ©sar Ã\x89vora',
#  'joÃ£o Ã\x81lvares Fagundes',
#  'cÄ\x83ile Ferate RomÃ¢ne',
#  'guantÃ¡namo',
#  "cramÃ©r's conjecture",
#  'atilia (gens)',
#  'birminghamâ\x80\x93Shuttlesworth International Airport',
#  'kÅ«kai',
#  'commandâ\x80\x93query separation',
#  'kÄ\x81lidÄ\x81sa',
#  'international Hockey League (1945â\x80\x932001)',
#  'maracanÃ£ Stadium',
#  'university of TrÃ¡s-os-Montes and Alto Douro',
#  'trÃ¡s-os-Montes e Alto Douro Province',
#  'jÅ\x8ddo ShinshÅ«',
#  'ryszard KapuÅ\x9bciÅ\x84ski',
#  'tÃ¢mega (river)',
#  'sacrÃ©-CÅ\x93ur, Paris',
#  'will & Grace',
#  'peterâ\x80\x93Weyl theorem',
#  "tÄ«tokowaru's War",
#  'á¹\x9atusaá¹\x83hÄ\x81ra',
#  'yongeâ\x80\x93Dundas Square',
#  'chinatownâ\x80\x93International District, Seattle',
#  'vÃ¡clav Havel Airport Prague',
#  'tÅ\x82Ä±Ì¨chÇ«',
#  'bayamÃ³n City Hall',
#  'institut national de la statistique et des Ã©tudes Ã©conomiques',
#  'mel MartÃ\xadnez',
#  'skÃ¥ne Line',
#  'sentÅ\x8d',
#  'national awakening of Romania',
#  'canadaâ\x80\x93United States softwood lumber dispute',
#  'paasikiviâ\x80\x93Kekkonen doctrine',
#  'fuerzas Armadas de LiberaciÃ³n Nacional PuertorriqueÃ±a',
#  'mÃ©dard des Groseilliers',
#  'sÃ©rgio Vieira de Mello',
#  'marcel AymÃ©',
#  'list of municipalities in Ã\x81lava',
#  'citroÃ«n Saxo',
#  'tree of TÃ©nÃ©rÃ©',
#  'winâ\x80\x93loss record (pitching)',
#  'ilie NÄ\x83stase',
#  'mileva MariÄ\x87',
#  'tony FernÃ¡ndez',
#  'abbÃ© Pierre',
#  'leÃ³n, Spain',
#  'jÃ³zef Maria Hoene-WroÅ\x84ski',
#  'vÃ¡clav Klaus',
#  'ramÃ³n Mercader',
#  'fernando J. CorbatÃ³',
#  'raymond PoincarÃ©',
#  'mima JauÅ¡ovec',
#  '1936â\x80\x931939 Arab revolt in Palestine',
#  'route 179 (Pennsylvaniaâ\x80\x93New Jersey)',
#  'internet cafÃ©',
#  'pratÄ«tyasamutpÄ\x81da',
#  'jan Å\x81ukasiewicz',
#  'wikipedia:Missing Wikipedians',
#  'ribeirÃ£o Preto',
#  'list of kings of Gondor',
#  ...]

# %%
is_node('andré Gide')
# Out:
# True

# %% [markdown]
# ## LF-WikiSeeAlso-320K

# %%
data_path = f"{data_dir}/LF-WikiSeeAlso-320K/"

train_path = f"{data_path}/trn.json"
test_path = f"{data_path}/tst.json"

# %%
same_titles, diff_titles = [], []

separate_titles(same_titles, diff_titles, train_path)
separate_titles(same_titles, diff_titles, test_path)

# %%
len(same_titles), len(diff_titles), len(same_titles)+len(diff_titles)
# Out:
# (765946, 104651, 870597)

# %%
total_pages = len(same_titles)+len(diff_titles)
print(f"Number of similar pages : {len(same_titles)} ({100.*len(same_titles)/total_pages:.4f}%)")
print(f"Number of different pages : {len(diff_titles)} ({100.*len(diff_titles)/total_pages:.4f}%)")
# Out:
# Number of similar pages : 765946 (87.9794%)
# Number of different pages : 104651 (12.0206%)

# %%
redirects_titles = []
not_redirect_titles = []

for title in diff_titles: 
    if is_redirect(title):
        redirects_titles.append(title)
    else:
        not_redirect_titles.append(title)

# %%
print(f"Number of redirect pages : {len(redirects_titles)} ({100.*len(redirects_titles)/len(diff_titles):.4f}%)")
print(f"Number of not redirect pages : {len(not_redirect_titles)} ({100.*len(not_redirect_titles)/len(diff_titles):.4f}%)")
# Out:
# Number of redirect pages : 38052 (36.3609%)
# Number of not redirect pages : 66599 (63.6391%)

# %%
not_redirect_titles
# Out:
# ['asociaciÃ³n Alumni',
#  'andrÃ© Gide',
#  'casa BatllÃ³',
#  'park GÃ¼ell',
#  'casa MilÃ',
#  'atanasoffâ\x80\x93Berry computer',
#  'ã\x81lfheimr',
#  'ã\x86lle of Sussex',
#  'albrecht DÃ¼rer',
#  'andrÃ© the Giant',
#  'ã\x81ed mac CinÃ¡eda',
#  'alcobaÃ§a, Portugal',
#  'borsukâ\x80\x93Ulam theorem',
#  'beerâ\x80\x93Lambert law',
#  'braâ\x80\x93ket notation',
#  'batman & Robin (film)',
#  'brasÃ\xadlia',
#  'bjÃ¸rn Lomborg',
#  'canadaâ\x80\x93United States relations',
#  'czesÅ\x82aw MiÅ\x82osz',
#  'comet Haleâ\x80\x93Bopp',
#  'cuitlÃ¡huac',
#  'cuauhtÃ©moc',
#  'cauchyâ\x80\x93Riemann equations',
#  'deutsches Institut fÃ¼r Normung',
#  'diogo CÃ£o',
#  'domnall mac AilpÃ\xadn',
#  'dÃ©jÃ\xa0 vu',
#  'helsingÃ¸r',
#  'encyclopÃ¦dia Britannica',
#  'ã\x89douard Manet',
#  'ã\x89variste Galois',
#  'elblÄ\x85g',
#  'ã\x89lisabeth VigÃ©e Le Brun',
#  'ã\x86thelred the Unready',
#  'emperor ShÅ\x8dmu',
#  'ã\x89mile Baudot',
#  'evliya Ã\x87elebi',
#  'emperor YÅ\x8dmei',
#  'empress KÅ\x8dgyoku',
#  'emperor KÅ\x8dtoku',
#  'emperor KÅ\x8dbun',
#  'empress JitÅ\x8d',
#  'emperor SukÅ\x8d',
#  "emperor Go-En'yÅ«",
#  'emperor KÅ\x8dshÅ\x8d',
#  'emperor KÅ\x8dan',
#  'emperor KÅ\x8drei',
#  'emperor KÅ\x8dgen',
#  'emperor KeikÅ\x8d',
#  'emperor ChÅ«ai',
#  'emperor Å\x8cjin',
#  'emperor RichÅ«',
#  'emperor IngyÅ\x8d',
#  'emperor AnkÅ\x8d',
#  'emperor KenzÅ\x8d',
#  'emperor NinmyÅ\x8d',
#  'emperor KÅ\x8dkÅ\x8d',
#  'friedrich WÃ¶hler',
#  "franÃ§ois d'Aguilon",
#  'fÃ©lix Guattari',
#  'frÃ©dÃ©ric Bazille',
#  'fianna FÃ¡il',
#  'foixâ\x80\x93Alajouanine syndrome',
#  'gÃ¶ta Canal',
#  'gil Ã\x81lvarez Carrillo de Albornoz',
#  'gallâ\x80\x93Peters projection',
#  'giosuÃ¨ Carducci',
#  'hermann GÃ¶ring',
#  'heckler & Koch MP5',
#  'huygensâ\x80\x93Fresnel principle',
#  'interwiki links',
#  'ä°skender kebap',
#  'jean-FranÃ§ois Millet',
#  'jan DÅ\x82ugosz',
#  'takamine JÅ\x8dkichi',
#  'karl DÃ¶nitz',
#  'krakÃ³w',
#  'kitÃ¡b-i-Aqdas',
#  'kÅ\x8dan',
#  'kurfÃ¼rstendamm',
#  'koÅ\x82obrzeg',
#  'lÃ¼beck',
#  'lagÃ¢ri Hasan Ã\x87elebi',
#  'lyon & Healy',
#  'malmÃ¶',
#  'mÃ¤laren',
#  'maciej PÅ\x82aÅ¼yÅ\x84ski',
#  'the MorrÃ\xadgan',
#  "man'yÅ\x8dshÅ«",
#  'transport in New Caledonia',
#  'niccolÃ² Machiavelli',
#  'nÃ¼rburgring',
#  'owain GlyndÅµr',
#  'ã\x96tzi',
#  'paul CÃ©zanne',
#  'pedro MartÃ\xadnez',
#  'permianâ\x80\x93Triassic extinction event',
#  'pelÃ©',
#  'protonâ\x80\x93proton chain reaction',
#  'peenemÃ¼nde Army Research Center',
#  'renÃ© Descartes',
#  'riddarfjÃ¤rden',
#  'economy of RÃ©union',
#  'reykjavÃ\xadk',
#  'raÃ«lism',
#  'renÃ© Magritte',
#  'reforms of AmÄ\x81nullÄ\x81h KhÄ\x81n and civil war',
#  'î\x9c-recursive function',
#  'sabine River (Texasâ\x80\x93Louisiana)',
#  'å\xa0koda Auto',
#  'cLIÃ\x89',
#  'sÃ¸ren Kierkegaard',
#  'history of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'skÃ\xadÃ°blaÃ°nir',
#  'â\x99¯P',
#  'sinn FÃ©in',
#  'nicolas LÃ©onard Sadi Carnot',
#  'sigismund BÃ¡thory',
#  'suprÃªme sauce',
#  "soup all'Imperatrice",
#  'aos SÃ\xad',
#  'shÅ\x8dgun',
#  'science & Environmental Policy Project',
#  'telefÃ³nica',
#  'tlÄ\x81loc',
#  'titiusâ\x80\x93Bode law',
#  'thÃ\xadch Nháº¥t Háº¡nh',
#  'toruÅ\x84',
#  'umeÃ¥ University',
#  'urzÄ\x85d Ochrony PaÅ\x84stwa',
#  'vÃ¤nern',
#  'visegrÃ¡d Group',
#  'juan Pujol GarcÃ\xada',
#  'wÅ\x82adysÅ\x82aw Reymont',
#  'wisÅ\x82awa Szymborska',
#  'wacÅ\x82aw SierpiÅ\x84ski',
#  'emperor Go-IchijÅ\x8d',
#  'paweÅ\x82 Jasienica',
#  'jÃ¸rn Utzon',
#  'ã\x89raic',
#  'august Ferdinand MÃ¶bius',
#  'cosÃ¬ fan tutte',
#  'jacques VergÃ¨s',
#  'poznaÅ\x84 University of Technology',
#  'list of violent incidents in the Israeliâ\x80\x93Palestinian conflict, 2002',
#  'wikipedia:Article titles',
#  'juan GarcÃ\xada Esquivel',
#  'battle of MohÃ¡cs',
#  'alburyâ\x80\x93Wodonga',
#  'ã\x89lie Ducommun',
#  'wikipedia:Etiquette',
#  'salvador DalÃ\xad',
#  'ole Einar BjÃ¸rndalen',
#  'spragueâ\x80\x93Grundy theorem',
#  'ã\x89amon de Valera',
#  'sÅ\x82uÅ¼ba BezpieczeÅ\x84stwa',
#  'teresa of Ã\x81vila',
#  'dÃ¡l Riata',
#  'tÃ³rshavn',
#  'franÃ§ois Villon',
#  'north Ossetiaâ\x80\x93Alania',
#  'amÃ©lie',
#  'franÃ§ois Boucher',
#  'mÃ©tis in Canada',
#  'franÃ§ois Arago',
#  'gÃ©rard Depardieu',
#  'sartÃ¨ne',
#  'whatÃ¬',
#  'mise-en-scÃ¨ne',
#  'franÃ§ois Quesnay',
#  'sÃ¡ndor Ferenczi',
#  'ã\x86thelred I, King of Wessex',
#  'transistorâ\x80\x93transistor logic',
#  'embarazada',
#  'le PÃ©tomane',
#  'josÃ© Saramago',
#  'charles Maurice de Talleyrand-PÃ©rigord',
#  'hugo ChÃ¡vez',
#  'tÃºpac Katari Guerrilla Army',
#  'itÅ\x8d Hirobumi',
#  'marÃ\xada FÃ©lix',
#  'wikipedia:Offensive material',
#  'national Association for Research & Therapy of Homosexuality',
#  'daishÅ\x8d',
#  'paris MÃ©tro',
#  'star Wars: Episode I â\x80\x93 The Phantom Menace',
#  'miklÃ³s Horthy',
#  'citroÃ«n',
#  'miloÅ¡ Forman',
#  'buckingham Ï\x80 theorem',
#  'pratt & Whitney',
#  'julius PlÃ¼cker',
#  'cÃ¡diz',
#  'î\x92-lactam antibiotic',
#  'georges-EugÃ¨ne Haussmann',
#  'sautÃ©ing',
#  'jean EugÃ¨ne Robert-Houdin',
#  'stanisÅ\x82aw Wojciechowski',
#  'fordâ\x80\x93Fulkerson algorithm',
#  'ryÅ\x8dji Noyori',
#  'kÃ¼ltepe',
#  'de Broglieâ\x80\x93Bohm theory',
#  'praderâ\x80\x93Willi syndrome',
#  'treaty of NiÅ¡ (1739)',
#  'andrÃ© Breton',
#  'passes of the Silvretta and RÃ¤tikon Ranges',
#  'star Wars: Episode III â\x80\x93 Revenge of the Sith',
#  'humphreyâ\x80\x93Hawkins Full Employment Act',
#  'mannâ\x80\x93Elkins Act',
#  'norrisâ\x80\x93La Guardia Act of 1932',
#  'pelizaeusâ\x80\x93Merzbacher disease',
#  'ã\x8ele de RÃ©',
#  'pÃ©clet number',
#  'jean-FranÃ§ois de Galaup, comte de LapÃ©rouse',
#  'franÃ§ois-NoÃ«l Babeuf',
#  'ã\x89cole Polytechnique massacre',
#  'battle of CrÃ©cy',
#  'sagrada FamÃ\xadlia',
#  'palau GÃ¼ell',
#  'vladimÃ\xadr MeÄ\x8diar',
#  'front de libÃ©ration du QuÃ©bec',
#  'huáº¿',
#  'schrÃ¶dinger equation',
#  'bloc QuÃ©bÃ©cois',
#  'chancellor of Germany (1949â\x80\x93present)',
#  'boxâ\x80\x93Muller transform',
#  'timiÈ\x99oara',
#  'siege of OrlÃ©ans',
#  'bartolomeu de GusmÃ£o',
#  'finistÃ¨re',
#  'wilhelm RÃ¶ntgen',
#  'les MisÃ©rables (1935 film)',
#  'chÃ¢teau',
#  'lozÃ¨re',
#  'irÃ¨ne Joliot-Curie',
#  'organisation armÃ©e secrÃ¨te',
#  'jÃ©rÃ´me Bonaparte',
#  'napolÃ©on, Prince Imperial',
#  'eugÃ©nie de Montijo',
#  'eosinophiliaâ\x80\x93myalgia syndrome',
#  'roberto DurÃ¡n',
#  'jacques-BÃ©nigne Bossuet',
#  'soÄ\x8da',
#  'palantÃ\xadr',
#  'akallabÃªth',
#  'wikipedia:About',
#  'lothlÃ³rien',
#  'moirÃ© pattern',
#  'hÃ¡vamÃ¡l',
#  'mercÃ¨ Rodoreda',
#  'ã\x89dith Piaf',
#  'curaÃ§ao',
#  'democratic Party â\x80\x93 demokraci.pl',
#  'japanese aircraft carrier ShÅ\x8dkaku',
#  'soÄ\x8da Reggae Riversplash',
#  'plankalkÃ¼l',
#  'waterloo & City line',
#  'philip JosÃ© Farmer',
#  'mikimoto KÅ\x8dkichi',
#  'peÃ±Ã³n de VÃ©lez de la Gomera',
#  'tÃºpac Amaru',
#  'viá»\x87t Minh',
#  'ã\x81lava',
#  'lluÃ\xads Companys',
#  'eDE (desktop environment)',
#  'mcCabe & Mrs. Miller',
#  'ã\x86non',
#  'kaldorâ\x80\x93Hicks efficiency',
#  'táº¿t',
#  'brighton & Hove Albion F.C.',
#  'geÊ½ez',
#  'vigenÃ¨re cipher',
#  'castile and LeÃ³n',
#  'stanisÅ\x82awa Walasiewicz',
#  'tÃ¶di',
#  'sÃ©curitÃ©',
#  'ausiÃ\xa0s March',
#  'pa amb tomÃ\xa0quet',
#  'extended Backusâ\x80\x93Naur form',
#  'wikipedia:What is an article?',
#  'andrÃ©s Segovia',
#  'ã\x89cole Polytechnique FÃ©dÃ©rale de Lausanne',
#  'tâ\x80\x93V distinction',
#  'pietÃ\xa0 (Michelangelo)',
#  'osnabrÃ¼ck',
#  'vÄ\x9bra Ä\x8cÃ¡slavskÃ¡',
#  'nadia ComÄ\x83neci',
#  'bielsko-BiaÅ\x82a',
#  'waÅ\x82brzych',
#  'pÅ\x82ock',
#  'castellÃ³n de la Plana',
#  'jeanne SauvÃ©',
#  'biotâ\x80\x93Savart law',
#  'dÅ\x8dgen',
#  'minnesota Democraticâ\x80\x93Farmerâ\x80\x93Labor Party',
#  'jean ChrÃ©tien',
#  'nÃ\xadÃ°hÃ¶ggr',
#  'concepciÃ³n, Chile',
#  'orlÃ©ans',
#  'simona AmÃ¢nar',
#  'chindÅ\x8dgu',
#  'salomÃ© (1923 film)',
#  'wikipedia:Most wanted stubs',
#  'ã\x87',
#  'josÃ© Carioca',
#  'la DÃ©fense',
#  'luÃ\xads de CamÃµes',
#  'atÃ«',
#  "valÃ©ry Giscard d'Estaing",
#  'bouches-du-RhÃ´ne',
#  'alexis ArgÃ¼ello',
#  'list of rock music performers',
#  'matÃ³',
#  'rhÃ´ne (department)',
#  'wilfredo GÃ³mez',
#  "chÃ¢teau d'Amboise",
#  'wilfred BenÃ\xadtez',
#  'suprÃªme NTM',
#  'chÃ¢teau de Chenonceau',
#  'chÃ¢teau de Blois',
#  "chÃ¢teau d'Angers",
#  'heinrich BÃ¶ll',
#  'julio CÃ©sar ChÃ¡vez',
#  'teatro ColÃ³n',
#  'rape, Abuse & Incest National Network',
#  'luis MuÃ±oz MarÃ\xadn International Airport',
#  'danaÃ«',
#  'ã\x89cole centrale de Nantes',
#  'ã\x89cole Centrale Paris',
#  'ernst RÃ¶hm',
#  'chÃ¢teau de Saumur',
#  'copÃ¡n',
#  'beyoncÃ©',
#  'fÃ©lix Trinidad',
#  'wikipedia:Size comparisons',
#  'ã\x86thelbald of Mercia',
#  'salvador SÃ¡nchez',
#  'drÃ´me',
#  'angoulÃªme',
#  'hÃ©rault',
#  'louis-Ferdinand CÃ©line',
#  'aeromÃ©xico',
#  'matarÃ³',
#  'dÄ«s Pater',
#  'timeline of computing 1950â\x80\x931979',
#  'fÃ³dla',
#  'clÃ\xadodhna',
#  'cÅµn Annwn',
#  'scÃ¡thach',
#  'fergus mac RÃ³ich',
#  'gÃ¡e Bulg',
#  'hÃ©ctor Camacho',
#  'coxâ\x80\x93Forbes theory',
#  'besanÃ§on',
#  'adÃ©lie penguin',
#  'carlos MonzÃ³n',
#  'gunnar HÃ¡mundarson',
#  'vÃ¶lsung',
#  'ã\x81rvakr and AlsviÃ°r',
#  'ã\x9erÃºÃ°r',
#  'sÃ¦hrÃ\xadmnir',
#  'heiÃ°rÃºn',
#  'prince of Walesâ\x80\x93Hyder Census Area, Alaska',
#  'auÃ°umbla',
#  'le BÃ©bÃªte Show',
#  'adamari LÃ³pez',
#  'ada VÃ©lez',
#  'popular Front for the Liberation of Palestine â\x80\x93 General Command',
#  'hautes-PyrÃ©nÃ©es',
#  'chÃ¢teau de Chaumont',
#  'chÃ¢teau de Montsoreau',
#  'vÃ\xadctor Jara',
#  'vendÃ©e',
#  "chÃ¢teau d'UssÃ©",
#  'dievturÄ«ba',
#  'chÃ¢teau de Brissac',
#  'chÃ¢teau de Montreuil-Bellay',
#  "chÃ¢teau d'Oiron",
#  'ziemassvÄ\x93tki',
#  'meteÅ\x86i',
#  'appliquÃ©',
#  'cÅ\x8dÄ\x81tlÄ«cue',
#  'coyolxÄ\x81uhqui',
#  'mictlÄ\x81ntÄ\x93cutli',
#  'mictÄ\x93cacihuÄ\x81tl',
#  'xÅ\x8dchipilli',
#  'tlazÅ\x8dlteÅ\x8dtl',
#  'chicomecÅ\x8dÄ\x81tl',
#  'cihuacÅ\x8dÄ\x81tl',
#  'popocatÃ©petl',
#  'puy-de-DÃ´me',
#  'ardÃ¨che',
#  "cÃ´te-d'Or",
#  'niÃ¨vre',
#  'haute-SaÃ´ne',
#  'saÃ´ne-et-Loire',
#  'deux-SÃ¨vres',
#  "cÃ´tes-d'Armor",
#  'kÊ¼awiil',
#  'saint-RÃ©my-de-Provence',
#  'daitÅ\x8d-ryÅ« Aiki-jÅ«jutsu',
#  'milk River (Albertaâ\x80\x93Montana)',
#  'montana State Universityâ\x80\x93Northern',
#  'cÃ©sar Vallejo',
#  'mosinâ\x80\x93Nagant',
#  'solfÃ¨ge',
#  'auahitÅ«roa',
#  'hine-nui-te-pÅ\x8d',
#  'wÄ\x81kea',
#  'jesÃºs GonzÃ¡lez (boxer)',
#  'realencyclopÃ¤die der classischen Altertumswissenschaft',
#  'dauphinÃ©',
#  'coenzyme Q â\x80\x93 cytochrome c reductase',
#  'chÃ¢teau-Thierry',
#  'ironâ\x80\x93sulfur cluster',
#  "gabrielle d'EstrÃ©es",
#  'max OphÃ¼ls',
#  'treaty of LunÃ©ville',
#  'dacian Fortresses of the OrÄ\x83È\x99tie Mountains',
#  'sighiÈ\x99oara',
#  'renÃ© Farrait',
#  'chÃ¢lons-en-Champagne',
#  'ricky MelÃ©ndez',
#  'bertrand DelanoÃ«',
#  'federico GarcÃ\xada Lorca',
#  'á¹\x9ata',
#  'vÃ\xadctor RaÃºl Haya de la Torre',
#  'josemarÃ\xada EscrivÃ¡',
#  'ä\x80tman (Hinduism)',
#  'plonk (Usenet)',
#  'eulerâ\x80\x93Jacobi pseudoprime',
#  'uluá¹\x9fu-Kata Tjuá¹¯a National Park',
#  'rich GarcÃ©s',
#  'ant Broads & Marshes National Nature Reserve',
#  'jacques PrÃ©vert',
#  'hojÅ\x8djutsu',
#  'annika SÃ¶renstam',
#  'xavier SerbiÃ¡',
#  'josÃ© MartÃ\xad International Airport',
#  'university of TromsÃ¸',
#  'nÃ®mes',
#  'royal Space Force: The Wings of HonnÃªamise',
#  'benito JuÃ¡rez',
#  'maâ\x80\x99alpiku Island National Park',
#  'denise QuiÃ±ones',
#  'wildfowl & Wetlands Trust',
#  'salon des RefusÃ©s',
#  'imre KertÃ©sz',
#  'pallars SobirÃ',
#  'pallars JussÃ',
#  'palau de la MÃºsica Catalana',
#  'pedro MontaÃ±ez',
#  'parti QuÃ©bÃ©cois',
#  'roy RossellÃ³',
#  'josÃ© Ferrer',
#  'gÃ¼iro',
#  'empÃºries',
#  'ekerÃ¶ Municipality',
#  'lidingÃ¶ Municipality',
#  'norrtÃ¤lje Municipality',
#  'vÃ¤rmdÃ¶ Municipality',
#  'lidkÃ¶ping Municipality',
#  'skÃ¶vde',
#  'tjÃ¶rn Municipality',
#  'antoni KÄ\x99piÅ\x84ski',
#  'josÃ© Luis RodrÃ\xadguez (singer)',
#  'gÃ¤vle Municipality',
#  'jÃ¤mtland County',
#  'ã\x96stersund Municipality',
#  'jÃ¶nkÃ¶ping Municipality',
#  'luleÃ¥ Municipality',
#  'norrkÃ¶ping Municipality',
#  'sÃ¶derkÃ¶ping Municipality',
#  'vÃ¤rmland County',
#  'ã\x85rjÃ¤ng Municipality',
#  'vÃ¤sterbotten County',
#  'umeÃ¥ Municipality',
#  'vÃ¤nnÃ¤s Municipality',
#  'spanish conquest of YucatÃ¡n',
#  'bÃ¡thory family',
#  'hachette Filipacchi MÃ©dias',
#  'enciclopedia Libre Universal en EspaÃ±ol',
#  'beÅ\x82Å¼ec extermination camp',
#  'history of Baden-WÃ¼rttemberg',
#  'henryk GÃ³recki',
#  'marÃ\xada Celeste ArrarÃ¡s',
#  'josÃ© Ortiz (basketball)',
#  'amberley Museum & Heritage Centre',
#  'jean-FranÃ§ois Oeben',
#  'pedro RossellÃ³',
#  'namu MyÅ\x8dhÅ\x8d Renge KyÅ\x8d',
#  'nicÃ©phore NiÃ©pce',
#  'vatnajÃ¶kull',
#  'langjÃ¶kull',
#  'douÃ©-la-Fontaine',
#  'province of CÃ¡diz',
#  'province of LeÃ³n',
#  'doppelgÃ¤nger',
#  'samsÃ¸',
#  'grÃ¦sted-Gilleleje',
#  'leeâ\x80\x93Enfield',
#  'josÃ© Torres',
#  'north Walsham & Dilham Canal',
#  'wikipedia:Browser notes',
#  'ã\x86thelred of Mercia',
#  'hÃ¸je-Taastrup Municipality',
#  'hjÃ¸rring Municipality',
#  'lÃ¦sÃ¸',
#  'ã\x86thelweard (historian)',
#  'bill & Melinda Gates Foundation',
#  'uK firefighter dispute 2002â\x80\x9303',
#  'kÅ\x8dtoku ShÅ«sui',
#  'icelandic krÃ³na',
#  'ramsÃ¸',
#  'cearbhall Ã\x93 DÃ¡laigh',
#  'seÃ¡n Lemass',
#  'manu GinÃ³bili',
#  'hofsjÃ¶kull',
#  'ernst ZÃ¼ndel',
#  'goiÃ¡s',
#  'ã\x89tienne FranÃ§ois, duc de Choiseul',
#  'shin-Yokohama RÄ\x81men Museum',
#  'uirÅ\x8d',
#  'johan Paulik',
#  'mayagÃ¼ez, Puerto Rico',
#  'lÃ¼neburg',
#  'jean-AndrÃ© Deluc',
#  'abelardo DÃ\xadaz Alfaro',
#  'vitrolles, Bouches-du-RhÃ´ne',
#  'ã\x89douard Lucas',
#  'aleksander KwaÅ\x9bniewski',
#  'agustÃ\xadn de Iturbide',
#  'wilts & Berks Canal',
#  'carlos de LeÃ³n',
#  'josÃ© Celso Barbosa',
#  'sarriÃ\xa0-Sant Gervasi',
#  'charytÃ\xadn Goyco',
#  'ribagorÃ§a',
#  'bertrand BarÃ¨re',
#  'luis MuÃ±oz MarÃ\xadn',
#  'rÆ¡ MÄ\x83m people',
#  'lÄ\x99bork',
#  'southern Ireland (1921â\x80\x9322)',
#  'zamoÅ\x9bÄ\x87',
#  "kÅ\x91nig's lemma",
#  'bÃ©thune',
#  'helgÃ¶',
#  'wolfenbÃ¼ttel',
#  'sacatepÃ©quez Department',
#  'mÃ¼nster',
#  'krzysztof KieÅ\x9blowski',
#  'second DÃ¡il',
#  'prokop DiviÅ¡',
#  'vÃ¤stergÃ¶tland',
#  'wikipedia:Geographic references',
#  'gÃ¶ttingen (district)',
#  'teachta DÃ¡la',
#  'mieczysÅ\x82aw KarÅ\x82owicz',
#  'irene SÃ¡ez',
#  'battle of HÃ¶chstÃ¤dt (1800)',
#  'esteban de JesÃºs',
#  'association des Bibliophiles Universels',
#  'first DÃ¡il',
#  'lutheran Churchâ\x80\x93Missouri Synod',
#  'frankfurtâ\x80\x93Hahn Airport',
#  'biljana PlavÅ¡iÄ\x87',
#  'wikipedia:Chemical infobox',
#  'universitÃ© du QuÃ©bec Ã\xa0 MontrÃ©al',
#  'universitÃ© du QuÃ©bec',
#  'council on Americanâ\x80\x93Islamic Relations',
#  'ä\x80yah',
#  'klaipÄ\x97da',
#  'miloÅ¡ ObiliÄ\x87',
#  'miguel LÃ³pez de Legazpi',
#  'tirion',
#  'angrod',
#  'aegnor',
#  "seÃ¡n T. O'Kelly",
#  'lÃ¡szlÃ³ Papp',
#  'gregorio LuperÃ³n International Airport',
#  'proletÃ¤ren',
#  'ostroÅ\x82Ä\x99ka',
#  'vigdÃ\xads FinnbogadÃ³ttir',
#  'las PiÃ±as',
#  'louis BlÃ©riot',
#  'priceâ\x80\x93earnings ratio',
#  'juan de OÃ±ate',
#  'guillaume BudÃ©',
#  'saint-RÃ©my-Blanzy',
#  "standard & Poor's",
#  'cause cÃ©lÃ¨bre',
#  'lilo & Stitch',
#  'schÃ¶nbrunn Palace',
#  'linkÃ¶ping University',
#  'list of violent incidents in the Israeliâ\x80\x93Palestinian conflict, 2003',
#  'franÃ§ois-RenÃ© de Chateaubriand',
#  'in & Out (film)',
#  'louise LabÃ©',
#  'agedashi dÅ\x8dfu',
#  'fantÃ´mas',
#  'irish Famine (1740â\x80\x9341)',
#  'josÃ© Roman (boxer)',
#  'south Poleâ\x80\x93Aitken basin',
#  'jorge PÃ¡ez',
#  'vÃ©hicule Automatique LÃ©ger',
#  'naÃ¯ve physics',
#  'death of JonBenÃ©t Ramsey',
#  'liepÄ\x81ja',
#  'hÃ¥kan Lans',
#  'luis BuÃ±uel',
#  'mÄ\x81ori language revival',
#  'eugÃ¨ne Delacroix',
#  'murat & Jose',
#  'acadÃ©mie Julian',
#  'lance Cottrell',
#  'raÃ¯',
#  'galÃ¡pagos Islands',
#  'tÄ«tokowaru',
#  'lÃ©opold SÃ©dar Senghor',
#  'foreign relations of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'd. Napier & Son',
#  'zoltÃ¡n KodÃ¡ly',
#  'cayleyâ\x80\x93Hamilton theorem',
#  'law & Order',
#  'thorneâ\x80\x93Å»ytkow object',
#  'katÅ\x8d Takaaki',
#  'wakatsuki ReijirÅ\x8d',
#  'eisaku SatÅ\x8d',
#  'kid GavilÃ¡n',
#  'clintonâ\x80\x93Lewinsky scandal',
#  'raÄ\x8dak massacre',
#  'willy Wonka & the Chocolate Factory',
#  'guillaume Thomas FranÃ§ois Raynal',
#  'mindâ\x80\x93body dualism',
#  'anhÃ©e',
#  'hastiÃ¨re',
#  'jules GrÃ©vy',
#  'luis Ã\x81ngel Firpo',
#  'parkerâ\x80\x93Hulme murder case',
#  'greater Moncton RomÃ©o LeBlanc International Airport',
#  'tommy MuÃ±iz',
#  'fernÃ£o Pires de Andrade',
#  'adamâ\x80\x93God doctrine',
#  'wikipedia:Libel',
#  'special Circumstances',
#  'askÃ¸y',
#  'osterÃ¸y',
#  'gebhard Leberecht von BlÃ¼cher',
#  'vÃ¥gsÃ¸y',
#  'aFLâ\x80\x93CIO',
#  'sandnessjÃ¸en',
#  'franÃ§ois FÃ©nelon',
#  'renÃ©e Vivien',
#  'josÃ© Miguel Agrelot',
#  'tony PÃ©rez',
#  'greisenâ\x80\x93Zatsepinâ\x80\x93Kuzmin limit',
#  'adalberto RodrÃ\xadguez',
#  'gaÃ«tan Dugas',
#  'university of GÃ¶ttingen',
#  'blohm & Voss BV 155',
#  'knasterâ\x80\x93Tarski theorem',
#  'chÃ¢lus',
#  'aimable PÃ©lissier',
#  'bishÅ\x8dnen',
#  'wikipedia:OpenFacts',
#  'tÅ\x8dkai region',
#  'bjÃ¸rnstjerne BjÃ¸rnson',
#  'johnsonâ\x80\x93Nyquist noise',
#  'franÃ§ois Guizot',
#  'wikipedia:Manual of Style/Dates and numbers',
#  'alexandra David-NÃ©el',
#  'c. F. Martin & Company',
#  'list of Canadians of Asian ancestry',
#  'rafael LimÃ³n',
#  'rafael HernÃ¡ndez Airport',
#  'svatba v korÃ¡lovÃ©m moÅ\x99i',
#  'jÅ«kichi Yagi',
#  'shÅ«sei Tokuda',
#  'chÅ«ya Nakahara',
#  'itÅ\x8d Sachio',
#  'motojirÅ\x8d Kajii',
#  'shunrÅ\x8d Oshikawa',
#  'hiraide ShÅ«',
#  'ozaki KÅ\x8dyÅ\x8d',
#  'nickelâ\x80\x93cadmium battery',
#  'vendÃ´me',
#  'alfrÃ©d HajÃ³s',
#  'clube AtlÃ©tico Mineiro',
#  'konjaku MonogatarishÅ«',
#  'hakushÅ« Kitahara',
#  'kernavÄ\x97',
#  'ramÃ³n Arellano FÃ©lix',
#  'juan SebastiÃ¡n Elcano',
#  'emperor NinkÅ\x8d',
#  'emperor KÅ\x8dkaku',
#  "l'Ã\x8ele-Dorval",
#  'george-Ã\x89tienne Cartier',
#  'henri CoandÄ\x83',
#  'ã\x93engus II',
#  'causantÃ\xadn mac Fergusa',
#  'rigoberta MenchÃº',
#  'coandÄ\x83 effect',
#  'erich von DÃ¤niken',
#  'otto HÃ¶lder',
#  'memÃ\xadn PinguÃ\xadn',
#  'komura JutarÅ\x8d',
#  'martin NiemÃ¶ller',
#  'wikipedia:Article size',
#  'domangart RÃ©ti',
#  'fergus MÃ³r',
#  'å\x9awinoujÅ\x9bcie',
#  'sÅ\x8dtÅ\x8d',
#  'jayâ\x80\x93Gardoqui Treaty',
#  'de LÃ´me Letter',
#  'clÃ©ment Ader',
#  'robert Livingston (1708â\x80\x931790)',
#  'drÃ¸bak',
#  'goran IvaniÅ¡eviÄ\x87',
#  'marcos PÃ©rez JimÃ©nez',
#  'shunryÅ« Suzuki',
#  'emperor Go-YÅ\x8dzei',
#  'emperor ShijÅ\x8d',
#  'emperor ChÅ«kyÅ\x8d',
#  'emperor RokujÅ\x8d',
#  'wikipedia:List of bibliographies',
#  'adolfo PÃ©rez Esquivel',
#  'la GÃ¼era',
#  'acadÃ©mie royale de peinture et de sculpture',
#  'purÃ©pecha',
#  'michoacÃ¡n',
#  'josÃ© Clemente Orozco',
#  'jÃ©rÃ´me Lalande',
#  'jean-Marie Roland de la PlatiÃ¨re',
#  'constantin FranÃ§ois de ChassebÅ\x93uf, comte de Volney',
#  'yusuf AkÃ§ura',
#  'alfons KarpiÅ\x84ski',
#  'jerzy RÃ³Å¼ycki',
#  'chÅ«goku region',
#  'å\x92',
#  'ã\x9f',
#  "ngÅ©gÄ© wa Thiong'o",
#  'aosdÃ¡na',
#  'rhÃ´ne-Alpes',
#  'spanish aircraft carrier PrÃ\xadncipe de Asturias',
#  'viesÄ«te',
#  'bibliothÃ¨que nationale de France',
#  'pia KjÃ¦rsgaard',
#  'louis Christophe FranÃ§ois Hachette',
#  'joseph de VillÃ¨le',
#  'emmanuel Joseph SieyÃ¨s',
#  'bÃ©zier triangle',
#  'franÃ§ois Tombalbaye',
#  'marie-Joseph AngÃ©lique',
#  'ã\x89liphas LÃ©vi',
#  "chÃ¢teau d'If",
#  'kantÅ\x8d region',
#  'josÃ© de Acosta',
#  'kumÄ\x81rajÄ«va',
#  'alejandro GonzÃ¡lez MalavÃ©',
#  'å\x9aÅ«nyatÄ\x81',
#  'kanÅ\x8d Eitoku',
#  'hDMS SÃ¦len (S323)',
#  'chÃ¢teau de Coucy',
#  'galdhÃ¸piggen',
#  'composite BÃ©zier curve',
#  'limba noastrÄ\x83',
#  'orlÃ©anist',
#  'tÅ\x8dhoku region',
#  'lÃ©on Gambetta',
#  'coupÃ©',
#  'ferenc PuskÃ¡s',
#  'austral LÃ\xadneas AÃ©reas',
#  'sibleyâ\x80\x93Ahlquist taxonomy of birds',
#  "bahÃ¡'Ã\xad calendar",
#  'h&M',
#  'gÃ¶teborgs-Posten',
#  'cangaÃ§o',
#  'luÃ\xads Carlos Prestes',
#  'saguenayâ\x80\x93St. Lawrence Marine Park',
#  'josÃ© Feliciano',
#  'isabel MartÃ\xadnez de PerÃ³n',
#  'tigrisâ\x80\x93Euphrates river system',
#  'jacques Marie EugÃ¨ne Godefroy Cavaignac',
#  'ã\x86lfweard of Wessex',
#  'fideuÃ',
#  'sanzÅ\x8d Nosaka',
#  'germaine de StaÃ«l',
#  "canon d'Infanterie de 37 modÃ¨le 1916 TRP",
#  'ã\x9c',
#  'sDPâ\x80\x93Liberal Alliance',
#  'lÃ¡zaro CÃ¡rdenas',
#  'pÃ©cs',
#  '7.5 cm leichtes InfanteriegeschÃ¼tz 18',
#  'pierre Claude FranÃ§ois Daunou',
#  'barthÃ©lemy Prosper Enfantin',
#  'eugÃ¨ne Burnouf',
#  '7.5 cm InfanteriegeschÃ¼tz 37',
#  'agnetha FÃ¤ltskog',
#  'pedro de ArbuÃ©s',
#  'montbÃ©liard',
#  'nord-du-QuÃ©bec',
#  'wikipedia:Orphan',
#  'list of people known as "the Great"',
#  'cataÃ±o, Puerto Rico',
#  'lucecita BenÃ\xadtez',
#  'ertuÄ\x9frul',
#  'zoÃ« Porphyrogenita',
#  'luleÃ¥ University of Technology',
#  'the Institute of Technology at LinkÃ¶ping University',
#  'mÃ¤lardalen University College',
#  'sÃ¶dertÃ¶rn University',
#  'history of Sweden (800â\x80\x931521)',
#  'history of Sweden (1611â\x80\x9348)',
#  'ngÃ´ Ä\x90Ã¬nh Thá»¥c',
#  'byÅ\x8ddÅ\x8d-in',
#  'battle of KÃ¶niggrÃ¤tz',
#  'eugen BÃ¶hm von Bawerk',
#  'antonio Rivera RodrÃ\xadguez Airport',
#  'lÃ¼ Dongbin',
#  'ivÃ¡n CalderÃ³n (boxer)',
#  'niccolÃ² Piccinni',
#  'pierre-Louis GinguenÃ©',
#  'mjÃ¶lnir',
#  'josÃ© Cecilio del Valle',
#  'calixa LavallÃ©e',
#  'nuevo LeÃ³n',
#  'ramÃ³n Luis Rivera',
#  'nicolÃ¡s GuillÃ©n',
#  'christiane NÃ¼sslein-Volhard',
#  'josÃ© Luis RamÃ\xadrez',
#  'bernâ\x80\x93LÃ¶tschbergâ\x80\x93Simplon railway',
#  'wikipedia:WikiLove',
#  'san FermÃ\xadn',
#  'ferrocarril de SÃ³ller',
#  'timeline of preâ\x80\x93United States history',
#  'bronisÅ\x82aw Malinowski',
#  'romÃ©o LeBlanc',
#  'the HaÃ§ienda',
#  'rTÃ\x892',
#  'sÃ¼dliche WeinstraÃ\x9fe',
#  'gabriel Dumont (MÃ©tis leader)',
#  'ã\x89tude',
#  'vipÄ\x81ka',
#  'coat of arms of Ã\x96land',
#  'emperor Å\x8cgimachi',
#  'paranÃ¡ (state)',
#  'sÃ£o Paulo (state)',
#  'amapÃ¡',
#  'cearÃ¡',
#  'parÃ¡',
#  'paraÃ\xadba',
#  'mouvement RÃ©formateur',
#  'cinÃ©ma vÃ©ritÃ©',
#  'akraâ\x80\x93Bazzi method',
#  'josÃ© NÃ¡poles',
#  'dom PÃ©rignon (monk)',
#  'pÅ\x99emysl the Ploughman',
#  'index of Korea-related articles',
#  'george of PodÄ\x9bbrady',
#  'kermit CintrÃ³n',
#  'kÅ\x8dbe Station',
#  'neuilly-la-ForÃªt',
#  'history of the Ã\x85land Islands',
#  'polytechnique MontrÃ©al',
#  'norteÃ±os',
#  'ã\x89leuthÃ¨re IrÃ©nÃ©e du Pont',
#  'schrÃ¤ge Musik',
#  'calciumâ\x80\x93aluminium-rich inclusion',
#  'newtonâ\x80\x93Cotes formulas',
#  'museo Nacional Centro de Arte Reina SofÃ\xada',
#  'tol EressÃ«a',
#  'acilia (gens)',
#  'les MisÃ©rables (musical)',
#  "duÅ¡an's Code",
#  'domrÃ©my-la-Pucelle',
#  'amÃ©lie Mauresmo',
#  'stanfordâ\x80\x93Binet Intelligence Scales',
#  'viÄ¼Ä\x81ni',
#  'rÃ³bert BÃ¡rÃ¡ny',
#  'dNAâ\x80\x93DNA hybridization',
#  'cÃ³rdoba, Argentina',
#  'avalokiteÅ\x9bvara',
#  'dievs, svÄ\x93tÄ« Latviju!',
#  'jean-FranÃ§ois Lyotard',
#  'å\x81omÅ¼a',
#  'hana MandlÃ\xadkovÃ¡',
#  'beinecke Rare Book & Manuscript Library',
#  'physical information',
#  'ã\x81lvaro Uribe',
#  'gÃ¼nter Blobel',
#  "wikipedia:Modelling Wikipedia's growth",
#  'tullia (gens)',
#  'hradec KrÃ¡lovÃ©',
#  'gavia (gens)',
#  'philadelphia Wings (1987â\x80\x932014)',
#  'josÃ© Cuevas (boxer)',
#  'pedro Ã\x81lvares Cabral',
#  'eÃ¶l',
#  'romÃ¡n Baldorioty de Castro',
#  'æ\x91',
#  'glasses fetishism',
#  'duchy of Brunswick-LÃ¼neburg',
#  'ã\x82',
#  'ã\x89',
#  'ã\x8b',
#  'ã\x8f',
#  'ã\x93',
#  'christian BÃ¶k',
#  'copa AmÃ©rica',
#  'odalys GarcÃ\xada',
#  'peÃ±uelas, Puerto Rico',
#  'stefan UroÅ¡ V',
#  'toÃ±o Bicicleta',
#  'freeloading',
#  'marc-Vivien FoÃ©',
#  'jÃ¤ger Movement',
#  'mount PelÃ©e',
#  'tropicÃ¡lia',
#  'ramÃ³n Ramos',
#  'santiago RamÃ³n y Cajal',
#  'ilha de ItamaracÃ¡',
#  'wikipedia:Manual of Style/Images',
#  'å¬',
#  'jyvÃ¤skylÃ¤',
#  'university of JyvÃ¤skylÃ¤',
#  'rÃ©jean Ducharme',
#  'st. Marys River (Michiganâ\x80\x93Ontario)',
#  "hon'inbÅ\x8d",
#  'la FertÃ©-Alais',
#  'treaty of BrÃ©tigny',
#  'shÅ\x8dwa period',
#  'joaquÃ\xadn Crespo',
#  'juan Vicente GÃ³mez',
#  'sunshine LogroÃ±o',
#  'ä°skenderun',
#  'ignÃ¡c Goldziher',
#  'octave CrÃ©mazie',
#  'university of TÃ¼bingen',
#  'riviÃ¨re des Mille Ã\x8eles',
#  'anadoluhisarÄ±',
#  'troutonâ\x80\x93Noble experiment',
#  'rarÃ¡muri',
#  'rebellions of 1837â\x80\x931838',
#  'nÃ¡jera',
#  'rÃ\xado Muni',
#  'josef Ä\x8capek',
#  'lÃ©ognan',
#  'list of villages depopulated during the Arabâ\x80\x93Israeli conflict',
#  "pÃ¨re David's deer",
#  'lÃ¼ Meng',
#  'y-Î\x94 transform',
#  'botoÈ\x99ani County',
#  'galaÈ\x9bi County',
#  'timiÈ\x99 County',
#  'st. Peteâ\x80\x93Clearwater International Airport',
#  'reninâ\x80\x93angiotensin system',
#  'chaordic organization',
#  'roberto CofresÃ\xad',
#  'josÃ© Padilla (prisoner)',
#  'efraÃ\xadn RÃ\xados Montt',
#  'flores, El PetÃ©n',
#  'leÃ³n, Nicaragua',
#  'citroÃ«n Berlingo',
#  'felipe GonzÃ¡lez',
#  'manuel AzaÃ±a',
#  'dolores IbÃ¡rruri',
#  'weberâ\x80\x93Fechner law',
#  'carlos Morocho HernÃ¡ndez',
#  'antÃ´nio Rodrigo Nogueira',
#  'davÃ\xadÃ° Oddsson',
#  'schÃ¶n scandal',
#  'ã\x93Ã°r',
#  'dendermondeâ\x80\x93Puurs Steam Railway',
#  'humberto GonzÃ¡lez',
#  'french frigate MÃ©duse (1810)',
#  'etiÃ¤inen',
#  'mcCuneâ\x80\x93Reischauer',
#  'provenÃ§al dialect',
#  'baÄ\x8dka Palanka',
#  'beÄ\x8dej',
#  'ä\x8caÄ\x8dak',
#  'ä\x86uprija',
#  'inÄ\x91ija',
#  'kruÅ¡evac',
#  'peÄ\x87',
#  'poÅ¾arevac',
#  'zajeÄ\x8dar',
#  'ã\x96land',
#  'bÃ©zier surface',
#  'hÃ©lÃ¨ne Dutrieu',
#  'spokeâ\x80\x93hub distribution paradigm',
#  'zbigniew RybczyÅ\x84ski',
#  'josÃ© Fernando de Abascal y Sousa',
#  'black & White Records',
#  'radio y TelevisiÃ³n MartÃ\xad',
#  'henri CoandÄ\x83 International Airport',
#  'gaston, Duke of OrlÃ©ans',
#  'georges de ScudÃ©ry',
#  "shin'ichirÅ\x8d Tomonaga",
#  ...]

# %% [markdown]
# ## Wikipedia-500K

# %%
data_path = f"{data_dir}/Wikipedia-500K/"

train_path = f"{data_path}/trn.raw.json"
test_path = f"{data_path}/tst.raw.json"

# %%
same_titles, diff_titles = [], []

separate_titles(same_titles, diff_titles, train_path)
separate_titles(same_titles, diff_titles, test_path)

# %%
len(same_titles), len(diff_titles), len(same_titles)+len(diff_titles)
# Out:
# (2034155, 562979, 2597134)

# %%
total_pages = len(same_titles)+len(diff_titles)
print(f"Number of similar pages : {len(same_titles)} ({100.*len(same_titles)/total_pages:.4f}%)")
print(f"Number of different pages : {len(diff_titles)} ({100.*len(diff_titles)/total_pages:.4f}%)")
# Out:
# Number of similar pages : 2034155 (78.3231%)
# Number of different pages : 562979 (21.6769%)

# %%
diff_titles
# Out:
# ['asociaciÃ³n Alumni',
#  'abdul Alhazred',
#  'the Plague',
#  'ancient Pueblo peoples',
#  "all Souls\\' Day",
#  'andrÃ© Gide',
#  'royal Antigua and Barbuda Defence Force',
#  'alfonso CuarÃ³n',
#  'list of Governors of Alabama',
#  'aromatic hydrocarbon',
#  'annales School',
#  'casa BatllÃ³',
#  'park GÃ¼ell',
#  'casa MilÃ',
#  'apache Software Foundation',
#  'atanasoffâ\x80\x93Berry computer',
#  'andrÃ©-Marie AmpÃ¨re',
#  'abbotsford House',
#  'nYSE MKT',
#  "dodo (Alice\\'s Adventures in Wonderland)",
#  'alexander Emanuel Agassiz',
#  'ajax (mythology)',
#  'alexander Severus',
#  'alhazen',
#  'amara Sinha',
#  'alfonso XII of Spain',
#  'alphonsus a Sancta Maria',
#  'st. Ambrose Traversari',
#  'ananda',
#  'andrÃ© de Longjumeau',
#  'ã\x86gir',
#  'antibiotics',
#  'amalric I of Jerusalem',
#  'amalric II of Jerusalem',
#  'antibiotic resistance',
#  'adobe Systems',
#  'anne BrontÃ«',
#  'ã\x81satrÃº in the United States',
#  'ã\x86lfheah of Canterbury',
#  'list of animated television series',
#  'african American',
#  'cuisine of the United States',
#  "sid Meier\\'s Alpha Centauri",
#  'ã\x86lle of Sussex',
#  'list of Anglo-Saxon monarchs and kingdoms',
#  'american Media (publisher)',
#  'aramaic language',
#  "amdahl\\'s law",
#  'anointing of the Sick',
#  "ardal O\\'Hanlon",
#  'albrecht DÃ¼rer',
#  'minute of arc',
#  'adenylate cyclase',
#  'arapawa Island',
#  'andrÃ© the Giant',
#  "antoine Thomson d\\'Abbadie",
#  'aegean civilizations',
#  'abba Arika',
#  'abd al-Latif al-Baghdadi (medieval writer)',
#  'abd ar-Rahman II',
#  'abd ar-Rahman V',
#  'community acquis',
#  'ã\x81ed mac CinÃ¡eda',
#  'aberration of light',
#  'allene',
#  'andreas SchlÃ¼ter',
#  'anaÃ¯s Nin',
#  'anabaptists',
#  'alaska Interior',
#  "`Abdu\\'l-BahÃ¡",
#  'alcobaÃ§a, Portugal',
#  'islamic conquest of Afghanistan',
#  'arithmeticâ\x80\x93geometric mean',
#  'amiga 500 Plus',
#  'beavis and Butt-head',
#  'blindness',
#  'blindness in literature',
#  'military of Bulgaria',
#  'books of the Bible',
#  'list of Major League Baseball players with 4,000 total bases',
#  'bilge Khagan',
#  'lists of people',
#  'british and Irish Lions',
#  "banca d\\'Italia",
#  'bifrÃ¶st',
#  'brÃ\xadsingamen',
#  'borsukâ\x80\x93Ulam theorem',
#  'beast of Bodmin',
#  'boÃ¶tes',
#  'order of Saint Benedict',
#  'bollywood',
#  'big Brother (TV series)',
#  'bishopric of Brandenburg',
#  'boseâ\x80\x93Einstein condensate',
#  'beerâ\x80\x93Lambert law',
#  'bÃ©la BartÃ³k',
#  'baku (spirit)',
#  'blue Ã\x96yster Cult',
#  'political scandals in the United Kingdom',
#  'bÃ©zier curve',
#  'bunge y Born',
#  "bernoulli\\'s inequality",
#  'blu-Tack',
#  'ballad of the Green Berets',
#  'barÄ±Å\x9f ManÃ§o',
#  "bÃ©zout\\'s identity",
#  'born again (Christianity)',
#  'boer',
#  'bathyscaphe Trieste',
#  'bjÃ¸rn Lomborg',
#  'cold War (1947â\x80\x9353)',
#  'military of Costa Rica',
#  'military of Croatia',
#  'list of centuries',
#  "clarke\\'s three laws",
#  'ã\x87atalhÃ¶yÃ¼k',
#  'military of the Czech Republic',
#  'history of Comoros',
#  'demographics of Comoros',
#  'cathode ray tube',
#  'crash (J. G. Ballard novel)',
#  'chardonnay socialist',
#  'chojnÃ³w',
#  'wu Xing',
#  'clientâ\x80\x93server model',
#  'czesÅ\x82aw MiÅ\x82osz',
#  'conectiva',
#  'ciconiiformes',
#  'list of confederations of Germanic tribes',
#  'october 2003',
#  'mail (armour)',
#  'camelCase',
#  'companies law',
#  'comet Shoemakerâ\x80\x93Levy 9',
#  'constantine Kanaris',
#  'cultural production and nationalism',
#  'cRESU experiment',
#  'churchâ\x80\x93Turing thesis',
#  'cyborgs in fiction',
#  'a.C. Chievo Verona',
#  'rod (optics)',
#  'jean-Baptiste-SimÃ©on Chardin',
#  'chlamydia infection',
#  'code division multiple access',
#  'communist Party of China',
#  "charles d\\'Abancour",
#  'comet Haleâ\x80\x93Bopp',
#  'causantÃ\xadn mac CinÃ¡eda',
#  'coral 66',
#  'centimetreâ\x80\x93gramâ\x80\x93second system of units',
#  'clark Kent',
#  'cuauhtÃ©moc',
#  'centillion',
#  'centrifugal force (rotating reference frame)',
#  'comic fantasy',
#  'cauchyâ\x80\x93Riemann equations',
#  'cuba Libre',
#  'history of the term \\"Catholic\\"',
#  'comparative method (linguistics)',
#  'coriolis effect',
#  'common chimpanzee',
#  'charcotâ\x80\x93Marieâ\x80\x93Tooth disease',
#  'diffieâ\x80\x93Hellman key exchange',
#  'dungeons & Dragons',
#  'military of the Democratic Republic of the Congo',
#  'deutsches Institut fÃ¼r Normung',
#  'daugava River',
#  'list of decades',
#  'drama film',
#  'diogo CÃ£o',
#  'garbage picking',
#  'declarative memory',
#  'house of della Rovere',
#  'dartmoor wildlife',
#  'daoismâ\x80\x93Taoism romanization issue',
#  'ducati',
#  'digital Enhanced Cordless Telecommunications',
#  'diet of Nuremberg',
#  'dukkha',
#  "director\\'s cut",
#  "darwin\\'s Dangerous Idea",
#  'domnall mac AilpÃ\xadn',
#  'dÃ©jÃ\xa0 vu',
#  'dASS2',
#  'danceWriting',
#  'list of deities',
#  'dachau',
#  'catan: Cities & Knights',
#  'dave Thomas (businessperson)',
#  'ecuadorian people',
#  'military of Equatorial Guinea',
#  'helsingÃ¸r',
#  'encyclopÃ¦dia Britannica',
#  "euler\\'s formula",
#  'english country dance',
#  'eulerâ\x80\x93Maclaurin formula',
#  'eugÃ¨ne Viollet-le-Duc',
#  "euler\\'s sum of powers conjecture",
#  'episcopi vagantes',
#  'ecuadorâ\x80\x93United States relations',
#  'list of recently extinct birds',
#  'erdÅ\x91s number',
#  'exabyte',
#  'extra-vehicular activity',
#  'ã\x89variste Galois',
#  'elblÄ\x85g',
#  "european People\\'s Party (European Parliament group)",
#  'explorers program',
#  'european Company Regulation',
#  'ã\x86thelberht of Kent',
#  'erwin SchrÃ¶dinger',
#  'louise Ã\x89lisabeth VigÃ©e Le Brun',
#  'elliptic curve cryptography',
#  'eightfold Path (policy analysis)',
#  'timeline of evolutionary history of life',
#  'hP Enterprise Services',
#  'ã\x86thelred the Unready',
#  'east Caribbean dollar',
#  'esotericism',
#  'emperor ShÅ\x8dmu',
#  'elizabeth I of England',
#  'desiderius Erasmus',
#  'enhanced Data Rates for GSM Evolution',
#  'edward VI of England',
#  'epinephrine',
#  'electronic Delay Storage Automatic Calculator',
#  'orthodox Church organization',
#  'emin Boztepe',
#  'evliya Ã\x87elebi',
#  'pre-Islamic period of Afghanistan',
#  'the Elephant 6 Recording Company',
#  'emperor YÅ\x8dmei',
#  'empress JitÅ\x8d',
#  'empress GenshÅ\x8d',
#  'empress KÅ\x8dken',
#  'emperor Go-KÅ\x8dgon',
#  'emperor KÅ\x8dan',
#  'emperor KÅ\x8dgen',
#  'emperor ChÅ«ai',
#  'emperor Å\x8cjin',
#  'emperor RichÅ«',
#  'emperor IngyÅ\x8d',
#  'emperor AnkÅ\x8d',
#  'emperor KenzÅ\x8d',
#  'emperor YÅ\x8dzei',
#  'emperor KÅ\x8dkÅ\x8d',
#  'exile (video game series)',
#  'el NiÃ±o',
#  'flying disc',
#  'franÃ§ois Truffaut',
#  'flying car (aircraft)',
#  'friedrich WÃ¶hler',
#  'francophone',
#  'frÃ©dÃ©ric Chopin',
#  'plurality voting system',
#  "finagle\\'s law",
#  'melbourne Grand Prix Circuit',
#  "franÃ§ois d\\'Aguilon",
#  'francisco Ã\x81lvares',
#  'fÃ©lix Guattari',
#  'frÃ©dÃ©ric Bastiat',
#  'floccinaucinihilipilification',
#  "foster\\'s Lager",
#  'snap (American and Canadian football)',
#  'fabius Maximus',
#  'fiorello H. La Guardia',
#  'frÃ©dÃ©ric Bazille',
#  'fort William, Scotland',
#  'list of French expressions in English',
#  'fianna FÃ¡il',
#  'list of fictional guidebooks',
#  'fyodor Dostoyevsky',
#  'functional theories of grammar',
#  'fricative consonant',
#  'list of Greek words with English derivatives',
#  'military of Gabon',
#  'foreign relations of Georgia',
#  'gdaÅ\x84sk',
#  'gÃ¶ta Canal',
#  'gÃ¶ta Ã¤lv',
#  'military of Guatemala',
#  'gÃ¶ktÃ¼rks',
#  'goran BregoviÄ\x87',
#  'geography of Guadeloupe',
#  'politics of Guadeloupe',
#  'glagolitic alphabet',
#  "gÃ¶del\\'s ontological proof",
#  "gÃ¶del\\'s completeness theorem",
#  'gil Ã\x81lvarez Carrillo de Albornoz',
#  'cisâ\x80\x93trans isomerism',
#  'grÃ\xadmnismÃ¡l',
#  'german-style board game',
#  'gracchi',
#  "godwin\\'s law",
#  'graphics Interchange Format',
#  "original proof of GÃ¶del\\'s completeness theorem",
#  'gilbert Arthur Ã\xa0 Beckett',
#  'global-warming potential',
#  'game com',
#  'george PÃ³lya',
#  '-gry',
#  'lGBT social movements',
#  'gaspard-Gustave Coriolis',
#  'gÃ©za, Grand Prince of the Hungarians',
#  'list of historical anniversaries',
#  'military of Honduras',
#  'military of Hong Kong',
#  'hungarian Defence Force',
#  'list of historical period drama films',
#  'hermann GÃ¶ring',
#  'hTTP Secure',
#  'hel (being)',
#  'hindu',
#  'history of Microsoft Windows',
#  'hero Wars',
#  'harry Connick, Jr.',
#  'hebrew grammar',
#  'hahnâ\x80\x93Banach theorem',
#  'list of kings of Persia',
#  'h. J. Heinz Company',
#  'halldÃ³r Laxness',
#  'hersheyâ\x80\x93Chase experiment',
#  'history of religions',
#  'hopwood Program',
#  'helene KrÃ¶ller-MÃ¼ller',
#  'outline of healthcare science',
#  'hernÃ¡n CortÃ©s',
#  'house of Cards (UK TV series)',
#  'halfbakery',
#  'henry the Navigator',
#  'hÃ¶Ã°r',
#  'hazara people',
#  'henry VIII of England',
#  'hairpin (fashion)',
#  "horner\\'s method",
#  'hussite',
#  'hOTOL',
#  'hearst Corporation',
#  'huygensâ\x80\x93Fresnel principle',
#  'hydroxyl',
#  'hasidim',
#  'harold Eugene Edgerton',
#  'ä°smet Ä°nÃ¶nÃ¼',
#  'xChat',
#  'identity and change',
#  'iranâ\x80\x93Contra affair',
#  'public international law',
#  'iranâ\x80\x93Iraq War',
#  'intensive insulinotherapy',
#  'interwiki links',
#  'international Tropical Timber Agreement, 1983',
#  'international Tropical Timber Agreement, 1994',
#  'internet humor',
#  'intel 80486',
#  'iSM band',
#  'integrated NATO Air Defense System',
#  "isabella d\\'Este",
#  'iSO 6166',
#  'intoxicative inhalant',
#  'iceman (comics)',
#  'compounds of carbon',
#  'list of airports',
#  'simonâ\x80\x93Ehrlich wager',
#  'demographics of Jersey',
#  'john Lynch (New Hampshire)',
#  'judah the Prince',
#  'judit PolgÃ¡r',
#  'jÃ¶tunheimr',
#  'jean-Jacques AmpÃ¨re',
#  'gyula AndrÃ¡ssy',
#  'jutland Peninsula',
#  'john Brunner (novelist)',
#  'john James Rickard Macleod',
#  'juan FernÃ¡ndez Islands',
#  'jÃ¼rgen Habermas',
#  'joachim III Frederick, Elector of Brandenburg',
#  'jean-FranÃ§ois Millet',
#  'james Tiptree, Jr.',
#  'james Tiptree, Jr. Award',
#  'jokichi Takamine',
#  'johannes Nicolaus BrÃ¸nsted',
#  'joseph Lister, 1st Baron Lister',
#  'military of Kuwait',
#  'kolmogorovâ\x80\x93Smirnov test',
#  "kuiper\\'s test",
#  'kult',
#  'keplerâ\x80\x93Poinsot polyhedron',
#  'krakÃ³w',
#  'kitÃ¡b-i-Aqdas',
#  'kÅ\x8dan',
#  'karl Benz',
#  'kolmogorovâ\x80\x93Arnoldâ\x80\x93Moser theorem',
#  'kennellyâ\x80\x93Heaviside layer',
#  'kelloggâ\x80\x93Briand Pact',
#  'kansasâ\x80\x93Nebraska Act',
#  'karel Hynek MÃ¡cha',
#  'kaluzaâ\x80\x93Klein theory',
#  'hash-based message authentication code',
#  'korn shell',
#  'keflavÃ\xadk',
#  'karl BÃ¶ttiger',
#  'constantin Stanislavski',
#  'alpha-Ketoglutaric acid',
#  "king\\'s Royal Rifle Corps",
#  'calligra Suite',
#  'koÅ\x82obrzeg',
#  'kÃ¼nstlerroman',
#  'letter game',
#  'melissa officinalis',
#  'west Low German',
#  "lao People\\'s Armed Forces",
#  'military of Latvia',
#  'telecommunications in Lebanon',
#  'communications in Liberia',
#  'luxembourg Army',
#  'lagÃ¢ri Hasan Ã\x87elebi',
#  "monty Python\\'s Life of Brian",
#  'lomography',
#  'lucasArts',
#  'latin spelling and pronunciation',
#  "land\\'s End",
#  'lettre de cachet',
#  'list of political parties named \\"Labour Party\\" or similar',
#  'la TÃ¨ne culture',
#  'loa',
#  'relative direction',
#  'leRoy Homer, Jr.',
#  'libro de los juegos',
#  'lyon & Healy',
#  'list of facilities named after Lyndon Johnson',
#  'luxembourgish language',
#  'lens (optics)',
#  'li people',
#  'laocoÃ¶n',
#  'laparoscopic surgery',
#  "lord\\'s Prayer",
#  "l\\'HÃ´pital\\'s rule",
#  'louis XIV of France',
#  'ludwig Ritter von KÃ¶chel',
#  'lÃ©on Theremin',
#  'lincos (artificial language)',
#  "lorenzo de\\' Medici",
#  'loya jirga',
#  'live-bearing aquarium fish',
#  'list of food additives, Codex Alimentarius',
#  'list of male tennis players',
#  'manufacturing Consent: Noam Chomsky and the Media',
#  'mÃ¤laren',
#  'politics of the Republic of Macedonia',
#  'economy of the Republic of Macedonia',
#  'army of the Republic of Macedonia',
#  'foreign relations of the Republic of Macedonia',
#  'demographics of the Maldives',
#  'military of Mauritius',
#  'military of Moldova',
#  'military of Mozambique',
#  'moÄ\x9follar',
#  'mandrake (plant)',
#  'monkey Island (series)',
#  'michael Mann (director)',
#  'mythology',
#  'metrization theorem',
#  'magick (Thelema)',
#  'marcus Claudius Tacitus',
#  'maxwellâ\x80\x93Boltzmann distribution',
#  'maraÃ±Ã³n River',
#  'maciej PÅ\x82aÅ¼yÅ\x84ski',
#  'martin Luther King, Jr.',
#  'mIPS instruction set',
#  'mOO (programming language)',
#  'afghan Armed Forces',
#  'freescale 68HC11',
#  'the MorrÃ\xadgan',
#  'politics of Burma',
#  'economy of Burma',
#  'telecommunications in Burma',
#  'transport in Burma',
#  'motion (physics)',
#  "man\\'yÅ\x8dshÅ«",
#  'oS X',
#  'martin WaldseemÃ¼ller',
#  'mercalli intensity scale',
#  'rovi Corporation',
#  "m\\'Naghten rules",
#  'menorah (Temple)',
#  'mennonite',
#  'mentat',
#  'mithraic mysteries',
#  'maritime prepositioning ship',
#  'motÃ¶rhead',
#  'mind control',
#  'molotovâ\x80\x93Ribbentrop Pact',
#  'mÃ¶bius function',
#  'marxismâ\x80\x93Leninism',
#  'province of Massa and Carrara',
#  'constructivism (mathematics)',
#  'nupeCode',
#  'armed forces of the Netherlands',
#  'nez Perce people',
#  'nights into Dreams...',
#  "korean People\\'s Army",
#  'namibia Defence Force',
#  'military of Nicaragua',
#  'niccolÃ² Paganini',
#  'njÃ¶rÃ°r',
#  'nicolas Louis de Lacaille',
#  'nucleariid',
#  'modern paganism',
#  'lGBT topics and Wicca',
#  'non-fiction',
#  "ninon de l\\'Enclos",
#  'narrow gauge railway',
#  'non-deterministic Turing machine',
#  'n ray',
#  'non-steroidal anti-inflammatory drug',
#  'netwar',
#  "newton\\'s method",
#  'open content',
#  'objectivism (Ayn Rand)',
#  'old Turkic alphabet',
#  'ole RÃ¸mer',
#  'owain GlyndÅµr',
#  'magnavox OdysseyÂ²',
#  'object modeling language',
#  'ã\x96tzi',
#  'occidental language',
#  'old Fashioned',
#  'ordinary language',
#  'ovo-lacto vegetarianism',
#  'public Enemy (group)',
#  'paul Cohen (mathematician)',
#  'penÃ©lope Cruz',
#  'poker equipment',
#  'wild card (card games)',
#  'dead money (poker)',
#  "omaha hold \\'em",
#  'paul HÃ©roult',
#  'point of view shot',
#  'patrick Rafter',
#  'pattersonâ\x80\x93Gimlin film',
#  'paul ValÃ©ry',
#  'platonic idealism',
#  "there\\'s Plenty of Room at the Bottom",
#  'periodic table (large cells)',
#  'poznaÅ\x84',
#  'pokÃ©mon',
#  'panarchism',
#  'poincarÃ© conjecture',
#  'list of PokÃ©mon',
#  'phoenix (TV series)',
#  'polyhedral compound',
#  "the Night\\'s Dawn Trilogy",
#  'portable Document Format',
#  'puritan',
#  'religious affiliations of Presidents of the United States',
#  'piper (genus)',
#  'parousia',
#  'paul CÃ©zanne',
#  'pÄ\x81ramitÄ\x81',
#  'peter Principle',
#  'tax per head',
#  'autosomal dominant polycystic kidney',
#  'pedro MartÃ\xadnez',
#  'perihelion and aphelion',
#  'p5 (microarchitecture)',
#  'punjab region',
#  'planetary ring',
#  'porsche Boxster',
#  'permianâ\x80\x93Triassic extinction event',
#  'five Precepts',
#  'proteobacteria',
#  'pole weapon',
#  "pell\\'s equation",
#  'philips CD-i',
#  'list of Polish proverbs',
#  'psilanthropism',
#  'protonâ\x80\x93proton chain reaction',
#  'presbyterian Church (U.S.A.)',
#  'piÃ±a colada',
#  'poliomyelitis',
#  'puget Sound Naval Shipyard and Intermediate Maintenance Facility',
#  'quantum physics',
#  'quantum computer',
#  'deaths in 2003',
#  'ronald Reagan/Inaugural Speech',
#  'ronald Reagan/Inaugural Speech 2',
#  'red tide',
#  'rapcore',
#  'runâ\x80\x93D.M.C.',
#  'romantic comedy film',
#  'the Renaissance',
#  'demographics of RÃ©union',
#  'communications media in Romania',
#  'rNA world hypothesis',
#  'reykjavÃ\xadk',
#  'ragnarÃ¶k',
#  "rice\\'s theorem",
#  'rÃ¡n',
#  'the Ren & Stimpy Show',
#  'raÃ«lism',
#  "rubik\\'s Cube",
#  'renÃ© Magritte',
#  'religion and homosexuality',
#  'fARC',
#  "rehavam Ze\\'evi",
#  'renÃ© Laennec',
#  'rainhill Trials',
#  'reduced instruction set computing',
#  'rathaus SchÃ¶neberg',
#  'rÃ¦dwald of East Anglia',
#  "roget\\'s Thesaurus",
#  'redâ\x80\x93black tree',
#  'rosÃ³Å\x82',
#  'real Madrid C.F.',
#  'redshirt (character)',
#  'î\x9c-recursive function',
#  'ramsay Hunt syndrome type II',
#  'referential transparency (computer science)',
#  'marine archeology in the Gulf of Khambhat',
#  'rooster',
#  'stanisÅ\x82aw Lem',
#  'simon & Garfunkel',
#  'sabine River (Texasâ\x80\x93Louisiana)',
#  'saint Lawrence Seaway',
#  'å\xa0koda Auto',
#  'cLIÃ\x89',
#  'rock-paper-scissors',
#  'screwball comedy film',
#  'doctor (Star Trek: Voyager)',
#  'sami people',
#  'military of San Marino',
#  'history of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'geography of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'demographics of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'military of Slovakia',
#  'military of Slovenia',
#  'demographics of the Solomon Islands',
#  'politics of the Solomon Islands',
#  'swaziland',
#  'demographics of Swaziland',
#  'economy of Swaziland',
#  'military of Swaziland',
#  'split screen (filmmaking)',
#  'subset and superset',
#  'standard conditions for temperature and pressure',
#  'sam & Max',
#  'small arms',
#  'senryÅ«',
#  "schrÃ¶dinger\\'s cat",
#  'sÃ¡pmi (area)',
#  'skÃ\xadÃ°blaÃ°nir',
#  'glossary of Patience terms',
#  'szechwan cuisine',
#  'sharp-P-complete',
#  'sydney underground railways',
#  'rescue and recovery effort after the September 11 attacks',
#  'standard Alphabet by Lepsius',
#  'data storage device',
#  'sinn FÃ©in',
#  'short Message Service',
#  'nicolas LÃ©onard Sadi Carnot',
#  'star designation',
#  'spanishâ\x80\x93American War',
#  "sandler O\\'Neill and Partners",
#  'simon Templar',
#  'stephen BÃ¡thory',
#  'shooting sport',
#  'suprÃªme sauce',
#  'soong May-ling',
#  'salÃ², or the 120 Days of Sodom',
#  'scroll lock',
#  'superluminal communication',
#  "st. John\\'s, Antigua and Barbuda",
#  'stÃ©phane MallarmÃ©',
#  'stoneâ\x80\x93Weierstrass theorem',
#  'shÅ\x8dnen manga',
#  'shÅ\x8djo manga',
#  'soay, Skye',
#  'standard gauge',
#  'saint Ninian',
#  'sega Game Gear',
#  'sega 32X',
#  "stokes\\' theorem",
#  'segway PT',
#  'list of Seleucid rulers',
#  'spawn (comics)',
#  'lehi (group)',
#  'symphonic rock',
#  'send in the Clowns',
#  'sikh',
#  'stop consonant',
#  'scientific revolution',
#  'list of Sardinians',
#  'sigma-algebra',
#  'sierpinski carpet',
#  'sierpinski triangle',
#  'sergio AragonÃ©s',
#  'taiâ\x80\x93Kadai languages',
#  'texas A&M University',
#  'teliaSonera',
#  'qt Company',
#  'tÃ¼bingen',
#  'military of Tajikistan',
#  "his Majesty\\'s Armed Forces (Tonga)",
#  'military of Turkmenistan',
#  'theory of justification',
#  'list of highest-grossing films in Canada and the United States',
#  'inklings',
#  'associates (band)',
#  'tÃ½r',
#  "thirty Years\\' War",
#  'tunnels & Trolls',
#  'sprint (cycling)',
#  'tacitus on Christ',
#  'terabyte',
#  'the Terrorist (1997 film)',
#  'trinitrotoluene',
#  'titiusâ\x80\x93Bode law',
#  'john Clark (Tom Clancy character)',
#  'thÃ\xadch Nháº¥t Háº¡nh',
#  'teutonic Knights',
#  'tulsa race riot',
#  'tÃ©kumel',
#  'trance (music genre)',
#  'tolstoy (family)',
#  'throughput',
#  'tuatha DÃ© Danann',
#  'boston Molasses Disaster',
#  'analogy of the Divided Line',
#  'troy ounce',
#  "lagrange\\'s theorem (group theory)",
#  'april 2002',
#  'triassicâ\x80\x93Jurassic extinction event',
#  'bolzanoâ\x80\x93Weierstrass theorem',
#  'theoderic the Great',
#  'time division multiple access',
#  'toruÅ\x84',
#  'twinkle Twinkle Little Star',
#  'german Type II submarine',
#  'german Type IX submarine',
#  "the Hitchhiker\\'s Guide to the Galaxy",
#  'taitÅ\x8d',
#  'flash (comics)',
#  'tongue-twister',
#  'wizard of New Zealand',
#  'the Weakest Link (UK game show)',
#  'giant-cell arteritis',
#  'threads',
#  'united States Constitution',
#  'umeÃ¥ University',
#  "christ\\'s College, Cambridge",
#  'union Defence Force (UAE)',
#  'united States presidential election, 2000',
#  'uSS John C. Stennis (CVN-74)',
#  'united States presidential election, 1996',
#  'uniform resource identifier',
#  'uSS Greeneville (SSN-772)',
#  'uSS Scorpion',
#  'urzÄ\x85d Ochrony PaÅ\x84stwa',
#  'uSS Peleliu (LHA-5)',
#  'uSS City of Corpus Christi (SSN-705)',
#  'uralâ\x80\x93Altaic languages',
#  'universal Mobile Telecommunications System',
#  'uniform resource locator',
#  'uSS Triton',
#  'uSS Tullibee',
#  'vÃ¤nern',
#  'batavia (ship)',
#  'amsterdam (VOC ship)',
#  "van Diemen\\'s Land",
#  'verÃ°andi',
#  'visegrÃ¡d Group',
#  'vulvovaginal health',
#  'vÃ\xadÃ°arr',
#  'versailles (city)',
#  'voting paradox',
#  'von Hippelâ\x80\x93Lindau disease',
#  'victoria University, Australia',
#  'vÃ¤sterÃ¥s Municipality',
#  'volapÃ¼k',
#  'voortrekkers',
#  'wargaming',
#  'wÅ\x82adysÅ\x82aw Reymont',
#  'wisÅ\x82awa Szymborska',
#  'web commerce',
#  'waveâ\x80\x93particle duality',
#  'washington Dulles International Airport',
#  'gray wolf',
#  'world cup competition',
#  'list of national capitals in alphabetical order',
#  'war of independence',
#  'the World Calendar',
#  'casoratiâ\x80\x93Weierstrass theorem',
#  'wadeâ\x80\x93Giles',
#  'wemic',
#  "william O\\'Dwyer",
#  'list of tallest buildings and structures in the world',
#  "yahoo (Gulliver\\'s Travels)",
#  'military of Yemen',
#  'yiddish language',
#  'military of Serbia and Montenegro',
#  'zettabyte',
#  'zieglerâ\x80\x93Natta catalyst',
#  '0 (number)',
#  'å»arnowiec',
#  "zeno\\'s paradoxes",
#  '2000s (decade)',
#  'election threshold',
#  '1720s',
#  '1710s',
#  '1380s',
#  'nS320xx',
#  '817 BC',
#  '100 gigametres',
#  '10 terametres',
#  '100 petametres',
#  '1 exametre',
#  '10 exametres',
#  '100 exametres',
#  '1 gigametre',
#  '10 megametres',
#  '1 megametre',
#  '1 kilometre',
#  '1 decametre',
#  '1 metre',
#  '1 E-1 mÂ³',
#  '1 E-2 mÂ³',
#  '1 E-3 mÂ³',
#  '1 E-4 mÂ³',
#  '1 E-5 mÂ³',
#  '100 nanometres',
#  '1 decimetre',
#  '1 centimetre',
#  '1180s',
#  '1 micrometre',
#  '10 picometres',
#  '10 micrometres',
#  '100 micrometres',
#  '1948 Arabâ\x80\x93Israeli War',
#  '5-alpha-reductase deficiency',
#  '1670s',
#  '1 hectometre',
#  '1390s',
#  '1330s',
#  '1230s',
#  '1240s',
#  '1270s',
#  '100 zettametres',
#  '1 yottametre',
#  '10 yottametres',
#  'first Book of Nephi',
#  'second Book of Nephi',
#  'first Transcontinental Railroad',
#  'edward Higgins White',
#  'norman Cook',
#  'george Marshall',
#  'emperor Go-IchijÅ\x8d',
#  '2040s',
#  'animated cartoon',
#  'kingdom of Northumbria',
#  'burrowsâ\x80\x93Wheeler transform',
#  "benford\\'s law",
#  "sutter\\'s Mill",
#  "sutter\\'s Fort",
#  'gruyÃ¨res',
#  'arabesque (Islamic art)',
#  'television network',
#  'heavy Metal: F.A.K.K.Â²',
#  'pashtun people',
#  "today\\'s New International Version",
#  'the Price Is Right (U.S. game show)',
#  'battle of Lechfeld (955)',
#  'metin KaÃ§an',
#  "association for the Taxation of Financial Transactions and for Citizens\\' Action",
#  'brabanÃ§onne',
#  'jan KjÃ¦rstad',
#  'scooby Gang (Buffy the Vampire Slayer)',
#  'jÃ¸rn Utzon',
#  'rubidium-strontium dating',
#  'kannada language',
#  "miller\\'s knot",
#  "fisherman\\'s knot",
#  'anti-tank missile',
#  "duverger\\'s law",
#  "european Men\\'s Handball Championship",
#  "offa\\'s Dyke",
#  'national Academies (United States)',
#  'disabled sports',
#  'list of mountains',
#  'plzeÅ\x88',
#  'fallopia japonica',
#  'tajik people',
#  'media of Venezuela',
#  "hilbert\\'s paradox of the Grand Hotel",
#  'mÃ¶bius strip',
#  'solid-fuel rocket',
#  'hybrid rocket',
#  'protestant Reformation',
#  'nyquistâ\x80\x93Shannon sampling theorem',
#  'august Ferdinand MÃ¶bius',
#  'die Meistersinger von NÃ¼rnberg',
#  'la bohÃ¨me',
#  'warfare',
#  'yucatÃ¡n',
#  'franÃ§ois Mitterrand',
#  'die EntfÃ¼hrung aus dem Serail',
#  'matthew of KrakÃ³w',
#  'kidney stone',
#  'charles University in Prague',
#  'the Flying Dutchman (opera)',
#  'ã\x89mile Durkheim',
#  "lions\\' Commentary on UNIX 6th Edition, with Source Code",
#  'poznaÅ\x84 University of Technology',
#  'robert Ross (singer)',
#  'la fille du rÃ©giment',
#  'snakes and Ladders',
#  'sebastian MÃ¼nster',
#  'violence in the Israeliâ\x80\x93Palestinian conflict 2000',
#  'violence in the Israeliâ\x80\x93Palestinian conflict 2002',
#  'erich HÃ¼ckel',
#  "isoroku Yamamoto\\'s sleeping giant quote",
#  'franche-ComtÃ©',
#  "knight\\'s tour",
#  'about.com',
#  'gravitation',
#  'charles XIV John of Sweden',
#  'ã\x86sir',
#  'rupert, King of Germany',
#  'winter sport',
#  'bolesÅ\x82aw I Chrobry',
#  'harry Randall Truman',
#  'accelerating universe',
#  'philipp Melanchthon',
#  'uSS Mustin',
#  'labour United',
#  '1 E+27 mÂ³',
#  'spoiler effect',
#  "moore\\'s law",
#  'united States presidential election, 1992',
#  'ice dancing',
#  "shakespeare\\'s late romances",
#  'ã\x89lie Ducommun',
#  'edmund Rich',
#  'color guard',
#  'adnams Brewery',
#  'colin Renfrew, Baron Renfrew of Kaimsthorn',
#  'sanity testing',
#  'charles XV of Sweden',
#  'short track speed skating',
#  'dei Verbum',
#  'witenagemot',
#  "broca\\'s area",
#  'conjugate acid',
#  'niccolÃ² de Romanis',
#  'george IV of the United Kingdom',
#  'open Systems Interconnection',
#  'john Wentworth (Illinois)',
#  'carter Harrison, Sr.',
#  'positive-definite matrix',
#  'gaudium et Spes',
#  'united States presidential election, 1876',
#  'united States presidential election, 1788â\x80\x9389',
#  'united States presidential election, 1796',
#  'united States presidential election, 1800',
#  'united States presidential election, 1804',
#  'united States presidential election, 1808',
#  'united States presidential election, 1812',
#  'united States presidential election, 1816',
#  'united States presidential election, 1820',
#  'united States presidential election, 1824',
#  'united States presidential election, 1832',
#  'united States presidential election, 1836',
#  'united States presidential election, 1840',
#  'united States presidential election, 1852',
#  'united States presidential election, 1856',
#  'united States presidential election, 1860',
#  'united States presidential election, 1868',
#  'united States presidential election, 1872',
#  'united States presidential election, 1880',
#  'united States presidential election, 1888',
#  'united States presidential election, 1892',
#  'united States presidential election, 1896',
#  'united States presidential election, 1904',
#  'united States presidential election, 1912',
#  'united States presidential election, 1916',
#  'united States presidential election, 1920',
#  'united States presidential election, 1924',
#  'united States presidential election, 1928',
#  'adalbert (archbishop of Magdeburg)',
#  'united States presidential election, 1932',
#  'united States presidential election, 1936',
#  'united States presidential election, 1940',
#  'united States presidential election, 1944',
#  'united States presidential election, 1948',
#  'united States presidential election, 1956',
#  'united States presidential election, 1960',
#  'united States presidential election, 1964',
#  'united States presidential election, 1968',
#  'united States presidential election, 1972',
#  'united States presidential election, 1984',
#  ...]

# %%
redirects_titles = []
not_redirect_titles = []

for title in diff_titles: 
    if is_redirect(title):
        redirects_titles.append(title)
    else:
        not_redirect_titles.append(title)

# %%
print(f"Number of redirect pages : {len(redirects_titles)} ({100.*len(redirects_titles)/len(diff_titles):.4f}%)")
print(f"Number of not redirect pages : {len(not_redirect_titles)} ({100.*len(not_redirect_titles)/len(diff_titles):.4f}%)")
# Out:
# Number of redirect pages : 239167 (42.4824%)
# Number of not redirect pages : 323812 (57.5176%)

# %%
not_redirect_titles
# Out:
# ['asociaciÃ³n Alumni',
#  "all Souls\\' Day",
#  'andrÃ© Gide',
#  'alfonso CuarÃ³n',
#  'casa BatllÃ³',
#  'park GÃ¼ell',
#  'casa MilÃ',
#  'atanasoffâ\x80\x93Berry computer',
#  'andrÃ©-Marie AmpÃ¨re',
#  "dodo (Alice\\'s Adventures in Wonderland)",
#  'andrÃ© de Longjumeau',
#  'ã\x86gir',
#  'anne BrontÃ«',
#  'ã\x81satrÃº in the United States',
#  'ã\x86lfheah of Canterbury',
#  "sid Meier\\'s Alpha Centauri",
#  'ã\x86lle of Sussex',
#  "amdahl\\'s law",
#  "ardal O\\'Hanlon",
#  'albrecht DÃ¼rer',
#  'andrÃ© the Giant',
#  "antoine Thomson d\\'Abbadie",
#  'ã\x81ed mac CinÃ¡eda',
#  'andreas SchlÃ¼ter',
#  'anaÃ¯s Nin',
#  "`Abdu\\'l-BahÃ¡",
#  'alcobaÃ§a, Portugal',
#  'arithmeticâ\x80\x93geometric mean',
#  "banca d\\'Italia",
#  'bifrÃ¶st',
#  'brÃ\xadsingamen',
#  'borsukâ\x80\x93Ulam theorem',
#  'boÃ¶tes',
#  'boseâ\x80\x93Einstein condensate',
#  'beerâ\x80\x93Lambert law',
#  'bÃ©la BartÃ³k',
#  'blue Ã\x96yster Cult',
#  'bÃ©zier curve',
#  "bernoulli\\'s inequality",
#  'barÄ±Å\x9f ManÃ§o',
#  "bÃ©zout\\'s identity",
#  'bjÃ¸rn Lomborg',
#  'cold War (1947â\x80\x9353)',
#  "clarke\\'s three laws",
#  'ã\x87atalhÃ¶yÃ¼k',
#  'chojnÃ³w',
#  'clientâ\x80\x93server model',
#  'czesÅ\x82aw MiÅ\x82osz',
#  'conectiva',
#  'comet Shoemakerâ\x80\x93Levy 9',
#  'cultural production and nationalism',
#  'churchâ\x80\x93Turing thesis',
#  'jean-Baptiste-SimÃ©on Chardin',
#  "charles d\\'Abancour",
#  'comet Haleâ\x80\x93Bopp',
#  'causantÃ\xadn mac CinÃ¡eda',
#  'centimetreâ\x80\x93gramâ\x80\x93second system of units',
#  'cuauhtÃ©moc',
#  'cauchyâ\x80\x93Riemann equations',
#  'history of the term \\"Catholic\\"',
#  'charcotâ\x80\x93Marieâ\x80\x93Tooth disease',
#  'diffieâ\x80\x93Hellman key exchange',
#  'dungeons & Dragons',
#  'deutsches Institut fÃ¼r Normung',
#  'diogo CÃ£o',
#  'daoismâ\x80\x93Taoism romanization issue',
#  "director\\'s cut",
#  "darwin\\'s Dangerous Idea",
#  'domnall mac AilpÃ\xadn',
#  'dÃ©jÃ\xa0 vu',
#  'catan: Cities & Knights',
#  'helsingÃ¸r',
#  'encyclopÃ¦dia Britannica',
#  "euler\\'s formula",
#  'eulerâ\x80\x93Maclaurin formula',
#  'eugÃ¨ne Viollet-le-Duc',
#  "euler\\'s sum of powers conjecture",
#  'ecuadorâ\x80\x93United States relations',
#  'erdÅ\x91s number',
#  'ã\x89variste Galois',
#  'elblÄ\x85g',
#  "european People\\'s Party (European Parliament group)",
#  'ã\x86thelberht of Kent',
#  'erwin SchrÃ¶dinger',
#  'louise Ã\x89lisabeth VigÃ©e Le Brun',
#  'ã\x86thelred the Unready',
#  'emperor ShÅ\x8dmu',
#  'emin Boztepe',
#  'evliya Ã\x87elebi',
#  'emperor YÅ\x8dmei',
#  'empress JitÅ\x8d',
#  'empress GenshÅ\x8d',
#  'empress KÅ\x8dken',
#  'emperor Go-KÅ\x8dgon',
#  'emperor KÅ\x8dan',
#  'emperor KÅ\x8dgen',
#  'emperor ChÅ«ai',
#  'emperor Å\x8cjin',
#  'emperor RichÅ«',
#  'emperor IngyÅ\x8d',
#  'emperor AnkÅ\x8d',
#  'emperor KenzÅ\x8d',
#  'emperor YÅ\x8dzei',
#  'emperor KÅ\x8dkÅ\x8d',
#  'el NiÃ±o',
#  'franÃ§ois Truffaut',
#  'friedrich WÃ¶hler',
#  'frÃ©dÃ©ric Chopin',
#  "finagle\\'s law",
#  "franÃ§ois d\\'Aguilon",
#  'francisco Ã\x81lvares',
#  'fÃ©lix Guattari',
#  'frÃ©dÃ©ric Bastiat',
#  'floccinaucinihilipilification',
#  "foster\\'s Lager",
#  'frÃ©dÃ©ric Bazille',
#  'fianna FÃ¡il',
#  'list of fictional guidebooks',
#  'gdaÅ\x84sk',
#  'gÃ¶ta Canal',
#  'gÃ¶ta Ã¤lv',
#  'gÃ¶ktÃ¼rks',
#  'goran BregoviÄ\x87',
#  "gÃ¶del\\'s ontological proof",
#  "gÃ¶del\\'s completeness theorem",
#  'gil Ã\x81lvarez Carrillo de Albornoz',
#  'cisâ\x80\x93trans isomerism',
#  'grÃ\xadmnismÃ¡l',
#  "godwin\\'s law",
#  "original proof of GÃ¶del\\'s completeness theorem",
#  'gilbert Arthur Ã\xa0 Beckett',
#  'george PÃ³lya',
#  'gÃ©za, Grand Prince of the Hungarians',
#  'hermann GÃ¶ring',
#  'hahnâ\x80\x93Banach theorem',
#  'halldÃ³r Laxness',
#  'hersheyâ\x80\x93Chase experiment',
#  'helene KrÃ¶ller-MÃ¼ller',
#  'hernÃ¡n CortÃ©s',
#  'halfbakery',
#  'hÃ¶Ã°r',
#  "horner\\'s method",
#  'huygensâ\x80\x93Fresnel principle',
#  'ä°smet Ä°nÃ¶nÃ¼',
#  'iranâ\x80\x93Contra affair',
#  'iranâ\x80\x93Iraq War',
#  'interwiki links',
#  "isabella d\\'Este",
#  'simonâ\x80\x93Ehrlich wager',
#  'judit PolgÃ¡r',
#  'jÃ¶tunheimr',
#  'jean-Jacques AmpÃ¨re',
#  'gyula AndrÃ¡ssy',
#  'juan FernÃ¡ndez Islands',
#  'jÃ¼rgen Habermas',
#  'jean-FranÃ§ois Millet',
#  'johannes Nicolaus BrÃ¸nsted',
#  'kolmogorovâ\x80\x93Smirnov test',
#  "kuiper\\'s test",
#  'keplerâ\x80\x93Poinsot polyhedron',
#  'krakÃ³w',
#  'kitÃ¡b-i-Aqdas',
#  'kÅ\x8dan',
#  'kolmogorovâ\x80\x93Arnoldâ\x80\x93Moser theorem',
#  'kennellyâ\x80\x93Heaviside layer',
#  'kelloggâ\x80\x93Briand Pact',
#  'kansasâ\x80\x93Nebraska Act',
#  'karel Hynek MÃ¡cha',
#  'kaluzaâ\x80\x93Klein theory',
#  'keflavÃ\xadk',
#  'karl BÃ¶ttiger',
#  "king\\'s Royal Rifle Corps",
#  'koÅ\x82obrzeg',
#  'kÃ¼nstlerroman',
#  'letter game',
#  "lao People\\'s Armed Forces",
#  'lagÃ¢ri Hasan Ã\x87elebi',
#  "monty Python\\'s Life of Brian",
#  "land\\'s End",
#  'list of political parties named \\"Labour Party\\" or similar',
#  'la TÃ¨ne culture',
#  'lyon & Healy',
#  'laocoÃ¶n',
#  "lord\\'s Prayer",
#  "l\\'HÃ´pital\\'s rule",
#  'ludwig Ritter von KÃ¶chel',
#  'lÃ©on Theremin',
#  "lorenzo de\\' Medici",
#  'mÃ¤laren',
#  'moÄ\x9follar',
#  'maxwellâ\x80\x93Boltzmann distribution',
#  'maraÃ±Ã³n River',
#  'maciej PÅ\x82aÅ¼yÅ\x84ski',
#  'the MorrÃ\xadgan',
#  "man\\'yÅ\x8dshÅ«",
#  'martin WaldseemÃ¼ller',
#  "m\\'Naghten rules",
#  'motÃ¶rhead',
#  'molotovâ\x80\x93Ribbentrop Pact',
#  'mÃ¶bius function',
#  'marxismâ\x80\x93Leninism',
#  "korean People\\'s Army",
#  'niccolÃ² Paganini',
#  'njÃ¶rÃ°r',
#  "ninon de l\\'Enclos",
#  "newton\\'s method",
#  'ole RÃ¸mer',
#  'owain GlyndÅµr',
#  'magnavox OdysseyÂ²',
#  'ã\x96tzi',
#  'penÃ©lope Cruz',
#  "omaha hold \\'em",
#  'paul HÃ©roult',
#  'pattersonâ\x80\x93Gimlin film',
#  'paul ValÃ©ry',
#  "there\\'s Plenty of Room at the Bottom",
#  'poznaÅ\x84',
#  'pokÃ©mon',
#  'poincarÃ© conjecture',
#  'list of PokÃ©mon',
#  "the Night\\'s Dawn Trilogy",
#  'paul CÃ©zanne',
#  'pÄ\x81ramitÄ\x81',
#  'pedro MartÃ\xadnez',
#  'permianâ\x80\x93Triassic extinction event',
#  "pell\\'s equation",
#  'list of Polish proverbs',
#  'protonâ\x80\x93proton chain reaction',
#  'piÃ±a colada',
#  'ronald Reagan/Inaugural Speech',
#  'ronald Reagan/Inaugural Speech 2',
#  'runâ\x80\x93D.M.C.',
#  'demographics of RÃ©union',
#  'reykjavÃ\xadk',
#  'ragnarÃ¶k',
#  "rice\\'s theorem",
#  'rÃ¡n',
#  'the Ren & Stimpy Show',
#  'raÃ«lism',
#  "rubik\\'s Cube",
#  'renÃ© Magritte',
#  "rehavam Ze\\'evi",
#  'renÃ© Laennec',
#  'rathaus SchÃ¶neberg',
#  'rÃ¦dwald of East Anglia',
#  "roget\\'s Thesaurus",
#  'redâ\x80\x93black tree',
#  'rosÃ³Å\x82',
#  'î\x9c-recursive function',
#  'stanisÅ\x82aw Lem',
#  'simon & Garfunkel',
#  'sabine River (Texasâ\x80\x93Louisiana)',
#  'å\xa0koda Auto',
#  'cLIÃ\x89',
#  'history of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'geography of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'demographics of SÃ£o TomÃ© and PrÃ\xadncipe',
#  'senryÅ«',
#  "schrÃ¶dinger\\'s cat",
#  'sÃ¡pmi (area)',
#  'skÃ\xadÃ°blaÃ°nir',
#  'sinn FÃ©in',
#  'nicolas LÃ©onard Sadi Carnot',
#  'spanishâ\x80\x93American War',
#  "sandler O\\'Neill and Partners",
#  'stephen BÃ¡thory',
#  'suprÃªme sauce',
#  'salÃ², or the 120 Days of Sodom',
#  "st. John\\'s, Antigua and Barbuda",
#  'stÃ©phane MallarmÃ©',
#  'stoneâ\x80\x93Weierstrass theorem',
#  'shÅ\x8dnen manga',
#  'shÅ\x8djo manga',
#  "stokes\\' theorem",
#  'sergio AragonÃ©s',
#  'taiâ\x80\x93Kadai languages',
#  'texas A&M University',
#  'tÃ¼bingen',
#  "his Majesty\\'s Armed Forces (Tonga)",
#  'tÃ½r',
#  "thirty Years\\' War",
#  'tunnels & Trolls',
#  'titiusâ\x80\x93Bode law',
#  'thÃ\xadch Nháº¥t Háº¡nh',
#  'tÃ©kumel',
#  'tuatha DÃ© Danann',
#  "lagrange\\'s theorem (group theory)",
#  'triassicâ\x80\x93Jurassic extinction event',
#  'bolzanoâ\x80\x93Weierstrass theorem',
#  'toruÅ\x84',
#  "the Hitchhiker\\'s Guide to the Galaxy",
#  'taitÅ\x8d',
#  'umeÃ¥ University',
#  "christ\\'s College, Cambridge",
#  'uSS Scorpion',
#  'urzÄ\x85d Ochrony PaÅ\x84stwa',
#  'uralâ\x80\x93Altaic languages',
#  'uSS Triton',
#  'uSS Tullibee',
#  'vÃ¤nern',
#  "van Diemen\\'s Land",
#  'verÃ°andi',
#  'visegrÃ¡d Group',
#  'vÃ\xadÃ°arr',
#  'von Hippelâ\x80\x93Lindau disease',
#  'vÃ¤sterÃ¥s Municipality',
#  'volapÃ¼k',
#  'wÅ\x82adysÅ\x82aw Reymont',
#  'wisÅ\x82awa Szymborska',
#  'waveâ\x80\x93particle duality',
#  'casoratiâ\x80\x93Weierstrass theorem',
#  'wadeâ\x80\x93Giles',
#  "william O\\'Dwyer",
#  "yahoo (Gulliver\\'s Travels)",
#  'zieglerâ\x80\x93Natta catalyst',
#  'å»arnowiec',
#  "zeno\\'s paradoxes",
#  '1720s',
#  '1710s',
#  '1380s',
#  '1 E-1 mÂ³',
#  '1 E-2 mÂ³',
#  '1 E-3 mÂ³',
#  '1 E-4 mÂ³',
#  '1 E-5 mÂ³',
#  '1180s',
#  '1948 Arabâ\x80\x93Israeli War',
#  '1670s',
#  '1390s',
#  '1330s',
#  '1230s',
#  '1240s',
#  '1270s',
#  'emperor Go-IchijÅ\x8d',
#  'burrowsâ\x80\x93Wheeler transform',
#  "benford\\'s law",
#  "sutter\\'s Mill",
#  "sutter\\'s Fort",
#  'gruyÃ¨res',
#  'heavy Metal: F.A.K.K.Â²',
#  "today\\'s New International Version",
#  'metin KaÃ§an',
#  "association for the Taxation of Financial Transactions and for Citizens\\' Action",
#  'brabanÃ§onne',
#  'jan KjÃ¦rstad',
#  'jÃ¸rn Utzon',
#  "miller\\'s knot",
#  "fisherman\\'s knot",
#  "duverger\\'s law",
#  "european Men\\'s Handball Championship",
#  "offa\\'s Dyke",
#  'plzeÅ\x88',
#  "hilbert\\'s paradox of the Grand Hotel",
#  'mÃ¶bius strip',
#  'nyquistâ\x80\x93Shannon sampling theorem',
#  'august Ferdinand MÃ¶bius',
#  'die Meistersinger von NÃ¼rnberg',
#  'la bohÃ¨me',
#  'yucatÃ¡n',
#  'franÃ§ois Mitterrand',
#  'die EntfÃ¼hrung aus dem Serail',
#  'matthew of KrakÃ³w',
#  'ã\x89mile Durkheim',
#  "lions\\' Commentary on UNIX 6th Edition, with Source Code",
#  'poznaÅ\x84 University of Technology',
#  'la fille du rÃ©giment',
#  'sebastian MÃ¼nster',
#  'violence in the Israeliâ\x80\x93Palestinian conflict 2000',
#  'violence in the Israeliâ\x80\x93Palestinian conflict 2002',
#  'erich HÃ¼ckel',
#  "isoroku Yamamoto\\'s sleeping giant quote",
#  'franche-ComtÃ©',
#  "knight\\'s tour",
#  'ã\x86sir',
#  'bolesÅ\x82aw I Chrobry',
#  'uSS Mustin',
#  '1 E+27 mÂ³',
#  "moore\\'s law",
#  "shakespeare\\'s late romances",
#  'ã\x89lie Ducommun',
#  "broca\\'s area",
#  'niccolÃ² de Romanis',
#  'united States presidential election, 1788â\x80\x9389',
#  "polish United Workers\\' Party",
#  'lÃ©on: The Professional',
#  'adderâ\x80\x93subtractor',
#  'black facsimile transmission',
#  'black recording',
#  "brewster\\'s angle",
#  'busy verification',
#  'calling-party camp-on',
#  'cooperation factor',
#  "lambert\\'s cosine law",
#  'spragueâ\x80\x93Grundy theorem',
#  'principal clock',
#  "world\\'s Columbian Exposition",
#  'ã\x89mile Picard',
#  "saint Valentine\\'s Day Massacre",
#  'ã\x89amon de Valera',
#  'honorÃ© de Balzac',
#  'wÅ\x82adysÅ\x82aw II JagieÅ\x82Å\x82o',
#  'sÅ\x82uÅ¼ba BezpieczeÅ\x84stwa',
#  "sandra Day O\\'Connor",
#  "shor\\'s algorithm",
#  'andrÃ© Malraux',
#  "lady Audley\\'s Secret",
#  'alexander DubÄ\x8dek',
#  "jacobus Henricus van \\'t Hoff",
#  "snell\\'s law",
#  'ã\x89ire',
#  'battle of HÃ¼rtgen Forest',
#  "a Midsummer Night\\'s Dream",
#  "zipf\\'s law",
#  "grace O\\'Malley",
#  'thomas Ã\xa0 Kempis',
#  'karel Ä\x8capek',
#  "nine Men\\'s Morris",
#  "prisoner\\'s dilemma",
#  'dÃ¡l Riata',
#  'tÃ³rshavn',
#  "catherine de\\' Medici",
#  "hanlon\\'s razor",
#  "rosie O\\'Donnell",
#  'franÃ§ois Villon',
#  'andrzej Å»uÅ\x82awski',
#  'north Ossetiaâ\x80\x93Alania',
#  "wien\\'s displacement law",
#  "robert\\'s Rules of Order",
#  "state Council of the People\\'s Republic of China",
#  'franÃ§ois Boucher',
#  'ferdinand II of LeÃ³n',
#  'simÃ©on Denis Poisson',
#  "early texts of Shakespeare\\'s works",
#  'karplusâ\x80\x93Strong string synthesis',
#  "goldbach\\'s conjecture",
#  "who\\'s Afraid of Virginia Woolf?",
#  'redâ\x80\x93green alliance',
#  "\\'Ndrangheta",
#  'ã\x89mile Zola',
#  'borelâ\x80\x93Cantelli lemma',
#  "mongol invasion of Rus\\'",
#  'eliÃ¡n GonzÃ¡lez affair',
#  'gÃ©rard Depardieu',
#  'blueâ\x80\x93green alliance',
#  "richard D\\'Oyly Carte",
#  "nevi\\'im",
#  'emperor Go-NijÅ\x8d',
#  'emperor ChÅ\x8dkei',
#  'whatÃ¬',
#  "halley\\'s Comet",
#  "russell\\'s paradox",
#  "simpson\\'s paradox",
#  'qibla al-Qudsiyya',
#  "mother\\'s Day",
#  "long John Silver\\'s",
#  "arthur Treacher\\'s",
#  'mise en scÃ¨ne',
#  'dow Jones & Company',
#  "euler\\'s identity",
#  "simon and Garfunkel\\'s Greatest Hits",
#  'franÃ§ois Quesnay',
#  "painter\\'s algorithm",
#  "queen Elizabeth\\'s Grammar School for Boys",
#  "the King\\'s School, Canterbury",
#  'emperor ShÅ\x8dkÅ\x8d',
#  'ã\x86thelred of Wessex',
#  '100s BC (decade)',
#  "gabriele D\\'Annunzio",
#  "murphy\\'s law",
#  'aÃ©rospatiale',
#  'biaÅ\x82ystok',
#  'gÃ¶del, Escher, Bach',
#  'liberation Army of PreÅ¡evo, MedveÄ\x91a and Bujanovac',
#  'michaÅ\x82 Korybut WiÅ\x9bniowiecki',
#  'le PÃ©tomane',
#  'navierâ\x80\x93Stokes equations',
#  'josÃ© Saramago',
#  'charles Maurice de Talleyrand-PÃ©rigord',
#  'ã\x86thelwulf of Wessex',
#  'ã\x86thelbald of Wessex',
#  'ã\x86thelberht of Wessex',
#  "harry Potter and the Philosopher\\'s Stone",
#  'mahÄ\x81tmÄ\x81',
#  '440s BC',
#  "st John\\'s College, Cambridge",
#  'henri PoincarÃ©',
#  'philosophiÃ¦ Naturalis Principia Mathematica',
#  'camille Saint-SaÃ«ns',
#  "grimm\\'s law",
#  "verner\\'s law",
#  'josÃ© Ramos-Horta',
#  "cox\\'s theorem",
#  "st. Hedwig\\'s Cathedral",
#  "urysohn\\'s lemma",
#  "haidinger\\'s brush",
#  'isabella of AngoulÃªme',
#  "trucker\\'s hitch",
#  "hangman\\'s knot",
#  'laurent-DÃ©sirÃ© Kabila',
#  "boole\\'s syllogistic",
#  'die WalkÃ¼re',
#  'katsura TarÅ\x8d',
#  'nicolae CeauÈ\x99escu',
#  'link awareness',
#  'itÅ\x8d Hirobumi',
#  'marÃ\xada FÃ©lix',
#  "aaron\\'s rod",
#  "old Possum\\'s Book of Practical Cats",
#  "prosecutor\\'s fallacy",
#  "dirk Gently\\'s Holistic Detective Agency",
#  'daishÅ\x8d',
#  'paris MÃ©tro',
#  '110s BC',
#  "jean le Rond d\\'Alembert",
#  "war of Jenkins\\' Ear",
#  'miklÃ³s Horthy',
#  'citroÃ«n',
#  'miloÅ¡ Forman',
#  '370s BC',
#  "cantor\\'s diagonal argument",
#  "zorn\\'s lemma",
#  'moliÃ¨re',
#  "german Workers\\' Party",
#  "taylor\\'s theorem",
#  "graves\\' disease",
#  'bill Haley & His Comets',
#  "i\\'m Sorry I Haven\\'t a Clue",
#  'united Nations Iraqâ\x80\x93Kuwait Observation Mission',
#  'gabriel LamÃ©',
#  'julius PlÃ¼cker',
#  "tait\\'s conjecture",
#  'emerson, Lake & Palmer',
#  'cÃ¡diz',
#  'î\x92-Lactam antibiotic',
#  'georges-EugÃ¨ne Haussmann',
#  "alice\\'s Adventures in Wonderland",
#  'stoneâ\x80\x93Ä\x8cech compactification',
#  "bell\\'s palsy",
#  'sautÃ©ing',
#  'stefanâ\x80\x93Boltzmann law',
#  "kerckhoffs\\'s principle",
#  'stefanâ\x80\x93Boltzmann constant',
#  "the Magician\\'s Nephew",
#  "children\\'s Online Privacy Protection Act",
#  'jean EugÃ¨ne Robert-Houdin',
#  'kenzÅ\x8d Tange',
#  "euler\\'s totient function",
#  "minkowski\\'s theorem",
#  'gruyÃ¨re cheese',
#  'mnemonics (album)',
#  'skidmore, Owings & Merrill',
#  'cÃ³rdoba, Andalusia',
#  "methuselah\\'s Children",
#  "archimedes\\' screw",
#  "life A User\\'s Manual",
#  'santa Fe de Nuevo MÃ©xico',
#  "kruskal\\'s algorithm",
#  'fordâ\x80\x93Fulkerson algorithm',
#  "prim\\'s algorithm",
#  "i\\'d Rather Be Right",
#  'misznayâ\x80\x93Schardin effect',
#  'iSâ\x80\x93LM model',
#  'edgar the Ã\x86theling',
#  'awÃ¡-GuajÃ¡ people',
#  'ryÅ\x8dji Noyori',
#  "kuratowski\\'s theorem",
#  'kÃ¼ltepe',
#  "you Can\\'t Do That on Television",
#  'de Broglieâ\x80\x93Bohm theory',
#  "king Ottokar\\'s Sceptre",
#  'praderâ\x80\x93Willi syndrome',
#  'ivo AndriÄ\x87',
#  'jin dynasty (265â\x80\x93420)',
#  'andrÃ© Breton',
#  'mÃ¶ssbauer effect',
#  'passes of the Silvretta and RÃ¤tikon Ranges',
#  'dauphinÃ© Alps',
#  'ã\x98resund',
#  'bÃ¡bism',
#  "miller\\'s Crossing",
#  'smootâ\x80\x93Hawley Tariff Act',
#  'humphreyâ\x80\x93Hawkins Full Employment Act',
#  "macon\\'s Bill Number 2",
#  'wadeâ\x80\x93Davis Bill',
#  'blandâ\x80\x93Allison Act',
#  "gentlemen\\'s agreement",
#  'aldrichâ\x80\x93Vreeland Act',
#  'payneâ\x80\x93Aldrich Tariff Act',
#  'fordneyâ\x80\x93McCumber Tariff',
#  'eschâ\x80\x93Cummins Act',
#  'norrisâ\x80\x93La Guardia Act',
#  'primoÅ¾ Trubar',
#  'simÃ³n BolÃ\xadvar',
#  'leÃ³ SzilÃ¡rd',
#  "bell\\'s theorem",
#  'laá¹\x85kÄ\x81vatÄ\x81ra SÅ«tra',
#  'ã\x96rnskÃ¶ldsvik Municipality',
#  'pelizaeusâ\x80\x93Merzbacher disease',
#  'tayâ\x80\x93Sachs disease',
#  'ã\x8ele de RÃ©',
#  'baikalâ\x80\x93Amur Mainline',
#  "uganda People\\'s Defence Force",
#  "anita O\\'Day",
#  'economy of SÃ£o TomÃ© and PrÃ\xadncipe',
#  "fitts\\'s law",
#  'malÃ©',
#  "n\\'Djamena",
#  'lomÃ©',
#  "tohono O\\'odham",
#  'thÃ©ophile Gautier',
#  "de Moivre\\'s formula",
#  "przewalski\\'s horse",
#  'nu-Wood Decorative Millwork',
#  'pÃ©clet number',
#  "st. George\\'s, Grenada",
#  'yaoundÃ©',
#  "women\\'s National Basketball Association",
#  'franc MikloÅ¡iÄ\x8d',
#  "women\\'s Tennis Association",
#  'lewisâ\x80\x93Clark State College',
#  'hervÃ© Villechaize',
#  'jean-FranÃ§ois de Galaup, comte de LapÃ©rouse',
#  'ã\x89cole Polytechnique massacre',
#  "grover\\'s algorithm",
#  'ã\x86thelstan',
#  'zweibrÃ¼cken',
#  'tomÃ¡s de ZumalacÃ¡rregui',
#  'jerÃ³nimo Zurita y Castro',
#  "gÃ¶del\\'s incompleteness theorems",
#  'battle of CrÃ©cy',
#  'palau GÃ¼ell',
#  'heineâ\x80\x93Borel theorem',
#  'mission San Diego de AlcalÃ¡',
#  'merkleâ\x80\x93Hellman knapsack cryptosystem',
#  'front de libÃ©ration du QuÃ©bec',
#  'huáº¿',
#  "queen Anne\\'s County, Maryland",
#  'mission San Gabriel ArcÃ¡ngel',
#  'have Space Suitâ\x80\x94Will Travel',
#  'if This Goes Onâ\x80\x94',
#  'real Academia EspaÃ±ola',
#  "ra\\'anana",
#  'mission Santa Clara de AsÃ\xads',
#  'mission Nuestra SeÃ±ora de la Soledad',
#  'mission San JosÃ© (California)',
#  'mission San Miguel ArcÃ¡ngel',
#  'mission San Fernando Rey de EspaÃ±a',
#  'mission Santa InÃ©s',
#  'uSS Gato',
#  "foundation\\'s Edge",
#  "wilson\\'s disease",
#  "sjÃ¶gren\\'s syndrome",
#  "farnham\\'s Freehold",
#  "it\\'s a Wonderful Life",
#  "if on a winter\\'s night a traveler",
#  "peace Sells... but Who\\'s Buying?",
#  'bloc QuÃ©bÃ©cois',
#  'sind Province (1936â\x80\x9355)',
#  'augmented Backusâ\x80\x93Naur Form',
#  'chancellor of Germany (1949â\x80\x93)',
#  'wÅ\x82adysÅ\x82aw I Herman',
#  'bolesÅ\x82aw III Wrymouth',
#  'boxâ\x80\x93Muller transform',
#  'timiÈ\x99oara',
#  'siege of OrlÃ©ans',
#  "new Partnership for Africa\\'s Development",
#  'flight and expulsion of Germans (1944â\x80\x9350)',
#  'bartolomeu de GusmÃ£o',
#  'finistÃ¨re',
#  'ã\x89tienne-Louis BoullÃ©e',
#  "cauchy\\'s integral theorem",
#  'bolesÅ\x82aw Bierut',
#  'ã\x89cole nationale supÃ©rieure des tÃ©lÃ©communications de Bretagne',
#  "boy\\'s surface",
#  'les MisÃ©rables',
#  'les MisÃ©rables (1935 film)',
#  'renÃ© Thom',
#  'chÅ«bu region',
#  'kÅ\x8dchi Prefecture',
#  'judith GodrÃ¨che',
#  'chÃ¢teau',
#  "governor General\\'s Awards",
#  "stephenson\\'s Rocket",
#  'fermÃ\xadn LasuÃ©n',
#  'lozÃ¨re',
#  "mrs. Miniver\\'s problem",
#  "alexander\\'s Ragtime Band",
#  "bradford\\'s law",
#  "organisation de l\\'armÃ©e secrÃ¨te",
#  "martha\\'s Vineyard",
#  'oÈ\x9belu RoÈ\x99u',
#  'oraviÈ\x9ba',
#  'caransebeÈ\x99',
#  'bÄ\x83ile Herculane',
#  'junÃ\xadpero Serra',
#  'backusâ\x80\x93Naur Form',
#  'jÃ©rÃ´me Bonaparte',
#  'prince NapolÃ©on Bonaparte',
#  'josÃ©phine de Beauharnais',
#  'eugÃ¨ne de Beauharnais',
#  'eugÃ©nie de Montijo',
#  'ã\x89owyn',
#  'ã\x89omer',
#  'dÃ©agol',
#  'mika HÃ¤kkinen',
#  'lÃ©on-Paul Fargue',
#  'jÄ\x81bir ibn HayyÄ\x81n',
#  'antoine de Saint-ExupÃ©ry',
#  'vÃ¡clav Havel',
#  "childhood\\'s End",
#  'jacques-BÃ©nigne Bossuet',
#  "king\\'s Highway (Charleston to Boston)",
#  "crohn\\'s disease",
#  'johann Christian GÃ¼nther',
#  'soÄ\x8da',
#  'jaÃ©n, Spain',
#  'palantÃ\xadr',
#  'akallabÃªth',
#  "bresenham\\'s line algorithm",
#  "umney\\'s Last Case",
#  'nightmares & Dreamscapes',
#  "gerald\\'s Game",
#  'celebrÃ\xadan',
#  'lothlÃ³rien',
#  'timeline of the Israeliâ\x80\x93Palestinian conflict',
#  "bernoulli\\'s principle",
#  "reed\\'s law",
#  'moirÃ© pattern',
#  "you Can\\'t Take It with You",
#  'hÃ¡vamÃ¡l',
#  'fulgence BienvenÃ¼e',
#  'mercÃ¨ Rodoreda',
#  'ã\x89dith Piaf',
#  "list of children\\'s literature writers",
#  'manwÃ«',
#  'aulÃ«',
#  'finwÃ«',
#  'fÃ«anor',
#  "battle of Brice\\'s Crossroads",
#  'pontifÃ\xadcia Universidade CatÃ³lica de Campinas',
#  'zoÃ« Wanamaker',
#  "her Majesty\\'s Civil Service",
#  'democratic Party â\x80\x93 demokraci.pl',
#  'japanese aircraft carrier HiryÅ«',
#  'japanese aircraft carrier ShÅ\x8dkaku',
#  'japanese aircraft carrier SÅ\x8dryÅ«',
#  'xavier University â\x80\x93 Ateneo de Cagayan',
#  "a Knight\\'s Tale",
#  'ã\x93scar Romero',
#  'dÃ¼sseldorf',
#  "metcalfe\\'s law",
#  "schindler\\'s List",
#  'plankalkÃ¼l',
#  'pÃ©tanque',
#  "newcomb\\'s paradox",
#  'báº£o Ä\x90áº¡i',
#  'philippe PÃ©tain',
#  "blake\\'s 7",
#  'marie-JosÃ© PÃ©rec',
#  'braÈ\x99ov',
#  'pimsleur method',
#  'baden-WÃ¼rttemberg',
#  "dalton\\'s law",
#  "willis H. O\\'Brien",
#  'alfonso V of LeÃ³n',
#  'mikimoto KÅ\x8dkichi',
#  'peÃ±Ã³n de VÃ©lez de la Gomera',
#  "people\\'s Liberation Army",
#  'andrÃ© Derain',
#  'jÃ³zef PiÅ\x82sudski',
#  'duany Plater-Zyberk & Company',
#  'tÃºpac Amaru Revolutionary Movement',
#  'tÃºpac Amaru',
#  'sarbanesâ\x80\x93Oxley Act',
#  'active solar',
#  'bausch & Lomb',
#  'warcraft: Orcs & Humans',
#  "prix de l\\'Arc de Triomphe",
#  "queen\\'s Plate",
#  'cassiniâ\x80\x93Huygens',
#  'northern League (baseball, 1993â\x80\x932010)',
#  "adam\\'s Rib",
#  'gÃ¶ran Persson',
#  'ã\x81lava',
#  "slash\\'EM",
#  "baldur\\'s Gate (series)",
#  'paul Ã\x89luard',
#  'david A. Wheeler',
#  'renÃ© Lalique',
#  'nueva canciÃ³n',
#  'mÃ©rida, YucatÃ¡n',
#  'mÃ©rida, Spain',
#  "bridget Jones\\'s Diary",
#  'kaldorâ\x80\x93Hicks efficiency',
#  "actors\\' Equity Association",
#  "dahlia \\'Bishop of Llandaff\\'",
#  'bornâ\x80\x93Oppenheimer approximation',
#  'táº¿t',
#  'brighton & Hove Albion F.C.',
#  "ge\\'ez language",
#  'vigenÃ¨re cipher',
#  'alfonso VI of LeÃ³n and Castile',
#  'vÃ¶r',
#  "kurdistan Workers\\' Party",
#  'bartolomÃ© de las Casas',
#  "isaac D\\'Israeli",
#  'castile and LeÃ³n',
#  'new Yorkâ\x80\x93Penn League',
#  'ã\x98resund Bridge',
#  'vÃ¶lsunga saga',
#  'adÃ»naic',
#  'valparaÃ\xadso',
#  "st. John\\'s, Newfoundland and Labrador",
#  "ã\x8ele d\\'OrlÃ©ans",
#  'alfonso VII of LeÃ³n and Castile',
#  'tÃ¶di',
#  'sÃ©curitÃ©',
#  'ultravioletâ\x80\x93visible spectroscopy',
#  'pa amb tomÃ\xa0quet',
#  'shannonâ\x80\x93Hartley theorem',
#  "wigner\\'s friend",
#  'extended Backusâ\x80\x93Naur Form',
#  'champs-Ã\x89lysÃ©es',
#  'vafÃ¾rÃºÃ°nir',
#  'skÃ\xadrnismÃ¡l',
#  'luigino Longo',
#  'quick-and-dirty',
#  "women\\'s United Soccer Association",
#  'andrÃ©s Segovia',
#  'francisco VÃ¡squez de Coronado',
#  "uncle Tom\\'s Cabin",
#  'eugÃ¨ne Ionesco',
#  'encyclopÃ¦dia Britannica Eleventh Edition',
#  'svante PÃ¤Ã¤bo',
#  'bÃ¦rum',
#  "blackmore\\'s Night",
#  "st. Peter\\'s Basilica",
#  'frÃ©dÃ©ric Auguste Bartholdi',
#  "sullivan\\'s Travels",
#  'pietÃ\xa0 (Michelangelo)',
#  'osnabrÃ¼ck',
#  "hell\\'s Hinges",
#  "list of Emperors of China\\'s Southern Dynasties",
#  "list of Emperors of China\\'s Northern Dynasties",
#  'volkswagen KÃ¼belwagen',
#  'alfonso IV of LeÃ³n',
#  'nadia ComÄ\x83neci',
#  "disney\\'s House of Mouse",
#  'czÄ\x99stochowa',
#  'bielsko-BiaÅ\x82a',
#  'rzeszÃ³w',
#  'pÅ\x82ock',
#  "l\\'Hospitalet de Llobregat",
#  'mahÃ³n',
#  'chÃ¢teau de Malmaison',
#  'grudziÄ\x85dz',
#  'sÅ\x82upsk',
#  'jastrzÄ\x99bie-ZdrÃ³j',
#  'ruda Å\x9alÄ\x85ska',
#  'sociÃ©tÃ© des Auteurs et Compositeurs Dramatiques',
#  "jammin\\' the Blues",
#  "jazz on a Summer\\'s Day",
#  "a Hard Day\\'s Night (album)",
#  "let\\'s All Go to the Lobby",
#  "the Miracle of Morgan\\'s Creek",
#  "gauss\\'s law",
#  'jeanne SauvÃ©',
#  'sÃ£o Vicente, Cape Verde',
#  'dÅ\x8dgen',
#  'diziet Sma',
#  'minnesota Democraticâ\x80\x93Farmerâ\x80\x93Labor Party',
#  'jean ChrÃ©tien',
#  "texas hold \\'em",
#  'public cardroom rules',
#  'concepciÃ³n, Chile',
#  'suihÅ\x8d Tagawa',
#  'orlÃ©ans',
#  'lempelâ\x80\x93Zivâ\x80\x93Welch',
#  'ginÃ©s PÃ©rez de Hita',
#  'salomÃ© (1923 film)',
#  "sherman\\'s March (1986 film)",
#  'davisâ\x80\x93Monthan Air Force Base',
#  "twelve O\\'Clock High",
#  "kater\\'s pendulum",
#  's. P. L. SÃ¸rensen',
#  'antonÃ\xadn DvoÅ\x99Ã¡k',
#  "what\\'s Opera, Doc?",
#  'josÃ© Carioca',
#  'christian JÃ¼rgensen Thomsen',
#  'la DÃ©fense',
#  'luÃ\xads de CamÃµes',
#  'aeÃ«tes',
#  'diego VelÃ¡zquez',
#  'endeÃ¯s',
#  "wayne\\'s World (film)",
#  'montjuÃ¯c',
#  'mÃ\xadchel (footballer)',
#  'fredegar Bolger',
#  "kevin O\\'Neill (comics)",
#  'pensÃ©es',
#  'the Velvet Underground & Nico',
#  'la NiÃ±a',
#  'the Sandman: Preludes & Nocturnes',
#  "the Hitchhiker\\'s Guide to the Galaxy: The Original Radio Scripts",
#  "the Sandman: The Doll\\'s House",
#  'atÃ«',
#  'the Sandman: Fables & Reflections',
#  'history of the United States National Security Council 1961â\x80\x9363',
#  'history of the United States National Security Council 1953â\x80\x9361',
#  'history of the United States National Security Council 1981â\x80\x9389',
#  'history of the United States National Security Council 1993â\x80\x93present',
#  "valÃ©ry Giscard d\\'Estaing",
#  'mÃ\xadmir',
#  'sporting de GijÃ³n',
#  'albacete BalompiÃ©',
#  'diogenes LaÃ«rtius',
#  'lÃª Duáº©n',
#  'pháº¡m VÄ\x83n Ä\x90á»\x93ng',
#  'dÆ°Æ¡ng VÄ\x83n Minh',
#  'nguyá»\x85n KhÃ¡nh',
#  'nguyá»\x85n VÄ\x83n Thiá»\x87u',
#  'burmeister & Wain',
#  'philippe II, Duke of OrlÃ©ans',
#  'alexis ArgÃ¼ello',
#  "the Razor\\'s Edge",
#  'doughty Hanson & Co',
#  "the Bishop\\'s Wife",
#  '1 E+1 mÂ³',
#  '1 E+3 mÂ³',
#  '1 E+5 mÂ³',
#  '1 E+6 mÂ³',
#  '1 E+7 mÂ³',
#  '1 E+8 mÂ³',
#  '1 E+9 mÂ³',
#  'vÃ¡r',
#  'rhÃ´ne (department)',
#  'franÃ§ois Rabelais',
#  'sam & Max Hit the Road',
#  'idiran-Culture War',
#  "luigi\\'s Mansion",
#  "king Solomon\\'s Mines",
#  "val d\\'Aran",
#  "ousterhout\\'s dichotomy",
#  "pietro d\\'Abano",
#  'hugo SÃ¡nchez',
#  "jacob\\'s Mouse",
#  "orgel\\'s rule",
#  "franÃ§oise d\\'Eaubonne",
#  "viola d\\'amore",
#  'chÃ¢teau de Rambouillet',
#  'carlos PrÃ\xado SocarrÃ¡s',
#  "chÃ¢teau d\\'Amboise",
#  'wilfred BenÃ\xadtez',
#  'chÃ¢teau de Cheverny',
#  'chÃ¢teau de Loches',
#  'german proverbs',
#  'family life in literature',
#  'geigerâ\x80\x93MÃ¼ller tube',
#  'chÃ¢teau de Chenonceau',
#  "cat\\'s Cradle",
#  'masonâ\x80\x93Dixon line',
#  "chÃ¢teau d\\'Angers",
#  'gramâ\x80\x93Schmidt process',
#  'heinrich BÃ¶ll',
#  'julio CÃ©sar ChÃ¡vez',
#  "hoag\\'s Object",
#  'puigcerdÃ',
#  'teatro ColÃ³n',
#  "cap\\'n Crunch",
#  'luis MuÃ±oz MarÃ\xadn International Airport',
#  'danaÃ«',
#  'ã\x89cole centrale de Lyon',
#  'ã\x89cole centrale de Nantes',
#  'ernst RÃ¶hm',
#  'chÃ¢teau de Saumur',
#  "tess of the d\\'Urbervilles",
#  "super Mario World 2: Yoshi\\'s Island",
#  'copÃ¡n',
#  'beyoncÃ©',
#  'fÃ©lix Trinidad',
#  "graham\\'s law",
#  'ã\x86thelbald of Mercia',
#  'atlÃ©tico Madrid',
#  'salvador SÃ¡nchez',
#  'drÃ´me',
#  'tomaÅ¾ Pisanski',
#  'louis-Ferdinand CÃ©line',
#  'aeromÃ©xico',
#  "women\\'s boxing",
#  "mendeleev\\'s predicted elements",
#  'palamÃ³s',
#  'matarÃ³',
#  'bloodâ\x80\x93brain barrier',
#  'timeline of computing 1990â\x80\x9399',
#  'timeline of computing 1950â\x80\x9379',
#  'timeline of computing hardware 2400 BCâ\x80\x931949',
#  "bitzer\\'s Mill Covered Bridge",
#  'history of discovery and distribution of the remains of Aegean civilization',
#  "jackson\\'s Sawmill Covered Bridge",
#  "forry\\'s Mill Covered Bridge",
#  ...]

# %%
'atom probe' in title_to_id
# Out:
# True

# %%
'atom_probe'.replace('_',' ')
# Out:
# 'atom probe'
