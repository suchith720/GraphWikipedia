# %%
import os
import requests
import pandas as pd
import mwparserfromhell
from matplotlib import pyplot as plt
from bs4 import BeautifulSoup

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Loading Wikipedia Dumps

# %%
project = 'enwiki'
dump_date = "20220420"
dataset_home = '/home/scai/phd/aiz218323/scratch/XML/wikipedia-data-science/'

# %%
import re

data_paths = []
file_info = []

prog = re.compile(f'{project}-{dump_date}'+r'*')
for file in os.listdir(f'{dataset_home}/datasets'):
    if prog.match(file):
        path = f'{dataset_home}/datasets/{file}'
        
        data_paths.append(path)
        file_size = os.stat(path).st_size/1e6
        file_articles = int(file.split('p')[-1].split('.')[0]) - int(file.split('p')[-2])
        file_info.append((file, file_size, file_articles))

# %% [markdown]
# ## Parsing dumps

# %%
import bz2
import subprocess

data_path = data_paths[15]
data_path
# Out:
# '/home/scai/phd/aiz218323/scratch/XML/wikipedia-data-science//datasets/enwiki-20220420-pages-articles-multistream13.xml-p10672789p11659682.bz2'

# %%
import xml.sax

class WikiXmlHandler(xml.sax.handler.ContentHandler):
    
    def __init__(self):
        xml.sax.handler.ContentHandler.__init__(self)
        self._buffer = None
        self._values = {}
        self._current_tag = None
        self._pages = []
        
        self._redirects = {}
        self._add_page = True
        self._is_pageid = True
        
    def characters(self, content):
        if self._current_tag:
            self._buffer.append(content)
            
    def startElement(self, name, attrs):
        if name in ('title', 'text', 'ns'):
            self._current_tag = name
            self._buffer = []
        elif name == 'id' and self._is_pageid:
            self._is_pageid = False
            self._current_tag = name
            self._buffer = []    
        elif name == 'redirect':
            self._redirects[self._values['title']] = attrs.getValue('title').strip()
            self._add_page = False
            
            
    def endElement(self, name):
        if name == self._current_tag:
            self._values[name] = ' '.join(self._buffer)
            self._current_tag = None
                
        elif name == 'page':
            if int(self._values['ns']):
                self._add_page = False
                
            if self._add_page:
                self._pages.append( (self._values['title'], self._values['text'], self._values['id']) )
            
            self._add_page = True
            self._is_pageid = True

# %% [markdown]
# ### Parsing redirect page

# %%
lines = []
for i, line in enumerate(subprocess.Popen(['bzcat'],
                                         stdin = open(data_path),
                                         stdout = subprocess.PIPE).stdout):
    lines.append(line)
    if i > 1e6:
        break

# %%
page = lines[:1000]
for i, p in enumerate(page):
    print(i, p)
# Out:
# 0 b'<mediawiki xmlns="http://www.mediawiki.org/xml/export-0.10/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd" version="0.10" xml:lang="en">\n'
# 1 b'  <siteinfo>\n'
# 2 b'    <sitename>Wikipedia</sitename>\n'
# 3 b'    <dbname>enwiki</dbname>\n'
# 4 b'    <base>https://en.wikipedia.org/wiki/Main_Page</base>\n'
# 5 b'    <generator>MediaWiki 1.39.0-wmf.7</generator>\n'
# 6 b'    <case>first-letter</case>\n'
# 7 b'    <namespaces>\n'
# 8 b'      <namespace key="-2" case="first-letter">Media</namespace>\n'
# 9 b'      <namespace key="-1" case="first-letter">Special</namespace>\n'
# 10 b'      <namespace key="0" case="first-letter" />\n'
# 11 b'      <namespace key="1" case="first-letter">Talk</namespace>\n'
# 12 b'      <namespace key="2" case="first-letter">User</namespace>\n'
# 13 b'      <namespace key="3" case="first-letter">User talk</namespace>\n'
# 14 b'      <namespace key="4" case="first-letter">Wikipedia</namespace>\n'
# 15 b'      <namespace key="5" case="first-letter">Wikipedia talk</namespace>\n'
# 16 b'      <namespace key="6" case="first-letter">File</namespace>\n'
# 17 b'      <namespace key="7" case="first-letter">File talk</namespace>\n'
# 18 b'      <namespace key="8" case="first-letter">MediaWiki</namespace>\n'
# 19 b'      <namespace key="9" case="first-letter">MediaWiki talk</namespace>\n'
# 20 b'      <namespace key="10" case="first-letter">Template</namespace>\n'
# 21 b'      <namespace key="11" case="first-letter">Template talk</namespace>\n'
# 22 b'      <namespace key="12" case="first-letter">Help</namespace>\n'
# 23 b'      <namespace key="13" case="first-letter">Help talk</namespace>\n'
# 24 b'      <namespace key="14" case="first-letter">Category</namespace>\n'
# 25 b'      <namespace key="15" case="first-letter">Category talk</namespace>\n'
# 26 b'      <namespace key="100" case="first-letter">Portal</namespace>\n'
# 27 b'      <namespace key="101" case="first-letter">Portal talk</namespace>\n'
# 28 b'      <namespace key="118" case="first-letter">Draft</namespace>\n'
# 29 b'      <namespace key="119" case="first-letter">Draft talk</namespace>\n'
# 30 b'      <namespace key="710" case="first-letter">TimedText</namespace>\n'
# 31 b'      <namespace key="711" case="first-letter">TimedText talk</namespace>\n'
# 32 b'      <namespace key="828" case="first-letter">Module</namespace>\n'
# 33 b'      <namespace key="829" case="first-letter">Module talk</namespace>\n'
# 34 b'      <namespace key="2300" case="first-letter">Gadget</namespace>\n'
# 35 b'      <namespace key="2301" case="first-letter">Gadget talk</namespace>\n'
# 36 b'      <namespace key="2302" case="case-sensitive">Gadget definition</namespace>\n'
# 37 b'      <namespace key="2303" case="case-sensitive">Gadget definition talk</namespace>\n'
# 38 b'    </namespaces>\n'
# 39 b'  </siteinfo>\n'
# 40 b'  <page>\n'
# 41 b'    <title>Rational inference</title>\n'
# 42 b'    <ns>0</ns>\n'
# 43 b'    <id>10672790</id>\n'
# 44 b'    <redirect title="Inference" />\n'
# 45 b'    <revision>\n'
# 46 b'      <id>122881452</id>\n'
# 47 b'      <timestamp>2007-04-15T01:15:14Z</timestamp>\n'
# 48 b'      <contributor>\n'
# 49 b'        <username>Grumpyyoungman01</username>\n'
# 50 b'        <id>846078</id>\n'
# 51 b'      </contributor>\n'
# 52 b'      <comment>[[WP:AES|\xe2\x86\x90]]Redirected page to [[Inference]]</comment>\n'
# 53 b'      <model>wikitext</model>\n'
# 54 b'      <format>text/x-wiki</format>\n'
# 55 b'      <text bytes="23" xml:space="preserve">#REDIRECT [[Inference]]</text>\n'
# 56 b'      <sha1>jqp8qihogfm81gql7l3szaafyu82lj9</sha1>\n'
# 57 b'    </revision>\n'
# 58 b'  </page>\n'
# 59 b'  <page>\n'
# 60 b'    <title>Ripcot</title>\n'
# 61 b'    <ns>0</ns>\n'
# 62 b'    <id>10672797</id>\n'
# 63 b'    <redirect title="The Ripping Friends" />\n'
# 64 b'    <revision>\n'
# 65 b'      <id>122987209</id>\n'
# 66 b'      <parentid>122881505</parentid>\n'
# 67 b'      <timestamp>2007-04-15T14:23:39Z</timestamp>\n'
# 68 b'      <contributor>\n'
# 69 b'        <username>RHaworth</username>\n'
# 70 b'        <id>161142</id>\n'
# 71 b'      </contributor>\n'
# 72 b'      <comment>[[WP:AES|\xe2\x86\x90]]Redirected page to [[The Ripping Friends]]</comment>\n'
# 73 b'      <model>wikitext</model>\n'
# 74 b'      <format>text/x-wiki</format>\n'
# 75 b'      <text bytes="33" xml:space="preserve">#redirect [[The Ripping Friends]]</text>\n'
# 76 b'      <sha1>biyizsvwopzalozl09xwmyrmd39vu3n</sha1>\n'
# 77 b'    </revision>\n'
# 78 b'  </page>\n'
# 79 b'  <page>\n'
# 80 b'    <title>Category:Wikipedia sockpuppets of Billy Ego</title>\n'
# 81 b'    <ns>14</ns>\n'
# 82 b'    <id>10672799</id>\n'
# 83 b'    <revision>\n'
# 84 b'      <id>233160114</id>\n'
# 85 b'      <parentid>131712470</parentid>\n'
# 86 b'      <timestamp>2008-08-20T18:35:51Z</timestamp>\n'
# 87 b'      <contributor>\n'
# 88 b'        <username>WilyD</username>\n'
# 89 b'        <id>466673</id>\n'
# 90 b'      </contributor>\n'
# 91 b'      <comment>template</comment>\n'
# 92 b'      <model>wikitext</model>\n'
# 93 b'      <format>text/x-wiki</format>\n'
# 94 b'      <text bytes="351" xml:space="preserve">Accounts confirmed to have been used by [[User:Billy Ego]] for disruptive activities. See [[Wikipedia:Requests for arbitration/Billy Ego-Sandstein]] for details. See also [[Wikipedia:Requests for checkuser/Case/Regulations]] and [[Wikipedia:Requests for checkuser/Case/Billy Ego]].\n'
# 95 b'\n'
# 96 b'[[Category:Wikipedia sockpuppets]]\n'
# 97 b'{{sockpuppet category|Billy Ego}}</text>\n'
# 98 b'      <sha1>638xnvvtsl2m0sgygpeum54iooyv6kv</sha1>\n'
# 99 b'    </revision>\n'
# 100 b'  </page>\n'
# 101 b'  <page>\n'
# 102 b'    <title>Category:Railway stations opened in 1972</title>\n'
# 103 b'    <ns>14</ns>\n'
# 104 b'    <id>10672802</id>\n'
# 105 b'    <revision>\n'
# 106 b'      <id>956370922</id>\n'
# 107 b'      <parentid>952982461</parentid>\n'
# 108 b'      <timestamp>2020-05-13T00:22:00Z</timestamp>\n'
# 109 b'      <contributor>\n'
# 110 b'        <username>BrownHairedGirl</username>\n'
# 111 b'        <id>754619</id>\n'
# 112 b'      </contributor>\n'
# 113 b'      <comment>use [[Template:Railway stations opened in YYYY category header]]</comment>\n'
# 114 b'      <model>wikitext</model>\n'
# 115 b'      <format>text/x-wiki</format>\n'
# 116 b'      <text bytes="104" xml:space="preserve">{{Commons category|Railway stations opened in 1972}}\n'
# 117 b'{{Railway stations opened in YYYY category header}}</text>\n'
# 118 b'      <sha1>gazy7zml66m13pb9p9bnvblzjvykhkm</sha1>\n'
# 119 b'    </revision>\n'
# 120 b'  </page>\n'
# 121 b'  <page>\n'
# 122 b'    <title>Category:Video games developed in Finland</title>\n'
# 123 b'    <ns>14</ns>\n'
# 124 b'    <id>10672805</id>\n'
# 125 b'    <revision>\n'
# 126 b'      <id>1062865451</id>\n'
# 127 b'      <parentid>1053717743</parentid>\n'
# 128 b'      <timestamp>2021-12-30T23:25:15Z</timestamp>\n'
# 129 b'      <contributor>\n'
# 130 b'        <username>Kliituu</username>\n'
# 131 b'        <id>16249527</id>\n'
# 132 b'      </contributor>\n'
# 133 b'      <minor />\n'
# 134 b'      <comment>[[Category:Software developed in Finland]]</comment>\n'
# 135 b'      <model>wikitext</model>\n'
# 136 b'      <format>text/x-wiki</format>\n'
# 137 b'      <text bytes="561" xml:space="preserve">{{Category explanation|[[video game|computer and video games]] that were [[Video game developer|developed]] in [[Finland]]}}\n'
# 138 b"{{Category see also|LABEL=See the following category for video games '''[[Video game publisher|published]]''' by companies based in Finland|Video games by Finnish companies}}\n"
# 139 b'{{Portal|Finland|Video games}}\n'
# 140 b'{{CatAutoTOC}}\n'
# 141 b'\n'
# 142 b'[[Category:Finnish games]]\n'
# 143 b'[[Category:Mass media in Finland]]\n'
# 144 b'[[Category:Video games by country of developer|Finland]]\n'
# 145 b'[[Category:Video gaming in Finland|Games developed]]\n'
# 146 b'[[Category:Software developed in Finland]]</text>\n'
# 147 b'      <sha1>7qqve8p926bdhd4o0ip1en7r80cpfqd</sha1>\n'
# 148 b'    </revision>\n'
# 149 b'  </page>\n'
# 150 b'  <page>\n'
# 151 b'    <title>Dorsa Whiston</title>\n'
# 152 b'    <ns>0</ns>\n'
# 153 b'    <id>10672809</id>\n'
# 154 b'    <revision>\n'
# 155 b'      <id>794958646</id>\n'
# 156 b'      <parentid>544767645</parentid>\n'
# 157 b'      <timestamp>2017-08-11T02:59:22Z</timestamp>\n'
# 158 b'      <contributor>\n'
# 159 b'        <username>Jstuby</username>\n'
# 160 b'        <id>1369254</id>\n'
# 161 b'      </contributor>\n'
# 162 b'      <comment>+image</comment>\n'
# 163 b'      <model>wikitext</model>\n'
# 164 b'      <format>text/x-wiki</format>\n'
# 165 b'      <text bytes="394" xml:space="preserve">\'\'\'Dorsa Whiston\'\'\' is a [[wrinkle ridge]] system at {{Lunar coords and quad cat|29.4|N|56.4|W|globe:Moon}} in [[Oceanus Procellarum]] on the [[Moon]]. It is 85 km long and was named after [[William Whiston]] in 1976.\n'
# 166 b'[[File:Dorsa Whiston AS15-97-13264-5.jpg|thumb|right|300px|Mosaic of [[Apollo 15]] images, showing part of Dorsa Whiston]]\n'
# 167 b'{{moon-stub}}\n'
# 168 b'[[Category:Ridges on the Moon|Whiston]]</text>\n'
# 169 b'      <sha1>dp5g2cdblimkepicdg8itwgiedz710j</sha1>\n'
# 170 b'    </revision>\n'
# 171 b'  </page>\n'
# 172 b'  <page>\n'
# 173 b'    <title>Delphic of Gamma Sigma Tau Fraternity</title>\n'
# 174 b'    <ns>0</ns>\n'
# 175 b'    <id>10672810</id>\n'
# 176 b'    <redirect title="Delphic Fraternity" />\n'
# 177 b'    <revision>\n'
# 178 b'      <id>778172392</id>\n'
# 179 b'      <parentid>661978184</parentid>\n'
# 180 b'      <timestamp>2017-05-01T15:31:15Z</timestamp>\n'
# 181 b'      <contributor>\n'
# 182 b'        <username>Rich Farmbrough</username>\n'
# 183 b'        <id>82835</id>\n'
# 184 b'      </contributor>\n'
# 185 b'      <comment>Update deprecated redirect template.</comment>\n'
# 186 b'      <model>wikitext</model>\n'
# 187 b'      <format>text/x-wiki</format>\n'
# 188 b'      <text bytes="181" xml:space="preserve">#Redirect [[Delphic Fraternity]]\n'
# 189 b'\n'
# 190 b'{{Redirect category shell|1=\n'
# 191 b'{{Redirect from merge}}\n'
# 192 b'{{Redirect from duplicated article}}\n'
# 193 b'{{Redirect from long name}}\n'
# 194 b'{{Redirect unprintworthy}}\n'
# 195 b'}}</text>\n'
# 196 b'      <sha1>bgo5znirj0lg0dry4hvx5479yl34s4v</sha1>\n'
# 197 b'    </revision>\n'
# 198 b'  </page>\n'
# 199 b'  <page>\n'
# 200 b'    <title>Tir na n-og Awards</title>\n'
# 201 b'    <ns>0</ns>\n'
# 202 b'    <id>10672816</id>\n'
# 203 b'    <redirect title="Tir na n-Og Award" />\n'
# 204 b'    <revision>\n'
# 205 b'      <id>249914750</id>\n'
# 206 b'      <parentid>178262189</parentid>\n'
# 207 b'      <timestamp>2008-11-05T21:43:10Z</timestamp>\n'
# 208 b'      <contributor>\n'
# 209 b'        <username>UnitedStatesian</username>\n'
# 210 b'        <id>3461395</id>\n'
# 211 b'      </contributor>\n'
# 212 b'      <comment>fix dbl rdr</comment>\n'
# 213 b'      <model>wikitext</model>\n'
# 214 b'      <format>text/x-wiki</format>\n'
# 215 b'      <text bytes="31" xml:space="preserve">#REDIRECT [[Tir na n-Og Award]]</text>\n'
# 216 b'      <sha1>4abr47b7tf0gj321hjbityv7jn6zkwm</sha1>\n'
# 217 b'    </revision>\n'
# 218 b'  </page>\n'
# 219 b'  <page>\n'
# 220 b'    <title>Chantiers de l\xe2\x80\x99Atlantique</title>\n'
# 221 b'    <ns>0</ns>\n'
# 222 b'    <id>10672827</id>\n'
# 223 b'    <redirect title="Chantiers de l&#039;Atlantique" />\n'
# 224 b'    <revision>\n'
# 225 b'      <id>122881861</id>\n'
# 226 b'      <timestamp>2007-04-15T01:17:32Z</timestamp>\n'
# 227 b'      <contributor>\n'
# 228 b'        <username>Petri Krohn</username>\n'
# 229 b'        <id>382847</id>\n'
# 230 b'      </contributor>\n'
# 231 b"      <comment>[[WP:AES|\xe2\x86\x90]]Redirected page to [[Chantiers de l'Atlantique]]</comment>\n"
# 232 b'      <model>wikitext</model>\n'
# 233 b'      <format>text/x-wiki</format>\n'
# 234 b'      <text bytes="39" xml:space="preserve">#REDIRECT [[Chantiers de l\'Atlantique]]</text>\n'
# 235 b'      <sha1>kujpiehpi4u3mvxkyukr4coktipjkgm</sha1>\n'
# 236 b'    </revision>\n'
# 237 b'  </page>\n'
# 238 b'  <page>\n'
# 239 b'    <title>South Australian general election campaign, 2006</title>\n'
# 240 b'    <ns>0</ns>\n'
# 241 b'    <id>10672834</id>\n'
# 242 b'    <redirect title="2006 South Australian state election" />\n'
# 243 b'    <revision>\n'
# 244 b'      <id>956184141</id>\n'
# 245 b'      <parentid>880882293</parentid>\n'
# 246 b'      <timestamp>2020-05-11T23:31:50Z</timestamp>\n'
# 247 b'      <contributor>\n'
# 248 b'        <username>JJMC89 bot III</username>\n'
# 249 b'        <id>35936988</id>\n'
# 250 b'      </contributor>\n'
# 251 b'      <minor />\n'
# 252 b'      <comment>Moving [[:Category:Protected redirects]] to [[:Category:Fully protected redirects]] per [[Wikipedia:Categories for discussion/Log/2020 May 2#Category:Protected redirects]]</comment>\n'
# 253 b'      <model>wikitext</model>\n'
# 254 b'      <format>text/x-wiki</format>\n'
# 255 b'      <text bytes="89" xml:space="preserve">#REDIRECT [[2006 South Australian state election]]\n'
# 256 b'[[Category:Fully protected redirects]]</text>\n'
# 257 b'      <sha1>h824nksu3d4b2021gvd1jzwuvg8kgmm</sha1>\n'
# 258 b'    </revision>\n'
# 259 b'  </page>\n'
# 260 b'  <page>\n'
# 261 b'    <title>Wikipedia:Featured article review/Lindsay Lohan/archive1</title>\n'
# 262 b'    <ns>4</ns>\n'
# 263 b'    <id>10672841</id>\n'
# 264 b'    <revision>\n'
# 265 b'      <id>1078811473</id>\n'
# 266 b'      <parentid>131534612</parentid>\n'
# 267 b'      <timestamp>2022-03-23T13:10:53Z</timestamp>\n'
# 268 b'      <contributor>\n'
# 269 b'        <username>MalnadachBot</username>\n'
# 270 b'        <id>41830889</id>\n'
# 271 b'      </contributor>\n'
# 272 b'      <minor />\n'
# 273 b'      <comment>Fixed [[WP:LINT|Lint errors]]. ([[User:MalnadachBot/Task 12|Task 12]])</comment>\n'
# 274 b'      <model>wikitext</model>\n'
# 275 b'      <format>text/x-wiki</format>\n'
# 276 b'      <text bytes="6551" xml:space="preserve">&lt;!--FARtop--&gt;&lt;div class=&quot;boilerplate metadata vfd&quot; style=&quot;background-color: #E6F2FF; margin: 2em 0 0 0; padding: 0 10px 0 10px; border: 1px solid #AAAAAA;&quot;&gt;\n'
# 277 b":''The following is an archived discussion of a [[Wikipedia:Featured article review|featured article review]]. &lt;span style=&quot;color:red&quot;&gt;'''Please do not modify it.'''&lt;/span&gt;  Further comments should be made on the article's talk page or at [[Wikipedia talk:Featured article review]]). No further edits should be made to this page.''\n"
# 278 b'\n'
# 279 b"The article was '''removed''' 06:28, 17 May 2007.\n"
# 280 b'----\n'
# 281 b'\n'
# 282 b'===[[Lindsay Lohan]]===\n'
# 283 b'====Review commentary====\n'
# 284 b"::''Messages left at [[User talk:RadioKirk]], [[Wikipedia talk:WikiProject Biography|Bio]], [[Wikipedia talk:WikiProject Biography/Arts and entertainment|Arts and entertainment]], [[Wikipedia talk:WikiProject Films|Films]], [[Wikipedia talk:WikiProject Entertainment|Entertainment]] and [[Wikipedia talk:WikiProject Actors and Filmmakers|Actors and Filmmakers]]''. [[User:LuciferMorgan|LuciferMorgan]] 19:49, 18 April 2007 (UTC)\n"
# 285 b'I am requesting this review at the urging of {{User|67.174.226.172}} and because I agree with the points that that user brings up.  67.174.226.172 states, &quot;Lindsay Lohan is not FA-quality because it fails [[Wikipedia:Why stable versions]], [[WP:BLP]], [[WP:V]] and [[WP:NPOV]] at the very least, and requires de-listing.&quot;  I believe this is absolutely true.  If one or two people spent some time to seriously review the article, we could perhaps get it back to featured-article status but this would require an ongoing effort as well because it is a frequent target of vandalism.  It is on my watchlist but so are so many other articles that I often do not catch edits that reduce its quality.  This request for a review is no reflection on the people who initially brought the article to featured article status.  --[[User:Yamla|Yamla]] 01:18, 15 April 2007 (UTC)\n'
# 286 b'\n'
# 287 b":My response to [[User:Ollie|Ollie]]: How about the repeated addition of anything resembling the drunken &quot;firecrotch&quot; spew? Step for Cep again? Stuart for Mitchell again? (Both cited, once...) How can Lohan and Duff have &quot;reconciled&quot; when both claimed there was no feud to begin with (source fails [[WP:RS]] anyway)? &quot;Lindsay&quot; for &quot;Lohan&quot; (we're on a first-name basis now?)? Dating a female DJ ([[WP:RS]])? Film listings with no sources? A MySpace fan page? Crap like this gets in over and over and over and over again, so [[Wikipedia:Why stable versions]] goes out the window. Not an FA.\n"
# 288 b'\n'
# 289 b"::I've only really been involved with this article to revert vandalism and I'm not a Lohan fan, so I've probably missed most of the non-obvious stuff. What's the &quot;Step for Cep again? Stuart for Mitchell again?&quot; thing? I'll keep an eye out for it in future. --[[User:Kurt Shaped Box|Kurt Shaped Box]] 08:13, 15 April 2007 (UTC)\n"
# 290 b'\n'
# 291 b":::It's Lola Cep (cited, once...) and Casey Mitchell (cited, once...).\n"
# 292 b'\n'
# 293 b"::::I've fixed the 'Cep'. As for the 'Mitchell' thing - there seems to be conflicting online references (some references to the character use one name, some the other). What's the deal here? A screencap of the credits screen would be great... ;) --[[User:Kurt Shaped Box|Kurt Shaped Box]] 16:47, 15 April 2007 (UTC)\n"
# 294 b'\n'
# 295 b":::::Used to be a Disney link, but it's gone. [http://www.variety.com/review/VE1117778750.html?categoryid=32&amp;cs=1 This one] is the most reliable I've found, and I'm pretty sure one was added to the article once. I believe Stuart was announced and it was changed to Mitchell before filming or release, or something like that. But the big picture is getting lost in the more minor [[WP:V]] violations, and that is the [[WP:BLP]]/[[Wikipedia:Why stable versions]] problem, because every time some tabloid scum writes her name or some drunken no-name wannabe scum speaks her name, some &quot;editor&quot; scum makes damned sure it gets in with the most salacious wording possible.\n"
# 296 b'\n'
# 297 b"::::::I assume that you're referring to the 'firecrotch' thing? I've been looking at that myself for a while and TBH, I'm not really sure what to do with it (it *is* cited but I'm unsure as to whether the sources referenced are what WP would consider 'reliable'). I've raised the issue at [[WP:BLPN]]. Hopefully someone with more experience can take a look at it... --[[User:Kurt Shaped Box|Kurt Shaped Box]] 21:28, 15 April 2007 (UTC)\n"
# 298 b'\n'
# 299 b":::::::That's the biggest one now, but it's hardly an orphan. The question with this one is not reliability (we know he said it, I think there were cameras there) but its inclusion weighed against [[WP:BLP]]. It allows the article to demean its subject by validating the drunken spew of an industry wannabe who doesn't merit his own article (because his most famous moment is that spew).\n"
# 300 b'\n'
# 301 b"::::::::You may have a point. I'm not particularly experienced in dealing with BLP issues... --[[User:Kurt Shaped Box|Kurt Shaped Box]] 21:47, 15 April 2007 (UTC)\n"
# 302 b'\n'
# 303 b":&quot;In March, she told OK! magazine that she was writing lyrics for her third album, which she called &quot;different [from] the first two&quot;.&quot;  Click on citation 44, and you'll find that this quote appears nowhere in the original article, which in fact is citing something she said while working on her second album.  Neither Lohan, her management, or Motown records have ever stated that she's creating a third album.  It's a myth that her fans have concocted from a few press slip-ups and disseminated by means of Wikipedia. [[User:75.49.224.232|75.49.224.232]] 15:29, 21 April 2007 (UTC)\n"
# 304 b'\n'
# 305 b'====FARC commentary====\n'
# 306 b'\n'
# 307 b":''Suggested FA criteria concerns are stability (1e), POV (1d), and verifiability (1c).'' [[User:Marskell|Marskell]] 21:11, 30 April 2007 (UTC)\n"
# 308 b'\n'
# 309 b"'''Comment''': Does no one care about Miss Lohan? What will she think of us? [[User:Marskell|Marskell]] 08:48, 13 May 2007 (UTC)\n"
# 310 b"*Well, she can't think much of us already; it's an embarrassment.  '''Remove''', unless someone is prepared to go through and complete the reference formatting, evaluate each source per the highest quality standards required of a BLP, and remove the gossip sources.  [[User:SandyGeorgia|Sandy&lt;span style=&quot;color:green;&quot;&gt;Georgia&lt;/span&gt;]] ([[User talk:SandyGeorgia|Talk]]) 13:40, 13 May 2007 (UTC)\n"
# 311 b"*'''Remove''' per Sandy's reasoning. [[User:LuciferMorgan|LuciferMorgan]] 11:20, 16 May 2007 (UTC)\n"
# 312 b":''The above discussion is preserved as an archive. &lt;span style=&quot;color:red&quot;&gt;'''Please do not modify it.'''&lt;/span&gt; Subsequent comments should be made on the article's talk page or in [[Wikipedia talk:Featured article review]]. No further edits should be made to this page.''&lt;/div&gt;&lt;!--FARbottom--&gt;&lt;!--Tagged by FA bot--&gt;</text>\n"
# 313 b'      <sha1>8zdpnovd7kc01yy7nhs9x2cwjw85axb</sha1>\n'
# 314 b'    </revision>\n'
# 315 b'  </page>\n'
# 316 b'  <page>\n'
# 317 b'    <title>Sr. Maria Stanisia</title>\n'
# 318 b'    <ns>0</ns>\n'
# 319 b'    <id>10672849</id>\n'
# 320 b'    <redirect title="Mary Stanisia" />\n'
# 321 b'    <revision>\n'
# 322 b'      <id>123543890</id>\n'
# 323 b'      <parentid>122882167</parentid>\n'
# 324 b'      <timestamp>2007-04-17T15:10:37Z</timestamp>\n'
# 325 b'      <contributor>\n'
# 326 b'        <username>RussBot</username>\n'
# 327 b'        <id>279219</id>\n'
# 328 b'      </contributor>\n'
# 329 b'      <minor />\n'
# 330 b'      <comment>Robot: Fixing [[Special:DoubleRedirects|double-redirect]] -&quot;Sr. Mary Stanisia&quot; +&quot;Mary Stanisia&quot;</comment>\n'
# 331 b'      <model>wikitext</model>\n'
# 332 b'      <format>text/x-wiki</format>\n'
# 333 b'      <text bytes="27" xml:space="preserve">#REDIRECT [[Mary Stanisia]]</text>\n'
# 334 b'      <sha1>hrgo81vgqoor2m1e5ncmh74j8fczzer</sha1>\n'
# 335 b'    </revision>\n'
# 336 b'  </page>\n'
# 337 b'  <page>\n'
# 338 b'    <title>Humor Monastery</title>\n'
# 339 b'    <ns>0</ns>\n'
# 340 b'    <id>10672850</id>\n'
# 341 b'    <revision>\n'
# 342 b'      <id>1042318732</id>\n'
# 343 b'      <parentid>1013456482</parentid>\n'
# 344 b'      <timestamp>2021-09-04T10:22:21Z</timestamp>\n'
# 345 b'      <contributor>\n'
# 346 b'        <username>Johnsoniensis</username>\n'
# 347 b'        <id>21165869</id>\n'
# 348 b'      </contributor>\n'
# 349 b'      <comment>/* External links */ not stub</comment>\n'
# 350 b'      <model>wikitext</model>\n'
# 351 b'      <format>text/x-wiki</format>\n'
# 352 b'      <text bytes="3142" xml:space="preserve">[[Image:Rares.jpg|thumb|Petru Rare\xc5\x9f]]\n'
# 353 b"'''Humor Monastery''' located in [[M\xc4\x83n\xc4\x83stirea Humorului]], about 5&amp;nbsp;km north of the town of [[Gura Humorului]], [[Romania]]. It is a [[monastery]] for nuns dedicated to the [[Dormition]] of Virgin Mary, or [[Theotokos]]. It was constructed in 1530 by Voievod [[Petru Rare\xc5\x9f]]  and his chancellor [[Teodor Bubuiog]]. The monastery was built over the foundation of a previous monastery that dated from around 1415. The Humor monastery was closed in 1786 and was not reopened until 1990.\n"
# 354 b'\n'
# 355 b'The church has been inscribed by [[UNESCO]] on its list of [[World Heritage Sites]], as one of the [[Churches of Moldavia|Painted churches of Moldavia]].\n'
# 356 b'\n'
# 357 b'==Frescoes==\n'
# 358 b"Humor was one of the first of [[Moldavia]]'s painted monasteries to be frescoed and, along with [[Voronet Monastery (Bucovina, Romania)|Vorone\xc5\xa3]], is probably the best preserved. The dominant colour of the frescoes is a reddish brown. The master painter responsible for Humor's frescoes, which were painted in 1535, is one ''Toma of Suceava''.\n"
# 359 b'\n'
# 360 b"The subjects of the frescoes at Humor include the ''Siege of Constantinople'' and the ''Last Judgment'', common on the exterior of the painted monasteries of Bucovina, but also the ''Hymn to the Virgin'' inspired by the poem of Patriarch [[Sergius I of Constantinople|Sergius of Constantinople]] relating to the miraculous intervention of the [[Theotokos]] in saving the city from Persian conquest in 626. The Persians are, however, depicted as Turks which is a common device in these monasteries, their paintings being used in part for political propaganda in addition to their spiritual meaning.\n"
# 361 b'\n'
# 362 b'==Gallery==\n'
# 363 b'&lt;gallery&gt;\n'
# 364 b'File:Humor Monastery, Romania.jpg|Humor monastery church\n'
# 365 b'File:Humor Monastery Tower.JPG |The tower\n'
# 366 b'File:Humor monastery4.jpg|Interior\n'
# 367 b'File:Humor monastery3.jpg|Interior\n'
# 368 b'File:Humor murals 2010 29.jpg|Exterior\n'
# 369 b'File:Humor murals 2010 01.jpg|Murals\n'
# 370 b'File:Humor murals 2010 24.jpg|Murals\n'
# 371 b'File:Humor murals 2010 05.jpg|Murals\n'
# 372 b'File:Humor murals 2010 04.jpg|Murals\n'
# 373 b'File:Humor murals 2010 28.jpg|Murals\n'
# 374 b'File:Humor murals 2010 14.jpg|Murals\n'
# 375 b'&lt;/gallery&gt;\n'
# 376 b'\n'
# 377 b'==External links==\n'
# 378 b'* Koc\xc3\xb3j E., \xc5\x9awi\xc4\x85tynie, postacie, ikony. Malowane cerkwie i monastyry Bukowiny Po\xc5\x82udniowej w wyobra\xc5\xbceniach rumu\xc5\x84skich, Krak\xc3\xb3w 2006, Wydawnictwo Uniwersytetu Jagiello\xc5\x84skiego, ss. 444, 120 pf, https://www.academia.edu/24331662/%C5%9Awi%C4%85tynie_postacie_ikony._Malowane_cerkwie_i_monastyry_Bukowiny_Po%C5%82udniowej_w_wyobra%C5%BCeniach_rumu%C5%84skich_Temples_persons_icons._Painted_churches_and_monasteries_of_South_Bukovina_in_Romanian_imagology_Wydawnictwo_Uniwersytetu_Jagiello%C5%84skiego_Krak%C3%B3w_2006_s._440\n'
# 379 b'\n'
# 380 b'{{Commons category|Humor monastery}}\n'
# 381 b'* [http://www.romaniaphotos.ro/2010/12/humor-monastery.html Humor Monastery]\n'
# 382 b'* [http://www.users.cloud9.net/~romania/Churches/humor.htm users.cloud9.net]\n'
# 383 b'\n'
# 384 b'{{Authority control}}\n'
# 385 b'{{Coord|47.5931|N|25.8569|E|source:dewiki_region:RO_type:landmark|format=dms|display=title}}\n'
# 386 b'\n'
# 387 b'[[Category:Churches completed in 1473]]\n'
# 388 b'[[Category:Churches completed in 1530]]\n'
# 389 b'[[Category:Christian monasteries established in the 15th century]]\n'
# 390 b'[[Category:Churches of Moldavia]]</text>\n'
# 391 b'      <sha1>mrb1akv329sh7hwlzyywbx4vrfyxivx</sha1>\n'
# 392 b'    </revision>\n'
# 393 b'  </page>\n'
# 394 b'  <page>\n'
# 395 b'    <title>Category:Railway stations opened in 2000</title>\n'
# 396 b'    <ns>14</ns>\n'
# 397 b'    <id>10672853</id>\n'
# 398 b'    <revision>\n'
# 399 b'      <id>956327552</id>\n'
# 400 b'      <parentid>952982621</parentid>\n'
# 401 b'      <timestamp>2020-05-12T19:08:49Z</timestamp>\n'
# 402 b'      <contributor>\n'
# 403 b'        <username>BrownHairedGirl</username>\n'
# 404 b'        <id>754619</id>\n'
# 405 b'      </contributor>\n'
# 406 b'      <comment>use [[Template:Railway stations opened in YYYY category header]]</comment>\n'
# 407 b'      <model>wikitext</model>\n'
# 408 b'      <format>text/x-wiki</format>\n'
# 409 b'      <text bytes="104" xml:space="preserve">{{Commons category|Railway stations opened in 2000}}\n'
# 410 b'{{Railway stations opened in YYYY category header}}</text>\n'
# 411 b'      <sha1>t0g9ixg41i6kfaqw6vmb8b38jkng13u</sha1>\n'
# 412 b'    </revision>\n'
# 413 b'  </page>\n'
# 414 b'  <page>\n'
# 415 b'    <title>Monica Kurkowski</title>\n'
# 416 b'    <ns>0</ns>\n'
# 417 b'    <id>10672855</id>\n'
# 418 b'    <redirect title="Mary Stanisia" />\n'
# 419 b'    <revision>\n'
# 420 b'      <id>124370776</id>\n'
# 421 b'      <parentid>122882250</parentid>\n'
# 422 b'      <timestamp>2007-04-20T15:02:15Z</timestamp>\n'
# 423 b'      <contributor>\n'
# 424 b'        <username>RussBot</username>\n'
# 425 b'        <id>279219</id>\n'
# 426 b'      </contributor>\n'
# 427 b'      <minor />\n'
# 428 b'      <comment>Robot: Fixing [[Special:DoubleRedirects|double-redirect]] -&quot;Sr. Mary Stanisia&quot; +&quot;Mary Stanisia&quot;</comment>\n'
# 429 b'      <model>wikitext</model>\n'
# 430 b'      <format>text/x-wiki</format>\n'
# 431 b'      <text bytes="29" xml:space="preserve">#REDIRECT [[Mary Stanisia]] .</text>\n'
# 432 b'      <sha1>fku1rspbgrbtn0kagxxh9qkuztg2blz</sha1>\n'
# 433 b'    </revision>\n'
# 434 b'  </page>\n'
# 435 b'  <page>\n'
# 436 b'    <title>File:StusDownhillBike.jpg</title>\n'
# 437 b'    <ns>6</ns>\n'
# 438 b'    <id>10672858</id>\n'
# 439 b'    <revision>\n'
# 440 b'      <id>483247463</id>\n'
# 441 b'      <parentid>468483545</parentid>\n'
# 442 b'      <timestamp>2012-03-21T22:31:56Z</timestamp>\n'
# 443 b'      <contributor>\n'
# 444 b'        <username>Helpful Pixie Bot</username>\n'
# 445 b'        <id>14216826</id>\n'
# 446 b'      </contributor>\n'
# 447 b'      <minor />\n'
# 448 b'      <comment>Dated {{Copy to Wikimedia Commons}}. (Build J/)</comment>\n'
# 449 b'      <model>wikitext</model>\n'
# 450 b'      <format>text/x-wiki</format>\n'
# 451 b'      <text bytes="113" xml:space="preserve">== Licensing ==\n'
# 452 b'{{PD-self|date=April 2007}}\n'
# 453 b'\n'
# 454 b'{{Copy to Wikimedia Commons|bot=Fbot|priority=true|date=March 2012}}</text>\n'
# 455 b'      <sha1>47ijjns9r07p0objh9ok1bfls7cnc3z</sha1>\n'
# 456 b'    </revision>\n'
# 457 b'  </page>\n'
# 458 b'  <page>\n'
# 459 b'    <title>Atlantoaxial</title>\n'
# 460 b'    <ns>0</ns>\n'
# 461 b'    <id>10672862</id>\n'
# 462 b'    <redirect title="Atlanto-axial joint" />\n'
# 463 b'    <revision>\n'
# 464 b'      <id>122882348</id>\n'
# 465 b'      <timestamp>2007-04-15T01:20:16Z</timestamp>\n'
# 466 b'      <contributor>\n'
# 467 b'        <username>Arcadian</username>\n'
# 468 b'        <id>104523</id>\n'
# 469 b'      </contributor>\n'
# 470 b'      <comment>redir</comment>\n'
# 471 b'      <model>wikitext</model>\n'
# 472 b'      <format>text/x-wiki</format>\n'
# 473 b'      <text bytes="33" xml:space="preserve">#REDIRECT [[Atlanto-axial joint]]</text>\n'
# 474 b'      <sha1>fgfavh3j7etoefxv9tctfzrq4ugemz2</sha1>\n'
# 475 b'    </revision>\n'
# 476 b'  </page>\n'
# 477 b'  <page>\n'
# 478 b'    <title>Category:WikiProject New Mexico</title>\n'
# 479 b'    <ns>14</ns>\n'
# 480 b'    <id>10672867</id>\n'
# 481 b'    <revision>\n'
# 482 b'      <id>480978138</id>\n'
# 483 b'      <parentid>149606315</parentid>\n'
# 484 b'      <timestamp>2012-03-09T10:09:25Z</timestamp>\n'
# 485 b'      <contributor>\n'
# 486 b'        <username>Yobot</username>\n'
# 487 b'        <id>7328338</id>\n'
# 488 b'      </contributor>\n'
# 489 b'      <minor />\n'
# 490 b'      <comment>Updated hatnote per [[WP:BOTREQ]] + [[WP:GENFIXES|general fixes]] using [[Project:AWB|AWB]] (8000)</comment>\n'
# 491 b'      <model>wikitext</model>\n'
# 492 b'      <format>text/x-wiki</format>\n'
# 493 b'      <text bytes="98" xml:space="preserve">{{Further2|[[Wikipedia:WikiProject New Mexico]]}}\n'
# 494 b'\n'
# 495 b'[[Category:WikiProject U.S. states|New Mexico]]</text>\n'
# 496 b'      <sha1>i3dxrwvduop47fjls2uosixdwddrjw7</sha1>\n'
# 497 b'    </revision>\n'
# 498 b'  </page>\n'
# 499 b'  <page>\n'
# 500 b'    <title>URGI</title>\n'
# 501 b'    <ns>0</ns>\n'
# 502 b'    <id>10672886</id>\n'
# 503 b'    <redirect title="Avenue (store)" />\n'
# 504 b'    <revision>\n'
# 505 b'      <id>512079052</id>\n'
# 506 b'      <parentid>122882674</parentid>\n'
# 507 b'      <timestamp>2012-09-12T21:52:43Z</timestamp>\n'
# 508 b'      <contributor>\n'
# 509 b'        <username>AvicBot</username>\n'
# 510 b'        <id>11952314</id>\n'
# 511 b'      </contributor>\n'
# 512 b'      <minor />\n'
# 513 b'      <comment>Robot: Fixing double redirect to [[Avenue (store)]]</comment>\n'
# 514 b'      <model>wikitext</model>\n'
# 515 b'      <format>text/x-wiki</format>\n'
# 516 b'      <text bytes="28" xml:space="preserve">#REDIRECT [[Avenue (store)]]</text>\n'
# 517 b'      <sha1>hgdpzqdu2rvypzqi3herx6gpdftdxs2</sha1>\n'
# 518 b'    </revision>\n'
# 519 b'  </page>\n'
# 520 b'  <page>\n'
# 521 b'    <title>Template:University of Wisconsin\xe2\x80\x93Milwaukee</title>\n'
# 522 b'    <ns>10</ns>\n'
# 523 b'    <id>10672889</id>\n'
# 524 b'    <revision>\n'
# 525 b'      <id>963300589</id>\n'
# 526 b'      <parentid>963214359</parentid>\n'
# 527 b'      <timestamp>2020-06-19T01:20:42Z</timestamp>\n'
# 528 b'      <contributor>\n'
# 529 b'        <username>Tom Danson</username>\n'
# 530 b'        <id>1788837</id>\n'
# 531 b'      </contributor>\n'
# 532 b'      <model>wikitext</model>\n'
# 533 b'      <format>text/x-wiki</format>\n'
# 534 b'      <text bytes="3808" xml:space="preserve">{{Navbox\n'
# 535 b'| name = University of Wisconsin\xe2\x80\x93Milwaukee\n'
# 536 b'| title = {{colored link|white|University of Wisconsin\xe2\x80\x93Milwaukee}}\n'
# 537 b'| basestyle = {{CollegePrimaryStyle|Milwaukee Panthers|color=white}}\n'
# 538 b'| state = {{{state&lt;includeonly&gt;|collapsed&lt;/includeonly&gt;}}}\n'
# 539 b'| listclass = hlist\n'
# 540 b'\n'
# 541 b'|group1 = {{colored link|white|University of Wisconsin\xe2\x80\x93Milwaukee academics|Academics}}\n'
# 542 b'|list1 =\n'
# 543 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee College of Engineering and Applied Science|College of Engineering &amp; Applied Science]]\n'
# 544 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee College of Health Sciences|College of Health Sciences]]\n'
# 545 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee College of Letters and Science|College of Letters and Science]]\n'
# 546 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee College of Nursing|College of Nursing]]\n'
# 547 b'* [[Helen Bader School of Social Welfare|School of Social Welfare]]\n'
# 548 b'* [[Peck School of the Arts|School of the Arts]]\n'
# 549 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee School of Architecture and Urban Planning|School of Architecture &amp; Urban Planning]]\n'
# 550 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee School of Education|School of Education]]\n'
# 551 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee School of Information Studies|School of Information Studies]]\n'
# 552 b'* [[Sheldon B. Lubar School of Business|School of Business]]\n'
# 553 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee School of Public Health|School of Public Health]]\n'
# 554 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee School of Freshwater Sciences|School of Freshwater Sciences]]\n'
# 555 b'\n'
# 556 b'|group2 = Research\n'
# 557 b'|list2 =\n'
# 558 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee#UWM Research Foundation|UWM Research Foundation]]\n'
# 559 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee#Research Growth Initiative|Research Growth Initiative]]\n'
# 560 b'* [[Great Lakes WATER Institute]]\n'
# 561 b'* [[Einstein@Home]]\n'
# 562 b'\n'
# 563 b'|group3 = Campus\n'
# 564 b'|list3 =\n'
# 565 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee Libraries]]\n'
# 566 b'* [[UWM Union]]\n'
# 567 b'* [[Sandburg  Halls]]\n'
# 568 b'* [[Thomas A. Greene Memorial Museum|Greene Geological Museum]]\n'
# 569 b'* [[Helene Zelazo Center for the Performing Arts|Helene Zelazo Center]]\n'
# 570 b'\n'
# 571 b'|group4 = Athletics\n'
# 572 b'|list4 =\n'
# 573 b'* [[Milwaukee Panthers]]\n'
# 574 b'** [[Milwaukee Panthers baseball|Baseball]]\n'
# 575 b"** [[Milwaukee Panthers men's basketball|Men's basketball]]\n"
# 576 b"** [[Milwaukee Panthers women's basketball|Women's basketball]]\n"
# 577 b'** [[Milwaukee Panthers football|Football]]\n'
# 578 b'* [[Horizon League]]\n'
# 579 b'* [[Engelmann Field]]\n'
# 580 b'* [[Klotsche Center|J. Martin Klotsche Center]]\n'
# 581 b'* [[Franklin Field (Wisconsin)|Franklin Field]]\n'
# 582 b'\n'
# 583 b'|group5 = {{colored link|white|List of University of Wisconsin\xe2\x80\x93Milwaukee people|People}}\n'
# 584 b'|list5 =\n'
# 585 b'* [[List of University of Wisconsin\xe2\x80\x93Milwaukee people#Notable alumni|Notable alumni]]\n'
# 586 b'* [[List of University of Wisconsin\xe2\x80\x93Milwaukee people#Notable faculty|Notable faculty]]\n'
# 587 b'* [[Milwaukee Panthers#Notable people|Notable athletes and sports figures]]\n'
# 588 b'* [[List of University of Wisconsin\xe2\x80\x93Milwaukee people#University chancellors|University chancellors]]\n'
# 589 b'\n'
# 590 b'|group6 = Student life\n'
# 591 b'|list6 =\n'
# 592 b'* [[Student Association at UWM|Student Association]]\n'
# 593 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee#Housing|Housing]]\n'
# 594 b'* [[WUWM]]\n'
# 595 b"* ''[[UWM Post]]''\n"
# 596 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee#Student organizations|Student organizations]]\n'
# 597 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee#Performing arts venues|Performing arts venues]]\n'
# 598 b'* [[University of Wisconsin\xe2\x80\x93Milwaukee#In popular culture|In popular culture]]\n'
# 599 b'* [[History of the University of Wisconsin\xe2\x80\x93Milwaukee|History]]\n'
# 600 b'\n'
# 601 b'|group7 = Public art\n'
# 602 b'|list7 =\n'
# 603 b"* ''[[Lapham Memorial]]''\n"
# 604 b"* ''[[Three Bronze Discs]]''\n"
# 605 b"* ''[[Milwaukee (Greenamyer)|Milwaukee]]''\n"
# 606 b"* ''[[Polyphony (Weiner)|Polyphony]]''\n"
# 607 b"* ''[[Float (sculpture)|Float]]''\n"
# 608 b"* ''[[Happy-Go-Luckies of Nature and Technology]]''\n"
# 609 b"* ''[[Jantar-Mantar]]''\n"
# 610 b"* ''[[Pangaea (sculpture)|Pangaea]]''\n"
# 611 b'\n'
# 612 b'| group8 = Related\n'
# 613 b'| list8 =\n'
# 614 b'* [[University of Wisconsin System]]\n'
# 615 b'}}&lt;noinclude&gt;\n'
# 616 b'[[Category:Wisconsin universities and colleges navigational boxes]]\n'
# 617 b'&lt;/noinclude&gt;</text>\n'
# 618 b'      <sha1>b9svfe3z7fr1uqzrj1v8e7yfm8lfsl1</sha1>\n'
# 619 b'    </revision>\n'
# 620 b'  </page>\n'
# 621 b'  <page>\n'
# 622 b'    <title>Panagiotis Fassoulas</title>\n'
# 623 b'    <ns>0</ns>\n'
# 624 b'    <id>10672891</id>\n'
# 625 b'    <redirect title="Panagiotis Fasoulas" />\n'
# 626 b'    <revision>\n'
# 627 b'      <id>122882756</id>\n'
# 628 b'      <timestamp>2007-04-15T01:22:35Z</timestamp>\n'
# 629 b'      <contributor>\n'
# 630 b'        <username>Parisinos</username>\n'
# 631 b'        <id>1297602</id>\n'
# 632 b'      </contributor>\n'
# 633 b'      <comment>[[WP:AES|\xe2\x86\x90]]Redirected page to [[Panagiotis Fasoulas]]</comment>\n'
# 634 b'      <model>wikitext</model>\n'
# 635 b'      <format>text/x-wiki</format>\n'
# 636 b'      <text bytes="33" xml:space="preserve">#REDIRECT [[Panagiotis Fasoulas]]</text>\n'
# 637 b'      <sha1>l5efd145gbbtgk0rt0vtlb2kbsm27ej</sha1>\n'
# 638 b'    </revision>\n'
# 639 b'  </page>\n'
# 640 b'  <page>\n'
# 641 b'    <title>Portal:Michigan/Selected biography/2</title>\n'
# 642 b'    <ns>100</ns>\n'
# 643 b'    <id>10672895</id>\n'
# 644 b'    <revision>\n'
# 645 b'      <id>907529505</id>\n'
# 646 b'      <parentid>853901945</parentid>\n'
# 647 b'      <timestamp>2019-07-23T14:43:03Z</timestamp>\n'
# 648 b'      <contributor>\n'
# 649 b"        <username>Spike 'em</username>\n"
# 650 b'        <id>23908470</id>\n'
# 651 b'      </contributor>\n'
# 652 b'      <minor />\n'
# 653 b'      <comment>/* top */replace links to [[batting average]] with relevant sport specific link</comment>\n'
# 654 b'      <model>wikitext</model>\n'
# 655 b'      <format>text/x-wiki</format>\n'
# 656 b'      <text bytes="1269" xml:space="preserve">{{Portal:Michigan/Selected biography/Layout \n'
# 657 b'  |image=\n'
# 658 b'  |size=80px\n'
# 659 b'  |caption=Frederick Lee &quot;Ted&quot; Petoskey\n'
# 660 b"  |text='''[[Ted Petoskey|Frederick Lee &quot;Ted&quot; Petoskey]]''' (born January 5, 1911 in [[St. Charles, Michigan]], died November 30, 1996 in [[Elgin, Kershaw County, South Carolina|Elgin, South Carolina]]) was a three-sport athlete at the [[University of Michigan]], a [[Major League Baseball]] player, a collegiate coach in three sports and an [[athletic director]]. At the [[University of Michigan]], Petoskey received eight [[varsity letter]]s in three sports.  In [[American football]], he was a two-time [[College Football All-America Team|All-American]] [[End (football)|end]] for the undefeated [[Michigan Wolverines football]] teams that won back-to-back [[college football]] National Championships in 1932 and 1933.  He was also a guard and captain of Michigan's [[basketball]] team in the 1933&amp;ndash;34 season.  As a [[baseball]] player in 1934, Petoskey led the [[Big Ten Conference]] with a .452 [[batting average (baseball)|batting average]]. Petoskey played parts of the {{by|1934}} and {{by|1935}} Major League Baseball seasons as an [[outfielder]] for the [[Cincinnati Reds]] and played [[minor league baseball]] until 1944.\n"
# 661 b'  |link=Ted Petoskey\n'
# 662 b'}}</text>\n'
# 663 b'      <sha1>ooijxy7kfppdrlar7dvpdwmoovspc7h</sha1>\n'
# 664 b'    </revision>\n'
# 665 b'  </page>\n'
# 666 b'  <page>\n'
# 667 b'    <title>Dysplasia of the hip</title>\n'
# 668 b'    <ns>0</ns>\n'
# 669 b'    <id>10672897</id>\n'
# 670 b'    <redirect title="Hip dysplasia" />\n'
# 671 b'    <revision>\n'
# 672 b'      <id>122882867</id>\n'
# 673 b'      <timestamp>2007-04-15T01:23:05Z</timestamp>\n'
# 674 b'      <contributor>\n'
# 675 b'        <username>Arcadian</username>\n'
# 676 b'        <id>104523</id>\n'
# 677 b'      </contributor>\n'
# 678 b'      <comment>redir</comment>\n'
# 679 b'      <model>wikitext</model>\n'
# 680 b'      <format>text/x-wiki</format>\n'
# 681 b'      <text bytes="27" xml:space="preserve">#REDIRECT [[Hip dysplasia]]</text>\n'
# 682 b'      <sha1>cp3wbg9x2q4z606ecc0vcj9u0d7dibv</sha1>\n'
# 683 b'    </revision>\n'
# 684 b'  </page>\n'
# 685 b'  <page>\n'
# 686 b'    <title>Tir na n-Og Award</title>\n'
# 687 b'    <ns>0</ns>\n'
# 688 b'    <id>10672900</id>\n'
# 689 b'    <revision>\n'
# 690 b'      <id>1082813551</id>\n'
# 691 b'      <parentid>965307230</parentid>\n'
# 692 b'      <timestamp>2022-04-15T07:30:55Z</timestamp>\n'
# 693 b'      <contributor>\n'
# 694 b'        <username>BrownHairedGirl</username>\n'
# 695 b'        <id>754619</id>\n'
# 696 b'      </contributor>\n'
# 697 b'      <minor />\n'
# 698 b'      <comment>add {{[[Template:Use dmy dates|Use dmy dates]]}}</comment>\n'
# 699 b'      <model>wikitext</model>\n'
# 700 b'      <format>text/x-wiki</format>\n'
# 701 b'      <text bytes="22415" xml:space="preserve">{{Use dmy dates|date=April 2022}}\n'
# 702 b"The '''Tir na n-Og Awards''' (abbreviated '''TnaO''') are a set of annual [[children's literature|children's]] [[literary awards]] in Wales from 1976. They are presented by the [[Books Council of Wales]] to the best books published during the preceding calendar year in each of three awards categories, one [[English-language]] and two [[Welsh-language]]. Their purpose is &quot;[to raise] the standard of children's and young people's books and to encourage the buying and reading of good books.&quot; There is no restriction to fiction or prose. Each prize is \xc2\xa31,000.&lt;ref name=about2012/&gt;\n"
# 703 b'\n'
# 704 b'The awards are named for [[T\xc3\xadr na n\xc3\x93g]], the &quot;Land of the Young&quot;, an otherworldly realm in [[Irish mythology]].\n'
# 705 b'\n'
# 706 b"The English-language award honours one book with an &quot;authentic Welsh background&quot; whose original language is English. It is sponsored by the British [[Chartered Institute of Library and Information Professionals]], Cymru Wales division (CILIP/Wales), and presented at that association's annual conference in May.&lt;ref name=about2012/&gt;\n"
# 707 b'\n'
# 708 b'The Welsh-language Primary Sector and Secondary Sector awards honour one book written for [[Primary Education in Wales|primary school]] children and one for [[Secondary Education in Wales|secondary school]] children.&lt;!-- see Talk --&gt;&lt;ref name=about2012/&gt;\n'
# 709 b'They are presented at the annual [[Urdd National Eisteddfod]], recently at the beginning of June or end of May.&lt;ref name=about2012/&gt;&lt;ref name=award2011/&gt;&lt;ref name=award2012/&gt;&lt;ref name=award2013/&gt;\n'
# 710 b'Since 2011, the Welsh-language awards are co-sponsored by the Cardigan-based publisher [[Cymdeithas Lyfrau Ceredigion]].&lt;ref name=award2011/&gt;&lt;ref name=award2012/&gt;&lt;ref name=award2013/&gt;&lt;ref name=award2014/&gt;\n'
# 711 b'\n'
# 712 b'Shortlists comprising three or four books in each awards category have been published by BCW at least from 2011.&lt;ref name=award2011/&gt;&lt;ref name=award2012/&gt;&lt;ref name=award2013/&gt;&lt;ref name=award2014/&gt;\n'
# 713 b'\n'
# 714 b'== Recent awards ==\n'
# 715 b'\n'
# 716 b';2019\n'
# 717 b'\n'
# 718 b'The 2018/2019 cycle was completed by announcements of the English-language winner on 16 May 2019 and the two Welsh-language winners at the Urdd National Eisteddfod on 30 May.\n'
# 719 b'\n'
# 720 b"The primary sector award went to Elin Meek and Val\xc3\xa9riane Leblond for ''Cymru ar y Map'', a lavishly illustrated picture atlas of Wales, published by Rily Publications.\n"
# 721 b'\n'
# 722 b"The secondary sector award went to [[Manon Steffan Ros]] for ''Fi a Joe Allen'', a football novel about a fan following the Welsh team to France, published by [[Y Lolfa]].\n"
# 723 b'\n'
# 724 b"The English-language award was presented to [[Catherine Fisher]] for ''The Clockwork Crow'', a tale of enchantment involving Welsh folklore and set in a snowy Welsh landscape, published by Firefly Press.&lt;ref&gt;[http://www.books.wales/news/news-detail?id=13300 &quot;Catherine Fisher wins the Tir na n-Og children's literature award with The Clockwork Crow&quot;] Welsh Books Council. 16 May 2019. Retrieved 2019-09-07.&lt;/ref&gt;\n"
# 725 b'\n'
# 726 b';2016\n'
# 727 b'\n'
# 728 b'The 2015/2016 cycle was completed by announcements of the English-language winner on 26 May 2016 and the two Welsh-language winners at the Urdd National Eisteddfod on 2 June. Three shortlists of three or four books had been announced in March.&lt;ref&gt;[http://www.gomer.co.uk/index.php/news/2016TirnanOgShortlist/ 2016 Tir na n-Og shortlist, Gomer Press]&lt;/ref&gt;\n'
# 729 b'\n'
# 730 b"The primary sector award went to Sian Lewis and Val\xc3\xa9riane Leblond for ''Pedair Cainc y Mabinogi'', a retelling of the [[Four Branches of the Mabinogi]], published by Rily Publications.\n"
# 731 b'\n'
# 732 b"The secondary sector award went to Llyr Titus for ''Gwalia'', a space travel adventure, published by [[Gomer Press]].\n"
# 733 b'\n'
# 734 b"The English-language award was presented to Griff Rowland for ''The Search For Mister Lloyd'', about a Welsh boy's search for his missing racing pigeon, published by Candy Jar Books.&lt;ref&gt;[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-n-og-2016 Tir na-g 2016, Welsh Books Council]&lt;/ref&gt;\n"
# 735 b'\n'
# 736 b';2015\n'
# 737 b'The 2014/2015 cycle was completed by announcements of the English-language winner on 14 May 2015 and the two Welsh-language winners at the Urdd National Eisteddfod on 28 May. Three shortlists of three or four books had been announced 26 March.&lt;ref&gt;[http://www.books.wales/newyddion-news/news-detail?id=12912 &quot;2015 Tir na n-Og Award Shortlist Announced&quot;]. Welsh Books Council. Retrieved 2015-04-27.&lt;/ref&gt;\n'
# 738 b'\n'
# 739 b"The primary sector award went to [[Caryl Lewis]] for ''Straeon Gorau'r Byd'', a collection of stories from all over the world, published by [[Gwasg Carreg Gwalch]].&lt;ref name=WBN /&gt;\n"
# 740 b'\n'
# 741 b"The secondary sector award went to Gareth F. Williams for ''Y G\xc3\xaam'', a novel about football and friendship centred on events of the First World War, notably the [[Christmas truce]], published by [[Gwasg Carreg Gwalch]].&lt;ref name=WBN /&gt;\n"
# 742 b'\n'
# 743 b"The English-language award was presented on 14 May 2015 at Swansea Central Library to Giancarlo Gemin for ''Cowgirl'', a story of two very different girls in contemporary south Wales, published by [[Nosy Crow]].&lt;ref&gt;[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog2015 &quot;Tir Na n-Og 2015: First-time author scoops Tir Na n-Og Award&quot;]. WBC. Retrieved 2015-10-18.&lt;/ref&gt;\n"
# 744 b'\n'
# 745 b';2014\n'
# 746 b'The 2013/2014 cycle was completed 29 May 2014 at the [[Urdd National Eisteddfod]] in [[Pembrokeshire]] with the presentation of the two Welsh-language awards.&lt;ref&gt;[http://aberdareonline.co.uk/content/historical-novels-triumph-2014-tir-na-n-og-awards &quot;Historical Novels Triumph At The 2014 Tir Na N-Og Awards&quot;]. AberdareOnline. 29 May 2014. Retrieved 2014-06-23.&lt;/ref&gt;\n'
# 747 b'\n'
# 748 b"The primary sector award went to Gareth F. Williams for ''Cwmwl dros y Cwm'', a historical novel set in [[Senghenydd]] in South Wales at the time of the [[Senghenydd Colliery Disaster|disastrous colliery explosion]] in 1913, published by [[Gwasg Carreg Gwalch]].\n"
# 749 b'\n'
# ...
# 776 b"* Welsh, Primary: ''Dosbarth Miss Prydderch a'r Carped Hud'', [[Mererid Hopwood]] (her 2nd TnO Award) \n"
# 777 b"* Welsh, Secondary: ''Mae'r Lleuad ynGoch'', [[Myrddin ap Dafydd]] (his 2nd TnO Award)\n"
# 778 b'\n'
# 779 b';2017\n'
# 780 b"* English-language: ''Sweet Pizza'', [[Giancarlo Gemin]] (his 2nd TnO Award)\n"
# 781 b"* Welsh, Primary: ''ABC Byd Natur'', [[Luned Aaron]] \n"
# 782 b"* Welsh, Secondary: ''Pluen'', [[Manon Steffan Ros]] (her 3rd TnO Award)\n"
# 783 b'\n'
# 784 b';2016\n'
# 785 b"* English-language: ''The Search for Mister Lloyd'', [[Griff Rowland]]\n"
# 786 b"* Welsh, Primary: ''Pedair Cainc Y Mabinogi'', [[Si\xc3\xa2n Lewis]] (her 2nd TnO Award), illustrated by Valeriane Leblond\n"
# 787 b"* Welsh, Secondary: ''Gwalia'', [[Ll\xc5\xb7r Titus]]\n"
# 788 b'\n'
# 789 b';2015\n'
# 790 b"* English-language: ''Cowgirl'', [[Giancarlo Gemin]]\n"
# 791 b"* Welsh, Primary: ''Straeon Gorau'r Byd'', [[Caryl Lewis]] (her 2nd TnO Award)\n"
# 792 b"* Welsh, Secondary: ''Y G\xc3\xaam'', [[Gareth F. Williams]]  (his 6th TnO Award)\n"
# 793 b'\n'
# 794 b';2014&lt;ref name=award2014/&gt;\n'
# 795 b"* English-language: ''Welsh Cakes and Custard'', [[Wendy White (writer)|Wendy White]], illustrated by Helen Flook &lt;!--publ Pont/Gomer --&gt;\n"
# 796 b"* Welsh, Primary: ''Cwmwl dros y Cwm'', [[Gareth F. Williams]] (his 5th TnO Award) &lt;!--publ Carreg Gwalch --&gt;\n"
# 797 b"* Welsh, Secondary: ''Diffodd y S\xc3\xaar'', [[Haf Llewelyn]] &lt;!--publ Y Lolfa --&gt;\n"
# 798 b'\n'
# 799 b';2013&lt;ref name=award2013/&gt;\n'
# 800 b"* English-language: ''[[Tree of Leaf and Flame]]'', [[Daniel Morden]]\n"
# 801 b"* Welsh, Primary: ''Cynefin yr Ardd'', [[Iolo Williams]] and [[Bethan Wyn Jones]]\n"
# 802 b"* Welsh, Secondary: ''Y G\xc3\xaamau Olympaidd a Champau\xe2\x80\x99r Cymry'', [[Alun Wyn Bevan]]\n"
# 803 b'\n'
# 804 b';2012&lt;ref name=award2012/&gt;\n'
# 805 b"* English-language: ''[[Full Moon (Jenny Sullivan novel)|Full Moon]]'', [[Jennifer Sullivan (writer)|Jenny Sullivan]]\n"
# 806 b"* Welsh, Primary: ''[[Prism (novel)|Prism]]'', [[Manon Steffan Ros]]\n"
# 807 b"* Welsh, Secondary: ''[[Yr Alarch Du]]'', [[Rhiannon Wyn]]\n"
# 808 b'\n'
# 809 b';2011&lt;ref name=award2011/&gt;\n'
# 810 b"* English-language:  ''[[Three Little Sheep]]'', [[Rob Lewis (writer)|Rob Lewis]]\n"
# 811 b"* Welsh, Primary: ''[[Dirgelwch y Bont]]'', [[Hywel Griffiths]]\n"
# 812 b"* Welsh, Secondary: ''[[Stwff Guto S. Tomos]]'', [[Lleucu Roberts]]\n"
# 813 b'\n'
# 814 b';2010&lt;ref name=award2010/&gt;\n'
# 815 b"* English-language: ''[[Dear Mr Author]]'', [[Paul Manship (author)|Paul Manship]]\n"
# 816 b"* Welsh, Primary: ''[[Trwy\xe2\x80\x99r Tonnau]]'', [[Manon Steffan Ros]]\n"
# 817 b"* Welsh, Secondary: ''[[Codi Bwganod]]'', [[Rhiannon Wyn]]\n"
# 818 b'\n'
# 819 b';2009&lt;ref name=award2009/&gt;\n'
# 820 b"* English-language: ''[[Merlin's Magical Creatures]]'', [[Graham Howells]]\n"
# 821 b"* Welsh, Primary: ''[[Bownsio]]'', [[Emily Huws]]\n"
# 822 b"* Welsh, Secondary: ''[[Annwyl Smotyn Bach]]'', [[Lleucu Roberts]]\n"
# 823 b'\n'
# 824 b';2008&lt;ref name=award2008/&gt;\n'
# 825 b"* English-language: ''[[Finding Minerva]]'', [[Frances Thomas]]\n"
# 826 b"* Welsh, Primary: ''[[Y Llyfr Ryseitiau: Gwaed y Tylwyth]]'', [[Nicholas Daniels]]\n"
# 827 b"* Welsh, Secondary: ''[[Eira M\xc3\xa2n, Eira Mawr]]'', [[Gareth F. Williams]]\n"
# 828 b'\n'
# 829 b';2007&lt;ref name=award2007/&gt;\n'
# 830 b"* English-language: ''[[Dark Tales from the Woods]]'', [[Daniel Morden]]\n"
# 831 b"* Welsh, Primary: ''[[Ein Rhyfel Ni]]'', [[Mair Wynn Hughes]]\n"
# 832 b"* Welsh, Secondary: ''[[Adref Heb Elin]]'', [[Gareth F. Williams]]\n"
# 833 b'\n'
# 834 b';2006\n'
# 835 b"* English-language: ''[[Tirion's Secret Journal]]'', [[Jennifer Sullivan (writer)|Jenny Sullivan]]\n"
# 836 b"* Welsh, Primary: ''[[Carreg Ateb]]'', [[Emily Huws]]\n"
# 837 b"* Welsh, Secondary: ''[[Creadyn]]'', [[Gwion Hallam]]\n"
# 838 b'\n'
# 839 b'Before 2006 the dual Welsh-language awards recognised fiction and nonfiction books.\n'
# 840 b';2005\n'
# 841 b"* English-language: ''[[The Seal Children]]'', [[Jackie Morris]]\n"
# 842 b"* Welsh, Fiction: ''[[Eco (children's book)|Eco]]'', [[Emily Huws]]\n"
# 843 b"* Welsh, Nonfiction: ''[[Byd Llawn Hud]]'', [[Ceri Wyn Jones]], [[Tudur Dylan]], [[Mererid Hopwood]], [[Sonia Edwards]] and [[Elinor Wyn Reynold]]\n"
# 844 b';2004\n'
# 845 b"* English-language: ''[[The Battle of Mametz Wood, 1916]]'', [[Robert Phillips (writer)|Robert Phillips]]\n"
# 846 b"* Welsh, Fiction: ''[[Iawn Boi?]]'', [[Caryl Lewis]]\n"
# 847 b"* Welsh, Nonfiction: ''[[Stori Dafydd ap Gwilym]]'', [[Gwyn Thomas (poet)|Gwyn Thomas]] &amp; [[Margaret Jones (writer)|Margaret Jones]]\n"
# 848 b';2003\n'
# 849 b"* English-language: ''[[Cold Jac]]'', [[Rob Lewis (writer)|Rob Lewis]]\n"
# 850 b"* Welsh, Fiction: ''[[Sg\xc3\xb4r]]'', [[Bethan Gwanas]]\n"
# 851 b"* Welsh, Nonfiction: ''[[Saint David|Dewi Sant]]'', [[Rhiannon Ifans]] &amp; [[Margaret Jones (writer)|Margaret Jones]]\n"
# 852 b';2002\n'
# 853 b"* English-language: ''[[Georgie (book)|Georgie]]'', [[Malachy Doyle]]\n"
# 854 b"* Welsh, Fiction: ''[[Gwirioni]]'', [[Shoned Wyn Jones]]\n"
# 855 b"* Welsh, Nonfiction: ''[[Poeth! Cerddi Poeth ac Oer]]'', [[Non ap Emlyn]] &amp; [[Marian Delyth]]\n"
# 856 b';2001\n'
# 857 b"* English-language: ''[[The Seeing Stone]]'', [[Kevin Crossley-Holland]]\n"
# 858 b"* Welsh, Fiction: ''[[Llinyn Tr\xc3\xb4ns]]'', [[Bethan Gwanas]]\n"
# 859 b"* Welsh, Nonfiction: ''[[Jam Coch Mewn Pwdin Reis]]'', [[Myrddin ap Dafydd]]\n"
# 860 b';2000\n'
# 861 b"* English-language: ''[[Artworks On ... Interiors]]'', [[Jo Dahn]] &amp; [[Justine Baldwin]]\n"
# 862 b"* Welsh, Fiction: ''[[Ta Ta-Tryweryn]]'', [[Gwenno Hughes]]\n"
# 863 b"* Welsh, Nonfiction: ''[[Chwedlau o\xe2\x80\x99r Gwledydd Celtaidd]]'', [[Rhiannon Ifans]] &amp; [[Margaret Jones (writer)|Margaret Jones]]\n"
# 864 b'\n'
# 865 b';1999\n'
# 866 b"* English-language: ''[[Rhian\xe2\x80\x99s Song]]'', [[Gillian Drake]]\n"
# 867 b"* Welsh, Fiction: ''[[Pam Fi Eto, Duw?]]'', [[John Owen (author)|John Owen]]\n"
# 868 b"* Welsh, Nonfiction: ''[[Byw a Bod yn y B\xc3\xa0th]]'', [[Lis Jones]]\n"
# 869 b';1998\n'
# 870 b"* English-language: ''[[Alwena\xe2\x80\x99s Garden]]'', [[Mary Oldham]]\n"
# 871 b"* Welsh, Fiction: ''[[Dyddiau C\xc5\xb5n]]'', [[Gwen Redvers Jones]]\n"
# 872 b"* Welsh, Nonfiction: ''[[Stori Branwen]]'', [[Tegwyn Jones]] &amp; [[Jac Jones]]\n"
# 873 b';1997\n'
# 874 b"* English-language: ''[[Cities in the Sea]]'', [[Si\xc3\xa2n Lewis]] &amp; [[Jackie Morris]]\n"
# 875 b"* Welsh, Fiction: ''[[Ydy Fe!]]'', [[John Owen (author)|John Owen]]\n"
# 876 b"* Welsh, Nonfiction: ''[[Dirgelwch Loch Ness]]'', [[Gareth F. Williams]]\n"
# 877 b';1996\n'
# 878 b"* English-language: ''[[Who\xe2\x80\x99s Afraid of the Bwgan-wood?]]'', [[Anne Lewis (writer)|Anne Lewis]]\n"
# 879 b"* Welsh, Fiction: ''[[Coch yw Lliw Hunllef]]'', [[Mair Wynn Hughes]]\n"
# 880 b"* Welsh, Nonfiction: ''[[Sbectol Inc]]'', [[Eleri Ellis Jones]] &amp; [[Marian Delyth]]\n"
# 881 b';1995\n'
# 882 b"* English-language: ''[[The Candle Man]]'', [[Catherine Fisher]]\n"
# 883 b"* Welsh, Fiction: ''[[Pam Fi, Duw, Pam Fi?]]'', [[John Owen (author)|John Owen]]\n"
# 884 b"* Welsh, Nonfiction: ''[[Geiriadur Gomer i\xe2\x80\x99r Ifanc]]'', [[D Geraint Lewis]]\n"
# 885 b';1994\n'
# 886 b"* English-language: ''[[Denny and the Magic Pool]]'', [[Pamela Purnell]]\n"
# 887 b"* Welsh, Fiction: ''[[Sothach a Sglyfath]]'', [[Angharad Tomos]]\n"
# 888 b"* Welsh, Nonfiction: ''[[Cristion Ydw I]]'', [[Huw John Hughes &amp; Rheinallt Thomas]]\n"
# 889 b';1993\n'
# 890 b"* English-language: ''Award withheld''\n"
# 891 b"* Welsh, Fiction: ''[[\xe2\x80\x99Tisio Tshipsan?]]'', [[Emily Huws]]\n"
# 892 b"* Welsh, Nonfiction: ''[[Chwedl Taliesin]]'', [[Gwyn Thomas (poet)|Gwyn Thomas]] &amp; [[Margaret Jones (writer)|Margaret Jones]]\n"
# 893 b';1992\n'
# 894 b"* English-language: ''[[Who Stole a Bloater?]]'', [[Frances Thomas]]\n"
# 895 b'* Welsh, Fiction: joint winners:\n'
# 896 b"** ''[[Wmffra]]'', [[Emily Huws]]\n"
# 897 b"** ''[[Broc M\xc3\xb4r]]'', [[Gwen Redvers Jones]]\n"
# 898 b"* Welsh, Nonfiction: ''[[Yn y Dechreuad]]'', [[Robert M. Morris]] &amp; [[Catrin Stephens]]\n"
# 899 b';1991\n'
# 900 b"* English-language: ''Award withheld''\n"
# 901 b"* Welsh, Fiction:  ''[[O Ddawns i Ddawns]]'', [[Gareth F. Williams]]\n"
# 902 b"* Welsh, Nonfiction: ''[[Cymru Ddoe a Heddiw]]'', [[Geraint H. Jenkins]]\n"
# 903 b';1990\n'
# 904 b"* English-language: ''Award withheld''\n"
# 905 b"* Welsh, Fiction: ''[[Llygedyn o Heulwen]]'', [[Mair Wynn Hughes]]\n"
# 906 b"* Welsh, Nonfiction: ''[[Lleuad yn Olau]]'', [[T. Llew Jones]] &amp; [[Jac Jones]]\n"
# 907 b'\n'
# 908 b';1989\n'
# 909 b"* English-language: ''Award withheld''\n"
# 910 b'* Welsh, Fiction: joint winners:\n'
# 911 b"** ''[[Liw (book)|Liw]]'', [[Irma Chilton]]\n"
# 912 b"** ''[[Ben y Garddwr a Stor\xc3\xafau Eraill]]'', [[Jac Jones]]\n"
# 913 b"* Welsh, Nonfiction: ''Culhwch ac Olwen'', [[Gwyn Thomas (poet)|Gwyn Thomas]] &amp; [[Margaret Jones (writer)|Margaret Jones]] \xe2\x80\x94a retelling of ''[[Culhwch and Olwen]]''\n"
# 914 b';1988\n'
# 915 b"* English-language: ''[[Steel Town Cats]]'', [[Celia Lucas]]\n"
# 916 b"* Welsh, Fiction: ''[[\xe2\x80\x99Tydi Bywyd yn Boen!]]'', [[Gwenno Hywyn]]\n"
# 917 b"* Welsh, Nonfiction: ''[[Yr Atlas Cymraeg]]'', [[Dafydd Orwig]] (editor)\n"
# 918 b';1987\n'
# 919 b"* English-language: ''[[The Magician Trilogy|The Snow Spider]]'', [[Jenny Nimmo]]\n"
# 920 b"* Welsh, Fiction: ''[[Jabas]]'', [[Penri Jones]]\n"
# 921 b"* Welsh, Nonfiction: ''[[Gardd o Gerddi]]'', [[Alun Jones (writer)|Alun Jones]] &amp; [[John Pinion Jones]]\n"
# 922 b'\n'
# 923 b'Before 1987 there were only two awards, one for English- and one for Welsh-language books.\n'
# 924 b';1986\n'
# 925 b"* English: ''[[Region of the Summer Stars]]'', [[Frances Thomas]]\n"
# 926 b"* Welsh: ''[[Y Llipryn Llwyd]]'', [[Angharad Tomos]]\n"
# 927 b';1985\n'
# 928 b"* ''Awards withheld''\n"
# 929 b';1984\n'
# 930 b"* English: ''[[The Prize (children's book)|The Prize]]'', [[Irma Chilton]]\n"
# 931 b'* Welsh: joint winners:\n'
# 932 b"**''[[Y Llinyn Arian]]'', [[Mair Wynn Hughes]]\n"
# 933 b"**''[[Herio\xe2\x80\x99r Cestyll]]'', [[Malcolm M. Jones]], [[Cyril Jones (writer)|Cyril Jones]] &amp; [[Gwen Redvers Jones]]\n"
# 934 b';1983\n'
# 935 b"* English: ''[[Bluestones (novel)|Bluestones]]'', [[Mary John (writer)|Mary John]]\n"
# 936 b"* Welsh: ''[[Croes Bren yn Norwy]]'', [[J. Selwyn Lloyd]]\n"
# 937 b';1982\n'
# 938 b"* English: ''Award withheld''\n"
# 939 b"* Welsh: ''[[Gaeaf y Cerrig]]'', [[Gweneth Lilly]]\n"
# 940 b';1981\n'
# 941 b"* English: ''[[The Blindfold Track]]'', [[Frances Thomas]]\n"
# 942 b"* Welsh: ''[[Y Drudwy Dewr]]'', [[Gweneth Lilly]]\n"
# 943 b';1980\n'
# 944 b"* English: ''Award withheld''\n"
# 945 b"* Welsh: ''[[Y Llong]]'', [[Irma Chilton]]\n"
# 946 b'\n'
# 947 b';1979\n'
# 948 b"* English: ''[[Time Circles]]'', [[Bette Meyrick]]\n"
# 949 b"* Welsh: ''[[Y Flwyddyn Honno]]'', [[Dyddgu Owen]]\n"
# 950 b';1978\n'
# 951 b"* English: ''[[Silver on the Tree]]'', [[Susan Cooper]]\n"
# 952 b"* Welsh: ''[[Miriam (children's book)|Miriam]]'', [[Jane Edwards]]\n"
# 953 b';1977\n'
# 954 b"* English: ''[[A String in the Harp]]'', [[Nancy Bond]]\n"
# 955 b"* Welsh: ''[[Trysor Bryniau Caspar]]'', [[J. Selwyn Lloyd]]\n"
# 956 b';1976\n'
# 957 b"* English: ''[[The Grey King]]'', [[Susan Cooper]]\n"
# 958 b"* Welsh: ''[[T\xc3\xa2n ar y Comin]]'', [[T. Llew Jones]]\n"
# 959 b'\n'
# 960 b'== Winners of multiple awards ==\n'
# 961 b'\n'
# 962 b"[[Pont Books]], the children's imprint of [[Gomer Press]] (Gwasg Gomer), has published the last nine books to win the English award, 2006 to 2014.&lt;ref name=winners/&gt;&lt;ref name=award2014/&gt; Gwasg Gomer has also published five winners of Welsh awards during that time. [[Y Lolfa |Y Lolfa, Tal-y-bont]] published six of the eight&lt;!--7 of 12 to 2014--&gt; books to win the Welsh-language awards, 2009 to 2012.&lt;ref name=winners/&gt;\n"
# 963 b'\n'
# 964 b'Several authors have won two awards, including all three winners in 2012&lt;ref name=award2012/&gt; and both winners of the first awards in 1976, [[Susan Cooper]] and [[T. Llew Jones]].&lt;ref name=winners/&gt;&lt;!-- by inspection --&gt;\n'
# 965 b'\n'
# 966 b"For the inaugural English Award-winning novel, ''The Grey King'' (1975), Cooper also won the [[Newbery Medal]] recognising the year's &quot;most distinguished contribution to American literature for children&quot;. She won the third English Award in 1978 for its sequel, ''Silver on the Tree'', the concluding [[The Dark Is Rising Sequence|Dark is Rising]] novel. For that series, in April 2012 she won the annual [[American Library Association]] lifetime award for &quot;lasting contribution to young adult literature&quot;, the [[Margaret A. Edwards Award]].&lt;ref name=pr2012&gt;\n"
# 967 b'[http://www.ala.org/news/press-releases/2012/01/susan-cooper-wins-2012-edwards-award-dark-rising-sequence &quot;Susan Cooper wins 2012 Edwards Award for The Dark Is Rising Sequence&quot;]. ALA Press Release. 23 January 2012. Retrieved 2012-04-19.&lt;/ref&gt;\n'
# 968 b'\n'
# 969 b'==See also==\n'
# 970 b"{{Portal bar |Children's literature |Wales }} &lt;!-- delete the word &quot;bar&quot; if there are enough ordinary See also --&gt;\n"
# 971 b'\n'
# 972 b'==References==\n'
# 973 b'{{reflist |35em |refs=\n'
# 974 b'\n'
# 975 b'&lt;ref name=about2012&gt;\n'
# 976 b"[https://web.archive.org/web/20120310021233/http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog &quot;Tir na n-Og Awards&quot;]. [[Books Council of Wales]] ('''BCW'''). Archived 2012-03-10. Retrieved 2012-06-08.&lt;/ref&gt;\n"
# 977 b'\n'
# 978 b'&lt;ref name=winners&gt;\n'
# 979 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/rhestr-list &quot;Tir na n-Og awards Past Winners&quot;] {{Webarchive|url=https://web.archive.org/web/20120310093112/http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/rhestr-list |date=2012-03-10 }}. BCW. Retrieved 2012-06-08.&lt;/ref&gt;\n'
# 980 b'\n'
# 981 b'&lt;!-- 2014-06-22 annual sources below this line --&gt;\n'
# 982 b'&lt;!-- 2014-06-22: the main 2013 page remains the Tir na n-Og Awards top page, without &quot;2013&quot; in its URL; the main 2014 page was not easy to find; I suppose both URL likely to change\n'
# 983 b' --&gt;\n'
# 984 b'&lt;ref name=award2014&gt;\n'
# 985 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog2014 &quot;Tir na n-Og Awards 2014&quot;]. BCW. Retrieved 2014-06-22.&lt;/ref&gt;\n'
# 986 b'&lt;ref name=award2013&gt;\n'
# 987 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog &quot;Tir na n-Og Awards 2013&quot;]. BCW. Retrieved 2014-06-22.&lt;/ref&gt;\n'
# 988 b'&lt;!-- 2014-06-22: the 2014 and 2013 URL may be unstable, probably should change\n'
# 989 b' --&gt;\n'
# 990 b'&lt;ref name=award2012&gt;\n'
# 991 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/tir-na-n-og-2012?diablo.lang=eng &quot;Tir na n-Og Awards 2012&quot;]. BCW. Retrieved 2014-06-22.&lt;/ref&gt;\n'
# 992 b'&lt;ref name=award2011&gt;\n'
# 993 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/gwobrau-tir-na-n-og-2011 &quot;The 2011 Tir na n-Og Awards&quot;]. BCW. Retrieved 2012-06-08.&lt;/ref&gt;\n'
# 994 b'&lt;ref name=award2010&gt;\n'
# 995 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/nanog10 &quot;Tir na n-Og Awards 2010&quot;]. BCW. Retrieved 2014-06-22.&lt;/ref&gt;\n'
# 996 b'&lt;ref name=award2009&gt;\n'
# 997 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/nanog09 &quot;Tir na n-Og Awards 2009&quot;] {{Webarchive|url=https://web.archive.org/web/20120310110833/http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/nanog09 |date=2012-03-10 }}. BCW. Retrieved 2014-06-22.&lt;/ref&gt;\n'
# 998 b'&lt;ref name=award2008&gt;\n'
# 999 b'[http://www.cllc.org.uk/gwasanaethau-services/plant-children/gwobrau-prizes/tir-na-nog/nanog08 &quot;Tir na n-Og Awards 2008&quot;]. BCW. Retrieved 2014-06-22.&lt;/ref&gt;\n'

# %%
handler = WikiXmlHandler()

parser = xml.sax.make_parser()
parser.setContentHandler(handler)

for i, line in enumerate(page):
    parser.feed(line)

# %%
handler._redirects
# Out:
# {'Rational inference': 'Inference'}

# %% [markdown]
# __Putting it all together__

# %%
handler = WikiXmlHandler()

parser = xml.sax.make_parser()
parser.setContentHandler(handler)

for i, line in enumerate(subprocess.Popen(['bzcat'],
                                         stdin=open(data_path),
                                         stdout=subprocess.PIPE).stdout):
    parser.feed(line)
    
    if len(handler._pages) > 50:
        break

# %%
handler._pages
# Out:
# [('Dorsa Whiston',
#   "'''Dorsa Whiston''' is a [[wrinkle ridge]] system at {{Lunar coords and quad cat|29.4|N|56.4|W|globe:Moon}} in [[Oceanus Procellarum]] on the [[Moon]]. It is 85 km long and was named after [[William Whiston]] in 1976. \n [[File:Dorsa Whiston AS15-97-13264-5.jpg|thumb|right|300px|Mosaic of [[Apollo 15]] images, showing part of Dorsa Whiston]] \n {{moon-stub}} \n [[Category:Ridges on the Moon|Whiston]]",
#   '1369254'),
#  ('Humor Monastery',
#   "[[Image:Rares.jpg|thumb|Petru Rareş]] \n '''Humor Monastery''' located in [[Mănăstirea Humorului]], about 5 & nbsp;km north of the town of [[Gura Humorului]], [[Romania]]. It is a [[monastery]] for nuns dedicated to the [[Dormition]] of Virgin Mary, or [[Theotokos]]. It was constructed in 1530 by Voievod [[Petru Rareş]]  and his chancellor [[Teodor Bubuiog]]. The monastery was built over the foundation of a previous monastery that dated from around 1415. The Humor monastery was closed in 1786 and was not reopened until 1990. \n \n The church has been inscribed by [[UNESCO]] on its list of [[World Heritage Sites]], as one of the [[Churches of Moldavia|Painted churches of Moldavia]]. \n \n ==Frescoes== \n Humor was one of the first of [[Moldavia]]'s painted monasteries to be frescoed and, along with [[Voronet Monastery (Bucovina, Romania)|Voroneţ]], is probably the best preserved. The dominant colour of the frescoes is a reddish brown. The master painter responsible for Humor's frescoes, which were painted in 1535, is one ''Toma of Suceava''. \n \n The subjects of the frescoes at Humor include the ''Siege of Constantinople'' and the ''Last Judgment'', common on the exterior of the painted monasteries of Bucovina, but also the ''Hymn to the Virgin'' inspired by the poem of Patriarch [[Sergius I of Constantinople|Sergius of Constantinople]] relating to the miraculous intervention of the [[Theotokos]] in saving the city from Persian conquest in 626. The Persians are, however, depicted as Turks which is a common device in these monasteries, their paintings being used in part for political propaganda in addition to their spiritual meaning. \n \n ==Gallery== \n < gallery > \n File:Humor Monastery, Romania.jpg|Humor monastery church \n File:Humor Monastery Tower.JPG |The tower \n File:Humor monastery4.jpg|Interior \n File:Humor monastery3.jpg|Interior \n File:Humor murals 2010 29.jpg|Exterior \n File:Humor murals 2010 01.jpg|Murals \n File:Humor murals 2010 24.jpg|Murals \n File:Humor murals 2010 05.jpg|Murals \n File:Humor murals 2010 04.jpg|Murals \n File:Humor murals 2010 28.jpg|Murals \n File:Humor murals 2010 14.jpg|Murals \n < /gallery > \n \n ==External links== \n * Kocój E., Świątynie, postacie, ikony. Malowane cerkwie i monastyry Bukowiny Południowej w wyobrażeniach rumuńskich, Kraków 2006, Wydawnictwo Uniwersytetu Jagiellońskiego, ss. 444, 120 pf, https://www.academia.edu/24331662/%C5%9Awi%C4%85tynie_postacie_ikony._Malowane_cerkwie_i_monastyry_Bukowiny_Po%C5%82udniowej_w_wyobra%C5%BCeniach_rumu%C5%84skich_Temples_persons_icons._Painted_churches_and_monasteries_of_South_Bukovina_in_Romanian_imagology_Wydawnictwo_Uniwersytetu_Jagiello%C5%84skiego_Krak%C3%B3w_2006_s._440 \n \n {{Commons category|Humor monastery}} \n * [http://www.romaniaphotos.ro/2010/12/humor-monastery.html Humor Monastery] \n * [http://www.users.cloud9.net/~romania/Churches/humor.htm users.cloud9.net] \n \n {{Authority control}} \n {{Coord|47.5931|N|25.8569|E|source:dewiki_region:RO_type:landmark|format=dms|display=title}} \n \n [[Category:Churches completed in 1473]] \n [[Category:Churches completed in 1530]] \n [[Category:Christian monasteries established in the 15th century]] \n [[Category:Churches of Moldavia]]",
#   '21165869'),
#  ('Tir na n-Og Award',
#   '{{Use dmy dates|date=April 2022}} \n The \'\'\'Tir na n-Og Awards\'\'\' (abbreviated \'\'\'TnaO\'\'\') are a set of annual [[children\'s literature|children\'s]] [[literary awards]] in Wales from 1976. They are presented by the [[Books Council of Wales]] to the best books published during the preceding calendar year in each of three awards categories, one [[English-language]] and two [[Welsh-language]]. Their purpose is  " [to raise] the standard of children\'s and young people\'s books and to encourage the buying and reading of good books. "  There is no restriction to fiction or prose. Each prize is £1,000. < ref name=about2012/ > \n \n The awards are named for [[Tír na nÓg]], the  " Land of the Young " , an otherworldly realm in [[Irish mythology]]. \n \n The English-language award honours one book with an  " authentic Welsh background "  whose original language is English. It is sponsored by the British [[Chartered Institute of Library and Information Professionals]], Cymru Wales division (CILIP/Wales), and presented at that association\'s annual conference in May. < ref name=about2012/ > \n \n The Welsh-language Primary Sector and Secondary Sector awards honour one book written for [[Primary Education in Wales|primary school]] children and one for [[Secondary Education in Wales|secondary school]] children. < !-- see Talk -- > < ref name=about2012/ > \n They are presented at the annual [[Urdd National Eisteddfod]], recently at the beginning of June or end of May. < ref name=about2012/ > < ref name=award2011/ > < ref name=award2012/ > < ref name=award2013/ > \n Since 2011, the Welsh-language awards are co-sponsored by the Cardigan-based publisher [[Cymdeithas Lyfrau Ceredigion]]. < ref name=award2011/ > < ref name=award2012/ > < ref name=award2013/ > < ref name=award2014/ > \n \n Shortlists comprising three or four books in each awards category have been published by BCW at least from 2011. < ref name=award2011/ > < ref name=award2012/ > < ref name=award2013/ > < ref name=award2014/ > \n \n == Recent awards == \n \n ;2019 \n \n The 2018/2019 cycle was completed by announcements of the English-language winner on 16 May 2019 and the two Welsh-language winners at the Urdd National Eisteddfod on 30 May. \n \n The primary sector award went to Elin Meek and Valériane Leblond for \'\'Cymru ar y Map\'\', a lavishly illustrated picture atlas of Wales, published by Rily Publications. \n \n The secondary sector award went to [[Manon Steffan Ros]] for \'\'Fi a Joe Allen\'\', a football novel about a fan following the Welsh team to France, published by [[Y Lolfa]]. \n \n The English-language award was presented to [[Catherine Fisher]] for \'\'The Clockwork Crow\'\', a tale of enchantment involving Welsh folklore and set in a snowy Welsh landscape, published by Firefly Press. < ref > [http://www.books.wales/news/news-detail?id=13300  " Catherine Fisher wins the Tir na n-Og children\'s literature award with The Clockwork Crow " ] Welsh Books Council. 16 May 2019. Retrieved 2019-09-07. < /ref > \n \n ;2016 \n \n The 2015/2016 cycle was completed by announcements of the English-language winner on 26 May 2016 and the two Welsh-language winners at the Urdd National Eisteddfod on 2 June. Three shortlists of three or four books had been announced in March. < ref > [http://www.gomer.co.uk/index.php/news/2016TirnanOgShortlist/ 2016 Tir na n-Og shortlist, Gomer Press] < /ref > \n \n The primary sector award went to Sian Lewis and Valériane Leblond for \'\'Pedair Cainc y Mabinogi\'\', a retelling of the [[Four Branches of the Mabinogi]], published by Rily Publications. \n \n The secondary sector award went to Llyr Titus for \'\'Gwalia\'\', a space travel adventure, published by [[Gomer Press]]. \n \n The English-language award was presented to Griff Rowland for \'\'The Search For Mister Lloyd\'\', about a Welsh boy\'s search for his missing racing pigeon, published by Candy Jar Books. < ref > [http://www.cllc.org.uk/gwasanaethau-services/plant-c ...
#   '754619'),
#  ('Barrington Passage, Nova Scotia',
#   '{{distinguish|Barrington, Nova Scotia (disambiguation){{!}}Barrington, Nova Scotia}} \n {{Infobox settlement \n |name                   = Barrington Passage \n |settlement_type        = Community \n |image_map              =  \n |mapsize                =  \n |map_caption            =  \n |image_map1             =  \n |mapsize1               =  \n |map_caption1           =  \n |pushpin_map            = Nova Scotia \n |pushpin_label_position = right \n |pushpin_map_caption    =\'\'\'Location of Barrington Passage, Nova Scotia\'\'\' \n |pushpin_mapsize        =275 \n |subdivision_type       = [[Country]] \n |subdivision_name       = {{CAN}} \n |subdivision_type1      = [[Provinces and territories of Canada|Province]] \n |subdivision_name1      = {{NS}} \n |subdivision_type2      = [[List of counties of Nova Scotia|County]] \n |subdivision_name2      = [[Shelburne County, Nova Scotia|Shelburne]] \n |subdivision_type3      = [[Municipal district]] \n |subdivision_name3      = [[Municipality of the District of Barrington|Barrington]] \n |government_footnotes   = < ref name= " GNS " > [http://www.gov.ns.ca/finance/communitycounts/summary.asp?gnum=com105 & gview=1 & sub=demographics Government of Nova Scotia website: Barrington] < /ref > \n |government_type        = \n |leader_title           = \n |leader_name            = \n |area_magnitude         =  \n |unit_pref                =  < !--Enter: Imperial, if Imperial (metric) is desired-- > \n |area_footnotes           = \n |area_total_km2           =   \n |area_land_km2            =  \n |area_water_km2           =  \n |area_total_sq_mi         =  \n |area_land_sq_mi          =  \n |area_water_sq_mi         =  \n |area_water_percent       =  \n |area_urban_km2           =  \n |area_urban_sq_mi         =  \n |area_metro_km2           =   \n |area_metro_sq_mi         =  \n |area_blank1_title         =  \n |area_blank1_km2           = \n |area_blank1_sq_mi         = \n |population_as_of         = 2006 \n |population_footnotes     = < ref name= " SC2006 " > [http://www12.statcan.ca/census-recensement/2006/dp-pd/prof/92-591/details/page.cfm?Lang=E & Geo1=CSD & Code1=1201001 & Geo2=PR & Code2=12 & Data=Count & SearchText=Barrington & SearchType=Begins & SearchPR=12 & B1=Custom & Custom=1000,8000 2006 Statistics Canada Community Profile: Barrington Municipal District, Nova Scotia] < /ref > \n |timezone               = [[Atlantic Standard Time Zone|AST]] \n |utc_offset             = -4 \n |timezone_DST           = [[Atlantic Standard Time Zone|ADT]] \n |utc_offset_DST         = -3 \n |coordinates_footnotes  = < ref > [http://142.176.62.102/scripts/esrimap.dll?name=nsplacenames & cmd=4 & zoomcons=1 & action=zoomToPlace & objid=1110 & prov=false Nova Scotia Geographical Names: Barrington Passage]{{dead link|date=October 2016 |bot=InternetArchiveBot |fix-attempted=yes }} < /ref > \n |coordinates            = {{coord|43.5275|-65.609167|region:CA-NS|display=inline,title}} \n |postal_code_type       =[[Canadian postal code|Postal code(s)]] \n |postal_code            =[[List of B postal codes of Canada|B0W 1G0]] \n |area_code              =[[Area code 902|902]] \n |blank_name             =Access & nbsp;Routes \n |blank_info             ={{jct|state=NS|Trunk|3}} \n |blank2_name            =  \n |blank2_info            =     \n |blank3_name            =  \n |blank3_info            =   \n |website                =  \n |footnotes              =  \n }} \n \n \'\'\'Barrington Passage\'\'\' is a community in the [[Canada|Canadian]] province of [[Nova Scotia]], located in the [[Municipality of the District of Barrington]] of [[Shelburne County, Nova Scotia|Shelburne County]]. < ref name= " GNS-2 " > [http://www.gov.ns.ca/finance/communitycounts/geogpage.asp?p=com & gtype=Community & acctype= & gnew= & table= & chartid= & mapid= & dcol= & ptype=geo & gview=3 & sub= & tid= Government of Nova Scotia website: Community Counts] < /ref > \n It is named after [[William Barrington, 2nd Viscount Barrington]]. < r ...
#   '7903804'),
#  ('University of Wisconsin–Milwaukee College of Engineering and Applied Science',
#   '{{Infobox university \n |image= < !-- Do NOT place a non-free image here without complying with WP:NFCC #10c -- > \n |motto= \'\'Discover. Innovate. Lead.\'\' \n |name=UW-Milwaukee College of Engineering and Applied Science \n |type            = [[Public university|Public]] \n |established     = 1964 < ref > [http://www4.uwm.edu/ceas/explore_ceas/about_ceas/ceas_history.cfm History of CEAS on the UW-Milwaukee website] < /ref > \n |dean            = [[Brett Peters]] \n |undergrad       = 1,568 < ref name=enrollment > [http://www4.uwm.edu/acad_aff/assessment/intranet/enroll/enrtodat/ay201314/cedall2139_passthrough.cfm Fall 2013 Headcount Report], available on UWM campus or off-campus with UWM student/staff logon < /ref > \n |postgrad        = 399 < ref name=enrollment / > \n |city            =[[Milwaukee]] \n |state           =[[Wisconsin]] \n |country         =[[United States]] \n |campus          =[[University of Wisconsin–Milwaukee]] \n |website= [http://www.uwm.edu/CEAS http://www.uwm.edu/CEAS] \n |logo=UW-Milwaukee.png \n |}} \n \n The \'\'\'College of Engineering and Applied Science\'\'\' is a college within the [[University of Wisconsin–Milwaukee]]. It offers bachelor, master and doctoral degrees in [[civil engineering]], [[electrical engineering]], [[industrial engineering]], [[materials engineering]], [[mechanical engineering]], and [[computer science]]. \n \n Based on the statistical analysis by H.J. Newton, Professor of Statistics at Texas A & M University in 1997 on the [[United States National Research Council|National Research Council]] report issued in 1995, the school was  ranked 73rd nationally in the [[United States National Research Council rankings|National Research Council]] (NRC) rankings, < ref > [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc1.html#RANKBYAREA A Brief Summary of the NRC Rankings], Texas A & M University < /ref >  with its [[Civil Engineering]] program 69th, < ref > [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area22 NRC Rankings in each of the 41 Areas:] civil engineering, Texas A & M University < /ref >  [[Electronic Engineering]] 96th, < ref > [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area23 NRC Rankings in each of the 41 Areas:] Electronic Engineering, Texas A & M University < /ref >  [[Industrial Engineering]] 34th, < ref > [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area24 NRC Rankings in each of the 41 Areas:] Industrial Engineering, Texas A & M University < /ref >  [[Materials science]] 60th, < ref > [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area25 NRC Rankings in each of the 41 Areas:] Materials science, Texas A & M University < /ref >   and [[Mechanical Engineering]] 87th. < ref > [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area26 NRC Rankings in each of the 41 Areas:] Mechanical Engineering, Texas A & M University < /ref >  The school ranks 129th nationally by \'\'[[U.S. News  &  World Report]]\'\', < ref name= " Best Engineering Schools " > [http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-engineering-schools/eng-rankings/page+6 Best Engineering Schools],\'\'[[U.S. News  &  World Report]]\'\'. < /ref >  with its [[computer science]] program ranked 110th in 2011. < ref name= " Rankings: Computer Science " > [http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-science-schools/computer-science-rankings/page+5 Rankings: Computer Science], \'\'[[US News  &  World Report]]\'\', 2010. < /ref > \n \n ==Departments== \n *[[Civil Engineering]]  &  [[Mechanics]] \n *[[Computer Science]] \n *[[Electrical Engineering]] \n *[[Industrial engineering|Industrial  &  Manufacturing Engineering]] \n *[[Materials Science]] \n *[[Mechanical Engineering]] \n \n ==Research centers== \n *[http://www4.uwm.edu/ceas/faculty_research/research_centers/alternative_fuels/ Center for Alternative Fuels Research Programs] \n *[http://cbu.ceas.uwm.edu/wordpress/ Center for By-Prod ...
#   '982105965'),
#  ('University of Wisconsin–Milwaukee School of Education',
#   '{{Infobox university \n |image=  < !-- Do NOT place a non-free image here without complying with WP:NFCC #10c -- > \n |name=University of Wisconsin–Milwaukee School of Education \n |type            = [[Public university|Public]] \n |established= 1951 \n |dean= Carol Colbeck \n |city            =[[Milwaukee]] \n |state           =[[Wisconsin]] \n |country         =[[United States]] \n |enrollment=2,693 \n |undergrad= \n |postgrad=735 \n |faculty= \n |campus          =[[University of Wisconsin–Milwaukee]] \n |website= [http://www4.uwm.edu/soe www.uwm.edu/soe]   \n |logo=UW-Milwaukee.png \n |}} \n The \'\'\'University of Wisconsin–Milwaukee School of Education\'\'\' is an academic division of the [[University of Wisconsin–Milwaukee]]. It offers five undergraduate major, five master\'s, and 12 doctoral programs. It also offers the only four-year interpreter training degree in [[Wisconsin]]. \n \n The school was ranked 86th nationally by \'\'[[U.S. News  &  World Report]]\'\' in 2011. < ref name= " Rankings:Best Education Programs " > [http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-education-schools/university-of-wisconsin-milwaukee-06222 Rankings:Best Education Programs],  \'\'[[U.S. News  &  World Report]]\'\' 2011 < /ref > \n \n == History == \n The School of Education’s history is intertwined with the history of UWM. The school’s predecessor, Milwaukee Normal School, opened in 1885 to train teachers in downtown [[Milwaukee]] at 18th Street and Wells Avenue. In 1909, the Normal School moved to its new location, the Milwaukee Normal School Building (today’s Mitchell Hall on the UWM campus). The Normal School became Milwaukee State Teachers College, offering four-year degrees. In 1951, Milwaukee State Teachers College became Wisconsin State College (WSC), Milwaukee, with liberal arts degrees. WSC merged with UW Milwaukee Extension to form UWM. \n \n == Departments == \n {{col-begin}}{{col-break|width=40%}} \n *Administrative Leadership \n *Curriculum and Instruction \n *Education Outreach \n *Educational Policy and Community Studies \n {{col-break|width=40%}}  \n *Educational Psychology \n *Exceptional Education \n *Urban Education Doctoral Program \n {{col-end}} \n \n ==Academic Centers== \n *Center for Mathematics and Science Education Research \n *Center for New and Professional Educators \n *Early Childhood Research Center (ECRC) \n *Institute for Intercultural Research \n \n ==Notable people== \n *[[Martin Haberman]], educator, university professor \n *[[Golda Meir]], fourth [[Prime Minister of Israel]], one of the founders of the State of Israel \n *[[Bruce Weber (coach)|Bruce Weber]], men\'s basketball head coach at University of Illinois at Urbana-Champaign \n \n ==References== \n {{Reflist}} \n \n ==External links== \n *[http://www.soe.uwm.edu/pages/welcome/ University of Wisconsin–Milwaukee School of Education] \n \n {{University of Wisconsin–Milwaukee}} \n {{Authority control}} \n \n {{Coord|43|04|32.6|N|87|52|44.4|W|type:edu_region:US-WI|display=title}} \n \n {{DEFAULTSORT:University Of Wisconsin-Milwaukee School Of Education}} \n [[Category:University of Wisconsin–Milwaukee]] \n [[Category:Educational institutions established in 1951]] \n [[Category:Schools of education in Wisconsin]] \n [[Category:1951 establishments in Wisconsin]]',
#   '9784415'),
#  ('Loiner',
#   '{{Short description|Demonym for a citizen of Leeds, England}} \n {{Use dmy dates|date=November 2019}} \n \'\'\'Loiner\'\'\' is a [[demonym]], describing the citizens of [[Leeds]]. \n \n The [[Rugby league]] club [[Leeds Rhinos]] were previously nicknamed the \'\'Loiners\'\'. < ref > {{cite news|url=http://www.yorkshireeveningpost.co.uk/sport/rugby-league/leeds-rhinos/leeds-rhinos-flashback-loiners-come-back-from-the-dead-to-beat-saints-and-retain-the-cup-1-7253506|work=[[Yorkshire Evening Post]]|title=Leeds Rhinos Flashback: Loiners come back from the dead to beat Saints and retain the Cup|first=Peter|last=Smith|date=11 May 2015}} < /ref > \n \n ==History== \n While there are several theories, the actual origin of the term remains uncertain. \n \n The three competing theories are: \n \n * Loiner could derive from the name Loidis (in use by the eighth century for the district around modern-day Leeds). < ref > {{cite web|url=https://englandsnortheast.co.uk/yorkshire-leeds-west-yorkshire|website=www.englandsnortheast.co.uk|title=LEEDS AND WEST YORKSHIRE|accessdate=12 November 2018}} < /ref > \n * Another explanation says that in the 19th century there were many yards and closes around Briggate whose back entrances were known as Low Ins or Loins, hence Loiner. \n * A third theory is that, in the area of Briggate, locals referred to numerous nearby streets as \'loins’, as a Leeds cognate for the Standard English word \'lanes\'. People who gathered in these loins to gossip were therefore termed Loiners. < ref > {{cite web|url=https://www.bbc.co.uk/leeds/content/articles/2005/01/06/voices2005_loiner_feature.shtml|work=BBC voices2005|title=Loiners of the world unite!|date=24 September 2014|accessdate =12 November 2018}} < /ref > \n \n ==Dialect== \n The term \'\'Leeds Loiner\'\' was included by [[Joseph Wright (linguist)|Joseph Wright]], a native of nearby [[Windhill and Wrose]], in the [[English Dialect Dictionary]].  The definition was  " An inhabitant of Leeds " .  The entry suggests that the origin is linked to Marsh Lane in Leeds. < ref > Wright, Joseph (1902), \'\'The English Dialect Dictionary, being the complete vocabulary of all dialect words still in use, or known to have been in use during the last two hundred years; founded on the publications of the English Dialect Society and on a large amount of material never before printed\'\', Volume 3 H-L < /ref > \n \n ==References== \n {{reflist}} \n \n [[Category:People from Leeds| ]] \n [[Category:Demonyms]]',
#   '38775'),
#  ("Standin' on the Corner Park",
#   '{{short description|Public park in Winslow, Arizona}} \n {{Use mdy dates|date=March 2015}} \n {{Infobox park \n | name = Standin\' on the Corner Park \n | photo = Standing on the Corner.JPG \n | photo_width = 300 \n | photo_caption = Standin\' on the Corner Park, a tribute to the [[Jackson Browne]]/[[Glenn Frey]] song  " [[Take It Easy]] " \n | type = Municipal \n | location = [[Winslow, Arizona]] \n | coords = {{Coord|35|1|24.54|N|110|41|53.03|W|display=inline|}} \n | area =  \n | created = 1999 \n | operator = Standin\' On The Corner Foundation \n | visitation_num =  \n | status =  \n }} \n \n \'\'\'Standin\' on the Corner Park\'\'\' is a public park in [[Winslow, Arizona]], opened in 1999, commemorating the song  " [[Take It Easy]] "  which was written by [[Jackson Browne]] and [[Glenn Frey]] and most famously recorded by the [[Eagles (band)|Eagles]]. The song includes the verse  " Well, I\'m a-standin\' on a corner in Winslow, Arizona and such a fine sight to see. It\'s a girl, my Lord, in a flatbed Ford slowin\' down to take a look at me. "  The park contains a two-story [[trompe-l\'œil]] mural by [[John Pugh (artist)|John Pugh]], a flatbed Ford truck, and a bronze statue by Ron Adamson < ref > {{cite web|url=http://www.ronadamson.com|title=Ron Adamson Studio and Artworks – Original Western Art|website=ronadamson.com}} < /ref >  of a life-sized man who is standing on a corner with a guitar by his side. The park is surrounded by a wall of bricks, with windows to peer into; each brick has a donor\'s name on it, and a story by each of the donors describing their fondness for Winslow, Arizona. < ref name= " official_site " > {{cite web |url= http://standinonthecorner.com/park-history/ |title= History of the Park |publisher= Standin\' On The Corner Foundation |access-date= March 6, 2015}} < /ref > \n [[File:Arizona US 66 Standing on the Corner Park Winslow Arizona.jpg|thumb|The Arizona US Route 66 marker at Standing on the Corner Park Winslow, Arizona]] \n \n == History == \n Until the 1970s, Winslow was a thriving town in northern Arizona just off [[U.S. Route 66 in Arizona|Route 66]]. When [[Interstate 40 in Arizona|I-40]] bypassed the community many local businesses disappeared, the tourism sector being among the hardest hit. While some local jobs remained (Winslow is the base of operation for nearly 1,000 railroad workers), the local downtown was badly hurt by the influx of national chains such as [[Walmart]] and [[McDonald\'s]] along the new interstate highway to the north of the town. < ref name= " insideout " > {{cite magazine |date= July 2007 |title= In Winslow Arizona |first= L. |last= Bell |work= Inside Outside Southwest |url= http://insideoutsidemag.com/issues/2007/July_August/In_Winslow_Arizona/ |url-status= dead |archive-url= https://web.archive.org/web/20101130092418/http://insideoutsidemag.com/issues/2007/July_August/In_Winslow_Arizona/ |archive-date= November 30, 2010 |df= mdy-all }} < /ref >  Twenty years passed and Winslow was stuck in a commercial rut. \n \n The Standin\' on the Corner Foundation was formed to create a renaissance of Winslow. Determined to build on tourism, the foundation took advantage of the town being mentioned in the song  " Take It Easy "  made famous by the Eagles. From 1997 until 1999, the foundation sought out donors and planned design concepts. On September 10 and 11, 1999 the park was opened to the public. < ref name= " official_site "  / > \n \n On October 18, 2004, there was a fire at the Standin\' on the Corner Park.  While the face of the building and the actual corner survived, the rest of the building was burned down. < ref > {{cite news |last1=Bruner |first1=Betsey |title=Not just Standin\' still |url=https://azdailysun.com/news/not-just-standin-still/article_7ff4f332-e6d4-5fe8-afc7-41e4544d34e3.html |accessdate=August 15, 2018 |work=Arizona Daily Sun |date=October 13, 2007 |language=en}} < /ref > {{Failed verification|date=July 2021}} \n \n The 2006 release of [[computer ...
#   '1042585799'),
#  ('The Adventurers (1970 film)',
#   '{{short description|1970 film}} \n {{Use mdy dates|date=February 2015}} \n {{Infobox film \n | name           = The Adventurers \n | image          = The Adventurers - 1970 - poster.png \n | caption        = Theatrical release poster \n | producer       = Lewis Gilbert \n | director       = [[Lewis Gilbert]] \n | screenplay     = [[Michael Hastings (playwright)|Michael Hastings]] < br / > Lewis Gilbert \n | based_on       = {{based on|\'\'The Adventurers\'\'|[[Harold Robbins]]}} \n | starring       = [[Bekim Fehmiu]] < br / > [[Candice Bergen]] < br / > [[Charles Aznavour]] < br / > [[Olivia de Havilland]] < br / > [[Fernando Rey]] < br / > [[Ernest Borgnine]] < br / > [[Alan Badel]] < br / > [[Leigh Taylor-Young]] \n | music          = [[Antonio Carlos Jobim]] \n | cinematography = [[Claude Renoir]] \n | editing        = [[Anne V. Coates]] \n | studio         = [[Embassy Pictures]] \n | distributor    = [[Paramount Pictures]] \n | released       = {{Film date|1970|3|25}} \n | runtime        = 171 minutes \n | country        = United States \n | language       = English \n | budget         = $12 million < ref name= " afi "  / > \n | gross          = $7,750,000 (US/ Canada rentals) < ref > " Big Rental Films of 1970 " , \'\'Variety\'\', 6 January 1971 p 11 < /ref > \n }} \n \'\'\'\'\'The Adventurers\'\'\'\'\' is a 1970 American [[adventure film|adventure]] [[drama film]] directed, produced, and co-written by [[Lewis Gilbert]]. It is based on the 1966 novel of the same name by [[Harold Robbins]]. \n \n The film stars [[Bekim Fehmiu]], [[Candice Bergen]], [[Charles Aznavour]], [[Olivia de Havilland]], [[Fernando Rey]], [[Ernest Borgnine]], [[Alan Badel]], and [[Leigh Taylor-Young]]. The film was the American film debut of Yugoslavian actor Fehmiu and was shot in Europe and parts of South America. It is loosely based on the life of Dominican diplomat and playboy [[Porfirio Rubirosa]]. \n \n ==Plot== \n Dax Xenos, a ten-year old boy in the [[South America]]n country of Corteguay, witnesses the rape and murder of his mother by government soldiers and runs to his father, Jaime, who is with a band of revolutionaries. Jaime\'s men capture the government soldiers, give Dax the privilege of personally executing his mother\'s murderers, and then take the boy to their hideout in the mountains where he meets Amparo, the daughter of revolutionary leader Rojo. After the rebels oust the dictator and establish Rojo as president, Dax accompanies his father to Rome, where Jaime is to serve as ambassador. \n \n Years later, Jaime returns to Corteguay to find that Rojo has established himself as dictator; he contacts El Condor, the new revolutionary leader, but is killed by Colonel Gutierrez, Rojo\'s security chief. Dax, now a young man, returns to Corteguay for his father\'s funeral. Rojo persuades Dax, who does not know the cause of his father\'s death, to convince El Condor to surrender, but when El Condor surrenders, he is killed by Gutierrez. \n \n Because his promise to El Condor was betrayed, Dax murders Gutierrez, confronts Rojo with his treachery, and returns to Rome. He becomes a gigolo and finally marries millionairess Sue Anne Daley, but they soon divorce. Dax again returns to Corteguay, this time for the unveiling of a statue of his father, and finds himself thrust into yet another revolution. \n \n Led this time by El Lobo, the revolution succeeds when Dax murders Rojo. Meanwhile, Dax learns that Amparo has borne him a son. Delighted, he sends her back to Rome with the intention of establishing a democracy in Corteguay and returning to his new family, but he is assassinated by the vengeful son of El Condor. \n \n ==Cast== \n {{castlist| \n *[[Bekim Fehmiu]] as Dax Xenos \n **Loris Loddi as young Dax \n *[[Charles Aznavour]] as Marcel Campion \n *[[Candice Bergen]] as Sue Ann Daley \n *[[Alan Badel]] as President Rojo \n *[[Thommy Berggren]] as Sergei Nikovitch \n **Carl Eklund as young Sergei \n *[[Delia Boccardo]] as Caroline de C ...
#   '7903804'),
#  ('Stéphane Haccoun',
#   '{{short description|French boxer}} \n {{Use dmy dates|date=April 2020}} \n {{short description|English boxer}} \n {{Infobox boxer \n |name        = Stephane Haccoun \n |image       =   \n |imagesize   =   \n |caption     =   \n |realname    = Stephane Haccoun \n |nickname    =   \n |weight      = [[Featherweight]] < br > [[Super Featherweight]] < br > [[Junior Lightweight]] \n |height      = {{convert|5|ft|5.5|in|m|2|abbr=on}}  \n |reach       =  \n |nationality = French \n |birth_date  = {{Birth date|1967|08|31|df=y}} \n |birth_place = Paris, France   \n |death_place =   \n |style       = [[Southpaw stance|Southpaw]];left-handed  \n |wins        = 35 < ref name= " Haccoun " > {{cite web|website=Boxing Record|title=Stephane Haccoun|url=https://boxrec.com/en/proboxer/4790|publisher=BoxRec|accessdate=7 March 2020}} < /ref > \n |KO          = 22 \n |losses      =  4 \n |draws       =  1 \n |no contests =  \n }} \n \'\'\'Stéphane Haccoun\'\'\' (born 31 August 1967 in [[Paris, France]]) is a former southpaw French [[Boxing|boxer]]. \n \n He fought as a featherweight, a super featherweight, and a junior lightweight. \n \n In preparation to compete for the European Featherweight title, he defeated Fabrice Benichou on 3 June 1993, at the Palais de Sport in Marseille, winning in a ten round points decision. < ref name= " Haccoun " / > \n \n ==Taking the EBU Featherweight title== \n On 24 September 1993, he defeated Mauricio Stecca for the EBU European Feather Title at the Marseille\'s Palais de Sports in a ninth round technical knockout. < ref name= " Haccoun " / > \n \n He competed unsuccessfully for the IBF World Featherweight title against Tom  " Boom Boom "  Johnson, losing in a ninth round knockout, on 30 November 1993 at the Palais de Sports in Marseille.  Johnson easily won every round, using his superior speed, reach and ability, to dominate the bout with direct rights and hard left jabs. He scored the knockdown 1 minute and 15 seconds into the ninth. < ref > " Sportspeople: QB Ward " , \'\'The Tribune\'\', Scranton, Pennsylvania, pg. 12, 1 December 1993 < /ref >   \n \n He relinquished the EBU Featherweight title on 22 March 1994, losing to Stephano Zoff in Charleroi, Belgium in a ninth round technical knockout. < ref name= " Haccoun " / > \n \n ==See also== \n *[[List of Jews in sports#Boxers|List of select Jewish boxers]] \n \n == References == \n {{Reflist}} \n \n ==Link== \n * {{boxrec|id=004790}} \n \n {{DEFAULTSORT:Haccoun, Stephane}} \n [[Category:1967 births]] \n [[Category:Living people]] \n [[Category:Featherweight boxers]] \n [[Category:Jewish boxers]] \n [[Category:Jewish French sportspeople]] \n [[Category:Boxers from Paris]] \n [[Category:French male boxers]] \n \n \n {{france-boxing-bio-stub}}',
#   '1083218127'),
#  ('Rendezvous Hotel Singapore',
#   "{{short description|Hotel in Singapore}} \n {{Infobox hotel \n | hotel_name   = Rendezvous Hotel \n | footnotes    =  \n | website      = {{Official website}} \n | parking      =  \n | floor_area   =  \n | architect    =  \n | logo         =  \n | closing_date =  \n | diamonds     =  \n | pushpin_map  = Singapore \n | location     = 9 Bras Basah Rd, Singapore 189559 \n | caption      = The Rendezvous Hotel Singapore when it was known as the Rendezvous Grand Hotel Singapore \n | image_width  =  \n | image        = Rendezvous Grand Hotel (8645381320).jpg \n | logo_width   =  \n | coordinates  = {{Coord|1|17|58.06|N|103|50|59.89|E|display=title,inline}} \n }} \n The '''Rendezvous Hotel Singapore''' (formerly the '''Rendezvous Grand Hotel Singapore''') is a hotel located on [[Bras Basah Road]] in the [[Museum District, Singapore|Museum District]] of [[Singapore]], across from the [[Singapore Management University]] (SMU). It is located on the historic site of the Hock Lock Kee Restaurant which began operations in the early 1950s. Later called the Rendezvous Restaurant, it remained in the hotel complex for a number of years before moving to [[The Central]]. < ref > {{citation|editor=Pamela Lee|title=Fodor's Singapore|edition=12th|url=https://books.google.com/books?id=UqX_5YvDkTgC & pg=PA75|location=New York, N.Y.|publisher=Fodor's Travel Publications|year=2005 \n |page=75|isbn=978-1-4000-1476-7}}; {{citation|author=Jennifer Eveland|title=Frommer's Singapore  &  Malaysia|edition=5th|url=https://books.google.com/books?id=uANmYGe2ZQIC & pg=PA110|location=Hoboken, N.J.|publisher=[[John Wiley  &  Sons|Wiley Publishing]]|year=2007|isbn=978-0-470-10049-3}}; < /ref > \n \n Rendezvous Hotel Singapore is part of a chain of Rendezvous Hotels owned by [[Straits Trading Company|The Straits Trading Company Ltd.]] In 2013, Far East Hospitality Holdings Pte. Ltd., a premier hospitality assets owner and operator, acquired the Rendezvous Grand Hotel Singapore and the adjoining Rendezvous Gallery for [[Singapore dollar|S$]]270.1 million. < ref > {{citation|author=Nikki De Guzman|title=Far East fully acquires Rendezvous site|url=http://www.propertyguru.com.sg/property-management-news/2013/8/36373/far-east-fully-acquires-rendezvous-site|archiveurl=https://web.archive.org/web/20140202155601/http://www.propertyguru.com.sg/property-management-news/2013/8/36373/far-east-fully-acquires-rendezvous-site|archivedate=2 February 2014|publisher=PropertyGuru|date=5 August 2013}}. < /ref >  It formed a 70%–30% joint venture between Far East Orchard Limited (a listed company under [[Far East Organization]]) and The Straits Trading Company.{{citation needed|date=July 2015}} \n \n On 17 January 2014, the Rendezvous brand was re-branded with an art-inspired character. Refurbished common areas embody the art theme. The Club Rooms reflect three artsy styles, Performing Arts, Retro or [[Peranakan]], and Club Rendezvous (a club lounge) offers a scenic view of the city. \n [[File:RendezvousHotelSingapore-courtyard-20091213.jpg|thumb|center|The courtyard of the Rendezvous Hotel Singapore, before it was renovated and renamed the Rendezvous Grand Hotel Singapore]] \n ==References== \n {{Reflist}} \n \n ==External links== \n {{Commons category|Rendezvous Hotel Singapore}} \n \n *{{Official website|http://www.stayfareast.com/en/hotels/rendezvous-hotel-singapore.aspx}} \n \n {{Hotels in Singapore}} \n {{Use British English|date=July 2015}} {{use dmy dates|date=July 2015}} \n \n [[Category:Hotels in Singapore]] \n [[Category:Museum Planning Area]]",
#   '26021349'),
#  ('Whitacre College of Engineering',
#   '{{Infobox university \n |name = Edward E. Whitacre Jr. < br > College of Engineering \n |image_name = Whitacre College of Engineering logo.svg \n |image_size = 250px \n |established = {{start date|1925}} \n |endowment = $100 million \n |faculty = 155 \n |dean = [[Albert Sacco]] \n |students = 5,088 < ref name=EnrollmentbyCollege13 > {{cite web | url=http://www.irim.ttu.edu/FactBook/Enrollment/ENRCOLL.aspx | title=Total Enrollment by College - Fall 2013 | publisher=Texas Tech Institutional Research | website=www.irim.ttu.edu | access-date=2013-10-22}} < /ref > \n |undergrad = 4,360 < ref name=EnrollmentbyCollege13 / > \n |postgrad = 728 < ref name=EnrollmentbyCollege13 / > \n |city = [[Lubbock, Texas|Lubbock]] \n |state = [[Texas]] \n |country = U.S. \n |coor = {{coord|33.587172|-101.876017|type:edu|display=inline,title}} \n |website = {{url|www.coe.ttu.edu}} \n }} \n [[Image:TTeng.jpg|thumb|right|228px|Engineering Key]] \n The \'\'\'Edward E. Whitacre Jr. College of Engineering\'\'\' is the college of [[engineering]] at [[Texas Tech University]] in [[Lubbock, Texas]]. The engineering program has existed at Texas Tech University since 1925. Additionally, the Whitacre College of Engineering administers graduate engineering degree programs at the university\'s campus in [[Texas Tech University at Amarillo|Amarillo]], Texas. Many of the college\'s degree programs are accredited by [[ABET]]. The Whitacre College of Engineering is the first and, presently, only school in the world to offer a doctor of philosophy degree in wind science and engineering. < ref > {{cite web | url=http://today.ttu.edu/2007/08/coordinating-board-approves-first-wind-science-and-engineering-doctorate/ | title=Coordinating Board Approves First Wind Science and Engineering Doctorate - News | publisher=Texas Tech University }} < /ref > \n \n In August 2008, the Whitacre College of Engineering announced that it would rename its petroleum engineering department the Bob L. Herd Department of Petroleum Engineering. Herd, a Texas Tech petroleum engineering alumnus and [[Tyler, Texas]] oil man, donated $15 million to the college. < ref > {{cite web|title=Petroleum Engineering Receives $15 Million Gift | publisher=Texas Tech University |url=http://today.ttu.edu/2008/08/petroleum-engineering-receives-15-million-gift/|access-date=2008-08-29}} < /ref >  The department was ranked tenth in the nation in the April 2008 edition of \'\'U.S. News  &  World Report.\'\' < ref name= " 4-tech-grad-programs-top-100 " > {{cite web | url=http://today.ttu.edu/2008/04/us-news-world-report-ranks-texas-tech-graduate-programs-among-best/. |title=U.S. News  &  World Report Ranks Texas Tech Graduate Programs Among Best  | publisher=Texas Tech University}} < /ref > \n \n == History == \n The Texas Technological College, present day Texas Tech University, School of Engineering was created in the fall of 1925. At that time the school consisted of 313 students and two faculty members, and was housed in the textile engineering building, now the industrial engineering building. < ref name=History > {{cite web | title=About the College :: History | publisher=Texas Tech University College of Engineering | url=http://www.depts.ttu.edu/coe/about/history.php | access-date=2008-09-20}} < /ref >  In 1928, the School of Engineering expanded and opened the west engineering building, now the electrical and computer engineering building. < ref name= " History "  / >  The school\'s civil, electrical, industrial, mechanical, and textile engineering programs were accredited by the Engineering Council for Professional Development in 1933. The chemical engineering and petroleum engineering programs were accredited in 1959 and 1960 respectively. < ref name= " History "  / >  The chemical engineering building opened for classes in 1960. In the early 1970s the Pulsed Power Research Center was created for the purpose of plasma research. < ref name= " History "  / > \n \n On November 12, 2008, Texas Tech announce ...
#   '20483999'),
#  ('Check Point IPSO',
#   '{{Use dmy dates|date=July 2012}} \n \'\'\'Check Point IPSO\'\'\' is the [[operating system]] for the \'Check Point firewall\' [[computer appliance|appliance]] and other security devices, based on [[FreeBSD]], with numerous hardening features applied. < ref > {{cite web|url=https://honor.icsalabs.com/pipermail/firewall-wizards/2000-February/007795.html |title=Archived copy |accessdate=2007-04-15 |url-status=dead |archiveurl=https://web.archive.org/web/20060313082831/http://honor.icsalabs.com/pipermail/firewall-wizards/2000-February/007795.html |archivedate=13 March 2006 |df=dmy }} < /ref > \n \n The IP in IPSO refers to [[Ipsilon Networks]], a company specialising in [[IP switching]] acquired by [[Nokia]] in 1997. < ref > {{cite web|url=http://europe.nokia.com/microsites/aboutnokia/company_information/news/news_htmls/ntc_971209a.html |title=Archived copy |accessdate=2007-04-15 |url-status=dead |archiveurl=https://web.archive.org/web/20060323115712/http://europe.nokia.com/microsites/aboutnokia/company_information/news/news_htmls/ntc_971209a.html |archivedate=23 March 2006 |df=dmy }} < /ref > \n \n In 2009, [[Check Point]] acquired the Nokia security appliance business, including IPSO, from Nokia. < ref > {{cite web |url=http://www.checkpoint.com/nokia/welcome/index.html |title=Archived copy |accessdate=2009-06-02 |url-status=dead |archiveurl=https://web.archive.org/web/20090601153257/http://www.checkpoint.com/nokia/welcome/index.html |archivedate=1 June 2009 |df=dmy }} < /ref > \n \n == Variations == \n IPSO, now at version 6.2, is a fork of FreeBSD 6.  There were two other systems, called IPSO-SX and IPSO-LX, that were Linux-based: \n \n * \'\'\'IPSO SX\'\'\' was Nokia\'s first release of a Linux-based IPSO, and was deployed in 2002 on the now-defunct Message Protector, < ref > {{Cite web|url=http://www.nokia.com/A4136001?newsid=880176|title = The latest Nokia phones and accessories  & #124; Nokia Phones US}} < /ref >  and briefly thereafter on a short-lived appliance version of the  " Nokia Access Mobilizer " , acquired from [[Eizel]].  It had a partitioning scheme somewhat reminiscent of IPSO SB, a [[LILO (boot loader)|LILO]] configuration and [[boot manager]] also somewhat inspired by IPSO SB, and a software package installer that made [[RPM Package Manager|RPM]] packaging look more familiar to a Nokia IPSO administrator.  It did not, however, include a full configuration database or Voyager web interface, the two things that normally define IPSO. \n * \'\'\'IPSO LX\'\'\' is a nearly [[Vanilla (computing)|vanilla]] [[Gentoo Linux|Gentoo]]-based Linux OS, < ref > {{Cite web|url=http://www.secinfo.com/dsvRq.uu2.a.htm|title = SEC Info}} < /ref >  and is used on Nokia appliances sold with [[Sourcefire]] 3D.  It includes a full Voyager and database implementation—in fact, the Voyager look and feel in IPSO SB 4.0 onwards was based on that implemented for IPSO LX. \n \n Check Point offers three lines of security appliances - one based on IPSO 6.x, one based on an operating system called SecurePlatform and the latest based on Gaia platform (RHEL4 based). \n \n === Features === \n \n IPSO notable features or firsts include: \n * Effective firewall load-balancing (in conjunction with [[Check Point]] synchronization), derived from Network Alchemy [[cluster (computing)|clustering]] technology, predating and still independently developed from Check Points [[ClusterXL]]. \n * The first commercial [[IPv6]] [[router (computing)|router]] out of [[beta-testing]] (ahead of [[Cisco]] and [[Juniper Networks]]) \n * Firewall Flows for putting Check Point security rule implementation into the dedicated network processor circuitry on-the-fly (though this is now largely evolved into Check Point\'s SecureXL) \n \n === Versions === \n IPSO SB was originally derived by [[Ipsilon Networks]] from FreeBSD 2.1-STABLE and cross-compiled on FreeBSD 2.2.6-RELEASE and 3.5-RELEASE platforms. Its major components are: \n *  A configuration database held in me ...
#   '7903804'),
#  ('Tyson Griffin',
# ...
#   '125972'),
#  ('Raver, Maharashtra',
#   "{{More citations needed|date=July 2015}} \n {{Original research|date=March 2021}} \n {{Use dmy dates|date=June 2015}} \n {{Use Indian English|date=June 2015}} \n {{Infobox settlement \n | name                            = Raver \n | other_name                      = Banana City \n | nickname                        =  \n | settlement_type                 = City \n | image_skyline                   =  \n | image_alt                       =  \n | image_caption                   =  \n | pushpin_map                     = India Maharashtra \n | pushpin_label_position          = right \n | pushpin_map_alt                 =  \n | pushpin_map_caption             = Location in Maharashtra, India \n | coordinates                     = {{coord|21|14|35|N|76|02|00|E|display=inline,title}} \n | subdivision_type                = Country \n | subdivision_name                = {{flag|India}} \n | subdivision_type1               = [[States and territories of India|State]] \n | subdivision_name1               = [[Maharashtra]] \n | subdivision_type2               = [[List of districts of India|District]] \n | subdivision_name2               = [[Jalgaon district|Jalgaon]] \n | established_title               =  < !-- Established -- > \n | established_date                =  \n | founder                         =  \n | named_for                       =  \n | government_type                 =  \n | governing_body                  = Municipal Council \n | unit_pref                       = Metric \n | leader_title                    = MLA(Raver Vidhansabha Constituency) \n | leader_name                     = Shirish Madhukarrao Chaudhary (INC) \n | leader_title2                   = MP(Raver Loksabha Constituency) \n | leader_name2                    = Raksha Khadse(BJP). \n | precidant - dara mohmad area_footnotes =  \n | area_rank                       =  \n | area_total_km2                  =  \n | elevation_footnotes             =  \n | elevation_m                     = 248 \n | population_total                = 25,949 \n | population_as_of                = 2011 \n | population_rank                 =  \n | population_density_km2          = auto \n | population_demonym              =  \n | population_footnotes            =  \n | demographics_type1              = Languages \n | demographics1_title1            = Official \n | demographics1_info1             = [[Marathi language|Marathi]] \n | timezone1                       = [[Indian Standard Time|IST]] \n | utc_offset1                     = +5:30 \n | postal_code_type                =  < !-- [[Postal Index Number|PIN]] -- > \n | postal_code                     = 425508 \n | area_code_type                  = Telephone code \n | area_code                       = 02584 \n | registration_plate              = [[List of RTO districts in India#MH.E2.80.94Maharashtra|MH]]-19 \n | website                         =  \n | iso_code                        = [[ISO 3166-2:IN|IN-MH]] \n | footnotes                       =  \n | official_name                   =  \n }} \n '''Raver''' is a city and [[municipal council]] in [[Jalgaon district]] in the [[India]]n [[States and territories of India|state]] of [[Maharashtra]]. It is the administrative center of Raver Taluka. Raver is famous for the Bhagvan Dattatreya-temple which is 200 years old and was founded by Sachidanand Swami Maharaj. Built in the old Mughal Kaleen tradition, it also has some ancient photos of Bhagvan Dattreyay in form of Malaang Fakir, Bhagwan Dattreyay's Charan Paduka. It is part of the Khandesh region. \n \n ==Economy== \n The economy of the city is mainly dependent on agriculture and related businesses.{{citation needed|date=March 2018}} Raver Taluka is an important market for bananas in the state of Maharashtra and India. It contributes to about more than 80% of production in Jalgaon district. \n \n ==Geography== \n Raver is located in North Maharashtra Region. It is {{convert|22|km|mi}} from [[Madhya Pradesh]]. It has an average elevation  ...
#   '1078174302'),
#  ('HD 69830 b',
#   '{{Short description|Neptune-mass or Super-earth exoplanet}} \n {{Infobox planet \n | name                     = HD 69830 b \n < !-- DISCOVERY           -- > \n | discoverer               = [[Christophe Lovis|C. Lovis]] et al. < ref name= " Lovis2006 " / > \n | discovered               = May 18, 2006 \n | discovery_method         = [[Radial velocity]] \n < !-- DESIGNATIONS        -- > \n < !-- ORBITAL             -- >   \n | apsis                    = astron \n | semimajor                = {{convert|0.0785|AU|km|abbr=on}} \n | eccentricity             = 0.1 ± 0.04 \n | period                   = 8.667 ± 0.003 [[day|d]] \n | time_periastron          = 2,453,496.8 ± 0.06 \n | arg_peri                 = 340 ± 26 \n | semi-amplitude           = 3.51 ± 0.15 \n | star                     = [[HD 69830]] \n < !-- PHYS CHARS          -- >   \n | single_temperature       = ~804 [[kelvin|K]] \n < !-- ATMOSPHERE          -- >   \n < !-- NOTES               -- >   \n |image=HD_69830_b_(Celestia).jpg}} \n \n \'\'\'HD 69830 b\'\'\' is a [[Neptune|Neptune-mass]] or [[super-Earth]]-mass [[exoplanet]] orbiting the star [[HD 69830]]. It is 10 times more [[mass]]ive than [[Earth]]. It also orbits very close to its [[star|parent star]] and takes 8 < sup > 2 < /sup > / < sub > 3 < /sub >  [[day]]s to complete an orbit. \n \n This is likely to be a [[rocky planet]], not a [[gas giant]]. < ref name= " Lovis2006 " / >  If it had formed as a gas giant, it would have stayed that way. < ref > {{cite journal | journal=Geophysical Research Abstracts | volume=9| issue=7850 |date=2007 | url=http://www.cosis.net/abstracts/EGU2007/07850/EGU2007-J-07850.pdf?PHPSESSID=1eb3a7a98603083dda25d18001ea2a33 | title=The impact of nonthermal loss processes on planet masses from Neptunes to Jupiters |author=H. Lammer|display-authors=etal}} < /ref > \n \n If HD 69830 b is a terrestrial planet, models predict that [[tidal heating]] would produce a heat flux at the surface of about 55 W/m < sup > 2 < /sup > . This is 20 times that of [[Io (moon)|Io]]. < ref > {{cite journal|title=Tidal Heating of Extra-Solar Planets| first= Brian| last= Jackson|author2=Richard Greenberg |author3=Rory Barnes | journal=Astrophysical Journal | date=2008|doi=10.1086/587641|volume=681|pages=1631|arxiv=0803.0026|issue=2| bibcode=2008ApJ...681.1631J}} < /ref > \n \n ==References== \n {{Reflist|refs= \n \n < ref name= " Lovis2006 " > {{cite journal | title=An extrasolar planetary system with three Neptune-mass planets | url=http://obswww.unige.ch/~pernier/publications-www/articles-pdf-ps/2006Natur.441..305L.pdf | last1=Lovis | first1=Christophe | last2=Mayor | first2=Michel | last3=Pepe | first3=Francesco | last4=Alibert | first4=Yann | last5=Benz | first5=Willy | last6=Bouchy | first6=François | last7=Correia | first7=Alexandre C. M. | last8=Laskar | first8=Jacques | last9=Mordasini | first9=Christoph | last10=Queloz | first10=Didier | last11=Santos | first11=Nuno C. | last12=Udry | first12=Stéphane | last13=Bertaux | first13=Jean-Loup | last14=Sivan | first14=Jean-Pierre | display-authors=1 | journal=Nature | volume=441 | issue=7091 | pages=305–309 | date=2006 | arxiv=astro-ph/0703024 | bibcode=2006Natur.441..305L | doi=10.1038/nature04828 | pmid=16710412}} < /ref > \n \n }} \n \n {{HD 69830}} \n {{Sky|08|18|23.9|-|12|37|55.8|41}} \n \n {{clear}} \n \n [[Category:HD 69830]] \n [[Category:Super-Earths]] \n [[Category:Terrestrial planets]] \n [[Category:Exoplanets discovered in 2006]] \n [[Category:Exoplanets detected by radial velocity]] \n [[Category:Hot Neptunes]] \n \n \n {{extrasolar-planet-stub}}',
#   '39679749'),
#  ('Ideal observer theory',
#   '\'\'\'Ideal observer theory\'\'\' is the [[meta-ethics|meta-ethical]] view which claims that ethical [[Sentence (linguistics)|sentence]]s express [[truth-apt]] [[proposition]]s about the attitudes of a hypothetical \'\'ideal observer\'\'. In other words, ideal observer theory states that ethical judgments should be interpreted as statements about the judgments that a neutral and fully informed observer would make;  " \'\'x\'\' is good "  means  " an ideal observer would approve of \'\'x\'\' " . \n \n {{cquote|The main idea [of the ideal observer theory] is that ethical terms should be defined after the pattern of the following example:  " \'\'x\'\' is better than \'\'y\'\' "  means  " If anyone were, in respect of \'\'x\'\' and \'\'y\'\', fully informed and vividly imaginative, impartial, in a calm frame of mind and otherwise normal, he would \'\'prefer x\'\' to \'\'y\'\'. < ref > {{cite book |last=Brandt |first=Richard |author-link=Richard Brandt |title=[[Ethical Theory]] |year=1959 |location=[[Englewood Cliffs]] |publisher=[[Prentice Hall]] |chapter=Ethical Naturalism |pages=173 |lccn=59010075 }} < /ref > }} \n \n This makes ideal observer theory a [[ethical subjectivism|subjectivist]] < ref > Brandt 1959, p. 153:  " [Objectivism and subjectivism] have been used more vaguely, confusedly, and in more different senses than the others we are considering. We suggest as a convenient usage, however, that a theory be called subjectivist [[if and only if]], according to it, any ethical assertion implies that somebody does, or somebody of a certain sort under certain conditions would, take \'\'some specified attitude\'\' toward something. " < /ref >  yet [[moral universalism|universalist]] form of [[Cognitivism (ethics)|cognitivism]]. Ideal observer theory stands in opposition to other forms of ethical subjectivism (e.g.[[moral relativism]], and [[individualist ethical subjectivism]]), as well as to [[moral realism]] (which claims that moral propositions refer to objective facts, independent of anyone\'s attitudes or opinions), [[error theory]] (which denies that any moral propositions are true in any sense), and [[non-cognitivism]] (which denies that moral sentences express propositions at all). \n \n [[Adam Smith]] and [[David Hume]] espoused versions of the ideal observer theory. [[Roderick Firth]] laid out a more sophisticated modern version. < ref > {{cite journal |title=Ethical Absolutism and the Ideal Observer |first=Roderick |last=Firth |journal=Philosophy and Phenomenological Research |volume=12 |issue=3 |date=March 1952 |pages=317–345 |jstor=2103988}} < /ref >  According to Firth, an ideal observer has the following specific characteristics: omniscience with respect to nonmoral facts, [[omnipercipience]], disinterestedness, dispassionateness, consistency, and normalcy in all other respects. Notice that, by defining an Ideal Observer as omniscient with respect to nonmoral facts, Firth avoids [[Begging the question|circular logic]] that would arise from defining an ideal observer as omniscient in both nonmoral and moral facts. A complete knowledge of morality is not born of itself but is an [[Emergence|emergent property]] of Firth\'s minimal requirements. There are also sensible restrictions to the trait of omniscience with respect to nonmoral facts. For instance, to make a moral judgment about a case of theft or murder on [[Earth]] it is not necessary to know about geological events in another [[Solar System|solar system]]. \n \n Those using the ideal observer theory do not usually assert that ideal observers actually exist. An analogous idea in law is the [[reasonable person]] criterion. \n \n ==References== \n < references / > \n \n ==External links== \n * [http://plato.stanford.edu/entries/impartiality/ Impartiality] in the [[Stanford Encyclopedia of Philosophy]] \n \n {{Ethics}} \n \n [[Category:Meta-ethics]] \n [[Category:Ethical theories]] \n [[Category:Emergence]] \n [[Category:Point of view]] \n [[Category:Thought ...
#   '41906662'),
#  ('Rania, Sirsa',
#   '{{more citations needed|date=September 2016}} \n {{Use dmy dates|date=December 2019}} \n {{Use Indian English|date=October 2017}} \n {{Infobox settlement \n | name                    = Rania \n | native_name             =  \n | native_name_lang        =  \n | other_name              =  \n | nickname                =  \n | settlement_type         = Town < ref > {{cite web |title=Towns {{!}} Sirsa {{!}} India |url=https://sirsa.gov.in/towns/ |website=sirsa.gov.in |access-date=27 September 2020}} < /ref > \n | image_skyline           =  \n | image_alt               =  \n | image_caption           =  \n | pushpin_map             = India Haryana#India3 \n | pushpin_label_position  = right \n | pushpin_map_alt         =  \n | pushpin_map_caption     = Location in Haryana, India \n | coordinates             = {{coord|29.53|N|74.83|E|display=inline,title}} \n | subdivision_type        = Country \n | subdivision_name        = {{flag|India}} \n | subdivision_type1       = [[States and territories of India|State]] \n | subdivision_name1       = [[Haryana]] \n | subdivision_type2       = [[List of districts of India|District]] \n | subdivision_name2       = [[Sirsa district|Sirsa]] \n | established_title       =  < !-- Established -- > \n | established_date        =  \n | founder                 =  \n | named_for               =  \n | government_type         =  \n | governing_body          =  \n | unit_pref               = Metric \n | area_footnotes          =  \n | area_rank               =  \n | area_total_km2          =  \n | elevation_footnotes     =  \n | elevation_m             = 190 \n | population_total        = 25123 \n | population_as_of        = 2011 \n | population_rank         =  \n | population_density_km2  = auto \n | population_demonym      =  \n | population_footnotes    =  < ref name= " Census2011Gov " / > \n | demographics_type1      = Languages < ref name=nclmanurep2010 > {{cite web |url = http://www.nclm.nic.in/shared/linkimages/NCLM52ndReport.pdf |title = Report of the Commissioner for linguistic minorities: 52nd report (July 2014 to June 2015) |pages = 24 |publisher = Commissioner for Linguistic Minorities, Ministry of Minority Affairs, Government of India |access-date = 7 March 2019 |archive-url = https://web.archive.org/web/20161115133948/http://nclm.nic.in/shared/linkimages/NCLM52ndReport.pdf |archive-date = 15 November 2016 |url-status = dead }} < /ref > < ref name= " punjabiofficial " > {{cite web |url=https://www.hindustantimes.com/india/haryana-grants-second-language-status-to-punjabi/story-MTUeEQDE4fRCbEyPkAm63N.html |title=Haryana grants second language status to Punjabi |work=[[Hindustan Times]] |author=IANS |date=28 January 2010 |access-date=2 January 2019|author-link=Indo-Asian News Service }} < /ref > \n | demographics1_title1   = Official \n | demographics1_info1    = [[Hindi]] \n | demographics1_title2   = Additional & nbsp;official \n | demographics1_info2    = [[English language|English]], [[Punjabi language|Punjabi]] \n | timezone1               = [[Indian Standard Time|IST]] \n | utc_offset1             = +5:30 \n | postal_code_type        = [[Postal Index Number|PIN]] \n | postal_code             = 125076 \n | area_code_type          = Telephone code \n | area_code               = 01698 \n | registration_plate      =[[List of RTO districts in India#HR.E2.80.94Haryana|HR]]-44 \n | blank1_name_sec1        = [[Lok Sabha]] constituency \n | blank1_info_sec1        = [[Sirsa (Lok Sabha constituency)|Sirsa]] \n | website                 = {{URL|haryana.gov.in}}  \n | iso_code                = [[ISO 3166-2:IN|IN-HR]] \n | footnotes               = \n \n }} \n \'\'\'Rania\'\'\' is a city and a municipal committee [[Sirsa district]] in the [[India]]n [[States and territories of India|state]] of [[Haryana]]. Rania Town is the biggest [[grain trade|grain market]] in Sirsa district. \n \n =={{anchor | Rania State | Rania Princely State }} History== \n Rania, which means  " queen " , was formerly called Bh ...
#   '563447')]

# %%
handler._redirects
# Out:
# {'Rational inference': 'Inference',
#  'Ripcot': 'The Ripping Friends',
#  'Delphic of Gamma Sigma Tau Fraternity': 'Delphic Fraternity',
#  'Tir na n-og Awards': 'Tir na n-Og Award',
#  'Chantiers de l’Atlantique': "Chantiers de l'Atlantique",
#  'South Australian general election campaign, 2006': '2006 South Australian state election',
#  'Sr. Maria Stanisia': 'Mary Stanisia',
#  'Monica Kurkowski': 'Mary Stanisia',
#  'Atlantoaxial': 'Atlanto-axial joint',
#  'URGI': 'Avenue (store)',
#  'Panagiotis Fassoulas': 'Panagiotis Fasoulas',
#  'Dysplasia of the hip': 'Hip dysplasia',
#  'Uk.yahoo.com': 'Yahoo!',
#  'Twilight of the idols': 'Twilight of the Idols',
#  'Factions in Supreme Commander': 'Supreme Commander (video game)',
#  'Tir na n-Og awards': 'Tir na n-Og Award',
#  'Thon the Egyptian': 'Polydamna',
#  'Egg Harbor City (NJT Station)': 'Egg Harbor City station',
#  'Nyrondal': 'Greyhawk',
#  'William M. Fowler, Jr.': 'William M. Fowler',
#  'Allendale (NJT Station)': 'Allendale station (NJ Transit)',
#  'Independent School Athletic League': 'Independent Schools Athletic League',
#  'Stan Switek': 'Miami Vice',
#  'Sheldon B. Lubar School of Business': 'University of Wisconsin–Milwaukee academics',
#  'Bahadir Gokay': 'Bahadır Gökay',
#  'Cardinal Rigali': 'Justin Rigali',
#  'Pingree, David': 'David Pingree',
#  'Sister Mary Stanisia': 'Mary Stanisia',
#  'Elazığ province': 'Elazığ Province',
#  'Engineering Technology': 'Engineering technologist',
#  'Krzyż Zasługi z Mieczami': 'Cross of Merit with Swords (Poland)',
#  'Client Logic': 'Sitel',
#  'SC430': 'SC 430',
#  'Salatut Elämät': 'Salatut elämät',
#  'Disney Animation Studios': 'Walt Disney Animation Studios',
#  'Texas Tech University Engineering': 'Whitacre College of Engineering',
#  'Strawbridge  &  Clothier': "Strawbridge's",
#  'Ivan alexander of bulgaria': 'Ivan Alexander of Bulgaria',
#  'The Snow Spider': 'The Magician Trilogy',
#  'Deadly Game (novel)': 'Christine Feehan',
#  'Idiopathic orofacial dystonia': "Meige's syndrome",
#  'Orofacial dyskinesia': "Meige's syndrome",
#  'Love And Sex': 'Love and Sex',
#  'Andrew Quick': 'List of The Dark Tower characters',
#  'High-technology business district': 'List of technology centers',
#  'Lubar School of Business': 'University of Wisconsin–Milwaukee academics',
#  'Trudy Joplin': 'Miami Vice',
#  'Curtis Baldwin': '227 (TV series)',
#  'UWM Lubar School of Business': 'University of Wisconsin–Milwaukee academics',
#  'Zamosts': 'Zamość',
#  'UWM School of Education': 'University of Wisconsin–Milwaukee academics',
#  'Hawker Siddeley HS121 Trident': 'Hawker Siddeley Trident',
#  'Cherry Darling': 'Grindhouse (film)',
#  'UWM College of Engineering and Applied Science': 'University of Wisconsin–Milwaukee academics',
#  'Marches on Washington': 'List of rallies and protest marches in Washington, D.C.',
#  'Marches on washington': 'List of rallies and protest marches in Washington, D.C.',
#  'C. Litton Falkiner': 'Caesar Litton Falkiner',
#  'March on Washington, D.C.': 'List of rallies and protest marches in Washington, D.C.',
#  'Pesseta': 'Peseta',
#  'Marches on Washington, D.C.': 'List of rallies and protest marches in Washington, D.C.',
#  'Hens  &  Kelly': 'Hens and Kelly',
#  'Catalan pesseta': 'Catalan peseta',
#  'Monet-twins': 'M (Marvel Comics)',
#  'Spanish pesseta': 'Spanish peseta',
#  'Marches on Washington, DC': 'List of rallies and protest marches in Washington, D.C.',
#  'Pezeta': 'Peseta',
#  'WizzAir': 'Wizz Air',
#  'Spanish pezeta': 'Spanish peseta',
#  'Safety Training (The Office episode)': 'Safety Training',
#  'March on Washington, DC': 'List of rallies and protest marches in Washington, D.C.',
#  'March on Washington DC': 'List of rallies and protest marches in Washington, D.C.',
#  'AYSTA5G': 'Are You Smarter than a 5th Grader? (American game show)',
#  'March on Washington D.C.': 'List of rallies and protest marches in Washington, D.C.',
#  'Artis Leon Ivey, Jr.': 'Coolio',
#  'Marches on Washington DC': 'List of rallies and protest marches in Washington, D.C.',
#  'Yu-gi-oh 2007': 'List of Yu-Gi-Oh! video games',
#  'AFL Ladder 2007': '2007 AFL season',
#  'Artis Leon Ivey Jr.': 'Coolio',
#  'Marches on Washington D.C.': 'List of rallies and protest marches in Washington, D.C.',
#  'Wikipedia:WPNM': 'Wikipedia:WikiProject New Mexico',
#  'Brotherhood winery': 'Brotherhood Winery',
#  'Principles of Islamic Jurisprudence': 'Principles of Islamic jurisprudence',
#  'Rusty anderson': 'Rusty Anderson',
#  'Texas Tech University College of Agricultural Resources  &  Natural Sciences': 'Davis College of Agricultural Sciences & Natural Resources',
#  'Golden axe (series)': 'Golden Axe',
#  'Grand Street (disambiguation)': 'Grand Street',
#  'Larry Zito': 'Miami Vice',
#  'Mark Jacobs (t.v character)': 'Blue Heelers',
#  'Beardlip Penstemon': 'Penstemon barbatus',
#  'Grays River (disambiguation)': 'Grays River',
#  'Scarlet bugler': 'Penstemon centranthifolius',
#  'Tusaras': 'Tushara',
#  'HIM (disambiguation)': 'HIM',
#  'The Dundies (The Office episode)': 'The Dundies',
#  'Office Olympics (The Office episode)': 'Office Olympics',
#  'Ragdoll Kung Fu': 'Rag Doll Kung Fu',
#  'Performance Review (The Office episode)': 'Performance Review',
#  'E-mail Surveillance (The Office episode)': 'Email Surveillance',
#  'Parasika': 'Saka',
#  'The Injury (The Office episode)': 'The Injury',
#  'The Carpet (The Office episode)': 'The Carpet (The Office)',
#  'Amy Fox (Blue Heelers)': 'Blue Heelers',
#  'Nanase Ōkawa': 'Nanase Ohkawa',
#  "Dwight's Speech (The Office episode)": "Dwight's Speech",
#  "Michael's Birthday (The Office episode)": "Michael's Birthday",
#  'Gay Witch Hunt (The Office episode)': 'Gay Witch Hunt',
#  'Democratic Republic of Belarus': 'Belarusian Democratic Republic',
#  'Live at Thee Mardi Gras': 'Psychic TV discography',
#  'Branch Closing (The Office episode)': 'Branch Closing',
#  'Brooklyn Tip Tops': 'Brooklyn Tip-Tops',
#  'Chalet Schell': 'Northfield Chateau',
#  'Wikipedia:Wikiquette alerts/archive': 'Wikipedia:Wikiquette assistance/archive1',
#  'Birnam House': 'Northfield Chateau',
#  'Haddington (disambiguation)': 'Haddington',
#  'A Benihana Christmas (The Office episode)': 'A Benihana Christmas',
#  'Bryn Athyn College of the New Church': 'Bryn Athyn College',
#  'Wikipedia:Articles for deletion/Mother Dearest - History': 'Wikipedia:Articles for deletion/Mother Dearest',
#  "Phyllis' Wedding (The Office episode)": "Phyllis' Wedding",
#  'Judges of Singapore': 'Judge of Singapore',
#  'Zelophhad': 'Daughters of Zelophehad',
#  'Zelophchad': 'Daughters of Zelophehad',
#  'Census of India 2001': '2001 Census of India',
#  'Tzlofchad': 'Daughters of Zelophehad',
#  'Zelofhad': 'Daughters of Zelophehad',
#  'Tzlofchod': 'Daughters of Zelophehad',
#  'Tzlafchad': 'Daughters of Zelophehad',
#  'Tzlafchod': 'Daughters of Zelophehad',
#  'Wikipedia:Requests for arbitration/Clarification/MONGO': 'Wikipedia talk:Requests for arbitration/MONGO',
#  'Kangaroo (arcade game)': 'Kangaroo (video game)',
#  'Southshore Commission': 'South Shore Commission',
#  'Dramacon 2': 'Dramacon',
#  'Cabinet meetings': 'Cabinet (government)',
#  'Preshov': 'Prešov',
#  'Dennis the Menace (TV series)': 'Dennis the Menace',
#  'Sava Sumanovc': 'Sava Šumanović',
#  'Multi-system degeneration': 'Multiple system atrophy',
#  'Heart of Jesus (disambiguation)': 'Heart of Jesus',
#  'Wikipedia:Wikiquette alerts/Header': 'Wikipedia:Wikiquette assistance/Header',
#  'Dennis the Menace (British TV series)': 'Dennis and Gnasher (1996 TV series)',
#  'Quest Aircraft Company': 'Quest Aircraft',
#  'Charlie brooks': 'Charlie Brooks',
#  'Helicon (disambiguation)': 'Helicon',
#  'Storm Owl': 'Mega Man X',
#  'Iranian-Armenian': 'Iranian Armenians',
#  'Iranian-Armenians': 'Iranian Armenians',
#  'Davenport-Moline-Rock Island': 'Quad Cities',
#  'Daughters of Charity of St. Vincent de Paul': 'Daughters of Charity of Saint Vincent de Paul'}

# %% [markdown]
# ### See also section filtering

# %%
matches = r'^([Ss]ee[ ]*|[Ss]ee[ ]*([Aa]lso|[Mm]ore|[Aa]ll)|[Ss]ee[ ]*[Aa]lso[ ]*\(.+\))$'

# %%
handler = WikiXmlHandler()

parser = xml.sax.make_parser()
parser.setContentHandler(handler)

headings = set()

prev_num_pages = 0
seealso_pages_idx = []

for i, line in enumerate(subprocess.Popen(['bzcat'],
                                         stdin=open(data_path),
                                         stdout=subprocess.PIPE).stdout):
    parser.feed(line)
    
    if len(handler._pages) > 1e5 or len(seealso_pages_idx) > 10:
        break
        
    if prev_num_pages < len(handler._pages):
        prev_num_pages += 1
        wiki = mwparserfromhell.parse(handler._pages[-1][1])
        for h in wiki.filter_headings():
            header = h.title.strip_code().strip()
            if re.search(matches, header):
            #if header.lower() == "see also":
                headings.add(header)
                seealso_pages_idx.append(prev_num_pages-1)

# %%
page_num_idx = 2
wiki = mwparserfromhell.parse(handler._pages[seealso_pages_idx[page_num_idx]][1])

# %%
wiki.strip_code()
# Out:
# ' \n \n The College of Engineering and Applied Science is a college within the University of Wisconsin–Milwaukee. It offers bachelor, master and doctoral degrees in civil engineering, electrical engineering, industrial engineering, materials engineering, mechanical engineering, and computer science. \n \n Based on the statistical analysis by H.J. Newton, Professor of Statistics at Texas A & M University in 1997 on the National Research Council report issued in 1995, the school was  ranked 73rd nationally in the National Research Council (NRC) rankings, < ref > A Brief Summary of the NRC Rankings, Texas A & M University < /ref >  with its Civil Engineering program 69th, < ref > NRC Rankings in each of the 41 Areas: civil engineering, Texas A & M University < /ref >  Electronic Engineering 96th, < ref > NRC Rankings in each of the 41 Areas: Electronic Engineering, Texas A & M University < /ref >  Industrial Engineering 34th, < ref > NRC Rankings in each of the 41 Areas: Industrial Engineering, Texas A & M University < /ref >  Materials science 60th, < ref > NRC Rankings in each of the 41 Areas: Materials science, Texas A & M University < /ref >   and Mechanical Engineering 87th. < ref > NRC Rankings in each of the 41 Areas: Mechanical Engineering, Texas A & M University < /ref >  The school ranks 129th nationally by U.S. News  &  World Report, < ref name= " Best Engineering Schools " > Best Engineering Schools,U.S. News  &  World Report. < /ref >  with its computer science program ranked 110th in 2011. < ref name= " Rankings: Computer Science " > Rankings: Computer Science, US News  &  World Report, 2010. < /ref > \n \n Departments \n *Civil Engineering  &  Mechanics \n *Computer Science \n *Electrical Engineering \n *Industrial  &  Manufacturing Engineering \n *Materials Science \n *Mechanical Engineering \n \n Research centers \n *Center for Alternative Fuels Research Programs \n *Center for By-Products Utilization \n *Center for Composite Materials \n *Center for Cryptography, Computer,  &  Network Security \n *Center for Ergonomics \n *Center for Urban Transportation Studies \n *Center for Energy Analysis  &  Diagnostics \n *Southeastern Wisconsin Energy Technology Research Center \n \n Notable people \n * Satya Nadella (\'90 MS Computer Science), Microsoft CEO.  \n * Michael Dhuey, electrical and computer engineer, co-inventor of the Macintosh II and the iPod. \n * Luther Graef (\'61 MS Structural Engineering), Founder of Graef Anhalt Schloemer  &  Associates Inc., and former President of ASCE. \n * Phil Katz (\'84, BS Computer Science), a computer programmer best known as the author of PKZIP. \n * Pradeep Rohatgi, Wisconsin Distinguished Professor of Engineering \n * Cheng Xu, aerodynamic design engineer, American Society of Mechanical Engineers Fellow \n * Y. Austin Chang, material engineering researcher and educator \n * Scott Yanoff (\'93 BS Computer Science), Internet pioneer. \n * Alan Kulwicki (\'77 BS Mechanical Engineering), 1992 NASCAR Cup Series champion driver and team owner \n \n See also \n * Jantar-Mantar \n \n References \n  \n \n External links \n *College of Engineering and Applied Science \n *University of Wisconsin–Milwaukee \n \n  \n \n  \n \n  \n Category:University of Wisconsin–Milwaukee \n Category:Engineering schools and colleges in the United States \n Category:Engineering universities and colleges in Wisconsin'

# %%
for i, n in enumerate(wiki.nodes):
    print(i, n, type(n))
# Out:
# 0 {{Infobox university
#  |image= < !-- Do NOT place a non-free image here without complying with WP:NFCC #10c -- >
#  |motto= ''Discover. Innovate. Lead.''
#  |name=UW-Milwaukee College of Engineering and Applied Science
#  |type            = [[Public university|Public]]
#  |established     = 1964 < ref > [http://www4.uwm.edu/ceas/explore_ceas/about_ceas/ceas_history.cfm History of CEAS on the UW-Milwaukee website] < /ref >
#  |dean            = [[Brett Peters]]
#  |undergrad       = 1,568 < ref name=enrollment > [http://www4.uwm.edu/acad_aff/assessment/intranet/enroll/enrtodat/ay201314/cedall2139_passthrough.cfm Fall 2013 Headcount Report], available on UWM campus or off-campus with UWM student/staff logon < /ref >
#  |postgrad        = 399 < ref name=enrollment / >
#  |city            =[[Milwaukee]]
#  |state           =[[Wisconsin]]
#  |country         =[[United States]]
#  |campus          =[[University of Wisconsin–Milwaukee]]
#  |website= [http://www.uwm.edu/CEAS http://www.uwm.edu/CEAS]
#  |logo=UW-Milwaukee.png
#  |}} <class 'mwparserfromhell.nodes.template.Template'>
# 1
#
#  The  <class 'mwparserfromhell.nodes.text.Text'>
# 2 '''College of Engineering and Applied Science''' <class 'mwparserfromhell.nodes.tag.Tag'>
# 3  is a college within the  <class 'mwparserfromhell.nodes.text.Text'>
# 4 [[University of Wisconsin–Milwaukee]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 5 . It offers bachelor, master and doctoral degrees in  <class 'mwparserfromhell.nodes.text.Text'>
# 6 [[civil engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 7 ,  <class 'mwparserfromhell.nodes.text.Text'>
# 8 [[electrical engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 9 ,  <class 'mwparserfromhell.nodes.text.Text'>
# 10 [[industrial engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 11 ,  <class 'mwparserfromhell.nodes.text.Text'>
# 12 [[materials engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 13 ,  <class 'mwparserfromhell.nodes.text.Text'>
# 14 [[mechanical engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 15 , and  <class 'mwparserfromhell.nodes.text.Text'>
# 16 [[computer science]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 17 .
#
#  Based on the statistical analysis by H.J. Newton, Professor of Statistics at Texas A & M University in 1997 on the  <class 'mwparserfromhell.nodes.text.Text'>
# 18 [[United States National Research Council|National Research Council]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 19  report issued in 1995, the school was  ranked 73rd nationally in the  <class 'mwparserfromhell.nodes.text.Text'>
# 20 [[United States National Research Council rankings|National Research Council]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 21  (NRC) rankings, < ref >  <class 'mwparserfromhell.nodes.text.Text'>
# 22 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc1.html#RANKBYAREA A Brief Summary of the NRC Rankings] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 23 , Texas A & M University < /ref >  with its  <class 'mwparserfromhell.nodes.text.Text'>
# 24 [[Civil Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 25  program 69th, < ref >  <class 'mwparserfromhell.nodes.text.Text'>
# 26 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area22 NRC Rankings in each of the 41 Areas:] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 27  civil engineering, Texas A & M University < /ref >   <class 'mwparserfromhell.nodes.text.Text'>
# 28 [[Electronic Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 29  96th, < ref >  <class 'mwparserfromhell.nodes.text.Text'>
# 30 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area23 NRC Rankings in each of the 41 Areas:] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 31  Electronic Engineering, Texas A & M University < /ref >   <class 'mwparserfromhell.nodes.text.Text'>
# 32 [[Industrial Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 33  34th, < ref >  <class 'mwparserfromhell.nodes.text.Text'>
# 34 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area24 NRC Rankings in each of the 41 Areas:] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 35  Industrial Engineering, Texas A & M University < /ref >   <class 'mwparserfromhell.nodes.text.Text'>
# 36 [[Materials science]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 37  60th, < ref >  <class 'mwparserfromhell.nodes.text.Text'>
# 38 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area25 NRC Rankings in each of the 41 Areas:] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 39  Materials science, Texas A & M University < /ref >   and  <class 'mwparserfromhell.nodes.text.Text'>
# 40 [[Mechanical Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 41  87th. < ref >  <class 'mwparserfromhell.nodes.text.Text'>
# 42 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area26 NRC Rankings in each of the 41 Areas:] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 43  Mechanical Engineering, Texas A & M University < /ref >  The school ranks 129th nationally by  <class 'mwparserfromhell.nodes.text.Text'>
# 44 ''[[U.S. News  &  World Report]]'' <class 'mwparserfromhell.nodes.tag.Tag'>
# 45 , < ref name= " Best Engineering Schools " >  <class 'mwparserfromhell.nodes.text.Text'>
# 46 [http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-engineering-schools/eng-rankings/page+6 Best Engineering Schools] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 47 , <class 'mwparserfromhell.nodes.text.Text'>
# 48 ''[[U.S. News  &  World Report]]'' <class 'mwparserfromhell.nodes.tag.Tag'>
# 49 . < /ref >  with its  <class 'mwparserfromhell.nodes.text.Text'>
# 50 [[computer science]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 51  program ranked 110th in 2011. < ref name= " Rankings: Computer Science " >  <class 'mwparserfromhell.nodes.text.Text'>
# 52 [http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-science-schools/computer-science-rankings/page+5 Rankings: Computer Science] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 53 ,  <class 'mwparserfromhell.nodes.text.Text'>
# 54 ''[[US News  &  World Report]]'' <class 'mwparserfromhell.nodes.tag.Tag'>
# 55 , 2010. < /ref >
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 56 ==Departments== <class 'mwparserfromhell.nodes.heading.Heading'>
# 57
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 58 [[Civil Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 59   &   <class 'mwparserfromhell.nodes.text.Text'>
# 60 [[Mechanics]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 61
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 62 [[Computer Science]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 63
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 64 [[Electrical Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 65
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 66 [[Industrial engineering|Industrial  &  Manufacturing Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 67
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 68 [[Materials Science]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 69
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 70 [[Mechanical Engineering]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 71
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 72 ==Research centers== <class 'mwparserfromhell.nodes.heading.Heading'>
# 73
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 74 [http://www4.uwm.edu/ceas/faculty_research/research_centers/alternative_fuels/ Center for Alternative Fuels Research Programs] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 75
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 76 [http://cbu.ceas.uwm.edu/wordpress/ Center for By-Products Utilization] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 77
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 78 [http://www4.uwm.edu/ceas/faculty_research/research_centers/composite_materials/ Center for Composite Materials] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 79
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 80 [http://www4.uwm.edu/ceas/faculty_research/research_centers/ccns/ Center for Cryptography, Computer,  &  Network Security] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 81
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 82 [http://www4.uwm.edu/ergonomics/ Center for Ergonomics] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 83
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 84 [http://www4.uwm.edu/cuts/ Center for Urban Transportation Studies] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 85
#  *Center for Energy Analysis  &  Diagnostics
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 86 [http://www4.uwm.edu/swetrc/ Southeastern Wisconsin Energy Technology Research Center] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 87
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 88 ==Notable people== <class 'mwparserfromhell.nodes.heading.Heading'>
# 89
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 90 [[Satya Nadella]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 91  ('90 MS Computer Science), Microsoft CEO.  <class 'mwparserfromhell.nodes.text.Text'>
# 92 [http://www5.uwm.edu/news/2014/02/04/uwm-alum-ms-ceo/] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 93
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 94 [[Michael Dhuey]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 95 , electrical and computer engineer, co-inventor of the  <class 'mwparserfromhell.nodes.text.Text'>
# 96 [[Macintosh II]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 97  and the  <class 'mwparserfromhell.nodes.text.Text'>
# 98 [[iPod]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 99 .
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 100 [[Luther Graef]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 101  ('61 MS Structural Engineering), Founder of  <class 'mwparserfromhell.nodes.text.Text'>
# 102 [[Graef Anhalt Schloemer  &  Associates Inc.]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 103 , and former President of  <class 'mwparserfromhell.nodes.text.Text'>
# 104 [[American Society of Civil Engineers|ASCE]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 105 .
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 106 [[Phil Katz]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 107  ('84, BS Computer Science), a computer programmer best known as the author of  <class 'mwparserfromhell.nodes.text.Text'>
# 108 [[PKZIP]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 109 .
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 110 [[Pradeep Rohatgi]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 111 , Wisconsin Distinguished Professor of Engineering
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 112 [[Cheng Xu]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 113 ,  <class 'mwparserfromhell.nodes.text.Text'>
# 114 [[aerodynamic]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 115  design engineer,  <class 'mwparserfromhell.nodes.text.Text'>
# 116 [[American Society of Mechanical Engineers]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 117  Fellow
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 118 [[Y. Austin Chang]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 119 , material engineering researcher and educator
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 120 [[Scott Yanoff]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 121  ('93 BS Computer Science), Internet pioneer.
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 122 [[Alan Kulwicki]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 123  ('77 BS Mechanical Engineering), 1992  <class 'mwparserfromhell.nodes.text.Text'>
# 124 [[NASCAR Cup Series]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 125  champion driver and team owner
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 126 ==See also== <class 'mwparserfromhell.nodes.heading.Heading'>
# 127
#  *  <class 'mwparserfromhell.nodes.text.Text'>
# 128 ''[[Jantar-Mantar]]'' <class 'mwparserfromhell.nodes.tag.Tag'>
# 129
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 130 ==References== <class 'mwparserfromhell.nodes.heading.Heading'>
# 131
#   <class 'mwparserfromhell.nodes.text.Text'>
# 132 {{Reflist}} <class 'mwparserfromhell.nodes.template.Template'>
# 133
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 134 ==External links== <class 'mwparserfromhell.nodes.heading.Heading'>
# 135
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 136 [http://www.uwm.edu/CEAS/ College of Engineering and Applied Science] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 137
#  * <class 'mwparserfromhell.nodes.text.Text'>
# 138 [http://www.uwm.edu/ University of Wisconsin–Milwaukee] <class 'mwparserfromhell.nodes.external_link.ExternalLink'>
# 139
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 140 {{University of Wisconsin–Milwaukee}} <class 'mwparserfromhell.nodes.template.Template'>
# 141
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 142 {{coord|43.0758|-87.8859|display=title}} <class 'mwparserfromhell.nodes.template.Template'>
# 143
#
#   <class 'mwparserfromhell.nodes.text.Text'>
# 144 {{DEFAULTSORT:University Of Wisconsin-Milwaukee College Of Engineering And Applied Science}} <class 'mwparserfromhell.nodes.template.Template'>
# 145
#   <class 'mwparserfromhell.nodes.text.Text'>
# 146 [[Category:University of Wisconsin–Milwaukee]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 147
#   <class 'mwparserfromhell.nodes.text.Text'>
# 148 [[Category:Engineering schools and colleges in the United States]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>
# 149
#   <class 'mwparserfromhell.nodes.text.Text'>
# 150 [[Category:Engineering universities and colleges in Wisconsin]] <class 'mwparserfromhell.nodes.wikilink.Wikilink'>

# %%
wiki.remove_nodetype(inplace=True)

# %%
for i, n in enumerate(wiki.nodes):
    print(i, n)
# Out:
# 0
#
#  The
# 1 '''College of Engineering and Applied Science'''
# 2  is a college within the
# 3 [[University of Wisconsin–Milwaukee]]
# 4 . It offers bachelor, master and doctoral degrees in
# 5 [[civil engineering]]
# 6 ,
# 7 [[electrical engineering]]
# 8 ,
# 9 [[industrial engineering]]
# 10 ,
# 11 [[materials engineering]]
# 12 ,
# 13 [[mechanical engineering]]
# 14 , and
# 15 [[computer science]]
# 16 .
#
#  Based on the statistical analysis by H.J. Newton, Professor of Statistics at Texas A & M University in 1997 on the
# 17 [[United States National Research Council|National Research Council]]
# 18  report issued in 1995, the school was  ranked 73rd nationally in the
# 19 [[United States National Research Council rankings|National Research Council]]
# 20  (NRC) rankings, < ref >
# 21 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc1.html#RANKBYAREA A Brief Summary of the NRC Rankings]
# 22 , Texas A & M University < /ref >  with its
# 23 [[Civil Engineering]]
# 24  program 69th, < ref >
# 25 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area22 NRC Rankings in each of the 41 Areas:]
# 26  civil engineering, Texas A & M University < /ref >
# 27 [[Electronic Engineering]]
# 28  96th, < ref >
# 29 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area23 NRC Rankings in each of the 41 Areas:]
# 30  Electronic Engineering, Texas A & M University < /ref >
# 31 [[Industrial Engineering]]
# 32  34th, < ref >
# 33 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area24 NRC Rankings in each of the 41 Areas:]
# 34  Industrial Engineering, Texas A & M University < /ref >
# 35 [[Materials science]]
# 36  60th, < ref >
# 37 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area25 NRC Rankings in each of the 41 Areas:]
# 38  Materials science, Texas A & M University < /ref >   and
# 39 [[Mechanical Engineering]]
# 40  87th. < ref >
# 41 [http://www.stat.tamu.edu/~jnewton/nrc_rankings/nrc41.html#area26 NRC Rankings in each of the 41 Areas:]
# 42  Mechanical Engineering, Texas A & M University < /ref >  The school ranks 129th nationally by
# 43 ''[[U.S. News  &  World Report]]''
# 44 , < ref name= " Best Engineering Schools " >
# 45 [http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-engineering-schools/eng-rankings/page+6 Best Engineering Schools]
# 46 ,
# 47 ''[[U.S. News  &  World Report]]''
# 48 . < /ref >  with its
# 49 [[computer science]]
# 50  program ranked 110th in 2011. < ref name= " Rankings: Computer Science " >
# 51 [http://grad-schools.usnews.rankingsandreviews.com/best-graduate-schools/top-science-schools/computer-science-rankings/page+5 Rankings: Computer Science]
# 52 ,
# 53 ''[[US News  &  World Report]]''
# 54 , 2010. < /ref >
#
#
# 55 ==Departments==
# 56
#  *
# 57 [[Civil Engineering]]
# 58   &
# 59 [[Mechanics]]
# 60
#  *
# 61 [[Computer Science]]
# 62
#  *
# 63 [[Electrical Engineering]]
# 64
#  *
# 65 [[Industrial engineering|Industrial  &  Manufacturing Engineering]]
# 66
#  *
# 67 [[Materials Science]]
# 68
#  *
# 69 [[Mechanical Engineering]]
# 70
#
#
# 71 ==Research centers==
# 72
#  *
# 73 [http://www4.uwm.edu/ceas/faculty_research/research_centers/alternative_fuels/ Center for Alternative Fuels Research Programs]
# 74
#  *
# 75 [http://cbu.ceas.uwm.edu/wordpress/ Center for By-Products Utilization]
# 76
#  *
# 77 [http://www4.uwm.edu/ceas/faculty_research/research_centers/composite_materials/ Center for Composite Materials]
# 78
#  *
# 79 [http://www4.uwm.edu/ceas/faculty_research/research_centers/ccns/ Center for Cryptography, Computer,  &  Network Security]
# 80
#  *
# 81 [http://www4.uwm.edu/ergonomics/ Center for Ergonomics]
# 82
#  *
# 83 [http://www4.uwm.edu/cuts/ Center for Urban Transportation Studies]
# 84
#  *Center for Energy Analysis  &  Diagnostics
#  *
# 85 [http://www4.uwm.edu/swetrc/ Southeastern Wisconsin Energy Technology Research Center]
# 86
#
#
# 87 ==Notable people==
# 88
#  *
# 89 [[Satya Nadella]]
# 90  ('90 MS Computer Science), Microsoft CEO.
# 91 [http://www5.uwm.edu/news/2014/02/04/uwm-alum-ms-ceo/]
# 92
#  *
# 93 [[Michael Dhuey]]
# 94 , electrical and computer engineer, co-inventor of the
# 95 [[Macintosh II]]
# 96  and the
# 97 [[iPod]]
# 98 .
#  *
# 99 [[Luther Graef]]
# 100  ('61 MS Structural Engineering), Founder of
# 101 [[Graef Anhalt Schloemer  &  Associates Inc.]]
# 102 , and former President of
# 103 [[American Society of Civil Engineers|ASCE]]
# 104 .
#  *
# 105 [[Phil Katz]]
# 106  ('84, BS Computer Science), a computer programmer best known as the author of
# 107 [[PKZIP]]
# 108 .
#  *
# 109 [[Pradeep Rohatgi]]
# 110 , Wisconsin Distinguished Professor of Engineering
#  *
# 111 [[Cheng Xu]]
# 112 ,
# 113 [[aerodynamic]]
# 114  design engineer,
# 115 [[American Society of Mechanical Engineers]]
# 116  Fellow
#  *
# 117 [[Y. Austin Chang]]
# 118 , material engineering researcher and educator
#  *
# 119 [[Scott Yanoff]]
# 120  ('93 BS Computer Science), Internet pioneer.
#  *
# 121 [[Alan Kulwicki]]
# 122  ('77 BS Mechanical Engineering), 1992
# 123 [[NASCAR Cup Series]]
# 124  champion driver and team owner
#
#
# 125 ==See also==
# 126
#  *
# 127 ''[[Jantar-Mantar]]''
# 128
#
#
# 129 ==References==
# 130
#
# 131
#
#
# 132 ==External links==
# 133
#  *
# 134 [http://www.uwm.edu/CEAS/ College of Engineering and Applied Science]
# 135
#  *
# 136 [http://www.uwm.edu/ University of Wisconsin–Milwaukee]
# 137
#
#
# 138
#
#
# 139
#
#
# 140
#
# 141 [[Category:University of Wisconsin–Milwaukee]]
# 142
#
# 143 [[Category:Engineering schools and colleges in the United States]]
# 144
#
# 145 [[Category:Engineering universities and colleges in Wisconsin]]

# %%
wiki.strip_code()
# Out:
# ' \n \n The College of Engineering and Applied Science is a college within the University of Wisconsin–Milwaukee. It offers bachelor, master and doctoral degrees in civil engineering, electrical engineering, industrial engineering, materials engineering, mechanical engineering, and computer science. \n \n Based on the statistical analysis by H.J. Newton, Professor of Statistics at Texas A & M University in 1997 on the National Research Council report issued in 1995, the school was  ranked 73rd nationally in the National Research Council (NRC) rankings, < ref > A Brief Summary of the NRC Rankings, Texas A & M University < /ref >  with its Civil Engineering program 69th, < ref > NRC Rankings in each of the 41 Areas: civil engineering, Texas A & M University < /ref >  Electronic Engineering 96th, < ref > NRC Rankings in each of the 41 Areas: Electronic Engineering, Texas A & M University < /ref >  Industrial Engineering 34th, < ref > NRC Rankings in each of the 41 Areas: Industrial Engineering, Texas A & M University < /ref >  Materials science 60th, < ref > NRC Rankings in each of the 41 Areas: Materials science, Texas A & M University < /ref >   and Mechanical Engineering 87th. < ref > NRC Rankings in each of the 41 Areas: Mechanical Engineering, Texas A & M University < /ref >  The school ranks 129th nationally by U.S. News  &  World Report, < ref name= " Best Engineering Schools " > Best Engineering Schools,U.S. News  &  World Report. < /ref >  with its computer science program ranked 110th in 2011. < ref name= " Rankings: Computer Science " > Rankings: Computer Science, US News  &  World Report, 2010. < /ref > \n \n Departments \n *Civil Engineering  &  Mechanics \n *Computer Science \n *Electrical Engineering \n *Industrial  &  Manufacturing Engineering \n *Materials Science \n *Mechanical Engineering \n \n Research centers \n *Center for Alternative Fuels Research Programs \n *Center for By-Products Utilization \n *Center for Composite Materials \n *Center for Cryptography, Computer,  &  Network Security \n *Center for Ergonomics \n *Center for Urban Transportation Studies \n *Center for Energy Analysis  &  Diagnostics \n *Southeastern Wisconsin Energy Technology Research Center \n \n Notable people \n * Satya Nadella (\'90 MS Computer Science), Microsoft CEO.  \n * Michael Dhuey, electrical and computer engineer, co-inventor of the Macintosh II and the iPod. \n * Luther Graef (\'61 MS Structural Engineering), Founder of Graef Anhalt Schloemer  &  Associates Inc., and former President of ASCE. \n * Phil Katz (\'84, BS Computer Science), a computer programmer best known as the author of PKZIP. \n * Pradeep Rohatgi, Wisconsin Distinguished Professor of Engineering \n * Cheng Xu, aerodynamic design engineer, American Society of Mechanical Engineers Fellow \n * Y. Austin Chang, material engineering researcher and educator \n * Scott Yanoff (\'93 BS Computer Science), Internet pioneer. \n * Alan Kulwicki (\'77 BS Mechanical Engineering), 1992 NASCAR Cup Series champion driver and team owner \n \n See also \n * Jantar-Mantar \n \n References \n  \n \n External links \n *College of Engineering and Applied Science \n *University of Wisconsin–Milwaukee \n \n  \n \n  \n \n  \n Category:University of Wisconsin–Milwaukee \n Category:Engineering schools and colleges in the United States \n Category:Engineering universities and colleges in Wisconsin'

# %%
seealso_sections, all_sections = wiki.split_sections(matches=matches)

# %%
wikilinks = []
for section in all_sections:
    links = section.filter_wikilinks()
    for link in links:
        wikilinks.append(link.title)
wikilinks
# Out:
# ['Civil Engineering',
#  'Mechanics',
#  'Computer Science',
#  'Electrical Engineering',
#  'Industrial engineering',
#  'Materials Science',
#  'Mechanical Engineering',
#  'Satya Nadella',
#  'Michael Dhuey',
#  'Macintosh II',
#  'iPod',
#  'Luther Graef',
#  'Graef Anhalt Schloemer  &  Associates Inc.',
#  'American Society of Civil Engineers',
#  'Phil Katz',
#  'PKZIP',
#  'Pradeep Rohatgi',
#  'Cheng Xu',
#  'aerodynamic',
#  'American Society of Mechanical Engineers',
#  'Y. Austin Chang',
#  'Scott Yanoff',
#  'Alan Kulwicki',
#  'NASCAR Cup Series',
#  'Category:University of Wisconsin–Milwaukee',
#  'Category:Engineering schools and colleges in the United States',
#  'Category:Engineering universities and colleges in Wisconsin']

# %%
wikilinks = []
for section in seealso_sections:
    links = section.filter_wikilinks()
    for link in links:
        wikilinks.append(link.title)
wikilinks
# Out:
# ['Jantar-Mantar']

# %% [markdown]
# #### filtering article links

# %%
wikilinks = []
for section in all_sections:
    links = section.filter_wikilinks()
    for link in links:
        link_title = link.title
        
        link_sections = link_title.split(':')
        link_sections[0] = link_sections[0].strip()
        
        if len(link_sections) == 1:
            wikilinks.append(link_sections[0])
        elif len(link_sections) == 2 and not link_sections[0]:
            wikilinks.append(link_sections[1])

# %%
wikilinks
# Out:
# ['Civil Engineering',
#  'Mechanics',
#  'Computer Science',
#  'Electrical Engineering',
#  'Industrial engineering',
#  'Materials Science',
#  'Mechanical Engineering',
#  'Satya Nadella',
#  'Michael Dhuey',
#  'Macintosh II',
#  'iPod',
#  'Luther Graef',
#  'Graef Anhalt Schloemer  &  Associates Inc.',
#  'American Society of Civil Engineers',
#  'Phil Katz',
#  'PKZIP',
#  'Pradeep Rohatgi',
#  'Cheng Xu',
#  'aerodynamic',
#  'American Society of Mechanical Engineers',
#  'Y. Austin Chang',
#  'Scott Yanoff',
#  'Alan Kulwicki',
#  'NASCAR Cup Series']
