# %%
import os
import re
import gc
import requests
import pandas as pd
import xml.sax
from matplotlib import pyplot as plt
from bs4 import BeautifulSoup
from IPython.display import display
import numpy as np

import json
import tqdm
from itertools import chain
from functools import partial
from collections import Counter
from timeit import default_timer as timer
from multiprocessing.dummy import Pool as Threadpool
from multiprocessing import Pool

# %%
def set_default(figsize=(10, 10), dpi=100):
    plt.style.use(['dark_background', 'bmh'])
    plt.rc('axes', facecolor='k')
    plt.rc('figure', facecolor='k')
    plt.rc('figure', figsize=figsize, dpi=dpi)

# %%
set_default()

# %%
project = 'enwiki'
dump_date = "20220420"
dataset_home = '/home/scai/phd/aiz218323/scratch/XML/wikipedia-data-science/'

partition_dir = f"{dataset_home}/partition"

# %% [markdown]
# # helper_code

# %%
def get_filepath(partition_dir, file_type="redirects"):
    paths = []
    info = []
    
    pattern = re.compile(r'^[0-9a-z-]+-[0-9]+-p[0-9]+p[0-9]+_'+file_type+r'.ndjson$')
    
    for file in sorted(os.listdir(partition_dir)):
        if pattern.match(file):
            paths.append(f'{partition_dir}/{file}')
            info.append(os.stat(f'{partition_dir}/{file}').st_size/1e6)
            
    return paths, info

# %%
def show_fileinfo(partition_dir, file_type="redirects", save_file=None, display=True):
    
    paths, info = get_filepath(partition_dir, file_type=file_type)
    
    if display:
        plt.figure(figsize=(15,10))
        plt.bar([os.path.basename(p).split('_')[0]  for p in paths],info, width=0.4)
        plt.setp(plt.gca().get_xticklabels(), rotation=90)

        plt.xlabel("filename")
        plt.ylabel("Size (MB)")
        plt.title("Compressed Wikidump Filesize")

    if save_file:
        plt.savefig(save_file)
    
    print(f"Total size of {file_type} files : {np.sum(info):.2f} MB")
    return paths, info

# %%
def combine_data(paths):
    threadpool = Threadpool(processes= 10)

    data_list = []
    for data in tqdm.notebook.tqdm(threadpool.map(read_data, paths), total=len(paths)):
        data_list.append(data)
        
    combined_data = {}
    for data in data_list:
        combined_data.update(data)

    m = re.search(r'(.*)/([0-9a-z-]+)-[0-9]+-p[0-9]+p[0-9]+_([a-z-]+).ndjson$', paths[0])
    save_file = f'{m.group(1)}/{m.group(2)}_{m.group(3)}.ndjson'
    
    with open(save_file, 'wt') as fout:
        fout.write(json.dumps(combined_data))
    
    print(f"Save data into {save_file}")
    return save_file

# %%
def read_data(filename):
    with open(filename, 'r') as fin:
        data = json.loads(fin.read())
    return data

# %%
def save_data(save_file, data):
    with open(save_file, 'wt') as fout:
        fout.write(json.dumps(data))

# %%
def multi_proc(func, tasks, num_proc=10):
    
    pool = Pool(processes=num_proc)
    results = []
    for x in tqdm.notebook.tqdm( pool.imap(func, tasks), total=len(tasks)):
        results.append(x)
    return results

# %% [markdown]
# # redirects

# %%
redirects_file = f'{partition_dir}/enwiki-20220420_redirects.ndjson'
redirects = read_data(redirects_file)

# %%
for i, (title1, title2) in enumerate(redirects.items()):
    print(f'{i+1}: {title1} - {title2}')
    if i > 4:
        break
# Out:
# 1: accessibleComputing - computer accessibility
# 2: afghanistanHistory - history of Afghanistan
# 3: afghanistanGeography - geography of Afghanistan
# 4: afghanistanPeople - demographics of Afghanistan
# 5: afghanistanCommunications - communications in Afghanistan
# 6: afghanistanTransportations - transport in Afghanistan

# %% [markdown]
# ## Making first character of title case insensitive

# %%
new_redirects = dict()
for title_1, title_2 in redirects.items():
    if title_1 and title_2:
        title_1 = title_1[0].lower()+title_1[1:]
        title_2 = title_2[0].lower()+title_2[1:]
        new_redirects[title_1] = title_2

# %%
for i, (title1, title2) in enumerate(new_redirects.items()):
    print(f'{i+1}: {title1} - {title2}')
    if i > 4:
        break
# Out:
# 1: accessibleComputing - computer accessibility
# 2: afghanistanHistory - history of Afghanistan
# 3: afghanistanGeography - geography of Afghanistan
# 4: afghanistanPeople - demographics of Afghanistan
# 5: afghanistanCommunications - communications in Afghanistan
# 6: afghanistanTransportations - transport in Afghanistan

# %%
save_data(redirects_file, new_redirects)

# %% [markdown]
# # id-to-title, title-to-id

# %%
id_title_file = f'{partition_dir}/enwiki-20220420_id-to-title.ndjson'

id_to_title = read_data(id_title_file)

# %%
len(id_to_title)
# Out:
# 6472830

# %%
for i, (page_id, title) in enumerate(id_to_title.items()):
    print(f'{i+1}: {page_id} {title}')
    if i > 4:
        break
# Out:
# 1: 12 anarchism
# 2: 25 autism
# 3: 39 albedo
# 4: 290 a
# 5: 303 alabama
# 6: 305 achilles

# %% [markdown]
# ## Making first character of title case insensitive

# %%
for page_id, title in id_to_title.items():
    id_to_title[page_id] = title[0].lower() + title[1:]

# %%
for i, (page_id, title) in enumerate(id_to_title.items()):
    print(f'{i+1}: {page_id} {title}')
    if i > 4:
        break
# Out:
# 1: 12 anarchism
# 2: 25 autism
# 3: 39 albedo
# 4: 290 a
# 5: 303 alabama
# 6: 305 achilles

# %%
save_data(id_title_file, id_to_title)

# %% [markdown]
# ## title-to-id

# %%
title_to_id = {title:page_id for page_id, title in id_to_title.items()}

# %%
for i, (title, page_id) in enumerate(title_to_id.items()):
    print(f'{i+1}: {title} {page_id}')
    if i > 4:
        break
# Out:
# 1: anarchism 12
# 2: autism 25
# 3: albedo 39
# 4: a 290
# 5: alabama 303
# 6: achilles 305

# %% [markdown]
# # Graphs

# %% [markdown]
# ## Remove redirect nodes

# %% [markdown]
# ### filenames and sizes

# %%
graph_paths, graph_info = show_fileinfo(partition_dir, file_type="graph")
# Out:
# Total size of graph files : 4484.27 MB

# %% [markdown]
# ### remove

# %%
def replace_redirects(path, redirects):

    graph = read_data(path)
    
    for edges, _ in graph.values():
        for i, edge in enumerate(edges):
            if edge:
                edge = edge[0].lower()+edge[1:]
                if edge in redirects:
                    edges[i] = redirects[edge]
           
    m = re.search(r'(.*)/(.*_graph).ndjson$', path)
    save_file = f"{m.group(1)}/{m.group(2)}_resolved.ndjson"
    
    with open(save_file, 'wt') as fout:
        fout.write(json.dumps(graph))
        
    return None

# %%
start = timer()

pool = Pool(processes=24)
resolve_graph = partial(replace_redirects, redirects=redirects)

result = []
for x in tqdm.notebook.tqdm(pool.imap_unordered(resolve_graph, graph_paths), total=len(graph_paths)):
    result.append(x)

end = timer()
print(f"Processing time {end-start:.3f} seconds.")
# Out:
#   0%|          | 0/62 [00:14<?, ?it/s]
# Processing time 631.781 seconds.

# %% [markdown]
# ## Filenames, sizes

# %%
graph_paths, graph_info = show_fileinfo(partition_dir, file_type="graph_resolved")
# Out:
# Total size of graph_resolved files : 4520.30 MB

# %% [markdown]
# ## Checks if all nodes are present in id-to-title

# %%
def check_node(filename):
    graph = read_data(filename)
    
    absent_nodes = list()
    for node in graph:
        if node not in id_to_title:
            absent_nodes.append(node)
        
    return absent_nodes

# %%
absent_nodes = multi_proc(check_node, graph_paths)
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]

# %%
list(chain(*absent_nodes))
# Out:
# []

# %% [markdown]
# verified that all nodes are present in the map

# %% [markdown]
# ## Edge statistics

# %%
def edge_counts(filename):
    graph = read_data(filename)
    
    edge_cnt = list()
    for edges, counts in graph.values():
        edge_cnt.append(len(edges))
        
    return edge_cnt

# %%
results = multi_proc(edge_counts, graph_paths)
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]

# %%
edge_count = list(chain(*results))

# %%
print(f"Minimum number of edges : {np.min(edge_count)}",
      f"Maximum number of edges : {np.max(edge_count)}",
      f"Mean number of edges : {np.mean(edge_count):.3f}",
      f"Std of number of edges : {np.std(edge_count):.3f}", 
      f"Std of number of edges : {np.sum(edge_count)}", sep='\n')
# Out:
# Minimum number of edges : 1
# Maximum number of edges : 12059
# Mean number of edges : 27.057
# Std of number of edges : 62.843
# Std of number of edges : 175085364

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
c1, r1, _ = plt.hist(edge_count)
plt.xlabel('edges')
plt.ylabel('samples')
plt.title('full range')

plt.subplot(1, 3, 2)
c2, r2, _ = plt.hist(edge_count, range=(0, 2000))
plt.xlabel('edges')
plt.ylabel('samples')
plt.title('range(0, 2000)')

plt.subplot(1, 3, 3)
c3, r3, _ = plt.hist(edge_count, range=(0, 50))
plt.xlabel('edges')
plt.ylabel('samples')
plt.title('range(0, 50)')
# Out:
# Text(0.5, 1.0, 'range(0, 50)')

# %% [markdown]
# ## Remove dead edges

# %%
def replace_dead(path, title_to_id):

    graph = read_data(path)
    
    for page_id, (edges, counts) in graph.items():
        active_edges = list()
        active_counts = list()
        
        while edges:
            e = edges.pop()
            c = counts.pop()
            
            if e:
                e = e[0].lower()+e[1:]
                if e in title_to_id:
                    active_edges.append(e)
                    active_counts.append(c)
            
        graph[page_id] = (active_edges, active_counts)
    
    m = re.search(r'(.*)/(.*_graph_resolved).ndjson$', path)
    save_file = f"{m.group(1)}/{m.group(2)}_active.ndjson"
    
    with open(save_file, 'wt') as fout:
        fout.write(json.dumps(graph))
    
    del graph
    gc.collect()
    
    return None

# %%
remove_dead = partial(replace_dead, title_to_id=title_to_id)
_ = multi_proc(remove_dead, graph_paths)
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]

# %% [markdown]
# ### statistics

# %%
graph_paths, graph_info = show_fileinfo(partition_dir, file_type="graph_resolved_active", display=False)
# Out:
# Total size of graph_resolved_active files : 4197.95 MB

# %%
results = multi_proc(edge_counts, graph_paths)
edge_count = list(chain(*results))
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]

# %%
print(f"Minimum number of edges : {np.min(edge_count)}",
      f"Maximum number of edges : {np.max(edge_count)}",
      f"Mean number of edges : {np.mean(edge_count):.3f}",
      f"Std of number of edges : {np.std(edge_count):.3f}", 
      f"Std of number of edges : {np.sum(edge_count)}", sep='\n')
# Out:
# Minimum number of edges : 0
# Maximum number of edges : 12047
# Mean number of edges : 25.391
# Std of number of edges : 57.348
# Std of number of edges : 164302613

# %%
plt.figure(figsize=(15, 5))
ranges = [None, 2000, 50]

count, rvalue = [], []

for i, b in enumerate(ranges):
    plt.subplot(1, 3, i+1)
    if b:
        c, r, _ = plt.hist(edge_count, range=(0, b))
        plt.title(f'range(0, {b})')
    else:
        c, r, _ = plt.hist(edge_count)
        plt.title('Full range')
    plt.xlabel('edges')
    plt.ylabel('samples')
    count.append(c)
    rvalue.append(r)

# %%
tables = []
for c, r, b in zip(count, rvalue, ranges):
    labels = []
    
    for i in range(len(r)-1):
        l = f'{r[i]:.0f} - {r[i+1]:.0f}'
        labels.append(l)
        
    if b:
        cap = f'range(0,{b})'
    else:
        cap = 'Full range'

    df = pd.DataFrame(c, index=labels, columns=['count'],dtype='int').T
    tables.append(df)
    display(df.style.set_caption(cap))
# Out:
# <style type="text/css">
# </style>
# <table id="T_ecc68">
#   <caption>Full range</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecc68_level0_col0" class="col_heading level0 col0" >0 - 1205</th>
#       <th id="T_ecc68_level0_col1" class="col_heading level0 col1" >1205 - 2409</th>
#       <th id="T_ecc68_level0_col2" class="col_heading level0 col2" >2409 - 3614</th>
#       <th id="T_ecc68_level0_col3" class="col_heading level0 col3" >3614 - 4819</th>
#       <th id="T_ecc68_level0_col4" class="col_heading level0 col4" >4819 - 6024</th>
#       <th id="T_ecc68_level0_col5" class="col_heading level0 col5" >6024 - 7228</th>
#       <th id="T_ecc68_level0_col6" class="col_heading level0 col6" >7228 - 8433</th>
#       <th id="T_ecc68_level0_col7" class="col_heading level0 col7" >8433 - 9638</th>
#       <th id="T_ecc68_level0_col8" class="col_heading level0 col8" >9638 - 10842</th>
#       <th id="T_ecc68_level0_col9" class="col_heading level0 col9" >10842 - 12047</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecc68_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ecc68_row0_col0" class="data row0 col0" >6469354</td>
#       <td id="T_ecc68_row0_col1" class="data row0 col1" >1337</td>
#       <td id="T_ecc68_row0_col2" class="data row0 col2" >185</td>
#       <td id="T_ecc68_row0_col3" class="data row0 col3" >54</td>
#       <td id="T_ecc68_row0_col4" class="data row0 col4" >15</td>
#       <td id="T_ecc68_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_ecc68_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_ecc68_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_ecc68_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_ecc68_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1e42a">
#   <caption>range(0,2000)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e42a_level0_col0" class="col_heading level0 col0" >0 - 200</th>
#       <th id="T_1e42a_level0_col1" class="col_heading level0 col1" >200 - 400</th>
#       <th id="T_1e42a_level0_col2" class="col_heading level0 col2" >400 - 600</th>
#       <th id="T_1e42a_level0_col3" class="col_heading level0 col3" >600 - 800</th>
#       <th id="T_1e42a_level0_col4" class="col_heading level0 col4" >800 - 1000</th>
#       <th id="T_1e42a_level0_col5" class="col_heading level0 col5" >1000 - 1200</th>
#       <th id="T_1e42a_level0_col6" class="col_heading level0 col6" >1200 - 1400</th>
#       <th id="T_1e42a_level0_col7" class="col_heading level0 col7" >1400 - 1600</th>
#       <th id="T_1e42a_level0_col8" class="col_heading level0 col8" >1600 - 1800</th>
#       <th id="T_1e42a_level0_col9" class="col_heading level0 col9" >1800 - 2000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e42a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_1e42a_row0_col0" class="data row0 col0" >6393730</td>
#       <td id="T_1e42a_row0_col1" class="data row0 col1" >58104</td>
#       <td id="T_1e42a_row0_col2" class="data row0 col2" >10859</td>
#       <td id="T_1e42a_row0_col3" class="data row0 col3" >3916</td>
#       <td id="T_1e42a_row0_col4" class="data row0 col4" >1780</td>
#       <td id="T_1e42a_row0_col5" class="data row0 col5" >946</td>
#       <td id="T_1e42a_row0_col6" class="data row0 col6" >529</td>
#       <td id="T_1e42a_row0_col7" class="data row0 col7" >313</td>
#       <td id="T_1e42a_row0_col8" class="data row0 col8" >221</td>
#       <td id="T_1e42a_row0_col9" class="data row0 col9" >147</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_dec69">
#   <caption>range(0,50)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dec69_level0_col0" class="col_heading level0 col0" >0 - 5</th>
#       <th id="T_dec69_level0_col1" class="col_heading level0 col1" >5 - 10</th>
#       <th id="T_dec69_level0_col2" class="col_heading level0 col2" >10 - 15</th>
#       <th id="T_dec69_level0_col3" class="col_heading level0 col3" >15 - 20</th>
#       <th id="T_dec69_level0_col4" class="col_heading level0 col4" >20 - 25</th>
#       <th id="T_dec69_level0_col5" class="col_heading level0 col5" >25 - 30</th>
#       <th id="T_dec69_level0_col6" class="col_heading level0 col6" >30 - 35</th>
#       <th id="T_dec69_level0_col7" class="col_heading level0 col7" >35 - 40</th>
#       <th id="T_dec69_level0_col8" class="col_heading level0 col8" >40 - 45</th>
#       <th id="T_dec69_level0_col9" class="col_heading level0 col9" >45 - 50</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dec69_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_dec69_row0_col0" class="data row0 col0" >1197395</td>
#       <td id="T_dec69_row0_col1" class="data row0 col1" >1542141</td>
#       <td id="T_dec69_row0_col2" class="data row0 col2" >932745</td>
#       <td id="T_dec69_row0_col3" class="data row0 col3" >638945</td>
#       <td id="T_dec69_row0_col4" class="data row0 col4" >449843</td>
#       <td id="T_dec69_row0_col5" class="data row0 col5" >322969</td>
#       <td id="T_dec69_row0_col6" class="data row0 col6" >237414</td>
#       <td id="T_dec69_row0_col7" class="data row0 col7" >180604</td>
#       <td id="T_dec69_row0_col8" class="data row0 col8" >139999</td>
#       <td id="T_dec69_row0_col9" class="data row0 col9" >130763</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## in_graph

# %%
graph_paths, graph_info = show_fileinfo(partition_dir, file_type="graph_resolved_active", display=False)
# Out:
# Total size of graph_resolved_active files : 4197.95 MB

# %%
def create_ingraph(path, title_to_id):
    graph = read_data(path)
    
    in_graph = dict()
    for p_id, (es, cs) in graph.items():
        for e, c in zip(es, cs):
            page_id = title_to_id[e]
            edge_count = in_graph.setdefault(page_id, {})
            edge_count[p_id] = edge_count.get(p_id, 0) + c
    
    m = re.search(r'(.*)/(.*)_graph_resolved_active.ndjson$', path)
    save_file = f"{m.group(1)}/{m.group(2)}_ingraph_resolved_active.ndjson"
    
    with open(save_file, 'wt') as fout:
        fout.write(json.dumps(in_graph))
    
    del in_graph
    del graph
    gc.collect()
    
    return None

# %%
generate_ingraph = partial(create_ingraph, title_to_id=title_to_id)
_ = multi_proc(generate_ingraph, graph_paths)
# Out:
#   0%|          | 0/62 [00:07<?, ?it/s]

# %%
graph_paths, graph_info = show_fileinfo(partition_dir, file_type="ingraph_resolved_active", display=False)
# Out:
# Total size of ingraph_resolved_active files : 3018.33 MB

# %% [markdown]
# ### Combine in_graph

# %%
def combine_ingraph(paths):
    threadpool = Threadpool(processes= 10)
    
    in_graph = {}
    for graph in tqdm.notebook.tqdm(threadpool.map(read_data, paths), total=len(paths)):
        for page_id, ec in graph.items():
            edge_count = in_graph.setdefault(page_id, Counter())
            edge_count.update(ec)
    return in_graph

# %%
in_graph = combine_ingraph(graph_paths)
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]

# %%
save_file = f'{partition_dir}/enwiki-20220420_ingraph_resolved_active.ndjson'
save_data(save_file, in_graph)

# %%
for i, (page_id, edge_count) in enumerate(in_graph.items()):
    print(f'{page_id} : {list(edge_count.keys())[:4]}')
    if i > 4:
        break
# Out:
# 1582235 : ['12', '9567', '14936', '15181']
# 40949353 : ['12', '5574', '7843', '7959']
# 40678598 : ['12', '15181', '17865', '18048']
# 1456771 : ['12', '738', '5588', '7485']
# 28831284 : ['12', '3986', '4721', '4822']
# 43134145 : ['12', '1193', '7175', '12720']

# %%
node_edge_count = []
for i, (page_id, edge_count) in enumerate(in_graph.items()):
    node_edge_count.append(len(edge_count))

# %%
print(f"Minimum number of edges : {np.min(node_edge_count)}",
      f"Maximum number of edges : {np.max(node_edge_count)}",
      f"Mean number of edges : {np.mean(node_edge_count):.3f}",
      f"Std of number of edges : {np.std(node_edge_count):.3f}", 
      f"Std of number of edges : {np.sum(node_edge_count)}", sep='\n')
# Out:
# Minimum number of edges : 1
# Maximum number of edges : 234153
# Mean number of edges : 27.602
# Std of number of edges : 338.012
# Std of number of edges : 160185775

# %%
plt.figure(figsize=(15, 5))
ranges = [None, 2000, 50]

count, rvalue = [], []

for i, b in enumerate(ranges):
    plt.subplot(1, 3, i+1)
    if b:
        c, r, _ = plt.hist(node_edge_count, range=(0, b))
        plt.title(f'range(0, {b})')
    else:
        c, r, _ = plt.hist(node_edge_count)
        plt.title('Full range')
    plt.xlabel('edges')
    plt.ylabel('samples')
    count.append(c)
    rvalue.append(r)

# %%
tables = []
for c, r, b in zip(count, rvalue, ranges):
    labels = []
    
    for i in range(len(r)-1):
        l = f'{r[i]:.0f} - {r[i+1]:.0f}'
        labels.append(l)
        
    if b:
        cap = f'range(0,{b})'
    else:
        cap = 'Full range'

    df = pd.DataFrame(c, index=labels, columns=['count'],dtype='int').T
    tables.append(df)
    display(df.style.set_caption(cap))
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6deb">
#   <caption>Full range</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6deb_level0_col0" class="col_heading level0 col0" >1 - 23416</th>
#       <th id="T_e6deb_level0_col1" class="col_heading level0 col1" >23416 - 46831</th>
#       <th id="T_e6deb_level0_col2" class="col_heading level0 col2" >46831 - 70247</th>
#       <th id="T_e6deb_level0_col3" class="col_heading level0 col3" >70247 - 93662</th>
#       <th id="T_e6deb_level0_col4" class="col_heading level0 col4" >93662 - 117077</th>
#       <th id="T_e6deb_level0_col5" class="col_heading level0 col5" >117077 - 140492</th>
#       <th id="T_e6deb_level0_col6" class="col_heading level0 col6" >140492 - 163907</th>
#       <th id="T_e6deb_level0_col7" class="col_heading level0 col7" >163907 - 187323</th>
#       <th id="T_e6deb_level0_col8" class="col_heading level0 col8" >187323 - 210738</th>
#       <th id="T_e6deb_level0_col9" class="col_heading level0 col9" >210738 - 234153</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6deb_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e6deb_row0_col0" class="data row0 col0" >5803345</td>
#       <td id="T_e6deb_row0_col1" class="data row0 col1" >121</td>
#       <td id="T_e6deb_row0_col2" class="data row0 col2" >17</td>
#       <td id="T_e6deb_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_e6deb_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_e6deb_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e6deb_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_e6deb_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_e6deb_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_e6deb_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f3b9b">
#   <caption>range(0,2000)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3b9b_level0_col0" class="col_heading level0 col0" >0 - 200</th>
#       <th id="T_f3b9b_level0_col1" class="col_heading level0 col1" >200 - 400</th>
#       <th id="T_f3b9b_level0_col2" class="col_heading level0 col2" >400 - 600</th>
#       <th id="T_f3b9b_level0_col3" class="col_heading level0 col3" >600 - 800</th>
#       <th id="T_f3b9b_level0_col4" class="col_heading level0 col4" >800 - 1000</th>
#       <th id="T_f3b9b_level0_col5" class="col_heading level0 col5" >1000 - 1200</th>
#       <th id="T_f3b9b_level0_col6" class="col_heading level0 col6" >1200 - 1400</th>
#       <th id="T_f3b9b_level0_col7" class="col_heading level0 col7" >1400 - 1600</th>
#       <th id="T_f3b9b_level0_col8" class="col_heading level0 col8" >1600 - 1800</th>
#       <th id="T_f3b9b_level0_col9" class="col_heading level0 col9" >1800 - 2000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3b9b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_f3b9b_row0_col0" class="data row0 col0" >5701300</td>
#       <td id="T_f3b9b_row0_col1" class="data row0 col1" >56550</td>
#       <td id="T_f3b9b_row0_col2" class="data row0 col2" >17930</td>
#       <td id="T_f3b9b_row0_col3" class="data row0 col3" >8220</td>
#       <td id="T_f3b9b_row0_col4" class="data row0 col4" >4844</td>
#       <td id="T_f3b9b_row0_col5" class="data row0 col5" >2959</td>
#       <td id="T_f3b9b_row0_col6" class="data row0 col6" >2165</td>
#       <td id="T_f3b9b_row0_col7" class="data row0 col7" >1451</td>
#       <td id="T_f3b9b_row0_col8" class="data row0 col8" >1142</td>
#       <td id="T_f3b9b_row0_col9" class="data row0 col9" >907</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_070dc">
#   <caption>range(0,50)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_070dc_level0_col0" class="col_heading level0 col0" >0 - 5</th>
#       <th id="T_070dc_level0_col1" class="col_heading level0 col1" >5 - 10</th>
#       <th id="T_070dc_level0_col2" class="col_heading level0 col2" >10 - 15</th>
#       <th id="T_070dc_level0_col3" class="col_heading level0 col3" >15 - 20</th>
#       <th id="T_070dc_level0_col4" class="col_heading level0 col4" >20 - 25</th>
#       <th id="T_070dc_level0_col5" class="col_heading level0 col5" >25 - 30</th>
#       <th id="T_070dc_level0_col6" class="col_heading level0 col6" >30 - 35</th>
#       <th id="T_070dc_level0_col7" class="col_heading level0 col7" >35 - 40</th>
#       <th id="T_070dc_level0_col8" class="col_heading level0 col8" >40 - 45</th>
#       <th id="T_070dc_level0_col9" class="col_heading level0 col9" >45 - 50</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_070dc_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_070dc_row0_col0" class="data row0 col0" >2480785</td>
#       <td id="T_070dc_row0_col1" class="data row0 col1" >1229156</td>
#       <td id="T_070dc_row0_col2" class="data row0 col2" >592849</td>
#       <td id="T_070dc_row0_col3" class="data row0 col3" >344532</td>
#       <td id="T_070dc_row0_col4" class="data row0 col4" >221175</td>
#       <td id="T_070dc_row0_col5" class="data row0 col5" >154051</td>
#       <td id="T_070dc_row0_col6" class="data row0 col6" >112038</td>
#       <td id="T_070dc_row0_col7" class="data row0 col7" >85596</td>
#       <td id="T_070dc_row0_col8" class="data row0 col8" >66825</td>
#       <td id="T_070dc_row0_col9" class="data row0 col9" >62823</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # See also

# %% [markdown]
# ## filesize

# %%
seealso_paths, seealso_info = show_fileinfo(partition_dir, file_type="seealso")
# Out:
# Total size of seealso files : 113.17 MB

# %% [markdown]
# ## Combine seealso

# %%
seealso_file = combine_data(seealso_paths)
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]
# Save data into /home/scai/phd/aiz218323/scratch/XML/wikipedia-data-science//partition/enwiki-20220420_seealso.ndjson

# %%
seealso = read_data(seealso_file)

# %%
for i, (page_id, (edges, counts)) in enumerate(seealso.items()):
    print(f"{i+1}. {page_id} : {edges[:5]}")
    if i > 5:
        break
# Out:
# 1. 39 : ['Cool roof', 'Daisyworld', 'Emissivity', 'Exitance', 'Global dimming']
# 2. 303 : ['Index of Alabama-related articles', 'Outline of Alabama']
# 3. 307 : ['Grace Bedell', 'Lincoln (film)', 'Linconia', 'List of civil rights leaders', 'List of photographs of Abraham Lincoln']
# 4. 316 : ['BAFTA Award for Best Production Design', "Critics' Choice Movie Award for Best Production Design"]
# 5. 324 : ['List of Academy Award records', 'List of actors with Academy Award nominations', 'List of film awards', 'List of superlative Academy Award winners and nominees']
# 6. 334 : ['Clock synchronization', 'Time and frequency transfer']
# 7. 336 : ['Altruria, California', 'Charitable organization', 'Comedy of the commons', 'Consideration', 'Egotism']

# %%
print(f"Number of nodes : {len(seealso)}")
# Out:
# Number of nodes : 1119539

# %%
node_edge_count = []
for page_id, (edges, count) in seealso.items():
    node_edge_count.append(len(edges))
    
print(f"Minimum number of edges : {np.min(node_edge_count)}",
      f"Maximum number of edges : {np.max(node_edge_count)}",
      f"Mean number of edges : {np.mean(node_edge_count):.3f}",
      f"Std of number of edges : {np.std(node_edge_count):.3f}", 
      f"Std of number of edges : {np.sum(node_edge_count)}", sep='\n')
# Out:
# Minimum number of edges : 1
# Maximum number of edges : 462
# Mean number of edges : 2.528
# Std of number of edges : 2.877
# Std of number of edges : 2830248

# %%
plt.figure(figsize=(15, 5))
ranges = [None, 50, 10]

count, rvalue = [], []

for i, b in enumerate(ranges):
    plt.subplot(1, 3, i+1)
    if b:
        c, r, _ = plt.hist(node_edge_count, range=(0, b))
        plt.title(f'range(0, {b})')
    else:
        c, r, _ = plt.hist(node_edge_count)
        plt.title('Full range')
    plt.xlabel('edges')
    plt.ylabel('samples')
    count.append(c)
    rvalue.append(r)

# %%
tables = []
for c, r, b in zip(count, rvalue, ranges):
    labels = []
    
    for i in range(len(r)-1):
        l = f'{r[i]:.0f} - {r[i+1]:.0f}'
        labels.append(l)
        
    if b:
        cap = f'range(0,{b})'
    else:
        cap = 'Full range'

    df = pd.DataFrame(c, index=labels, columns=['count'],dtype='int').T
    tables.append(df)
    display(df.style.set_caption(cap))
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8b5b">
#   <caption>Full range</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8b5b_level0_col0" class="col_heading level0 col0" >1 - 47</th>
#       <th id="T_a8b5b_level0_col1" class="col_heading level0 col1" >47 - 93</th>
#       <th id="T_a8b5b_level0_col2" class="col_heading level0 col2" >93 - 139</th>
#       <th id="T_a8b5b_level0_col3" class="col_heading level0 col3" >139 - 185</th>
#       <th id="T_a8b5b_level0_col4" class="col_heading level0 col4" >185 - 232</th>
#       <th id="T_a8b5b_level0_col5" class="col_heading level0 col5" >232 - 278</th>
#       <th id="T_a8b5b_level0_col6" class="col_heading level0 col6" >278 - 324</th>
#       <th id="T_a8b5b_level0_col7" class="col_heading level0 col7" >324 - 370</th>
#       <th id="T_a8b5b_level0_col8" class="col_heading level0 col8" >370 - 416</th>
#       <th id="T_a8b5b_level0_col9" class="col_heading level0 col9" >416 - 462</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8b5b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_a8b5b_row0_col0" class="data row0 col0" >1119371</td>
#       <td id="T_a8b5b_row0_col1" class="data row0 col1" >145</td>
#       <td id="T_a8b5b_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_a8b5b_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_a8b5b_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_a8b5b_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a8b5b_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_a8b5b_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_a8b5b_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_a8b5b_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1b841">
#   <caption>range(0,50)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b841_level0_col0" class="col_heading level0 col0" >0 - 5</th>
#       <th id="T_1b841_level0_col1" class="col_heading level0 col1" >5 - 10</th>
#       <th id="T_1b841_level0_col2" class="col_heading level0 col2" >10 - 15</th>
#       <th id="T_1b841_level0_col3" class="col_heading level0 col3" >15 - 20</th>
#       <th id="T_1b841_level0_col4" class="col_heading level0 col4" >20 - 25</th>
#       <th id="T_1b841_level0_col5" class="col_heading level0 col5" >25 - 30</th>
#       <th id="T_1b841_level0_col6" class="col_heading level0 col6" >30 - 35</th>
#       <th id="T_1b841_level0_col7" class="col_heading level0 col7" >35 - 40</th>
#       <th id="T_1b841_level0_col8" class="col_heading level0 col8" >40 - 45</th>
#       <th id="T_1b841_level0_col9" class="col_heading level0 col9" >45 - 50</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b841_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_1b841_row0_col0" class="data row0 col0" >977036</td>
#       <td id="T_1b841_row0_col1" class="data row0 col1" >113936</td>
#       <td id="T_1b841_row0_col2" class="data row0 col2" >19190</td>
#       <td id="T_1b841_row0_col3" class="data row0 col3" >5424</td>
#       <td id="T_1b841_row0_col4" class="data row0 col4" >1980</td>
#       <td id="T_1b841_row0_col5" class="data row0 col5" >927</td>
#       <td id="T_1b841_row0_col6" class="data row0 col6" >369</td>
#       <td id="T_1b841_row0_col7" class="data row0 col7" >238</td>
#       <td id="T_1b841_row0_col8" class="data row0 col8" >102</td>
#       <td id="T_1b841_row0_col9" class="data row0 col9" >205</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f89e4">
#   <caption>range(0,10)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f89e4_level0_col0" class="col_heading level0 col0" >0 - 1</th>
#       <th id="T_f89e4_level0_col1" class="col_heading level0 col1" >1 - 2</th>
#       <th id="T_f89e4_level0_col2" class="col_heading level0 col2" >2 - 3</th>
#       <th id="T_f89e4_level0_col3" class="col_heading level0 col3" >3 - 4</th>
#       <th id="T_f89e4_level0_col4" class="col_heading level0 col4" >4 - 5</th>
#       <th id="T_f89e4_level0_col5" class="col_heading level0 col5" >5 - 6</th>
#       <th id="T_f89e4_level0_col6" class="col_heading level0 col6" >6 - 7</th>
#       <th id="T_f89e4_level0_col7" class="col_heading level0 col7" >7 - 8</th>
#       <th id="T_f89e4_level0_col8" class="col_heading level0 col8" >8 - 9</th>
#       <th id="T_f89e4_level0_col9" class="col_heading level0 col9" >9 - 10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f89e4_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_f89e4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f89e4_row0_col1" class="data row0 col1" >529544</td>
#       <td id="T_f89e4_row0_col2" class="data row0 col2" >245880</td>
#       <td id="T_f89e4_row0_col3" class="data row0 col3" >127710</td>
#       <td id="T_f89e4_row0_col4" class="data row0 col4" >73902</td>
#       <td id="T_f89e4_row0_col5" class="data row0 col5" >45337</td>
#       <td id="T_f89e4_row0_col6" class="data row0 col6" >28577</td>
#       <td id="T_f89e4_row0_col7" class="data row0 col7" >18631</td>
#       <td id="T_f89e4_row0_col8" class="data row0 col8" >12708</td>
#       <td id="T_f89e4_row0_col9" class="data row0 col9" >14867</td>
#     </tr>
#   </tbody>
# </table>
